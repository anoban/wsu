# %%
import pandas as pd
import numpy as np
from apni import parse_apni_name_list
import re

# %%
apni = pd.read_csv(r"./data/APNI-names-2025-05-06-3043.csv", low_memory=False)
austraits = pd.read_csv(r"./data/austraits-3.0.2/taxa.csv", low_memory=False)

# %%
apni.columns
# Out:
# Index(['scientificNameID', 'nameType', 'scientificName', 'scientificNameHTML',
#        'canonicalName', 'canonicalNameHTML', 'nameElement',
#        'nomenclaturalStatus', 'scientificNameAuthorship', 'autonym', 'hybrid',
#        'cultivar', 'formula', 'scientific', 'nomInval', 'nomIlleg',
#        'namePublishedIn', 'namePublishedInID', 'namePublishedInYear',
#        'nameInstanceType', 'nameAccordingToID', 'nameAccordingTo',
#        'originalNameUsage', 'originalNameUsageID', 'originalNameUsageYear',
#        'typeCitation', 'kingdom', 'family', 'genericName', 'specificEpithet',
#        'infraspecificEpithet', 'cultivarEpithet', 'taxonRank',
#        'taxonRankSortOrder', 'taxonRankAbbreviation', 'firstHybridParentName',
#        'firstHybridParentNameID', 'secondHybridParentName',
#        'secondHybridParentNameID', 'created', 'modified', 'nomenclaturalCode',
#        'datasetName', 'taxonomicStatus', 'statusAccordingTo', 'license',
#        'ccAttributionIRI'],
#       dtype='object')

# %%
apni_tidied = apni.loc[:, ["family", "genericName", "specificEpithet"]].dropna().reset_index(drop=True)

# %%
apni_tidied
# Out:
#              family genericName specificEpithet
# 0       Acanthaceae    Acanthus     ebracteatus
# 1       Acanthaceae    Acanthus     ebracteatus
# 2       Acanthaceae    Acanthus     ebracteatus
# 3       Acanthaceae    Acanthus     ilicifolius
# 4       Acanthaceae    Acanthus     ilicifolius
# ...             ...         ...             ...
# 113678   Cyperaceae    Mariscus      laevigatus
# 113679      Poaceae  Oplismenus  undulatifolius
# 113680      Poaceae  Pennisetum        spicatum
# 113681      Poaceae  Hierochloe        borealis
# 113682      Poaceae   Agropyrum         pungens
#
# [113683 rows x 3 columns]

# %%
apni_tidied.query("genericName=='Heliotropium'")
# Out:
#              family   genericName specificEpithet
# 14906  Boraginaceae  Heliotropium      aenigmatum
# 14907  Boraginaceae  Heliotropium       aequoreum
# 14908  Boraginaceae  Heliotropium      albrechtii
# 14909  Boraginaceae  Heliotropium       alcyonium
# 14910  Boraginaceae  Heliotropium      ammophilum
# ...             ...           ...             ...
# 15138  Boraginaceae  Heliotropium           vagum
# 15139  Boraginaceae  Heliotropium     ventricosum
# 15140  Boraginaceae  Heliotropium        vestitum
# 15141  Boraginaceae  Heliotropium          viator
# 15142  Boraginaceae  Heliotropium      zeylanicum
#
# [235 rows x 3 columns]

# %%
austraits_tidied = austraits.loc[:, ["taxon_name", "family", "genus", "taxonDistribution"]].dropna().\
        reset_index(drop=True)

# %%
austraits_tidied
# Out:
#                                               taxon_name          family  \
# 0                                            Abelmoschus       Malvaceae
# 1                                  Abelmoschus ficulneus       Malvaceae
# 2                                    Abelmoschus manihot       Malvaceae
# 3                                  Abelmoschus moschatus       Malvaceae
# 4                                     Abildgaardia ovata      Cyperaceae
# ...                                                  ...             ...
# 25823                    Zoysia macrantha subsp. walshii         Poaceae
# 25824                                    Zoysia matrella         Poaceae
# 25825                                  Zuloagaea bulbosa         Poaceae
# 25826                                 Zygochloa paradoxa         Poaceae
# 25827  Zygophyllum sp. Simpson Desert NP (R.G.Atherto...  Zygophyllaceae
#
#               genus                                  taxonDistribution
# 0       Abelmoschus  WA, ChI, NT, Qld (native and naturalised), NSW...
# 1       Abelmoschus                                        WA, NT, Qld
# 2       Abelmoschus  ChI, NT, Qld (naturalised), NSW (doubtfully na...
# 3       Abelmoschus                     WA, NT, Qld, NSW (naturalised)
# 4      Abildgaardia                                       NT, Qld, NSW
# ...             ...                                                ...
# 25823        Zoysia                                       SA, Vic, Tas
# 25824        Zoysia     CoI, ChI (naturalised), Qld, NSW (naturalised)
# 25825     Zuloagaea                                  NSW (naturalised)
# 25826     Zygochloa                                   NT, SA, Qld, NSW
# 25827   Zygophyllum                                                Qld
#
# [25828 rows x 4 columns]

# %%
with pd.option_context("display.max_rows", None, "display.max_columns", None):
    print(
        austraits_tidied.loc[austraits_tidied.taxon_name.str.contains("Heliotropium"),
        ["taxon_name", "taxonDistribution"]]
    )
# Out:
#                                            taxon_name  \
# 13126                                    Heliotropium
# 13127                         Heliotropium aenigmatum
# 13128                          Heliotropium aequoreum
# 13129                         Heliotropium albrechtii
# 13130                          Heliotropium alcyonium
# 13131                         Heliotropium ammophilum
# 13132                        Heliotropium amnis-edith
# 13133                       Heliotropium amplexicaule
# 13134                            Heliotropium apertum
# 13135                         Heliotropium arenitense
# 13136                           Heliotropium argyreum
# 13137                         Heliotropium asperrimum
# 13138                             Heliotropium ballii
# 13139                         Heliotropium brachygyne
# 13140                        Heliotropium brachythrix
# 13141                         Heliotropium bracteatum
# 13142                        Heliotropium calvariavis
# 13143                       Heliotropium chalcedonium
# 13144                       Heliotropium chrysocarpum
# 13145                           Heliotropium collinum
# 13146                         Heliotropium conocarpum
# 13147                          Heliotropium consimile
# 13148                            Heliotropium cracens
# 13149                          Heliotropium crispatum
# 13150                       Heliotropium cunninghamii
# 13151                        Heliotropium cupressinum
# 13152                       Heliotropium curassavicum
# 13153                        Heliotropium delestangii
# 13154                         Heliotropium dichotomum
# 13155                           Heliotropium discorde
# 13156                      Heliotropium diversifolium
# 13157                         Heliotropium epacrideum
# 13158                             Heliotropium euodes
# 13159                          Heliotropium europaeum
# 13160                       Heliotropium fasciculatum
# 13161                       Heliotropium filaginoides
# 13162                            Heliotropium flintii
# 13163                           Heliotropium foliatum
# 13164                         Heliotropium foveolatum
# 13165                         Heliotropium frohlichii
# 13166                          Heliotropium galioides
# 13167                          Heliotropium geocharis
# 13168                          Heliotropium glabellum
# 13169                      Heliotropium glanduliferum
# 13170                             Heliotropium haesum
# 13171                        Heliotropium heteranthum
# 13172                            Heliotropium indicum
# 13173                       Heliotropium inexplicitum
# 13174                         Heliotropium lapidicola
# 13175                          Heliotropium leptaleum
# 13176                        Heliotropium melanopedii
# 13177                   Heliotropium microsalsoloides
# 13178                       Heliotropium microspermum
# 13179                         Heliotropium mitchellii
# 13180                             Heliotropium moorei
# 13181                           Heliotropium muelleri
# 13182                            Heliotropium murinum
# 13183                            Heliotropium muticum
# 13184                        Heliotropium nesopelydum
# 13185                            Heliotropium nexosum
# 13186                        Heliotropium ovalifolium
# 13187                       Heliotropium pachyphyllum
# 13188                        Heliotropium paniculatum
# 13189                        Heliotropium parviantrum
# 13190                        Heliotropium pauciflorum
# 13191                          Heliotropium peckhamii
# 13192                        Heliotropium peninsulare
# 13193                        Heliotropium pleiopterum
# 13194                           Heliotropium plumosum
# 13195                         Heliotropium prostratum
# 13196                          Heliotropium protensum
# 13197                           Heliotropium pulvinum
# 13198                       Heliotropium ramulipatens
# 13199                    Heliotropium rhadinostachyum
# 13200                        Heliotropium sarmentosum
# 13201                           Heliotropium skeleton
# 13202  Heliotropium sp. Ord River (W.Fitzgerald 1611)
# 13203                         Heliotropium sphaericum
# 13204                        Heliotropium styotrichum
# 13205                       Heliotropium subreniforme
# 13206                            Heliotropium supinum
# 13207                           Heliotropium synaimon
# 13208                       Heliotropium tabuliplagae
# 13209                    Heliotropium tachyglossoides
# 13210                          Heliotropium tanythrix
# 13211                        Heliotropium tenuifolium
# 13212                         Heliotropium transforme
# 13213                           Heliotropium tytoides
# 13214                          Heliotropium uniflorum
# 13215                              Heliotropium vagum
# 13216                        Heliotropium ventricosum
# 13217                           Heliotropium vestitum
# 13218                             Heliotropium viator
#
#                                        taxonDistribution
# 13126  WA (native and naturalised), CoI, ChI, AR, NT ...
# 13127                                                 WA
# 13128                                                Qld
# 13129                                                 NT
# 13130                                             WA, NT
# 13131                                    WA, NT, SA, Qld
# 13132                                                 NT
# 13133  SA (naturalised), Qld (naturalised), NSW (natu...
# 13134                                                 WA
# 13135                                                 NT
# 13136                                                 WA
# 13137                               WA, NT, SA, NSW, Vic
# 13138                                            NT, Qld
# 13139                                           Qld, NSW
# 13140                                             WA, NT
# 13141                                                 NT
# 13142                                                 WA
# 13143                                            WA, Qld
# 13144                                             WA, NT
# 13145                                                Qld
# 13146                                        WA, NT, Qld
# 13147                                            NT, Qld
# 13148                                                 NT
# 13149                                                 WA
# 13150                                    WA, NT, SA, Qld
# 13151                                             WA, NT
# 13152                          WA, NT, SA, Qld, NSW, Vic
# 13153                                                Qld
# 13154                                             WA, NT
# 13155                                             WA, NT
# 13156                                             WA, NT
# 13157                                             WA, NT
# 13158                                             WA, NT
# 13159           Qld, WA, SA, NSW, ACT (naturalised), Vic
# 13160                                            NT, Qld
# 13161                                        NT, SA, Qld
# 13162                                        WA, NT, Qld
# 13163                                        WA, NT, Qld
# 13164                                             WA, NT
# 13165                                                Qld
# 13166                                                 WA
# 13167                                        WA, NT, Qld
# 13168                                    WA, NT, SA, Qld
# 13169                                             WA, NT
# 13170                                        WA, NT, Qld
# 13171                                                 WA
# 13172  WA (naturalised), ChI (naturalised), NT (natur...
# 13173                                         WA, NT, SA
# 13174                                                Qld
# 13175                                        WA, NT, Qld
# 13176                                                Qld
# 13177                                                 WA
# 13178                                                Qld
# 13179                                                 WA
# 13180                               WA, NT, SA, Qld, NSW
# 13181                                                Qld
# 13182                                                 WA
# 13183                                                 WA
# 13184                                                 WA
# 13185                                                 WA
# 13186                                        WA, NT, Qld
# 13187                                         WA, NT, SA
# 13188                                        WA, NT, Qld
# 13189                                             WA, NT
# 13190                                                Qld
# 13191                                                 WA
# 13192                                                Qld
# 13193                                         WA, NT, SA
# 13194                                            NT, Qld
# 13195                                            NT, Qld
# 13196                                                 WA
# 13197                                                 NT
# 13198                                        WA, NT, Qld
# 13199                                            NT, Qld
# 13200                                                Qld
# 13201                                             WA, NT
# 13202                                                 WA
# 13203                                             WA, NT
# 13204                                                Qld
# 13205                                                 NT
# 13206  WA (naturalised), NT (naturalised), SA (natura...
# 13207                                             WA, NT
# 13208                                                Qld
# 13209                                             WA, NT
# 13210                                    WA, NT, SA, Qld
# 13211                                        WA, NT, Qld
# 13212                                             WA, NT
# 13213                                                Qld
# 13214                                             WA, NT
# 13215                                                Qld
# 13216                                             WA, NT
# 13217                                                 WA
# 13218                                                 WA

# %%
austraits_tidied.loc[austraits_tidied.taxon_name.str.contains("Heliotropium") & 
                        austraits_tidied.taxonDistribution.str.contains("NSW"),
                            ["taxon_name", "taxonDistribution"]]
# Out:
#                       taxon_name  \
# 13126               Heliotropium
# 13133  Heliotropium amplexicaule
# 13137    Heliotropium asperrimum
# 13139    Heliotropium brachygyne
# 13152  Heliotropium curassavicum
# 13159     Heliotropium europaeum
# 13180        Heliotropium moorei
# 13206       Heliotropium supinum
#
#                                        taxonDistribution
# 13126  WA (native and naturalised), CoI, ChI, AR, NT ...
# 13133  SA (naturalised), Qld (naturalised), NSW (natu...
# 13137                               WA, NT, SA, NSW, Vic
# 13139                                           Qld, NSW
# 13152                          WA, NT, SA, Qld, NSW, Vic
# 13159           Qld, WA, SA, NSW, ACT (naturalised), Vic
# 13180                               WA, NT, SA, Qld, NSW
# 13206  WA (naturalised), NT (naturalised), SA (natura...

# %%
apni_species_list = parse_apni_name_list(r"./Australian Plant Name Index (APNI).html")

# %%
HORDEUM_SPP = re.compile(pattern=r"Hordeum [\w\. \(\)]*", flags=re.IGNORECASE)

# all Hordeum species in APNI
[re.match(pattern=HORDEUM_SPP, string=_).group() for _ in apni_species_list if \
     re.match(pattern=HORDEUM_SPP, string=_)]
# Out:
# ['Hordeum distichon L.',
#  'Hordeum geniculatum All.',
#  'Hordeum glaucum Steud.',
#  'Hordeum hystrix Roth',
#  'Hordeum L.',
#  'Hordeum leporinum Link',
#  'Hordeum marinum Huds.',
#  'Hordeum maritimum Stokes',
#  'Hordeum murinum L.',
#  'Hordeum nodosum L.',
#  'Hordeum secalinum Schreb.',
#  'Hordeum vulgare L.',
#  'Hordeum vulgare subsp. distichon (L.) Korn.',
#  'Hordeum vulgare var. distichon (L.) Hook.f.',
#  'Hordeum vulgare var. hexastichum (L.) Asch.']

# %%
# COOL :)
apni_species_list[pd.Series(apni_species_list).str.contains("Hordeum")]#.unique()
# Out:
# array(['Hordeum distichon L.', 'Hordeum geniculatum All.',
#        'Hordeum glaucum Steud.', 'Hordeum hystrix Roth', 'Hordeum L.',
#        'Hordeum leporinum Link', 'Hordeum marinum Huds.',
#        'Hordeum maritimum Stokes', 'Hordeum murinum L.',
#        'Hordeum nodosum L.', 'Hordeum secalinum Schreb.',
#        'Hordeum vulgare L.',
#        'Hordeum vulgare subsp. distichon (L.) Korn.',
#        'Hordeum vulgare var. distichon (L.) Hook.f.',
#        'Hordeum vulgare var. hexastichum (L.) Asch.'], dtype='<U97')

# %%
austraits
# Out:
#                                               taxon_name source  \
# 0                ?Eucalyptus sp. Truslove (Brooker 7499)    NaN
# 1                 [Corymbia x candida subsp. lautifolia]    NaN
# 2                                [Corymbia x nowraensis]    NaN
# 3                                  [Corymbia x paractia]    NaN
# 4                                 [Corymbia x semiclara]    NaN
# ...                                                  ...    ...
# 28635                                  Zuloagaea bulbosa    APC
# 28636                                 Zygochloa paradoxa    APC
# 28637                                 Zygophyllaceae sp.    NaN
# 28638                                    Zygophyllum sp.    NaN
# 28639  Zygophyllum sp. Simpson Desert NP (R.G.Atherto...    APC
#
#                                     acceptedNameUsageID  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 28635  https://id.biodiversity.org.au/node/apni/2892759
# 28636  https://id.biodiversity.org.au/node/apni/2910190
# 28637                                               NaN
# 28638                                               NaN
# 28639  https://id.biodiversity.org.au/node/apni/2890972
#
#       scientificNameAuthorship taxonRank taxonomicStatus          family  \
# 0                          NaN       NaN         unknown             NaN
# 1                          NaN       NaN         unknown             NaN
# 2                          NaN       NaN         unknown             NaN
# 3                          NaN       NaN         unknown             NaN
# 4                          NaN       NaN         unknown             NaN
# ...                        ...       ...             ...             ...
# 28635             (Kunth) Bess   Species        accepted         Poaceae
# 28636        (R.Br.) S.T.Blake   Species        accepted         Poaceae
# 28637                      NaN       NaN         unknown             NaN
# 28638                      NaN       NaN     genus_known  Zygophyllaceae
# 28639            Qld Herbarium   Species        accepted  Zygophyllaceae
#
#        taxonDistribution                                   ccAttributionIRI  \
# 0                    NaN                                                NaN
# 1                    NaN                                                NaN
# 2                    NaN                                                NaN
# 3                    NaN                                                NaN
# 4                    NaN                                                NaN
# ...                  ...                                                ...
# 28635  NSW (naturalised)  https://id.biodiversity.org.au/tree/51354547/5...
# 28636   NT, SA, Qld, NSW  https://id.biodiversity.org.au/tree/51354547/5...
# 28637                NaN                                                NaN
# 28638                NaN                                                NaN
# 28639                Qld  https://id.biodiversity.org.au/tree/51354547/5...
#
#              genus
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ...            ...
# 28635    Zuloagaea
# 28636    Zygochloa
# 28637          NaN
# 28638  Zygophyllum
# 28639  Zygophyllum
#
# [28640 rows x 10 columns]
