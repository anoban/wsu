# %%
import pyarrow.parquet as pq
import pandas as pd
import numpy as np

# %%
austraits_700 =  pq.read_table(source=r"../../data/chapter2/austraits-7.0.0-flattened.parquet").to_pandas()
# Out:
# ---------------------------------------------------------------------------
# ArrowException                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 austraits_700 =  pq.read_table(source=r"../../data/chapter2/austraits-7.0.0-flattened.parquet").to_pandas()
#
# File C:\Program Files\Python313\Lib\site-packages\pyarrow\array.pxi:1032, in pyarrow.lib._PandasConvertible.to_pandas()
#
# File C:\Program Files\Python313\Lib\site-packages\pyarrow\table.pxi:5177, in pyarrow.lib.Table._to_pandas()
#
# File C:\Program Files\Python313\Lib\site-packages\pyarrow\pandas_compat.py:811, in table_to_dataframe(options, table, categories, ignore_metadata, types_mapper)
#     808 columns = _deserialize_column_index(table, all_columns, column_indexes)
#     810 column_names = table.column_names
# --> 811 result = pa.lib.table_to_blocks(options, table, categories,
#     812                                 list(ext_columns_dtypes.keys()))
# ...

# %%
aust
