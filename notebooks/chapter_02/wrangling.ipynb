# %% [markdown]
# # ___Data wrangling for the paper draft; with `FRED 4.0`___
# --------------------------------------

# %%
# !python --version
# Out:
# Python 3.14.6
# The system cannot find the path specified.

# %%
import json

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from numpy.typing import NDArray
# from numba import njit, vectorize, float32, float64
from scipy.stats import pearsonr, sem
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, PolynomialFeatures, StandardScaler
from sklearn.linear_model import LinearRegression

# %%
# including all the traits Luke advised

COLLABORATION_GRADIENT_TRAITS = [
    "F00679", # RD
    "F00727", # SRL
    # "F00104", # RCT
]

CONSERVATION_GRADIENT_TRAITS = [
    "F00709", # RTD
    # "F00261", # RN
]

CHOSEN_ROOT_TRAITS = COLLABORATION_GRADIENT_TRAITS + CONSERVATION_GRADIENT_TRAITS

CHOSEN_TRAITS_DICT = {
    "F00709":  "RTD",
    # "F00261":  "RN",
    "F00679":  "RD",
    "F00727":  "SRL",
    # "F00104":  "RCT",
}

PLANT_TAXONOMY_ACCEPTED_COLUMNS = [
    "F01286", # Genus of plant according to The Plant List
    "F01287", # Species epithet of plant according to The Plant List
    "F01289", # Family of plant according to The Plant List
    "F01290"  # Order of plant.
]

BINOMINAL_NAME = ["F01286", "F01287"]

BINOMINAL_NAME_DATA_SOURCE = ["F00018", "F00019"]

MISC = [
    "F00056", # root order
    "F00645", # Mycorrhiza_Type_Data source
   # "F01282" # Mycorrhiza_Type_Maherali - not present in FRED 4.0
]

TAXONOMY_COLUMNS_TO_CROSSCHECK = [
    "F01289", "F01290", # from FRED 4.0
    "family", "order", "group" # from the lookup table
]

# families Luke advised as important
FAMILIES_NOT_TO_MISS = ("Zamiaceae", "Cycadaceae", "Magnoliaceae", "Lauraceae", # generally thick rooted absorptive roots
                       "Cyperaceae", "Brassicaceae") # NM families

# %%
fred = pd.read_csv(r"../../data/chapter2/FRED/FRED4_Entire_Database_2026.csv", low_memory=False, header=0, skiprows=range(1, 7), encoding="latin1") # FRED 4.0
meta = pd.read_csv(r"../../data/chapter2/FRED/FRED3_Column_Definitions_2021.csv", usecols=["column_id", "name", "units"], index_col="column_id")

lookup = pd.read_csv(r"../../data/chapter2/plant_lookup.csv", low_memory=False, encoding="latin1", usecols=["genus", "apweb.family", # let's stick the the family info from APG website
                                                                                                         "order", "group"], index_col="genus").rename(mapper={"apweb.family": "family"}, axis=1) 

# thought we could use the data source's binominal names where FRED's binominal names are missing but looks like that won't help :/
# drop all the rows that do not have genus and species names
fred.dropna(subset=BINOMINAL_NAME, inplace=True)

# strip off all the unnecessary spaces
fred.loc[:, PLANT_TAXONOMY_ACCEPTED_COLUMNS] = fred.loc[:, PLANT_TAXONOMY_ACCEPTED_COLUMNS].apply(lambda col: col.str.strip())

# %%
meta.loc[PLANT_TAXONOMY_ACCEPTED_COLUMNS + BINOMINAL_NAME_DATA_SOURCE + CHOSEN_ROOT_TRAITS + MISC, :]
# Out:
#                                           name  units
# column_id
# F01286       Plant taxonomy_Accepted genus_TPL    NaN
# F01287     Plant Taxonomy_Accepted species_TPL    NaN
# F01289      Plant taxonomy_Accepted family_TPL    NaN
# F01290       Plant taxonomy_Accepted order_APW    NaN
# F00018        Plant taxonomy_Genus_Data Source    NaN
# F00019      Plant taxonomy_Species_Data source    NaN
# F00679                           Root diameter     mm
# F00727              Specific root length (SRL)    m/g
# F00709               Root tissue density (RTD)  g/cm3
# F00056                              Root order    NaN
# F00645             Mycorrhiza_Type_Data source    NaN

# %%
# records with missing binominal names aren't useful to us 
fred.loc[:, PLANT_TAXONOMY_ACCEPTED_COLUMNS + CHOSEN_ROOT_TRAITS].isna().mean() # dropna(subset=BINOMINAL_NAME)
# Out:
# F01286    0.000000
# F01287    0.000000
# F01289    0.000000
# F01290    0.000000
# F00679    0.796387
# F00727    0.796594
# F00709    0.844053
# dtype: float64

# %%
# that many records with missing binominal names???
fred.loc[:, BINOMINAL_NAME + BINOMINAL_NAME_DATA_SOURCE].isna().sum()
# Out:
# F01286     0
# F01287     0
# F00018     0
# F00019    60
# dtype: int64

# %% [markdown]
# ### ___$1^{st}$ order roots___
# __________________

# %%
fred.loc[:, PLANT_TAXONOMY_ACCEPTED_COLUMNS + CHOSEN_ROOT_TRAITS + MISC].query(r"F00056==1")
# Out:
#               F01286          F01287           F01289         F01290  \
# 0      Dicranopteris        linearis   Gleicheniaceae  Gleicheniales
# 3       Cunninghamia      lanceolata     Cupressaceae    Cupressales
# 6           Magnolia       baillonii     Magnoliaceae    Magnoliales
# 11            Acacia  auriculiformis         Fabaceae        Fabales
# 15         Polyspora       axillaris         Theaceae       Ericales
# ...              ...             ...              ...            ...
# 70350          Pinus         strobus         Pinaceae        Pinales
# 70354          Tsuga      canadensis         Pinaceae        Pinales
# 70358    Sciadopitys    verticillata  Sciadopityaceae    Cupressales
# 70363   Cephalotaxus    harringtonii  Cephalotaxaceae    Cupressales
# 70368          Taxus       cuspidata         Taxaceae    Cupressales
#
#          F00679     F00727    F00709  F00056 F00645
# 0           NaN        NaN       NaN     1.0     AM
# 3           NaN        NaN       NaN     1.0     AM
# 6           NaN        NaN       NaN     1.0     AM
# 11          NaN        NaN       NaN     1.0     AM
# 15          NaN        NaN       NaN     1.0     AM
# ...         ...        ...       ...     ...    ...
# 70350  0.421385  17.805402  0.337226     1.0     EM
# 70354  0.373780  30.873103  0.204034     1.0     EM
# 70358  0.620386  29.212460  0.125136     1.0     AM
# 70363  0.626291  21.950489  0.125251     1.0     AM
# 70368  0.543465  33.296519  0.138632     1.0     AM
#
# [2615 rows x 9 columns]

# %%
fred.loc[:, PLANT_TAXONOMY_ACCEPTED_COLUMNS + CHOSEN_ROOT_TRAITS + MISC].query(r"F00056==1").loc[:, BINOMINAL_NAME].drop_duplicates()
# Out:
#               F01286          F01287
# 0      Dicranopteris        linearis
# 3       Cunninghamia      lanceolata
# 6           Magnolia       baillonii
# 11            Acacia  auriculiformis
# 15         Polyspora       axillaris
# ...              ...             ...
# 70295  Encephalartos          gratus
# 70299          Zamia        lucayana
# 70303  Chamaecyparis        pisifera
# 70328        Ephedra       distachya
# 70358    Sciadopitys    verticillata
#
# [662 rows x 2 columns]

# %%
fred.loc[:, CHOSEN_ROOT_TRAITS + MISC].query(r"F00056==1").isna().mean().rename(index=CHOSEN_TRAITS_DICT)
# Out:
# RD        0.266157
# SRL       0.668451
# RTD       0.726195
# F00056    0.000000
# F00645    0.738815
# dtype: float64

# %% [markdown]
# ### ___RD $\le$ 2.0 mm___
# -----------------------

# %%
fred.loc[:, PLANT_TAXONOMY_ACCEPTED_COLUMNS + CHOSEN_ROOT_TRAITS].query(r"F00679 <= 2.000").dropna(subset=CHOSEN_ROOT_TRAITS)
# Out:
#              F01286     F01287        F01289    F01290    F00679     F00727  \
# 236           Larix   gmelinii      Pinaceae   Pinales  0.319412  32.211568
# 237           Larix   gmelinii      Pinaceae   Pinales  0.411555  25.480815
# 238           Larix   gmelinii      Pinaceae   Pinales  0.527621  12.980828
# 239           Larix   gmelinii      Pinaceae   Pinales  0.846975   6.250067
# 241           Larix   gmelinii      Pinaceae   Pinales  0.307450  34.615414
# ...             ...        ...           ...       ...       ...        ...
# 71902  Handroanthus  ochraceus  Bignoniaceae  Lamiales  0.740062   8.685170
# 71903  Handroanthus  ochraceus  Bignoniaceae  Lamiales  0.739066   8.855820
# 71904  Handroanthus  ochraceus  Bignoniaceae  Lamiales  0.666566   9.584048
# 71905  Handroanthus  ochraceus  Bignoniaceae  Lamiales  0.639820  10.362667
# 71906  Handroanthus  ochraceus  Bignoniaceae  Lamiales  0.743855   8.333673
#
#          F00709
# 236    0.354286
# 237    0.294286
# 238    0.382857
# 239    0.334286
# 241    0.382857
# ...         ...
# 71902  0.224091
# 71903  0.228155
# 71904  0.228379
# 71905  0.265331
# 71906  0.230190
#
# [5938 rows x 7 columns]

# %%
# focusing on rows that have data for all the three traits
fred.loc[:, PLANT_TAXONOMY_ACCEPTED_COLUMNS + CHOSEN_ROOT_TRAITS].query(r"F00679 <= 2.000").dropna(subset=CHOSEN_ROOT_TRAITS).loc[:, BINOMINAL_NAME].drop_duplicates()
# Out:
#               F01286       F01287
# 236            Larix     gmelinii
# 266         Fraxinus  mandshurica
# 382          Populus  trichocarpa
# 386          Populus      tremula
# 827       Cinnamomum   micranthum
# ...              ...          ...
# 71813        Sorocea   muriculata
# 71814  Stachyarrhena    acuminata
# 71815  Trymatococcus   amazonicus
# 71816          Zygia   inaequalis
# 71817   Handroanthus    ochraceus
#
# [1440 rows x 2 columns]

# %%
fred.loc[:, PLANT_TAXONOMY_ACCEPTED_COLUMNS + CHOSEN_ROOT_TRAITS].query(r"F00679 <= 2.000").dropna(subset=CHOSEN_ROOT_TRAITS).isna().mean().rename(index=CHOSEN_TRAITS_DICT)
# Out:
# F01286    0.0
# F01287    0.0
# F01289    0.0
# F01290    0.0
# RD        0.0
# SRL       0.0
# RTD       0.0
# dtype: float64

# %%
# inspect the coverage of thick rooted families in this subset
fred.loc[:, PLANT_TAXONOMY_ACCEPTED_COLUMNS + CHOSEN_ROOT_TRAITS].query(r"(F00679 <= 2.000) and F01289.isin(@FAMILIES_NOT_TO_MISS)").dropna(subset=CHOSEN_ROOT_TRAITS).drop_duplicates(subset=PLANT_TAXONOMY_ACCEPTED_COLUMNS)
# Out:
#                    F01286         F01287        F01289       F01290    F00679  \
# 827            Cinnamomum     micranthum     Lauraceae     Laurales  0.502558
# 832              Magnolia          odora  Magnoliaceae  Magnoliales  0.500991
# 837            Cinnamomum   chekiangense     Lauraceae     Laurales  0.499444
# 1450          Cryptocarya      chinensis     Lauraceae     Laurales  1.177410
# 1572               Gahnia        procera    Cyperaceae       Poales  0.320000
# ...                   ...            ...           ...          ...       ...
# 71756              Ocotea      scabrella     Lauraceae     Laurales  0.726000
# 71757              Ocotea      splendens     Lauraceae     Laurales  0.589000
# 71804  Rhodostemonodaphne  crenaticupula     Lauraceae     Laurales  0.703000
# 71805  Rhodostemonodaphne     paniculata     Lauraceae     Laurales  0.714000
# 71806  Rhodostemonodaphne     parvifolia     Lauraceae     Laurales  0.999000
#
#           F00727    F00709
# 827    24.150012  0.209434
# 832    24.405710  0.206190
# 837    23.180490  0.214529
# 1450    9.677503  0.248276
# 1572   58.700000  0.190000
# ...          ...       ...
# 71756   9.060000  0.275000
# 71757  11.920000  0.321000
# 71804   7.990000  0.382000
# 71805   4.670000  0.479000
# 71806   4.170000  0.407000
#
# [180 rows x 7 columns]

# %%
fred.loc[:, PLANT_TAXONOMY_ACCEPTED_COLUMNS + CHOSEN_ROOT_TRAITS].query(r"(F00679 <= 2.000) and F01289.isin(@FAMILIES_NOT_TO_MISS)").dropna(subset=CHOSEN_ROOT_TRAITS).drop_duplicates(subset=PLANT_TAXONOMY_ACCEPTED_COLUMNS).\
        groupby("F01289").agg({"F01289": "count"})
# Out:
#               F01289
# F01289
# Brassicaceae      18
# Cycadaceae         2
# Cyperaceae        17
# Lauraceae        111
# Magnoliaceae      29
# Zamiaceae          3

# %%
cutoff_2mm_taxa = fred.loc[:, PLANT_TAXONOMY_ACCEPTED_COLUMNS + CHOSEN_ROOT_TRAITS].query(r"(F00679 <= 2.000)").dropna(subset=CHOSEN_ROOT_TRAITS).loc[:, PLANT_TAXONOMY_ACCEPTED_COLUMNS].\
    drop_duplicates(subset=BINOMINAL_NAME).sort_values(["F01289", "F01290", "F01286", "F01287"]).reset_index(drop=True)
cutoff_2mm_taxa
# Out:
#              F01286          F01287         F01289        F01290
# 0     Strobilanthes  dimorphotricha    Acanthaceae      Lamiales
# 1         Actinidia       kolomikta  Actinidiaceae      Ericales
# 2          Saurauia         herthae  Actinidiaceae      Ericales
# 3       Liquidambar       formosana   Altingiaceae  Saxifragales
# 4       Liquidambar      gracilipes   Altingiaceae  Saxifragales
# ...             ...             ...            ...           ...
# 1435          Dioon      rzedowskii      Zamiaceae     Cycadales
# 1436  Encephalartos          gratus      Zamiaceae     Cycadales
# 1437          Zamia        lucayana      Zamiaceae     Cycadales
# 1438        Alpinia        japonica  Zingiberaceae  Zingiberales
# 1439     Wurfbainia         villosa  Zingiberaceae  Zingiberales
#
# [1440 rows x 4 columns]

# %%
# WE HAVE SPECIES CLASSIFIED UNDER DIFFERENT HIGHER TAXA IN THIS SUBSET!!!!!

# %% [markdown]
# ### ___RD $\le$ 1.00 mm___
# ------------------

# %%
fred.loc[:, PLANT_TAXONOMY_ACCEPTED_COLUMNS + CHOSEN_ROOT_TRAITS].query(r"F00679 <= 1.000").dropna(subset=CHOSEN_ROOT_TRAITS)
# Out:
#              F01286     F01287        F01289    F01290    F00679     F00727  \
# 236           Larix   gmelinii      Pinaceae   Pinales  0.319412  32.211568
# 237           Larix   gmelinii      Pinaceae   Pinales  0.411555  25.480815
# 238           Larix   gmelinii      Pinaceae   Pinales  0.527621  12.980828
# 239           Larix   gmelinii      Pinaceae   Pinales  0.846975   6.250067
# 241           Larix   gmelinii      Pinaceae   Pinales  0.307450  34.615414
# ...             ...        ...           ...       ...       ...        ...
# 71902  Handroanthus  ochraceus  Bignoniaceae  Lamiales  0.740062   8.685170
# 71903  Handroanthus  ochraceus  Bignoniaceae  Lamiales  0.739066   8.855820
# 71904  Handroanthus  ochraceus  Bignoniaceae  Lamiales  0.666566   9.584048
# 71905  Handroanthus  ochraceus  Bignoniaceae  Lamiales  0.639820  10.362667
# 71906  Handroanthus  ochraceus  Bignoniaceae  Lamiales  0.743855   8.333673
#
#          F00709
# 236    0.354286
# 237    0.294286
# 238    0.382857
# 239    0.334286
# 241    0.382857
# ...         ...
# 71902  0.224091
# 71903  0.228155
# 71904  0.228379
# 71905  0.265331
# 71906  0.230190
#
# [5218 rows x 7 columns]

# %%
fred.loc[:, PLANT_TAXONOMY_ACCEPTED_COLUMNS + CHOSEN_ROOT_TRAITS].query(r"F00679 <= 1.000").dropna(subset=CHOSEN_ROOT_TRAITS).loc[:, BINOMINAL_NAME].drop_duplicates()
# Out:
#               F01286       F01287
# 236            Larix     gmelinii
# 266         Fraxinus  mandshurica
# 382          Populus  trichocarpa
# 386          Populus      tremula
# 827       Cinnamomum   micranthum
# ...              ...          ...
# 71813        Sorocea   muriculata
# 71814  Stachyarrhena    acuminata
# 71815  Trymatococcus   amazonicus
# 71816          Zygia   inaequalis
# 71817   Handroanthus    ochraceus
#
# [1301 rows x 2 columns]

# %%
fred.loc[:, PLANT_TAXONOMY_ACCEPTED_COLUMNS + CHOSEN_ROOT_TRAITS].query(r"F00679 <= 1.000").dropna(subset=CHOSEN_ROOT_TRAITS).isna().mean().rename(index=CHOSEN_TRAITS_DICT)
# Out:
# F01286    0.0
# F01287    0.0
# F01289    0.0
# F01290    0.0
# RD        0.0
# SRL       0.0
# RTD       0.0
# dtype: float64

# %%
# inspect the thick rooted family coverage
fred.loc[:, PLANT_TAXONOMY_ACCEPTED_COLUMNS + CHOSEN_ROOT_TRAITS].query(r"(F00679 <= 1.000) and F01289.isin(@FAMILIES_NOT_TO_MISS)").dropna(subset=CHOSEN_ROOT_TRAITS).drop_duplicates(subset=PLANT_TAXONOMY_ACCEPTED_COLUMNS)
# Out:
#                    F01286         F01287        F01289       F01290    F00679  \
# 827            Cinnamomum     micranthum     Lauraceae     Laurales  0.502558
# 832              Magnolia          odora  Magnoliaceae  Magnoliales  0.500991
# 837            Cinnamomum   chekiangense     Lauraceae     Laurales  0.499444
# 1572               Gahnia        procera    Cyperaceae       Poales  0.320000
# 1573               Gahnia    xanthocarpa    Cyperaceae       Poales  0.460000
# ...                   ...            ...           ...          ...       ...
# 71756              Ocotea      scabrella     Lauraceae     Laurales  0.726000
# 71757              Ocotea      splendens     Lauraceae     Laurales  0.589000
# 71804  Rhodostemonodaphne  crenaticupula     Lauraceae     Laurales  0.703000
# 71805  Rhodostemonodaphne     paniculata     Lauraceae     Laurales  0.714000
# 71806  Rhodostemonodaphne     parvifolia     Lauraceae     Laurales  0.999000
#
#           F00727    F00709
# 827    24.150012  0.209434
# 832    24.405710  0.206190
# 837    23.180490  0.214529
# 1572   58.700000  0.190000
# 1573   45.600000  0.100000
# ...          ...       ...
# 71756   9.060000  0.275000
# 71757  11.920000  0.321000
# 71804   7.990000  0.382000
# 71805   4.670000  0.479000
# 71806   4.170000  0.407000
#
# [146 rows x 7 columns]

# %%
fred.loc[:, PLANT_TAXONOMY_ACCEPTED_COLUMNS + CHOSEN_ROOT_TRAITS].query(r"(F00679 <= 1.000) and F01289.isin(@FAMILIES_NOT_TO_MISS)").dropna(subset=CHOSEN_ROOT_TRAITS).drop_duplicates(subset=PLANT_TAXONOMY_ACCEPTED_COLUMNS).\
    groupby("F01289").agg({"F01289": "count"})
# Out:
#               F01289
# F01289
# Brassicaceae       5
# Cycadaceae         2
# Cyperaceae        12
# Lauraceae         96
# Magnoliaceae      28
# Zamiaceae          3

# %%
# diff in species counts, all three traits

fred.loc[:, PLANT_TAXONOMY_ACCEPTED_COLUMNS + CHOSEN_ROOT_TRAITS].query(r"(F00679 <= 2.000) and F01289.isin(@FAMILIES_NOT_TO_MISS)").dropna(subset=CHOSEN_ROOT_TRAITS).drop_duplicates(subset=PLANT_TAXONOMY_ACCEPTED_COLUMNS).\
    groupby("F01289").agg({"F01289": "count"}) - fred.loc[:, PLANT_TAXONOMY_ACCEPTED_COLUMNS + CHOSEN_ROOT_TRAITS].query(r"(F00679 <= 1.000) and F01289.isin(@FAMILIES_NOT_TO_MISS)").dropna(subset=CHOSEN_ROOT_TRAITS).drop_duplicates(subset=PLANT_TAXONOMY_ACCEPTED_COLUMNS).\
    groupby("F01289").agg({"F01289": "count"})
# Out:
#               F01289
# F01289
# Brassicaceae      13
# Cycadaceae         0
# Cyperaceae         5
# Lauraceae         15
# Magnoliaceae       1
# Zamiaceae          0

# %%
# diff in species counts, RD & SRL

fred.loc[:, PLANT_TAXONOMY_ACCEPTED_COLUMNS + CHOSEN_ROOT_TRAITS].query(r"(F00679 <= 2.000) and F01289.isin(@FAMILIES_NOT_TO_MISS)").dropna(subset=COLLABORATION_GRADIENT_TRAITS).drop_duplicates(subset=PLANT_TAXONOMY_ACCEPTED_COLUMNS).\
    groupby("F01289").agg({"F01289": "count"}) - fred.loc[:, PLANT_TAXONOMY_ACCEPTED_COLUMNS + CHOSEN_ROOT_TRAITS].query(r"(F00679 <= 1.000) and F01289.isin(@FAMILIES_NOT_TO_MISS)").dropna(subset=COLLABORATION_GRADIENT_TRAITS).drop_duplicates(subset=PLANT_TAXONOMY_ACCEPTED_COLUMNS).\
    groupby("F01289").agg({"F01289": "count"})
# Out:
#               F01289
# F01289
# Brassicaceae      14
# Cycadaceae         0
# Cyperaceae         5
# Lauraceae         15
# Magnoliaceae       1
# Zamiaceae          0

# %%
# dropping NaNs only in RD and SRL

cutoff_1mm_taxa = fred.loc[:, PLANT_TAXONOMY_ACCEPTED_COLUMNS + CHOSEN_ROOT_TRAITS].query(r"(F00679 <= 1.000)").dropna(subset=COLLABORATION_GRADIENT_TRAITS).loc[:, PLANT_TAXONOMY_ACCEPTED_COLUMNS].\
    drop_duplicates(subset=BINOMINAL_NAME).sort_values(["F01289", "F01290", "F01286", "F01287"]).reset_index(drop=True)
cutoff_1mm_taxa
# Out:
#              F01286          F01287         F01289        F01290
# 0            Rungia       pectinata    Acanthaceae      Lamiales
# 1     Strobilanthes  dimorphotricha    Acanthaceae      Lamiales
# 2         Actinidia       kolomikta  Actinidiaceae      Ericales
# 3          Saurauia         herthae  Actinidiaceae      Ericales
# 4       Liquidambar       formosana   Altingiaceae  Saxifragales
# ...             ...             ...            ...           ...
# 1439          Dioon      rzedowskii      Zamiaceae     Cycadales
# 1440  Encephalartos          gratus      Zamiaceae     Cycadales
# 1441          Zamia        lucayana      Zamiaceae     Cycadales
# 1442        Alpinia        japonica  Zingiberaceae  Zingiberales
# 1443     Wurfbainia         villosa  Zingiberaceae  Zingiberales
#
# [1444 rows x 4 columns]

# %%
# SUSPECT THIS SUBSET ALSO HAS SPECIES CLASSIFIED UNDER MULTIPLE HIGHER RANKS!!!!!!!!

# %%
# see what species we are losing going from 2mm to 1mm cutoff

species_lost_2mm_to_1mm = np.setdiff1d(cutoff_2mm_taxa.loc[:, BINOMINAL_NAME].apply(' '.join, axis=1).unique(), 
                                        cutoff_1mm_taxa.loc[:, BINOMINAL_NAME].apply(' '.join, axis=1).unique())# .size
species_lost_2mm_to_1mm
# Out:
# array(['Aglaia squamulosa', 'Agrostis stolonifera', 'Alchemilla arvensis',
#        'Alchemilla xanthochlora', 'Alopecurus geniculatus',
#        'Aniba citrifolia', 'Aniba williamsii', 'Arabidopsis arenosa',
#        'Arabidopsis thaliana', 'Arabis sagittata', 'Barbarea vulgaris',
#        'Beilschmiedia brachythyrsa', 'Beilschmiedia percoriacea',
#        'Beilschmiedia robusta', 'Bellis perennis', 'Berula erecta',
#        'Brassica rapa', 'Briza media', 'Bromus sterilis',
#        'Calamagrostis canescens', 'Campanula glomerata',
#        'Campanula patula', 'Campanula persicifolia',
#        'Campanula rapunculoides', 'Capsella bursa-pastoris',
#        'Cardamine pratensis', 'Carex leporina', 'Carex muricata',
#        'Carex ornithopoda', 'Carex praecox', 'Carex vulpina',
#        'Centaurium erythraea', 'Cerastium glomeratum',
#        'Cerastium pumilum', 'Cerastium semidecandrum',
#        'Clinopodium acinos', 'Clusia latipes', 'Cruciata laevipes',
#        'Cryptocarya densiflora', 'Cynanchica pyrenaica',
#        'Cynosurus cristatus', 'Dacryodes rugosa',
#        'Dianthus carthusianorum', 'Diospyros nigrocortex',
#        'Endlicheria melinonii', 'Endocomia macrocoma',
#        'Epilobium hirsutum', 'Epilobium parviflorum', 'Erigeron acris',
#        'Erophila verna', 'Euphrasia officinalis', 'Festuca guestfalica',
#        'Festuca nigrescens', 'Fragaria vesca', 'Fragaria viridis',
#        'Galium album', 'Galium pumilum', 'Galium verum',
#        'Geranium pusillum', 'Geum rivale', 'Geum urbanum',
#        'Glyceria fluitans', 'Griselinia littoralis',
#        'Helianthemum nummularium', 'Helictochloa pratensis',
#        'Helictotrichon pubescens', 'Horsfieldia kingii',
#        'Jacobaea erucifolia', 'Juncus inflexus', 'Knema globularia',
#        'Knema tenuinervia', 'Lamium purpureum', 'Lepidium campestre',
#        'Licania alba', 'Licaria cannella', 'Licaria polyphylla',
#        'Litsea accedens', 'Litsea calicaris', 'Litsea cambodiana',
#        'Litsea dilleniifolia', 'Litsea monopetala', 'Lolium pratense',
#        'Luzula campestris', 'Magnolia henryi', 'Matricaria discoidea',
#        'Myosotis arvensis', 'Myosotis discolor', 'Myosotis ramosissima',
#        'Otoba parvifolia', 'Persicaria lapathifolia', 'Phedimus spurius',
#        'Phleum bertolonii', 'Pittosporum kerrii', 'Poa angustifolia',
#        'Poa annua', 'Potentilla argentea', 'Potentilla heptaphylla',
#        'Potentilla recta', 'Potentilla verna', 'Potentilla x',
#        'Primula veris', 'Ranunculus minimus',
#        'Rhodostemonodaphne kunthiana', 'Ripogonum scadens',
#        'Rumex thyrsiflorus', 'Ruscus aculeatus',
#        'Saxifraga tridactylites', 'Scabiosa columbaria',
#        'Sesleria albicans', 'Sherardia arvensis', 'Silene vulgaris',
#        'Sinapis arvensis', 'Sisymbrium officinale', 'Spergula arvensis',
#        'Stachys arvensis', 'Stellaria graminea', 'Stellaria media',
#        'Sterculia macrophylla', 'Thlaspi arvense', 'Thlaspi perfoliatum',
#        'Thymus pulegioides', 'Valeriana locusta', 'Veronica arvensis',
#        'Veronica officinalis', 'Veronica serpyllifolia',
#        'Veronica spicata', 'Viola arvensis', 'Virola sebifera'],
#       dtype=object)

# %%
species_lost_2mm_to_1mm = pd.DataFrame({"F01286": [_.split()[0] for _ in species_lost_2mm_to_1mm], "F01287": [_.split()[1] for _ in species_lost_2mm_to_1mm]})
species_lost_2mm_to_1mm
# Out:
#          F01286         F01287
# 0        Aglaia     squamulosa
# 1      Agrostis    stolonifera
# 2    Alchemilla       arvensis
# 3    Alchemilla   xanthochlora
# 4    Alopecurus    geniculatus
# ..          ...            ...
# 134    Veronica    officinalis
# 135    Veronica  serpyllifolia
# 136    Veronica        spicata
# 137       Viola       arvensis
# 138      Virola       sebifera
#
# [139 rows x 2 columns]

# %%
# full taxonomic profile of the 139 species
species_lost_2mm_to_1mm = pd.merge(left=species_lost_2mm_to_1mm, left_on=BINOMINAL_NAME, right=cutoff_2mm_taxa, right_on=BINOMINAL_NAME, how="left").sort_values(["F01289", "F01290"] + BINOMINAL_NAME).reset_index(drop=True)
species_lost_2mm_to_1mm
# Out:
#           F01286         F01287         F01289        F01290
# 0         Berula         erecta       Apiaceae       Apiales
# 1         Ruscus      aculeatus   Asparagaceae   Asparagales
# 2         Bellis       perennis     Asteraceae     Asterales
# 3       Erigeron          acris     Asteraceae     Asterales
# 4    Hypochaeris       radicata     Asteraceae     Asterales
# ..           ...            ...            ...           ...
# 134       Galium        pumilum      Rubiaceae   Gentianales
# 135       Galium          verum      Rubiaceae   Gentianales
# 136    Sherardia       arvensis      Rubiaceae   Gentianales
# 137    Saxifraga  tridactylites  Saxifragaceae  Saxifragales
# 138        Viola       arvensis      Violaceae  Malpighiales
#
# [139 rows x 4 columns]

# %%
species_lost_2mm_to_1mm.to_csv(r"../../data/chapter2/FRED/subsets/species_lost_2mm_to_1mm_FRED4.csv", index=False)

# %%
# that's a lot of useful species
species_lost_2mm_to_1mm.query(r"F01289.isin(@FAMILIES_NOT_TO_MISS)").drop_duplicates()
# Out:
#                 F01286          F01287        F01289       F01290
# 10         Arabidopsis         arenosa  Brassicaceae  Brassicales
# 11         Arabidopsis        thaliana  Brassicaceae  Brassicales
# 12              Arabis       sagittata  Brassicaceae  Brassicales
# 13            Barbarea        vulgaris  Brassicaceae  Brassicales
# 14            Brassica            rapa  Brassicaceae  Brassicales
# 15            Capsella  bursa-pastoris  Brassicaceae  Brassicales
# 16           Cardamine       pratensis  Brassicaceae  Brassicales
# 17            Erophila           verna  Brassicaceae  Brassicales
# 18            Lepidium       campestre  Brassicaceae  Brassicales
# 19             Sinapis        arvensis  Brassicaceae  Brassicales
# 20          Sisymbrium      officinale  Brassicaceae  Brassicales
# 21             Thlaspi         arvense  Brassicaceae  Brassicales
# 22             Thlaspi     perfoliatum  Brassicaceae  Brassicales
# 42               Carex        leporina    Cyperaceae       Poales
# 43               Carex        muricata    Cyperaceae       Poales
# 44               Carex     ornithopoda    Cyperaceae       Poales
# 45               Carex         praecox    Cyperaceae       Poales
# 46               Carex         vulpina    Cyperaceae       Poales
# 59               Aniba      citrifolia     Lauraceae     Laurales
# 60               Aniba      williamsii     Lauraceae     Laurales
# 61       Beilschmiedia    brachythyrsa     Lauraceae     Laurales
# 62       Beilschmiedia     percoriacea     Lauraceae     Laurales
# 63       Beilschmiedia         robusta     Lauraceae     Laurales
# 64         Cryptocarya      densiflora     Lauraceae     Laurales
# 65         Endlicheria       melinonii     Lauraceae     Laurales
# 66             Licaria        cannella     Lauraceae     Laurales
# 67             Licaria      polyphylla     Lauraceae     Laurales
# 68              Litsea        accedens     Lauraceae     Laurales
# 69              Litsea       calicaris     Lauraceae     Laurales
# 70              Litsea      cambodiana     Lauraceae     Laurales
# 71              Litsea   dilleniifolia     Lauraceae     Laurales
# 72              Litsea      monopetala     Lauraceae     Laurales
# 73  Rhodostemonodaphne       kunthiana     Lauraceae     Laurales
# 74            Magnolia          henryi  Magnoliaceae  Magnoliales

# %%
# decide which columns in FRED 4.0 have mycorrhizal state info????
[col for col in fred.columns if ((fred.loc[:, col].dtype == pd.StringDtype(storage="python", na_value=np.nan)) and fred.loc[:, col].str.contains("AM").any())]
# Out:
# ['F00004', 'F00006', 'F00043', 'F00645', 'F01160', 'F00079']

# %%
fred.loc[:, ('F00004', 'F00006', 'F00043', 'F00645', 'F01160', 'F00079')]
# Out:
#                                                   F00004  \
# 0      Long Y, Kong D, Chen Z, Zeng H. 2013. Variatio...
# 1      Long Y, Kong D, Chen Z, Zeng H. 2013. Variatio...
# 2      Long Y, Kong D, Chen Z, Zeng H. 2013. Variatio...
# 3      Long Y, Kong D, Chen Z, Zeng H. 2013. Variatio...
# 4      Long Y, Kong D, Chen Z, Zeng H. 2013. Variatio...
# ...                                                  ...
# 77554  Kutschera L, Lichtenegger E, Sobotik M, Haas D...
# 77555  Kutschera L, Lichtenegger E (1960) Wurzelatlas...
# 77556  Kutschera L, Lichtenegger E, Sobotik M, Haas D...
# 77557  Kutschera L, Lichtenegger E (1960) Wurzelatlas...
# 77558  Kutschera L, Lichtenegger E, Sobotik M, Haas D...
#
#                                                   F00006  F00043 F00645  \
# 0                                                    NaN      C3     AM
# 1                                                    NaN      C3     AM
# 2                                                    NaN      C3     AM
# 3                                                    NaN      C3     AM
# 4                                                    NaN      C3     AM
# ...                                                  ...     ...    ...
# 77554  Tumber-Davila SJ, Schenk HJ, Du E, and Jackson...     NaN    NaN
# 77555  Tumber-Davila SJ, Schenk HJ, Du E, and Jackson...      C3    NaN
# 77556  Tumber-Davila SJ, Schenk HJ, Du E, and Jackson...     NaN    NaN
# 77557  Tumber-Davila SJ, Schenk HJ, Du E, and Jackson...      C3    NaN
# 77558  Tumber-Davila SJ, Schenk HJ, Du E, and Jackson...  C3/CAM    NaN
#
#       F01160 F00079
# 0        NaN    NaN
# 1        NaN    NaN
# 2        NaN    NaN
# 3        NaN    NaN
# 4        NaN    NaN
# ...      ...    ...
# 77554    NaN    NaN
# 77555    NaN    NaN
# 77556    NaN    NaN
# 77557    NaN    NaN
# 77558    NaN    NaN
#
# [53204 rows x 6 columns]

# %%
fred.loc[:, ('F00645', 'F01160', 'F00079')].dropna() # damn, FRED 3 has a row F01282 named Mycorrhiza_Type_Maherali, but FRED 4 hasn't
# Out:
#       F00645       F01160                                             F00079
# 1651      AM      control  RLD converted from 1m depth to 0.3m depth. Dat...
# 1656      AM      control  RLD converted from 1m depth to 0.3m depth. Dat...
# 1661      AM      control  RLD converted from 1m depth to 0.3m depth. Dat...
# 3581      EM  ambient CO2  Diameter, diameter production, and diameter mo...
# 3582      EM  ambient CO2  Diameter, diameter production, and diameter mo...
# ...      ...          ...                                                ...
# 54022     AM          N10  AM colonization taken from graph using Grab It...
# 55131     AM      control  Plant species categorical data not found in TR...
# 55134     AM      control  Plant species categorical data not found in TR...
# 55140     AM      control  Plant species categorical data not found in TR...
# 55141     AM      control  Plant species categorical data not found in TR...
#
# [753 rows x 3 columns]

# %% [markdown]
# ### ___Choosing to proceed with an RD cutoff $\le$ 1.00 mm___
# ---------------------------------------------------------------------------------------

# %%
# final subset for the phylogenetics work; using traits - RD, SRL and RTD and using RD <= 1.00 mm as the cutoff criteria

subset = fred.loc[:, PLANT_TAXONOMY_ACCEPTED_COLUMNS + CHOSEN_ROOT_TRAITS + MISC].query(r"F00679 <= 1.000").reset_index(drop=True)
subset
# Out:
#             F01286       F01287        F01289        F01290    F00679  \
# 0          Populus  tremuloides    Salicaceae  Malpighiales  0.220000
# 1             Acer      negundo   Sapindaceae    Sapindales  0.280000
# 2          Juglans        nigra  Juglandaceae       Fagales  0.300000
# 3          Quercus        rubra      Fagaceae       Fagales  0.230000
# 4            Carya       glabra  Juglandaceae       Fagales  0.220000
# ...            ...          ...           ...           ...       ...
# 9679  Handroanthus    ochraceus  Bignoniaceae      Lamiales  0.740062
# 9680  Handroanthus    ochraceus  Bignoniaceae      Lamiales  0.739066
# 9681  Handroanthus    ochraceus  Bignoniaceae      Lamiales  0.666566
# 9682  Handroanthus    ochraceus  Bignoniaceae      Lamiales  0.639820
# 9683  Handroanthus    ochraceus  Bignoniaceae      Lamiales  0.743855
#
#          F00727    F00709  F00056 F00645
# 0           NaN       NaN     NaN    NaN
# 1           NaN       NaN     NaN    NaN
# 2           NaN       NaN     NaN    NaN
# 3           NaN       NaN     NaN    NaN
# 4           NaN       NaN     NaN    NaN
# ...         ...       ...     ...    ...
# 9679   8.685170  0.224091     NaN     AM
# 9680   8.855820  0.228155     NaN     AM
# 9681   9.584048  0.228379     NaN     AM
# 9682  10.362667  0.265331     NaN     AM
# 9683   8.333673  0.230190     NaN     AM
#
# [9684 rows x 9 columns]

# %%
# examine the root orders within this RD <= 1.00 mm subset

freq = subset.F00056.value_counts(dropna=False)
fig, axes = plt.subplots()
fig.set_size_inches(4, 4)
axes.bar(x=freq.index.fillna(0), # without replacing with 0s, NaNs get ignored in x???
         height=freq.values, width=0.9, color="red")
axes.grid()
axes.set_axisbelow(True)
axes.set_xticks(ticks=np.linspace(start=0, stop=freq.size - 1, num=freq.size), labels=freq.index)
plt.tight_layout()
plt.show()

# %%
# drop records where root order is > 3 ???
# this is concerning but Luke advised against mixing the two approaches
subset.query(r"F00056 > 3")
# Out:
#          F01286     F01287         F01289        F01290    F00679      F00727  \
# 14         Acer  saccharum    Sapindaceae    Sapindales  0.220000   70.500000
# 15         Acer  saccharum    Sapindaceae    Sapindales  0.210000   83.100000
# 16         Acer  saccharum    Sapindaceae    Sapindales  0.200000  131.100000
# 17         Acer  saccharum    Sapindaceae    Sapindales  0.230000   80.200000
# 20     Fraxinus  americana       Oleaceae      Lamiales  0.210000  108.200000
# ...         ...        ...            ...           ...       ...         ...
# 7501      Vitis   vinifera       Vitaceae       Vitales  0.371517    0.480000
# 7502      Vitis   vinifera       Vitaceae       Vitales  0.590948    0.090000
# 7506      Vitis   vinifera       Vitaceae       Vitales  0.600550    0.290000
# 9001  Dacrydium   balansae  Podocarpaceae  Araucariales  0.847640    6.220949
# 9005     Nageia       nagi  Podocarpaceae  Araucariales  0.634425   27.550617
#
#         F00709  F00056 F00645
# 14         NaN     4.0    NaN
# 15         NaN     5.0    NaN
# 16         NaN     6.0    NaN
# 17         NaN     7.0    NaN
# 20         NaN     4.0    NaN
# ...        ...     ...    ...
# 7501       NaN     4.0     AM
# 7502       NaN     5.0     AM
# 7506       NaN     4.0     AM
# 9001  0.526719     4.0     AM
# 9005  0.312120     4.0     AM
#
# [494 rows x 9 columns]

# %%
subset.loc[:, BINOMINAL_NAME].drop_duplicates() # that's a good number of species
# Out:
#              F01286       F01287
# 0           Populus  tremuloides
# 1              Acer      negundo
# 2           Juglans        nigra
# 3           Quercus        rubra
# 4             Carya       glabra
# ...             ...          ...
# 9591        Sorocea   muriculata
# 9592  Stachyarrhena    acuminata
# 9593  Trymatococcus   amazonicus
# 9594          Zygia   inaequalis
# 9595   Handroanthus    ochraceus
#
# [1735 rows x 2 columns]

# %%
# species record with values for RD, SRL & RTD
subset.dropna(subset=CHOSEN_ROOT_TRAITS).drop_duplicates(subset=BINOMINAL_NAME)
# Out:
#              F01286       F01287        F01289        F01290    F00679  \
# 69            Larix     gmelinii      Pinaceae       Pinales  0.319412
# 92         Fraxinus  mandshurica      Oleaceae      Lamiales  0.288462
# 128         Populus  trichocarpa    Salicaceae  Malpighiales  0.142951
# 132         Populus      tremula    Salicaceae  Malpighiales  0.175513
# 358      Cinnamomum   micranthum     Lauraceae      Laurales  0.502558
# ...             ...          ...           ...           ...       ...
# 9591        Sorocea   muriculata      Moraceae       Rosales  0.643000
# 9592  Stachyarrhena    acuminata     Rubiaceae   Gentianales  0.376000
# 9593  Trymatococcus   amazonicus      Moraceae       Rosales  0.581000
# 9594          Zygia   inaequalis      Fabaceae       Fabales  0.367000
# 9595   Handroanthus    ochraceus  Bignoniaceae      Lamiales  0.565735
#
#           F00727    F00709  F00056 F00645
# 69     32.211568  0.354286     1.0    NaN
# 92     78.846169  0.231206     1.0    NaN
# 128   447.167648  0.169294     1.0    NaN
# 132   330.424588  0.169294     1.0    NaN
# 358    24.150012  0.209434     1.0    NaN
# ...          ...       ...     ...    ...
# 9591    8.540000  0.469000     NaN     AM
# 9592   20.890000  0.416000     NaN     AM
# 9593    7.460000  0.531000     NaN     AM
# 9594   26.160000  0.362000     NaN     AM
# 9595   18.959706  0.186354     NaN     AM
#
# [1301 rows x 9 columns]

# %%
# Luke advised that if a record has SRL & RD, RTD can be back calculated, so we can just filter out NaNs in SRL and RD??
# species records with values for both RD & SRL
#---------------------------------------------------------------------------------------------------------------------------

subset.dropna(subset=COLLABORATION_GRADIENT_TRAITS).drop_duplicates(subset=BINOMINAL_NAME)
# Out:
#              F01286      F01287        F01289        F01290    F00679  \
# 12             Acer   saccharum   Sapindaceae    Sapindales  0.450000
# 18         Fraxinus   americana      Oleaceae      Lamiales  0.670000
# 23            Viola   pubescens     Violaceae  Malpighiales  0.640000
# 27     Hydrophyllum   canadense  Boraginaceae   Boraginales  0.870000
# 69            Larix    gmelinii      Pinaceae       Pinales  0.319412
# ...             ...         ...           ...           ...       ...
# 9591        Sorocea  muriculata      Moraceae       Rosales  0.643000
# 9592  Stachyarrhena   acuminata     Rubiaceae   Gentianales  0.376000
# 9593  Trymatococcus  amazonicus      Moraceae       Rosales  0.581000
# 9594          Zygia  inaequalis      Fabaceae       Fabales  0.367000
# 9595   Handroanthus   ochraceus  Bignoniaceae      Lamiales  0.565735
#
#          F00727    F00709  F00056 F00645
# 12    11.500000       NaN     2.0    NaN
# 18     9.800000       NaN     2.0    NaN
# 23    13.000000       NaN     2.0    NaN
# 27    16.200000       NaN     2.0    NaN
# 69    32.211568  0.354286     1.0    NaN
# ...         ...       ...     ...    ...
# 9591   8.540000  0.469000     NaN     AM
# 9592  20.890000  0.416000     NaN     AM
# 9593   7.460000  0.531000     NaN     AM
# 9594  26.160000  0.362000     NaN     AM
# 9595  18.959706  0.186354     NaN     AM
#
# [1444 rows x 9 columns]

# %%
subset.dropna(subset=COLLABORATION_GRADIENT_TRAITS).loc[:, BINOMINAL_NAME].drop_duplicates()
# Out:
#              F01286      F01287
# 12             Acer   saccharum
# 18         Fraxinus   americana
# 23            Viola   pubescens
# 27     Hydrophyllum   canadense
# 69            Larix    gmelinii
# ...             ...         ...
# 9591        Sorocea  muriculata
# 9592  Stachyarrhena   acuminata
# 9593  Trymatococcus  amazonicus
# 9594          Zygia  inaequalis
# 9595   Handroanthus   ochraceus
#
# [1444 rows x 2 columns]

# %%
# proceed with records that have data for RD & SRL; where RTD, will be filled using back calculations
#-----------------------------------------------------------------------------------------------------------

subset.dropna(subset=COLLABORATION_GRADIENT_TRAITS, inplace=True)
subset.isna().sum()
# Out:
# F01286       0
# F01287       0
# F01289       0
# F01290       0
# F00679       0
# F00727       0
# F00709    1208
# F00056    4564
# F00645    3930
# dtype: int64

# %% [markdown]
# According to [Specific root length as an indicator of environmental change](https://www.tandfonline.com/doi/full/10.1080/11263500701626069);
#
# Specific root length is the length of a unit mass root segment $SRL = \frac{L}{M}$. But, mass is obviously equal to volume multiplied by density; $M = V \times RTD$. So; $SRL = \frac{L}{V \times RTD}$. Assuming a cylindrical shape, the volume `V` of an `L` length root fragment with `RD` diameter is, $V = \pi \times (\frac{RD}{2})^2 \times L$.
# That makes; $SRL = \frac{L}{\pi \times (\frac{RD}{2})^2 \times L \times RTD} = \frac{4}{\pi \times RD^2 \times RTD}$.
# Hence $RTD = \frac{4}{\pi \times RD^2 \times SRL}$.

# %%
def back_calculate_rtd(rd: NDArray[np.float64], srl: NDArray[np.float64]) -> NDArray[np.float64]:
    """
    reference: Ostonen, I. et al. (2007) ‘Specific root length as an indicator of environmental change’,
    Plant Biosystems - An International Journal Dealing with all Aspects of Plant Biology, 141(3), pp. 426–442.
    Available at: https://doi.org/10.1080/11263500701626069.

    FRED uses the following units for the following traits::
    Root diameter -	mm
    Specific root length - m/g
 	Root tissue density - g/cm3

    we need to reconcile the units before applying the equation!, the target (RTD) is in g/cm3, so change all the lengths to cm.
    RD (mm) => RD/10 (cm)
    SRL (m/g) => SRL * 100 (cm/g)

    so the equation becomes: 4.0000 / (pi * (RD/10)^2 * SRL * 100)
    so the output RTD will be in units => g/cm3
    """
    
    return 4.00000 / (np.pi * np.square(rd/10) * (srl * 100))

back_calculate_rtd = np.vectorize(pyfunc=back_calculate_rtd, otypes=[np.float64])

# %%
# before we fill the NaNs in RTD with calculated values, check how close our calculations are to actual values where RTD data is available
# this is pre log transformation of the traits

all_three_traits = subset.query(r"not F00709.isna()").loc[:, CHOSEN_ROOT_TRAITS]

fig, axes = plt.subplots()
fig.set_size_inches(6, 6)
axes.scatter(x=all_three_traits.F00709, y=back_calculate_rtd(all_three_traits.F00679.values, all_three_traits.F00727.values), color="red", edgecolor="black")
axes.set_xlabel(r"$RTD_{empirical}$")
axes.set_ylabel(r"$RTD_{calculated}$")
axes.set_axisbelow(True)
axes.grid()
plt.tight_layout()
plt.show()

# %%
# that's concerningly low????
pearsonr(x=all_three_traits.F00709, y=back_calculate_rtd(all_three_traits.F00679.values, all_three_traits.F00727.values))
# Out:
# PearsonRResult(statistic=np.float64(0.1940890421715866), pvalue=np.float64(1.8262099893534333e-45))

# %%
# try fitting a linear regression model instead of using the equation???

mmax_scaler = MinMaxScaler()
scaled_x = mmax_scaler.fit_transform(X=all_three_traits.loc[:, ["F00679", "F00727"]], y=all_three_traits.F00709)

# split the dataset into training set and testing set
scaled_x_train, scaled_x_test, y_train, y_test = train_test_split(scaled_x, all_three_traits.F00709, train_size=0.70)

lmod = LinearRegression(n_jobs=12)
lmod.fit(X=scaled_x_train, y=y_train)
# Out:
# LinearRegression(n_jobs=12)

# %%
lmod.predict(scaled_x_test) # hope it didn't memoize the train values
# Out:
# array([0.27027707, 0.34187939, 0.23743504, ..., 0.34899325, 0.31337429,
#        0.36206573], shape=(1566,))

# %%
pearsonr(x=y_test, y=lmod.predict(scaled_x_test)) # that sucks too :/
# Out:
# PearsonRResult(statistic=np.float64(0.4120107373943967), pvalue=np.float64(3.2261189918311986e-65))

# %%
# try a polynomial regression

polyfeats = PolynomialFeatures(degree=8)
mmax_scaler = MinMaxScaler()

scaled_x = mmax_scaler.fit_transform(X=all_three_traits.loc[:, ["F00679", "F00727"]], y=all_three_traits.F00709)
scaled_poly_x = polyfeats.fit_transform(scaled_x)

x_train, x_test, y_train, y_test = train_test_split(scaled_poly_x, all_three_traits.F00709, train_size=0.7)

polymod = LinearRegression(n_jobs=12)
polymod.fit(X=x_train, y=y_train)
# Out:
# LinearRegression(n_jobs=12)

# %%
# THE CORRELATION COEFFICIENT VARIES DRASTICALLY BETWEEN MODEL FITS?????
pearsonr(x=y_test, y=polymod.predict(x_test)) # that interesting????
# Out:
# PearsonRResult(statistic=np.float64(0.768568217914408), pvalue=np.float64(1.0912489693839955e-305))

# %%
fig, axes = plt.subplots()
fig.set_size_inches(6, 6)
axes.scatter(x=all_three_traits.F00709, y=back_calculate_rtd(all_three_traits.F00679.values, all_three_traits.F00727.values), color="red", edgecolor="black", label="equation")
axes.scatter(x=all_three_traits.F00709, y=lmod.predict(scaled_x), color="blue", edgecolor="black", label="LinearRegression")
axes.scatter(x=all_three_traits.F00709, y=polymod.predict(scaled_poly_x), color="green", edgecolor="black", label="PolynomialFeatures")
axes.set_xlabel(r"$RTD_{empirical}$")
axes.set_ylabel(r"$RTD_{calculated}$")
axes.legend()
axes.set_axisbelow(True)
axes.grid()
plt.tight_layout()
plt.show()

# %%
# CHOOSING NOT TO BACK CALCULATE THE RTD VALUES
#------------------------------------------------

# fill the NaNs in the RTD column with manual calculations
# subset.loc[subset.F00709.isna(), "F00709"] = back_calculate_rtd(rd=subset.query(r"F00709.isna()").loc[:, "F00679"], srl=subset.query(r"F00709.isna()").loc[:, "F00727"])
# subset.isna().sum() # cool

# %%
# abandon the plan to back propagate RTD values and drop the records that have missing RTD values
subset.dropna(subset="F00709", inplace=True)
subset.isna().mean()
# Out:
# F01286    0.000000
# F01287    0.000000
# F01289    0.000000
# F01290    0.000000
# F00679    0.000000
# F00727    0.000000
# F00709    0.000000
# F00056    0.721349
# F00645    0.589115
# dtype: float64

# %%
# examine the root orders within this RD <= 1.00 mm subset

freq = subset.F00056.value_counts(dropna=False)
fig, axes = plt.subplots()
fig.set_size_inches(4, 4)
axes.bar(x=freq.index.fillna(0), # without replacing with 0s, NaNs get ignored in x???
         height=freq.values, width=0.9, color="red")
axes.grid()
axes.set_axisbelow(True)
axes.set_xticks(ticks=np.linspace(start=0, stop=freq.size - 1, num=freq.size), labels=freq.index)
plt.tight_layout()
plt.show()

# %%
np.setdiff1d(subset.F01286.unique(), lookup.index)
# Out:
# array(['Alseodaphnopsis', 'Andesanthus', 'Austroblechnum',
#        'Chrysojasminum', 'Cranfillia', 'Eumachia', 'Helesia',
#        'Heptapleurum', 'Hesperostipa', 'Hymenopus', 'Imbralyx',
#        'Leptobalanus', 'Pectinopitys', 'Prasoxylon', 'Pseudodictamnus',
#        'Rubroshorea', 'Tetrapilus', 'Veronia', 'Wurfbainia'], dtype=object)

# %%
# we need to manually cross check these genera

# Austroblechnum
# Cranfillia
# Pectinopitys
# Helesia
# Tetrapilus
# Heptapleurum
# Veronia
# Prasoxylon
# Pseudodictamnus
# Chrysojasminum
# Hesperostipa
# Rubroshorea
# Wurfbainia
# Andesanthus
# Imbralyx
# Alseodaphnopsis
# Hymenopus
# Leptobalanus
# Eumachia

# %%
# for the genera that the lookup table has taxonomic data for, do the crosschecking
#------------------------------------------------------------------------------------

lookup_merged = pd.merge(left=subset.loc[:, PLANT_TAXONOMY_ACCEPTED_COLUMNS].query(r"F01286.isin(@lookup.index)").drop_duplicates(),
                         left_on="F01286", right=lookup, right_index=True, how="left").reset_index(drop=True)
lookup_merged
# Out:
#              F01286       F01287        F01289        F01290        family  \
# 0             Larix     gmelinii      Pinaceae       Pinales      Pinaceae
# 1          Fraxinus  mandshurica      Oleaceae      Lamiales      Oleaceae
# 2           Populus  trichocarpa    Salicaceae  Malpighiales    Salicaceae
# 3           Populus      tremula    Salicaceae  Malpighiales    Salicaceae
# 4        Cinnamomum   micranthum     Lauraceae      Laurales     Lauraceae
# ...             ...          ...           ...           ...           ...
# 1269        Sorocea   muriculata      Moraceae       Rosales      Moraceae
# 1270  Stachyarrhena    acuminata     Rubiaceae   Gentianales     Rubiaceae
# 1271  Trymatococcus   amazonicus      Moraceae       Rosales      Moraceae
# 1272          Zygia   inaequalis      Fabaceae       Fabales      Fabaceae
# 1273   Handroanthus    ochraceus  Bignoniaceae      Lamiales  Bignoniaceae
#
#              order        group
# 0          Pinales  Gymnosperms
# 1         Lamiales  Angiosperms
# 2     Malpighiales  Angiosperms
# 3     Malpighiales  Angiosperms
# 4         Laurales  Angiosperms
# ...            ...          ...
# 1269       Rosales  Angiosperms
# 1270   Gentianales  Angiosperms
# 1271       Rosales  Angiosperms
# 1272       Fabales  Angiosperms
# 1273      Lamiales  Angiosperms
#
# [1274 rows x 7 columns]

# %%
# family level coflicts
lookup_merged.query(r"F01289!=family").drop_duplicates()
# Out:
#             F01286        F01287           F01289         F01290  \
# 32       Hedycarya       arborea      Minimiaceae       Laurales
# 112          Nyssa     sylvatica        Nyssaceae       Cornales
# 367       Sambucus    williamsii      Viburnaceae     Dipsacales
# 504       Viburnum      dentatum      Viburnaceae     Dipsacales
# 531       Apodytes     dimidiata   Metteniusaceae  Metteniusales
# 631       Viburnum         tinus      Viburnaceae     Dipsacales
# 700       Galearia      maingayi         Fabaceae        Fabales
# 706          Nyssa      aquatica        Nyssaceae       Cornales
# 875       Viburnum    stipitatum      Viburnaceae     Dipsacales
# 1004  Cephalotaxus  harringtonii  Cephalotaxaceae    Cupressales
# 1073   Cryptocarya    acutifolia         Moraceae       Laurales
# 1086  Barringtonia     fusicarpa         Moraceae       Ericales
# 1087   Castanopsis        indica         Moraceae        Fagales
#
#              family         order        group
# 32      Monimiaceae      Laurales  Angiosperms
# 112       Cornaceae      Cornales  Angiosperms
# 367       Adoxaceae    Dipsacales  Angiosperms
# 504       Adoxaceae    Dipsacales  Angiosperms
# 531     Icacinaceae    Icacinales  Angiosperms
# 631       Adoxaceae    Dipsacales  Angiosperms
# 700       Pandaceae  Malpighiales  Angiosperms
# 706       Cornaceae      Cornales  Angiosperms
# 875       Adoxaceae    Dipsacales  Angiosperms
# 1004       Taxaceae       Pinales  Gymnosperms
# 1073      Lauraceae      Laurales  Angiosperms
# 1086  Lecythidaceae      Ericales  Angiosperms
# 1087       Fagaceae       Fagales  Angiosperms

# %%
# spelling mistakes in FRED are indicated with and asterisk*

# taxa that FRED has correctly
#---------------------------------

# Nyssa sylvatica - stick to FRED  https://powo.science.kew.org/taxon/urn:lsid:ipni.org:names:271953-1#higher-classification
# Sambucus williamsii - stick to FRED  https://powo.science.kew.org/taxon/urn:lsid:ipni.org:names:149409-1#higher-classification
# Viburnum dentatum - stick to FRED  https://powo.science.kew.org/taxon/urn:lsid:ipni.org:names:326264-2#higher-classification
# Apodytes dimidiata - stick to FRED  https://powo.science.kew.org/taxon/urn:lsid:ipni.org:names:434212-1#higher-classification
# Viburnum tinus - stick to FRED  https://powo.science.kew.org/taxon/urn:lsid:ipni.org:names:326271-2#higher-classification
# Nyssa aquatica - stick to FRED https://powo.science.kew.org/taxon/urn:lsid:ipni.org:names:302695-2#higher-classification
# Viburnum stipitatum - stick to FRED https://powo.science.kew.org/taxon/urn:lsid:ipni.org:names:77175761-1#higher-classification

# taxa that need intervention
#---------------------------------

# Hedycarya arborea - *Monimiaceae, Laurales  https://powo.science.kew.org/taxon/urn:lsid:ipni.org:names:581882-1#higher-classification
# Galearia maingayi - Pandaceae, Malpighiales https://powo.science.kew.org/taxon/urn:lsid:ipni.org:names:349146-1#higher-classification
# Cephalotaxus harringtonii - Cephalotaxaceae, Pinales https://powo.science.kew.org/taxon/urn:lsid:ipni.org:names:261818-1#higher-classification
# Cryptocarya acutifolia - Lauraceae, Laurales https://powo.science.kew.org/taxon/urn:lsid:ipni.org:names:463781-1#higher-classification
# Barringtonia fusicarpa - Lecythidaceae, Ericales https://powo.science.kew.org/taxon/urn:lsid:ipni.org:names:104061-1#higher-classification
# Castanopsis indica - Fagaceae, Fagales https://powo.science.kew.org/taxon/urn:lsid:ipni.org:names:295397-1#higher-classification

# %%
# correct the above in the subset and remerge with the lookup table to incorporate the corrections

subset.loc[subset.query(r"F01286=='Hedycarya'").index, "F01289"] = "Monimiaceae"
subset.loc[subset.query(r"F01286=='Hedycarya'").index, "F01290"] = "Laurales"

subset.loc[subset.query(r"F01286=='Galearia'").index, "F01289"] = "Pandaceae"
subset.loc[subset.query(r"F01286=='Galearia'").index, "F01290"] = "Malpighiales"

subset.loc[subset.query(r"F01286=='Cephalotaxus'").index, "F01289"] = "Cephalotaxaceae"
subset.loc[subset.query(r"F01286=='Cephalotaxus'").index, "F01290"] = "Pinales"

subset.loc[subset.query(r"F01286=='Cryptocarya'").index, "F01289"] = "Lauraceae"
subset.loc[subset.query(r"F01286=='Cryptocarya'").index, "F01290"] = "Laurales"

subset.loc[subset.query(r"F01286=='Barringtonia'").index, "F01289"] = "Lecythidaceae"
subset.loc[subset.query(r"F01286=='Barringtonia'").index, "F01290"] = "Ericales"

subset.loc[subset.query(r"F01286=='Castanopsis'").index, "F01289"] = "Fagaceae"
subset.loc[subset.query(r"F01286=='Castanopsis'").index, "F01290"] = "Fagales"

# %%
# remerging after corrections, this is necessary since these corrections may have solved some of the order level conflicts
# so before reconciling the order level conflicts, do the remerger

lookup_merged = pd.merge(left=subset.loc[:, PLANT_TAXONOMY_ACCEPTED_COLUMNS].query(r"F01286.isin(@lookup.index)").drop_duplicates(),
                         left_on="F01286", right=lookup, right_index=True, how="left").reset_index(drop=True)

# %%
# order level conflicts

# with pd.option_context("display.max_rows", 100, "display.max_columns", 10):
#     print(lookup_merged.query(r"F01290!=order").drop_duplicates())

lookup_merged.query(r"F01290!=order").drop_duplicates()

# even though our FRED subset has heaps of order level conflicts with the lookup table, U.PhyloMaker only expects the following columns:
# species, genus, family, species.relative, genus.relative
# don't waste time reconciling the orders :)
# Out:
#              F01286           F01287           F01289        F01290  \
# 15        Asplenium       bulbiferum     Aspleniaceae  Polypodiales
# 18          Lomaria         discolor      Blechnaceae  Polypodiales
# 19     Parablechnum  novae-zelandiae      Blechnaceae  Polypodiales
# 20     Parablechnum         procerum      Blechnaceae  Polypodiales
# 28        Dacrydium      cupressinum    Podocarpaceae  Araucariales
# ...             ...              ...              ...           ...
# 1014      Dacrydium         balansae    Podocarpaceae  Araucariales
# 1015         Nageia             nagi    Podocarpaceae  Araucariales
# 1019  Chamaecyparis         pisifera     Cupressaceae   Cupressales
# 1020        Ephedra        distachya      Ephedraceae    Ephedrales
# 1022    Sciadopitys     verticillata  Sciadopityaceae   Cupressales
#
#                family         order          group
# 15       Aspleniaceae  Eupolypod II  Pteridophytes
# 18        Blechnaceae  Eupolypod II  Pteridophytes
# 19        Blechnaceae  Eupolypod II  Pteridophytes
# 20        Blechnaceae  Eupolypod II  Pteridophytes
# 28      Podocarpaceae       Pinales    Gymnosperms
# ...               ...           ...            ...
# 1014    Podocarpaceae       Pinales    Gymnosperms
# 1015    Podocarpaceae       Pinales    Gymnosperms
# 1019     Cupressaceae       Pinales    Gymnosperms
# 1020      Ephedraceae      Gnetales    Gymnosperms
# 1022  Sciadopityaceae       Pinales    Gymnosperms
#
# [65 rows x 7 columns]

# %%
# now, examine the genera that are missing in the lookup table
#---------------------------------------------------------------

subset.loc[:, PLANT_TAXONOMY_ACCEPTED_COLUMNS].query(r"not F01286.isin(@lookup.index)").drop_duplicates().sort_values(by=BINOMINAL_NAME)
# Out:
#                F01286           F01287            F01289        F01290
# 9264  Alseodaphnopsis       andersonii         Lauraceae      Laurales
# 8172      Andesanthus        lepidotus   Melastomataceae      Myrtales
# 483    Austroblechnum      lanceolatum       Blechnaceae  Polypodiales
# 5589   Chrysojasminum        fruticans          Oleaceae      Lamiales
# 485        Cranfillia      fluviatilis       Blechnaceae  Polypodiales
# 9493         Eumachia     astrellantha         Rubiaceae   Gentianales
# 9494         Eumachia      podocephala         Rubiaceae   Gentianales
# 952           Helesia       tetraptera       Styracaceae      Ericales
# 7803     Heptapleurum     heptaphyllum        Araliaceae       Apiales
# 1153     Heptapleurum  minutistellatum        Araliaceae       Apiales
# 5706     Hesperostipa           comata           Poaceae        Poales
# 5707     Hesperostipa          spartea           Poaceae        Poales
# 9468        Hymenopus    adolphoduckei  Chrysobalanaceae  Malpighiales
# 9470        Hymenopus         caudatus  Chrysobalanaceae  Malpighiales
# 9476        Hymenopus     macrophyllus  Chrysobalanaceae  Malpighiales
# 9481        Hymenopus      reticulatus  Chrysobalanaceae  Malpighiales
# 9483        Hymenopus       sothersiae  Chrysobalanaceae  Malpighiales
# 9127         Imbralyx      leptobotrys          Fabaceae       Fabales
# 9472     Leptobalanus       granvillei  Chrysobalanaceae  Malpighiales
# 9474     Leptobalanus            latus  Chrysobalanaceae  Malpighiales
# 9475     Leptobalanus      longistylus  Chrysobalanaceae  Malpighiales
# 9479     Leptobalanus        octandrus  Chrysobalanaceae  Malpighiales
# 9484     Leptobalanus          sprucei  Chrysobalanaceae  Malpighiales
# 516      Pectinopitys       ferruginea     Podocarpaceae  Araucariales
# 1907       Prasoxylon         excelsum         Meliaceae    Sapindales
# 5559  Pseudodictamnus         hirsutus         Lamiaceae      Lamiales
# 5723      Rubroshorea        acuminata  Dipterocarpaceae      Malvales
# 5724      Rubroshorea        leprosula  Dipterocarpaceae      Malvales
# 1152       Tetrapilus           roseus          Oleaceae      Lamiales
# 1342          Veronia      fasciculata        Asteraceae     Asterales
# 7881       Wurfbainia          villosa     Zingiberaceae  Zingiberales

# %%
# leave as is
#----------------------

# Alseodaphnopsis - https://powo.science.kew.org/taxon/urn:lsid:ipni.org:names:77165678-1#higher-classification
# Andesanthus - https://powo.science.kew.org/taxon/urn:lsid:ipni.org:names:77205900-1#higher-classification
# Chrysojasminum - https://powo.science.kew.org/taxon/urn:lsid:ipni.org:names:77144221-1#higher-classification
# Eumachia - https://powo.science.kew.org/taxon/urn:lsid:ipni.org:names:77154315-1#higher-classification
# Heptapleurum spp. - https://powo.science.kew.org/taxon/urn:lsid:ipni.org:names:77196882-1#higher-classification
# Hesperostipa spp. - https://powo.science.kew.org/taxon/urn:lsid:ipni.org:names:969792-1#higher-classification
# Hymenopus spp. - https://powo.science.kew.org/taxon/urn:lsid:ipni.org:names:77156951-1#higher-classification
# Imbralyx - https://powo.science.kew.org/taxon/urn:lsid:ipni.org:names:77222791-1#higher-classification
# Leptobalanus spp. - https://powo.science.kew.org/taxon/urn:lsid:ipni.org:names:60472849-2#higher-classification
# Prasoxylon - https://powo.science.kew.org/taxon/urn:lsid:ipni.org:names:77222487-1#higher-classification
# Pseudodictamnus - https://powo.science.kew.org/taxon/urn:lsid:ipni.org:names:77191007-1#higher-classification
# Rubroshorea spp. - https://powo.science.kew.org/taxon/urn:lsid:ipni.org:names:77298388-1#higher-classification
# Tetrapilus - https://powo.science.kew.org/taxon/urn:lsid:ipni.org:names:611203-1#higher-classification
# Wurfbainia - https://powo.science.kew.org/taxon/urn:lsid:ipni.org:names:77178295-1#higher-classification

# corrections needed
#----------------------

# Austroblechnum lanceolatum - synonym of Blechnum chambersii - Aspleniaceae, Polypodiales https://powo.science.kew.org/taxon/urn:lsid:ipni.org:names:53460-3#higher-classification
# Helesia tetraptera - correct the spelling error in FRED - Halesia tetraptera - synonym of Halesia carolina - Styracaceae, Ericales https://powo.science.kew.org/taxon/urn:lsid:ipni.org:names:319532-2#higher-classification
# Cranfillia fluviatilis - synonym of Blechnum fluviatile - Aspleniaceae, Polypodiales https://powo.science.kew.org/taxon/urn:lsid:ipni.org:names:17058940-1#higher-classification
# Pectinopitys ferruginea - Podocarpaceae, Pinales https://powo.science.kew.org/taxon/urn:lsid:ipni.org:names:77203782-1#higher-classification
# Veronia fasciculata - misspelt - Vernonia fasciculata - https://powo.science.kew.org/taxon/urn:lsid:ipni.org:names:258347-1#higher-classification

# %%
subset.loc[subset.query(r"F01286=='Helesia' and F01287=='tetraptera'").index, "F01286"] = "Halesia"

subset.loc[subset.query(r"F01286=='Austroblechnum' and F01287=='lanceolatum'").index, "F01286"] = "Blechnum"
subset.loc[subset.query(r"F01286=='Austroblechnum' and F01287=='lanceolatum'").index, "F01287"] = "chambersii"
subset.loc[subset.query(r"F01286=='Blechnum'").index, "F01289"] = "Aspleniaceae"
subset.loc[subset.query(r"F01286=='Blechnum'").index, "F01290"] = "Polypodiales"

subset.loc[subset.query(r"F01286=='Cranfillia' and F01287=='fluviatilis'").index, "F01286"] = "Blechnum"
subset.loc[subset.query(r"F01286=='Cranfillia' and F01287=='fluviatilis'").index, "F01287"] = "fluviatile"
subset.loc[subset.query(r"F01286=='Blechnum'").index, "F01289"] = "Aspleniaceae"
subset.loc[subset.query(r"F01286=='Blechnum'").index, "F01290"] = "Polypodiales"

subset.loc[subset.query(r"F01286=='Pectinopitys'").index, "F01289"] = "Podocarpaceae"
subset.loc[subset.query(r"F01286=='Pectinopitys'").index, "F01290"] = "Pinales"

subset.loc[subset.query(r"F01286=='Veronia' and F01287=='fasciculata'").index, "F01286"] = "Vernonia"

# %%
# now, cross check if any genera are classified under multiple families
assert(not [g for g in subset.F01286.unique() if subset.query(r"F01286==@g").loc[:, "F01289"].unique().size > 1]), "must be an empty list!"

# %%
# one species classified under multiple orders, WE DON'T NEED TO RECTIFY THIS.......

[g for g in subset.F01286.unique() if subset.query(r"F01286==@g").loc[:, "F01290"].unique().size > 1]
# Out:
# ['Vitis']

# %%
subset.query(r"F01286=='Vitis'").loc[:, PLANT_TAXONOMY_ACCEPTED_COLUMNS].drop_duplicates()
# Out:
#      F01286     F01287    F01289       F01290
# 3440  Vitis    vulpina  Vitaceae  Alismatales
# 3443  Vitis    vulpina  Vitaceae      Vitales
# 5637  Vitis   vinifera  Vitaceae      Vitales
# 7832  Vitis  amurensis  Vitaceae      Vitales

# %%
# let's fix it, why not
# https://powo.science.kew.org/taxon/urn:lsid:ipni.org:names:30478388-2#higher-classification

subset.loc[subset.query(r"F01286=='Vitis'").index, "F01290"] = "Vitales"
assert(not [g for g in subset.F01286.unique() if subset.query(r"F01286==@g").loc[:, "F01290"].unique().size > 1]), "must be an empty list!"

# %%
lookup_merged = pd.merge(left=subset.loc[:, PLANT_TAXONOMY_ACCEPTED_COLUMNS].query(r"F01286.isin(@lookup.index)").drop_duplicates(),
                         left_on="F01286", right=lookup, right_index=True, how="left").reset_index(drop=True)

# %%
lookup_merged.query(r"F01289!=family").drop_duplicates(subset=BINOMINAL_NAME)
# Out:
#             F01286        F01287           F01289         F01290       family  \
# 18        Blechnum   lanceolatum     Aspleniaceae   Polypodiales  Blechnaceae
# 20        Blechnum   fluviatilis     Aspleniaceae   Polypodiales  Blechnaceae
# 115          Nyssa     sylvatica        Nyssaceae       Cornales    Cornaceae
# 371       Sambucus    williamsii      Viburnaceae     Dipsacales    Adoxaceae
# 507       Viburnum      dentatum      Viburnaceae     Dipsacales    Adoxaceae
# 534       Apodytes     dimidiata   Metteniusaceae  Metteniusales  Icacinaceae
# 634       Viburnum         tinus      Viburnaceae     Dipsacales    Adoxaceae
# 709          Nyssa      aquatica        Nyssaceae       Cornales    Cornaceae
# 878       Viburnum    stipitatum      Viburnaceae     Dipsacales    Adoxaceae
# 1007  Cephalotaxus  harringtonii  Cephalotaxaceae        Pinales     Taxaceae
#
#              order          group
# 18    Eupolypod II  Pteridophytes
# 20    Eupolypod II  Pteridophytes
# 115       Cornales    Angiosperms
# 371     Dipsacales    Angiosperms
# 507     Dipsacales    Angiosperms
# 534     Icacinales    Angiosperms
# 634     Dipsacales    Angiosperms
# 709       Cornales    Angiosperms
# 878     Dipsacales    Angiosperms
# 1007       Pinales    Gymnosperms

# %%
# all the taxa that we need to find mycorrhizal state data for
#------------------------------------------------------

subset.loc[:, PLANT_TAXONOMY_ACCEPTED_COLUMNS].drop_duplicates(subset=BINOMINAL_NAME).reset_index(drop=True)
# Out:
#              F01286       F01287        F01289        F01290
# 0             Larix     gmelinii      Pinaceae       Pinales
# 1          Fraxinus  mandshurica      Oleaceae      Lamiales
# 2           Populus  trichocarpa    Salicaceae  Malpighiales
# 3           Populus      tremula    Salicaceae  Malpighiales
# 4        Cinnamomum   micranthum     Lauraceae      Laurales
# ...             ...          ...           ...           ...
# 1296        Sorocea   muriculata      Moraceae       Rosales
# 1297  Stachyarrhena    acuminata     Rubiaceae   Gentianales
# 1298  Trymatococcus   amazonicus      Moraceae       Rosales
# 1299          Zygia   inaequalis      Fabaceae       Fabales
# 1300   Handroanthus    ochraceus  Bignoniaceae      Lamiales
#
# [1301 rows x 4 columns]

# %%
subset.loc[:, PLANT_TAXONOMY_ACCEPTED_COLUMNS].drop_duplicates(subset=BINOMINAL_NAME).reset_index(drop=True).F01286.unique()
# Out:
# <StringArray>
# [             'Larix',           'Fraxinus',            'Populus',
#          'Cinnamomum',           'Magnolia',        'Castanopsis',
#         'Liquidambar',        'Elaeocarpus',        'Endospermum',
#         'Aristotelia',
#  ...
#          'Carapichea',          'Chassalia', 'Rhodostemonodaphne',
#              'Rudgea',         'Scleronema',             'Simira',
#             'Sorocea',      'Stachyarrhena',      'Trymatococcus',
#               'Zygia']
# Length: 608, dtype: str

# %%
subset.F01289.unique()
# Out:
# <StringArray>
# [       'Pinaceae',        'Oleaceae',      'Salicaceae',       'Lauraceae',
#     'Magnoliaceae',        'Fagaceae',    'Altingiaceae',  'Elaeocarpaceae',
#    'Euphorbiaceae',  'Chloranthaceae',
#  ...
#    'Staphyleaceae',      'Myricaceae',   'Picramniaceae',     'Clethraceae',
#  'Cephalotaxaceae',      'Cycadaceae',       'Gnetaceae',       'Zamiaceae',
#  'Sciadopityaceae',    'Symplocaceae']
# Length: 152, dtype: str

# %%
sem([0.87365])
# Out:
# C:\Users\90963425\AppData\Local\Temp\ipykernel_16072\2314596426.py:1: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   sem([0.87365])
# np.float64(nan)

# %%
sem([10, 1.28970, 86]), np.std([10, 1.28970, 86], ddof=1) / np.sqrt(3) #  ddof=1 is critical with calls to np.std if we were to get identical results as numpy.std and scipy.stats.sem have different defaults to ddof
# Out:
# (np.float64(26.902813000564336), np.float64(26.902813000564336))

# %%
# all the raw records with RD <= 1.000 and data for the three traits
continuous = subset.assign(binominal=subset.F01286 + '_' + subset.F01287)
continuous = continuous.drop(["F00056", "F00645", "F01290"], axis=1)
continuous = continuous.loc[:, ["binominal", "F01286", "F01287", "F01289"] + CHOSEN_ROOT_TRAITS]

# %%
continuous
# Out:
#                    binominal        F01286     F01287        F01289    F00679  \
# 69            Larix_gmelinii         Larix   gmelinii      Pinaceae  0.319412
# 70            Larix_gmelinii         Larix   gmelinii      Pinaceae  0.411555
# 71            Larix_gmelinii         Larix   gmelinii      Pinaceae  0.527621
# 72            Larix_gmelinii         Larix   gmelinii      Pinaceae  0.846975
# 73            Larix_gmelinii         Larix   gmelinii      Pinaceae  0.307450
# ...                      ...           ...        ...           ...       ...
# 9679  Handroanthus_ochraceus  Handroanthus  ochraceus  Bignoniaceae  0.740062
# 9680  Handroanthus_ochraceus  Handroanthus  ochraceus  Bignoniaceae  0.739066
# 9681  Handroanthus_ochraceus  Handroanthus  ochraceus  Bignoniaceae  0.666566
# 9682  Handroanthus_ochraceus  Handroanthus  ochraceus  Bignoniaceae  0.639820
# 9683  Handroanthus_ochraceus  Handroanthus  ochraceus  Bignoniaceae  0.743855
#
#          F00727    F00709
# 69    32.211568  0.354286
# 70    25.480815  0.294286
# 71    12.980828  0.382857
# 72     6.250067  0.334286
# 73    34.615414  0.382857
# ...         ...       ...
# 9679   8.685170  0.224091
# 9680   8.855820  0.228155
# 9681   9.584048  0.228379
# 9682  10.362667  0.265331
# 9683   8.333673  0.230190
#
# [5218 rows x 7 columns]

# %%
# species that need to be renamed to match the phylogeny

continuous.loc[continuous.binominal == "Blechnopsis_orientalis", "F01286"] = "Blechnum"
continuous.loc[continuous.binominal == "Blechnopsis_orientalis", "F01287"] = "orientale"
continuous.loc[continuous.binominal == "Blechnopsis_orientalis", "binominal"] = "Blechnum_orientale"

continuous.loc[continuous.binominal == "Rubroshorea_acuminata", "F01286"] = "Shorea" # specific epithet is the same here
continuous.loc[continuous.binominal == "Rubroshorea_acuminata", "binominal"] = "Shorea_acuminata"

continuous.loc[continuous.binominal == "Rubroshorea_leprosula", "F01286"] = "Shorea" # specific epithet is the same here
continuous.loc[continuous.binominal == "Rubroshorea_leprosula", "binominal"] = "Shorea_leprosula"

continuous.loc[continuous.binominal == "Richetia_multiflora", "F01286"] = "Shorea" # specific epithet is the same here
continuous.loc[continuous.binominal == "Richetia_multiflora", "binominal"] = "Shorea_multiflora"

continuous.loc[continuous.binominal == "Lomaria_discolor", "F01286"] = "Blechnum" # specific epithet is the same here
continuous.loc[continuous.binominal == "Lomaria_discolor", "binominal"] = "Blechnum_discolor"

continuous.loc[continuous.binominal == "Parablechnum_novae-zelandiae", "F01286"] = "Blechnum" # specific epithet is the same here
continuous.loc[continuous.binominal == "Parablechnum_novae-zelandiae", "binominal"] = "Blechnum_novae-zelandiae"

continuous.loc[continuous.binominal == "Parablechnum_procerum", "F01286"] = "Blechnum" # specific epithet is the same here
continuous.loc[continuous.binominal == "Parablechnum_procerum", "binominal"] = "Blechnum_procerum"

continuous.loc[continuous.binominal == "Pseudodiphasium_volubile", "F01286"] = "Lycopodium" # specific epithet is the same here
continuous.loc[continuous.binominal == "Pseudodiphasium_volubile", "binominal"] = "Lycopodium_volubile"

# %%
continuous.to_csv(r"../../data/chapter2/FRED/subsets/continuous_raw.csv", index=False)

# %%
subset
# Out:
#                    binominal        F01286     F01287        F01289    F01290  \
# 69            Larix_gmelinii         Larix   gmelinii      Pinaceae   Pinales
# 70            Larix_gmelinii         Larix   gmelinii      Pinaceae   Pinales
# 71            Larix_gmelinii         Larix   gmelinii      Pinaceae   Pinales
# 72            Larix_gmelinii         Larix   gmelinii      Pinaceae   Pinales
# 73            Larix_gmelinii         Larix   gmelinii      Pinaceae   Pinales
# ...                      ...           ...        ...           ...       ...
# 9679  Handroanthus_ochraceus  Handroanthus  ochraceus  Bignoniaceae  Lamiales
# 9680  Handroanthus_ochraceus  Handroanthus  ochraceus  Bignoniaceae  Lamiales
# 9681  Handroanthus_ochraceus  Handroanthus  ochraceus  Bignoniaceae  Lamiales
# 9682  Handroanthus_ochraceus  Handroanthus  ochraceus  Bignoniaceae  Lamiales
# 9683  Handroanthus_ochraceus  Handroanthus  ochraceus  Bignoniaceae  Lamiales
#
#         F00679     F00727    F00709
# 69    0.319412  32.211568  0.354286
# 70    0.411555  25.480815  0.294286
# 71    0.527621  12.980828  0.382857
# 72    0.846975   6.250067  0.334286
# 73    0.307450  34.615414  0.382857
# ...        ...        ...       ...
# 9679  0.740062   8.685170  0.224091
# 9680  0.739066   8.855820  0.228155
# 9681  0.666566   9.584048  0.228379
# 9682  0.639820  10.362667  0.265331
# 9683  0.743855   8.333673  0.230190
#
# [5218 rows x 8 columns]

# %%
#-------------------------------------------------------------------
# continuous trait averages and standard errors for MR-PMM models
#-------------------------------------------------------------------

averaged_subset = subset.copy()

# log transform the continuous traits before computing mean and se
averaged_subset.F00679 = np.log(averaged_subset.F00679)
averaged_subset.F00727 = np.log(averaged_subset.F00727)
averaged_subset.F00709 = np.log(averaged_subset.F00709)

averaged_subset = averaged_subset.groupby(BINOMINAL_NAME, as_index=False).agg({"F00679": ["mean", sem], "F00727": ["mean", sem], "F00709": ["mean", sem]}) # we need this for the MCMCglmm models
averaged_subset.columns = ("F01286", "F01287", "F00679", "F00679_se", "F00727", "F00727_se", "F00709", "F00709_se")

averaged_subset.to_csv(r"../../data/chapter2/FRED/subsets/continuous.csv", index=False)
# Out:
# C:\Program Files\Python314\Lib\site-packages\pandas\core\groupby\generic.py:498: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   f = lambda x: func(x, *args, **kwargs)

# %%
# species with no root order data whatsoever

# rd_qntls = np.quantile(a=collab_fineroots.query(r"F00056.isna()").F00679, q=(.25, .5, .75)) # RD quantiles
# srl_qntls = np.quantile(a=collab_fineroots.query(r"F00056.isna()").F00727, q=(.25, .5, .75)) # SRL quantiles

fig = plt.figure()
fig.set_size_inches(10, 10)
gspec = fig.add_gridspec(nrows=2, ncols=2, hspace=0.025, wspace=0.025, width_ratios=(0.1, 0.9), height_ratios=(0.9, 0.1))


axes_b = fig.add_subplot(gspec[1, 1])
axes_b.boxplot(averaged_subset.F00679, showmeans=True, meanline=True, tick_labels=None, orientation="horizontal")
axes_b.set_xlabel(r"$RD(mm)$")
axes_b.grid()
axes_b.set_yticks([])

axes_l = fig.add_subplot(gspec[0, 0])
axes_l.boxplot(averaged_subset.F00727, showmeans=True, meanline=True, tick_labels=None)
axes_l.set_ylabel(r"$SRL(m/g)$")
axes_l.grid()
axes_l.set_xticks([])

axes = fig.add_subplot(gspec[0, 1], sharex=axes_b, sharey=axes_l)
axes.scatter(x=averaged_subset.F00679, y=averaged_subset.F00727, edgecolor="black", alpha=0.65)
axes.grid()
plt.setp(axes.get_xticklabels(), visible=False)
plt.setp(axes.get_yticklabels(), visible=False)
axes.set_axisbelow(True)

plt.show()

# %%
fig = plt.figure(figsize=(8, 8), layout="tight")
axes = fig.add_subplot(projection="3d", axisbelow=True)
axes.set_proj_type(proj_type="ortho")
axes.view_init(elev=40, azim=-10, roll=90)
axes.scatter(xs=averaged_subset.F00679, ys=averaged_subset.F00727, zs=averaged_subset.F00709, color="green", edgecolor="black", alpha=0.45, s=10)
axes.set_xlabel(r"$log(RD)\hspace{1}(mm)$")
axes.set_ylabel(r"$log(SRL)\hspace{1}(\frac{m}{g})$")
axes.set_zlabel(r"$log(RTD)\hspace{1}(\frac{g}{cm3})$")
axes.set_box_aspect(aspect=None, zoom=0.85) # zoom out to make the z label visible
plt.tight_layout()
plt.show()

# %% [markdown]
# ### ___Mycorrhizal state filling___
# -----------------------------

# %%
# 1301 unique taxa in FRED 4 RD <= 1.00 mm subset
taxa = pd.read_csv(r"../../data/chapter2/FRED/subsets/species_averaged_and_logged_continuous_traits_FRED4.csv").loc[:, PLANT_TAXONOMY_ACCEPTED_COLUMNS]
taxa.loc[:, "binominal"] = taxa.loc[:, BINOMINAL_NAME].apply(' '.join, axis=1) # introduce a new column for binominal names

# mycorrhizal states in FRED 4.0 (from the respective data sources)
# this dataset is a hand cleaned version of the programatically cleaned and serialized .csv
# fred_states = pd.read_excel(r"../../data/chapter2/FRED/subsets/states.xlsx", sheet_name="FRED4")

# a trimmed .csv version of the FungalRoot species level dataset
fungalroot = pd.read_csv(r"../../data/chapter2/FungalRoot/fungalroot.csv", low_memory=False, header=0, skiprows=[1])
fungalroot.species = fungalroot.species.str.strip()

fungalroot_genus_state_recommendations = pd.read_excel(r"../../data/chapter2/FungalRoot/nph16569-sup-0002-tabless1-s4.xlsx", sheet_name="Table S2", skiprows=(0, 1), names=("genus", "state"))

maherali = pd.read_csv(r"../../data/chapter2/Maherali.etal.AmNat.Data.csv", names=("binominal", "state"), skiprows=1)
maherali.binominal = maherali.binominal.str.replace('_', ' ').str.strip()

wcvp_synonyms_lookup_table = pd.read_csv(r"../../data/chapter2/wcvp/synonyms.csv", low_memory=False)

# %% [markdown]
# #### ___1. Genus level mycorrhizal state recommendations from `FungalRoot`___

# %%
taxa.F01286.unique().isin(fungalroot_genus_state_recommendations.genus).mean() # that's good
# Out:
# np.float64(0.9654605263157895)

# %%
pd.merge(left=taxa, left_on="F01286", right=fungalroot_genus_state_recommendations, right_on="genus", how="left").drop(["genus"], axis=1)#.isna().mean()
# Out:
#              F01286          F01287          F01289      F01290  \
# 0             Abies            alba        Pinaceae     Pinales
# 1             Abies     nephrolepis        Pinaceae     Pinales
# 2            Acacia  auriculiformis        Fabaceae     Fabales
# 3            Acacia     crassicarpa        Fabaceae     Fabales
# 4            Acacia         mangium        Fabaceae     Fabales
# ...             ...             ...             ...         ...
# 1296  Xanthophyllum           tenue    Polygalaceae     Fabales
# 1297        Zabelia         biflora  Caprifoliaceae  Dipsacales
# 1298          Zamia        lucayana       Zamiaceae   Cycadales
# 1299          Zizia           aurea        Apiaceae     Apiales
# 1300          Zygia      inaequalis        Fabaceae     Fabales
#
#                   binominal      state
# 0                Abies alba        EcM
# 1         Abies nephrolepis        EcM
# 2     Acacia auriculiformis     EcM-AM
# 3        Acacia crassicarpa     EcM-AM
# 4            Acacia mangium     EcM-AM
# ...                     ...        ...
# 1296    Xanthophyllum tenue         AM
# 1297        Zabelia biflora         AM
# 1298         Zamia lucayana         AM
# 1299            Zizia aurea         AM
# 1300       Zygia inaequalis  uncertain
#
# [1301 rows x 6 columns]

# %%
pd.merge(left=taxa, left_on="F01286", right=fungalroot_genus_state_recommendations, right_on="genus", how="left").drop(["genus"], axis=1)#.isna().mean()
# Out:
#              F01286          F01287          F01289      F01290  \
# 0             Abies            alba        Pinaceae     Pinales
# 1             Abies     nephrolepis        Pinaceae     Pinales
# 2            Acacia  auriculiformis        Fabaceae     Fabales
# 3            Acacia     crassicarpa        Fabaceae     Fabales
# 4            Acacia         mangium        Fabaceae     Fabales
# ...             ...             ...             ...         ...
# 1296  Xanthophyllum           tenue    Polygalaceae     Fabales
# 1297        Zabelia         biflora  Caprifoliaceae  Dipsacales
# 1298          Zamia        lucayana       Zamiaceae   Cycadales
# 1299          Zizia           aurea        Apiaceae     Apiales
# 1300          Zygia      inaequalis        Fabaceae     Fabales
#
#                   binominal      state
# 0                Abies alba        EcM
# 1         Abies nephrolepis        EcM
# 2     Acacia auriculiformis     EcM-AM
# 3        Acacia crassicarpa     EcM-AM
# 4            Acacia mangium     EcM-AM
# ...                     ...        ...
# 1296    Xanthophyllum tenue         AM
# 1297        Zabelia biflora         AM
# 1298         Zamia lucayana         AM
# 1299            Zizia aurea         AM
# 1300       Zygia inaequalis  uncertain
#
# [1301 rows x 6 columns]

# %%
subset_genus_level = pd.merge(left=taxa, left_on="F01286", right=fungalroot_genus_state_recommendations, right_on="genus", how="left").drop(["genus"], axis=1).\
            loc[:, ["binominal"] + PLANT_TAXONOMY_ACCEPTED_COLUMNS + ["state"]]
subset_genus_level
# Out:
#                   binominal         F01286          F01287          F01289  \
# 0                Abies alba          Abies            alba        Pinaceae
# 1         Abies nephrolepis          Abies     nephrolepis        Pinaceae
# 2     Acacia auriculiformis         Acacia  auriculiformis        Fabaceae
# 3        Acacia crassicarpa         Acacia     crassicarpa        Fabaceae
# 4            Acacia mangium         Acacia         mangium        Fabaceae
# ...                     ...            ...             ...             ...
# 1296    Xanthophyllum tenue  Xanthophyllum           tenue    Polygalaceae
# 1297        Zabelia biflora        Zabelia         biflora  Caprifoliaceae
# 1298         Zamia lucayana          Zamia        lucayana       Zamiaceae
# 1299            Zizia aurea          Zizia           aurea        Apiaceae
# 1300       Zygia inaequalis          Zygia      inaequalis        Fabaceae
#
#           F01290      state
# 0        Pinales        EcM
# 1        Pinales        EcM
# 2        Fabales     EcM-AM
# 3        Fabales     EcM-AM
# 4        Fabales     EcM-AM
# ...          ...        ...
# 1296     Fabales         AM
# 1297  Dipsacales         AM
# 1298   Cycadales         AM
# 1299     Apiales         AM
# 1300     Fabales  uncertain
#
# [1301 rows x 6 columns]

# %%
subset_genus_level.state.value_counts(dropna=False)
# Out:
# state
# AM                                             1057
# EcM                                             118
# NM-AM                                            40
# NaN                                              34
# EcM-AM                                           20
# NM                                               16
# ErM                                               9
# uncertain                                         5
# species-specific: AM or rarely EcM-AM or AM       2
# Name: count, dtype: int64

# %%
wcvp_synonyms_lookup_table.head()
# Out:
#                       name                                     synonym
# 0       Caladenia minorata                         Caladenia glossodia
# 1      Chiloglottis gunnii                            Caladenia gunnii
# 2     Volkameria acerbiana                     Clerodendrum acerbianum
# 3  Veronica sibthorpioides              Cochlidiosperma sibthorpioides
# 4  Veronica sibthorpioides  Veronica hederifolia subsp. sibthorpioides

# %%
# the rationale for leveraging synonyms is when Metrosideros umbellata and Agalmanthus umbellata are homotypic synonyms and the genus
# Metrosideros is unavailable in the lookup table, we could look up genus Agalmanthus.

# %%
# check the synonyms lookup table so we could fill some more species

genus_level_state_missing_species = subset_genus_level.query(r"state.isna()").binominal.values
# our binominal names in FRED 4.0 subset could be in the name column or synonym column of the lookup table!!!!

wcvp_synonyms_lookup_table.query(r"name.isin(@genus_level_state_missing_species)") # that's interesting!!
# Out:
#                                 name                     synonym
# 479        Heptapleurum heptaphyllum          Aralia heptaphylla
# 2573        Sciodaphyllum acuminatum          Brassaia acuminata
# 10338      Heptapleurum heptaphyllum  Sciodaphyllum heptaphyllum
# 11908             Wurfbainia villosa         Cardamomum villosum
# 12700       Sciodaphyllum acuminatum        Schefflera acuminata
# 12738      Heptapleurum heptaphyllum      Schefflera heptaphylla
# 14896             Wurfbainia villosa           Elettaria villosa
# 15808             Wurfbainia villosa           Zingiber villosum
# 20951       Leptobalanus longistylus          Licania longistyla
# 20970         Leptobalanus octandrus            Licania octandra
# 21060        Pectinopitys ferruginea           Nageia ferruginea
# 21478        Pectinopitys ferruginea      Prumnopitys ferruginea
# 21923      Callitropsis nootkatensis  Xanthocyparis nootkatensis
# 21924        Pectinopitys ferruginea    Stachycarpus ferrugineus
# 22182        Pectinopitys ferruginea      Stachypitys ferruginea
# 22359      Callitropsis nootkatensis  Chamaecyparis nootkatensis
# 41253            Prasoxylon excelsum        Macrochiton excelsum
# 48671     Alseodaphnopsis andersonii      Alseodaphne andersonii
# 56892           Imbralyx leptobotrys          Fordia leptobotrys
# 57603            Prasoxylon excelsum          Hartighsea excelsa
# 69885          Andesanthus lepidotus         Tibouchina lepidota
# 73195          Andesanthus lepidotus           Pleroma lepidotum
# 73331          Andesanthus lepidotus       Chaetogastra lepidota
# 104454    Alseodaphnopsis andersonii      Cryptocarya andersonii
# 106695      Didymocheton spectabilis        Dysoxylum spectabile
# 107156           Prasoxylon excelsum          Dysoxylum excelsum
# 107575           Richetia multiflora            Doona multiflora
# 108783           Richetia multiflora    Balanocarpus multiflorus
# 108784           Richetia multiflora           Shorea multiflora
# 110558         Andesanthus lepidotus             Rhexia lepidota
# 112889         Rubroshorea acuminata            Shorea acuminata
# 116882         Rubroshorea leprosula            Shorea leprosula
# 119172          Pterophylla racemosa         Weinmannia racemosa
# 119490          Pterophylla racemosa         Windmannia racemosa
# 121223         Hymenopus reticulatus          Licania reticulata
# 121518       Hymenopus adolphoduckei       Licania adolphoduckei
# 121519          Hymenopus sothersiae          Licania sothersiae
# 121524            Hymenopus caudatus             Licania caudata
# 122718          Imbralyx leptobotrys       Millettia leptobotrys
# 123017      Didymocheton spectabilis       Trichilia spectabilis
# 123308           Prasoxylon excelsum           Trichilia excelsa
# 130659          Leptobalanus sprucei            Moquilea sprucei
# 130660      Leptobalanus longistylus         Moquilea longistyla
# 133122        Hymenopus macrophyllus         Licania macrophylla
# 133127            Leptobalanus latus                Licania lata
# 133239          Leptobalanus sprucei             Licania sprucei
# 134280           Hesperostipa comata                Stipa comata
# 135779     Callitropsis nootkatensis      Cupressus nootkatensis
# 136332       Pectinopitys ferruginea      Podocarpus ferrugineus
# 137773          Pterophylla racemosa       Leiospermum racemosum
# 138030        Leptobalanus octandrus           Hirtella octandra
# 143866       Leptobalanus granvillei          Licania granvillei
# 154896  Heptapleurum minutistellatum   Schefflera minutistellata
# 157351     Heptapleurum heptaphyllum           Vitis heptaphylla
# 177471      Pseudodictamnus hirsutus          Marrubium hirsutum
# 181505      Sciodaphyllum acuminatum    Actinophyllum acuminatum
# 226901             Tetrapilus roseus                  Olea rosea
# 234229          Hesperostipa spartea               Stipa spartea
# 244381            Wurfbainia villosa             Amomum villosum
# 244811     Heptapleurum heptaphyllum      Ampelopsis heptaphylla

# %%
# binominal names in the synonym column
wcvp_synonyms_lookup_table.query(r"synonym.isin(@genus_level_state_missing_species)")
# Out:
#                            name                       synonym
# 30916       Lycopodium volubile      Pseudodiphasium volubile
# 50455         Blechnum discolor              Lomaria discolor
# 65897  Blechnum novae-zelandiae  Parablechnum novae-zelandiae
# 80586         Blechnum procerum         Parablechnum procerum

# %%
wcvp_synonyms_lookup_table.query(r"synonym.isin(@genus_level_state_missing_species)").rename({"synonym": "name", "name": "synonym"}, axis=1)
# Out:
#                         synonym                          name
# 30916       Lycopodium volubile      Pseudodiphasium volubile
# 50455         Blechnum discolor              Lomaria discolor
# 65897  Blechnum novae-zelandiae  Parablechnum novae-zelandiae
# 80586         Blechnum procerum         Parablechnum procerum

# %%
# with dicts; cannot have multiple identical keys

alternative_genus_names = np.unique([(name.split(' ')[0], syn.split(' ')[0]) for _, (name, syn) in wcvp_synonyms_lookup_table.query(r"name.isin(@genus_level_state_missing_species)").iterrows()], axis=0)

# the first genus name is what FRED 4.0 has and the second genus name is an accepted alternative
alternative_genus_names = np.concat([alternative_genus_names,
                                     # putting syn as the first element of the tuple here because that's what present in FRED 4.0
                                     np.unique([(syn.split(' ')[0], name.split(' ')[0]) for _, (name, syn) in wcvp_synonyms_lookup_table.query(r"synonym.isin(@genus_level_state_missing_species)").iterrows()], axis=0)])

alternative_genus_names
# Out:
# array([['Alseodaphnopsis', 'Alseodaphne'],
#        ['Alseodaphnopsis', 'Cryptocarya'],
#        ['Andesanthus', 'Chaetogastra'],
#        ['Andesanthus', 'Pleroma'],
#        ['Andesanthus', 'Rhexia'],
#        ['Andesanthus', 'Tibouchina'],
#        ['Callitropsis', 'Chamaecyparis'],
#        ['Callitropsis', 'Cupressus'],
#        ['Callitropsis', 'Xanthocyparis'],
#        ['Didymocheton', 'Dysoxylum'],
#        ['Didymocheton', 'Trichilia'],
#        ['Heptapleurum', 'Ampelopsis'],
#        ['Heptapleurum', 'Aralia'],
#        ['Heptapleurum', 'Schefflera'],
#        ['Heptapleurum', 'Sciodaphyllum'],
#        ['Heptapleurum', 'Vitis'],
#        ['Hesperostipa', 'Stipa'],
#        ['Hymenopus', 'Licania'],
#        ['Imbralyx', 'Fordia'],
#        ['Imbralyx', 'Millettia'],
#        ['Leptobalanus', 'Hirtella'],
#        ['Leptobalanus', 'Licania'],
#        ['Leptobalanus', 'Moquilea'],
#        ['Pectinopitys', 'Nageia'],
#        ['Pectinopitys', 'Podocarpus'],
#        ['Pectinopitys', 'Prumnopitys'],
#        ['Pectinopitys', 'Stachycarpus'],
#        ['Pectinopitys', 'Stachypitys'],
#        ['Prasoxylon', 'Dysoxylum'],
#        ['Prasoxylon', 'Hartighsea'],
#        ['Prasoxylon', 'Macrochiton'],
#        ['Prasoxylon', 'Trichilia'],
#        ['Pseudodictamnus', 'Marrubium'],
#        ['Pterophylla', 'Leiospermum'],
#        ['Pterophylla', 'Weinmannia'],
#        ['Pterophylla', 'Windmannia'],
#        ['Richetia', 'Balanocarpus'],
#        ['Richetia', 'Doona'],
#        ['Richetia', 'Shorea'],
#        ['Rubroshorea', 'Shorea'],
#        ['Sciodaphyllum', 'Actinophyllum'],
#        ['Sciodaphyllum', 'Brassaia'],
#        ['Sciodaphyllum', 'Schefflera'],
#        ['Tetrapilus', 'Olea'],
#        ['Wurfbainia', 'Amomum'],
#        ['Wurfbainia', 'Cardamomum'],
#        ['Wurfbainia', 'Elettaria'],
#        ['Wurfbainia', 'Zingiber'],
#        ['Lomaria', 'Blechnum'],
#        ['Parablechnum', 'Blechnum'],
#        ['Pseudodiphasium', 'Lycopodium']], dtype='<U15')

# %%
subset_genus_level.query("state.isna()").F01286.unique() # need states for these 25 genera
# Out:
# <StringArray>
# ['Alseodaphnopsis',     'Andesanthus',    'Callitropsis',    'Didymocheton',
#     'Heptapleurum',    'Hesperostipa',       'Hymenopus',        'Imbralyx',
#     'Leptobalanus',         'Lomaria',    'Parablechnum',    'Pectinopitys',
#       'Prasoxylon', 'Pseudodictamnus', 'Pseudodiphasium',     'Pterophylla',
#         'Richetia',     'Rubroshorea',   'Sciodaphyllum',      'Tetrapilus',
#       'Wurfbainia']
# Length: 21, dtype: str

# %%
# fungalroot_genus_state_recommendations.loc[fungalroot_genus_state_recommendations.genus.isin(alternative_genus_names_all[:, 1]), :]

# now, we match the alternative genus names with the FungalRoot genus level recommendations dataset, drop alternative genera that do not have data in it
# and remove the duplicates

fungalroot_synonym_salvaged_genus_level = pd.merge(left=pd.DataFrame(alternative_genus_names, columns=("genus", "synonym")), left_on="synonym", right=fungalroot_genus_state_recommendations,
         right_on="genus", how="left", suffixes=('', "_FungalRoot")).dropna().drop_duplicates(subset=("genus", "state")).drop("genus_FungalRoot", axis=1)

fungalroot_synonym_salvaged_genus_level
# Out:
#               genus        synonym  state
# 0   Alseodaphnopsis    Alseodaphne     AM
# 3       Andesanthus        Pleroma     AM
# 6      Callitropsis  Chamaecyparis     AM
# 9      Didymocheton      Dysoxylum     AM
# 11     Heptapleurum     Ampelopsis     AM
# 16     Hesperostipa          Stipa     AM
# 17        Hymenopus        Licania     AM
# 18         Imbralyx         Fordia     AM
# 20     Leptobalanus       Hirtella     AM
# 23     Pectinopitys         Nageia     AM
# 28       Prasoxylon      Dysoxylum     AM
# 32  Pseudodictamnus      Marrubium     AM
# 33      Pterophylla    Leiospermum     AM
# 38         Richetia         Shorea    EcM
# 39      Rubroshorea         Shorea    EcM
# 42    Sciodaphyllum     Schefflera     AM
# 43       Tetrapilus           Olea     AM
# 44       Wurfbainia         Amomum     AM
# 48          Lomaria       Blechnum     AM
# 49     Parablechnum       Blechnum     AM
# 50  Pseudodiphasium     Lycopodium  NM-AM

# %%
# need to update the genus level FRED 4 subset based on this
for row in fungalroot_synonym_salvaged_genus_level.itertuples():
   subset_genus_level.loc[subset_genus_level.query(r"F01286==@row.genus").index, "state"] = row.state

# %%
subset_genus_level.state.isna().sum() # that's awesome :)
# Out:
# np.int64(0)

# %%
subset_genus_level.state.value_counts()
# Out:
# state
# AM                                             1087
# EcM                                             121
# NM-AM                                            41
# EcM-AM                                           20
# NM                                               16
# ErM                                               9
# uncertain                                         5
# species-specific: AM or rarely EcM-AM or AM       2
# Name: count, dtype: int64

# %%
subset_genus_level
# Out:
#                   binominal         F01286          F01287          F01289  \
# 0                Abies alba          Abies            alba        Pinaceae
# 1         Abies nephrolepis          Abies     nephrolepis        Pinaceae
# 2     Acacia auriculiformis         Acacia  auriculiformis        Fabaceae
# 3        Acacia crassicarpa         Acacia     crassicarpa        Fabaceae
# 4            Acacia mangium         Acacia         mangium        Fabaceae
# ...                     ...            ...             ...             ...
# 1296    Xanthophyllum tenue  Xanthophyllum           tenue    Polygalaceae
# 1297        Zabelia biflora        Zabelia         biflora  Caprifoliaceae
# 1298         Zamia lucayana          Zamia        lucayana       Zamiaceae
# 1299            Zizia aurea          Zizia           aurea        Apiaceae
# 1300       Zygia inaequalis          Zygia      inaequalis        Fabaceae
#
#           F01290      state
# 0        Pinales        EcM
# 1        Pinales        EcM
# 2        Fabales     EcM-AM
# 3        Fabales     EcM-AM
# 4        Fabales     EcM-AM
# ...          ...        ...
# 1296     Fabales         AM
# 1297  Dipsacales         AM
# 1298   Cycadales         AM
# 1299     Apiales         AM
# 1300     Fabales  uncertain
#
# [1301 rows x 6 columns]

# %%
# now, serialize that to a .csv file

subset_genus_level.loc[:, "state"] = subset_genus_level.state.replace({"EcM-AM": "EcMAM", "NM-AM": "NMAM"})
subset_genus_level.to_csv(r"../../data/chapter2/FRED/subsets/FRED4_FungalRoot_genus_level_recommendations.csv", index=False)

# %% [markdown]
# #### ___2. Species specific mycorrhizal states___

# %%
# create a synonyms lookup table for all the 1301 species we have in the FRED 4.0 subset

wcvp_synonyms_lookup_table.query(r"name.isin(@taxa.binominal)")
# Out:
#                              name                                 synonym
# 116        Metrosideros umbellata                   Agalmanthus umbellata
# 264                 Inga ruiziana                      Feuilleea ruiziana
# 479     Heptapleurum heptaphyllum                      Aralia heptaphylla
# 603                Galium aparine                   Asterophyllum aparine
# 693      Syzygium acuminatissimum                   Acmena acuminatissima
# ...                           ...                                     ...
# 280952    Pappobolus microphyllus                 Helianthus microphyllus
# 280966         Helianthus praecox       Helianthus debilis subsp. praecox
# 280967         Helianthus praecox  Helianthus cucumerifolius var. praecox
# 280969          Helianthus radula     Helianthus atrorubens subsp. radula
# 280970          Helianthus radula                        Rudbeckia radula
#
# [1746 rows x 2 columns]

# %%
wcvp_synonyms_lookup_table.query(r"synonym.isin(@taxa.binominal)")
# Out:
#                                            name                       synonym
# 2485                       Ragala sanguinolenta  Chrysophyllum sanguinolentum
# 30916                       Lycopodium volubile      Pseudodiphasium volubile
# 50455                         Blechnum discolor              Lomaria discolor
# 50654                    Onoclea struthiopteris     Matteuccia struthiopteris
# 53136                      Camphora officinarum           Cinnamomum camphora
# 53148                        Camphora micrantha         Cinnamomum micranthum
# 53152                    Camphora parthenoxylon      Cinnamomum parthenoxylon
# 65897                  Blechnum novae-zelandiae  Parablechnum novae-zelandiae
# 75193                     Camphora glandulifera      Cinnamomum glanduliferum
# 80586                         Blechnum procerum         Parablechnum procerum
# 83514                  Phyllanthus lanceolarius       Glochidion lanceolarium
# 86559                        Blechnum orientale        Blechnopsis orientalis
# 100181                        Alsophila smithii               Cyathea smithii
# 101568  Meriania macrophylla subsp. franciscana          Meriania franciscana
# 109422                     Andea infrafoveolata         Ocotea infrafoveolata
# 110768                   Notelaea neolanceolata           Nestegis lanceolata
# 111211                           Anacis palmata             Coreopsis palmata
# 121879                     Paratrophis insignis                Morus insignis
# 123271                      Brosimum amazonicum      Trymatococcus amazonicus
# 162790                   Phyllanthus eriocarpus         Glochidion eriocarpum
# 181980                      Heterotheca villosa            Chrysopsis villosa
# 278815               Symphyotrichum lanceolatum             Aster lanceolatus

# %%
# the column name is the binominal name FRED 4.0 uses

taxa_synonyms = pd.concat([wcvp_synonyms_lookup_table.query(r"name.isin(@taxa.binominal)"),
            wcvp_synonyms_lookup_table.query(r"synonym.isin(@taxa.binominal)").rename({"name": "synonym", "synonym": "name"}, axis=1)]).reset_index(drop=True)
taxa_synonyms
# Out:
#                            name                     synonym
# 0        Metrosideros umbellata       Agalmanthus umbellata
# 1                 Inga ruiziana          Feuilleea ruiziana
# 2     Heptapleurum heptaphyllum          Aralia heptaphylla
# 3                Galium aparine       Asterophyllum aparine
# 4      Syzygium acuminatissimum       Acmena acuminatissima
# ...                         ...                         ...
# 1763             Morus insignis        Paratrophis insignis
# 1764   Trymatococcus amazonicus         Brosimum amazonicum
# 1765      Glochidion eriocarpum      Phyllanthus eriocarpus
# 1766         Chrysopsis villosa         Heterotheca villosa
# 1767          Aster lanceolatus  Symphyotrichum lanceolatum
#
# [1768 rows x 2 columns]

# %%
# the problem with this is that FRED 4.0 only uses simple binominal names, so having varieties and subspecies in synonyms will likely reduce 
# our chances at finding synonym matches

taxa_synonyms.loc[taxa_synonyms.synonym.str.split().apply(len) > 2, :]
# Out:
#                           name                                     synonym
# 9                 Viola adunca                    Viola canina var. adunca
# 11     Castanopsis echinocarpa    Castanopsis tribuloides var. echinocarpa
# 35               Malus baccata                    Malus microcarpa baccata
# 40              Inga marginata               Inga fagifolia var. marginata
# 57         Populus tremuloides          Populus tremula subsp. tremuloides
# ...                        ...                                         ...
# 1739  Helianthus heterophyllus  Helianthus atrorubens subsp. heterophyllus
# 1742        Helianthus praecox           Helianthus debilis subsp. praecox
# 1743        Helianthus praecox      Helianthus cucumerifolius var. praecox
# 1744         Helianthus radula         Helianthus atrorubens subsp. radula
# 1759      Meriania franciscana     Meriania macrophylla subsp. franciscana
#
# [303 rows x 2 columns]

# %%
# consider the synonyms Meriania franciscana and Meriania macrophylla subsp. franciscana
# here we transform Meriania macrophylla subsp. franciscana into just Meriania macrophylla so we get to find species level mycorrhizal state matches

#---------------------------------------------------------------------------------------------------------------------
# THIS IS DONE ASSUMING THERE WILL NOT BE ANY VARIETY OR SUBSPECIES LEVEL DIFFERENCES IN MYCORRHIZAL STATES
# I.E. WE ASSUME IF Helianthus atrorubens subsp. radula IS NM, ALL Helianthus atrorubens ARE NM!!!!
#---------------------------------------------------------------------------------------------------------------------

# gs here stands for genus species
taxa_synonyms.loc[:, "synonym_gs"] = taxa_synonyms.synonym.str.split().apply(lambda _list: _list[0] + ' ' + _list[1])
taxa_synonyms
# Out:
#                            name                     synonym  \
# 0        Metrosideros umbellata       Agalmanthus umbellata
# 1                 Inga ruiziana          Feuilleea ruiziana
# 2     Heptapleurum heptaphyllum          Aralia heptaphylla
# 3                Galium aparine       Asterophyllum aparine
# 4      Syzygium acuminatissimum       Acmena acuminatissima
# ...                         ...                         ...
# 1763             Morus insignis        Paratrophis insignis
# 1764   Trymatococcus amazonicus         Brosimum amazonicum
# 1765      Glochidion eriocarpum      Phyllanthus eriocarpus
# 1766         Chrysopsis villosa         Heterotheca villosa
# 1767          Aster lanceolatus  Symphyotrichum lanceolatum
#
#                       synonym_gs
# 0          Agalmanthus umbellata
# 1             Feuilleea ruiziana
# 2             Aralia heptaphylla
# 3          Asterophyllum aparine
# 4          Acmena acuminatissima
# ...                          ...
# 1763        Paratrophis insignis
# 1764         Brosimum amazonicum
# 1765      Phyllanthus eriocarpus
# 1766         Heterotheca villosa
# 1767  Symphyotrichum lanceolatum
#
# [1768 rows x 3 columns]

# %%
taxa_synonyms.loc[taxa_synonyms.synonym.str.split().apply(len) > 2, :]
# Out:
#                           name                                     synonym  \
# 9                 Viola adunca                    Viola canina var. adunca
# 11     Castanopsis echinocarpa    Castanopsis tribuloides var. echinocarpa
# 35               Malus baccata                    Malus microcarpa baccata
# 40              Inga marginata               Inga fagifolia var. marginata
# 57         Populus tremuloides          Populus tremula subsp. tremuloides
# ...                        ...                                         ...
# 1739  Helianthus heterophyllus  Helianthus atrorubens subsp. heterophyllus
# 1742        Helianthus praecox           Helianthus debilis subsp. praecox
# 1743        Helianthus praecox      Helianthus cucumerifolius var. praecox
# 1744         Helianthus radula         Helianthus atrorubens subsp. radula
# 1759      Meriania franciscana     Meriania macrophylla subsp. franciscana
#
#                      synonym_gs
# 9                  Viola canina
# 11      Castanopsis tribuloides
# 35             Malus microcarpa
# 40               Inga fagifolia
# 57              Populus tremula
# ...                         ...
# 1739      Helianthus atrorubens
# 1742         Helianthus debilis
# 1743  Helianthus cucumerifolius
# 1744      Helianthus atrorubens
# 1759       Meriania macrophylla
#
# [303 rows x 3 columns]

# %%
#------------------------------------------
# MYCORRHIZAL STATE HARVEST FROM FRED 4.0
#------------------------------------------

# %%
# consider only the species FRED 4.0 has mycorrhizal state info for doing this here so we can just load in the manually cleaned.csv into the state filling section
# we are using the whole FRED 4.0 dataset to look up mycorrhizal states, not just our subset!!!!

fred_states = fred.loc[:, BINOMINAL_NAME + ["F00645"]].dropna().drop_duplicates().sort_values(by=BINOMINAL_NAME).reset_index(drop=True)
fred_states = fred_states.apply(lambda col: col.str.strip(), axis=1)
fred_states.insert(loc=0, column="binominal", value=fred_states.F01286 + ' ' + fred_states.F01287)

# HERE WE NEED TO REDO THE TAXONOMIC CORRECTIONS WE DID TO BINOMINAL NAMES IN THE 1301 SPECIES SUBSET OF FRED 4.0!!!!

fred_states.loc[fred_states.query(r"F01286=='Helesia' and F01287=='tetraptera'").index, "F01286"] = "Halesia"
fred_states.loc[fred_states.query(r"F01286=='Austroblechnum' and F01287=='lanceolatum'").index, "F01286"] = "Blechnum"
fred_states.loc[fred_states.query(r"F01286=='Austroblechnum' and F01287=='lanceolatum'").index, "F01287"] = "chambersii"
fred_states.loc[fred_states.query(r"F01286=='Cranfillia' and F01287=='fluviatilis'").index, "F01286"] = "Blechnum"
fred_states.loc[fred_states.query(r"F01286=='Cranfillia' and F01287=='fluviatilis'").index, "F01287"] = "fluviatile"
fred_states.loc[fred_states.query(r"F01286=='Veronia' and F01287=='fasciculata'").index, "F01286"] = "Vernonia"

MYCORRHIZAL_STATE_REPLACEMENTS = { # mycorrhizal state encoding replacements
     "EM": "EcM",
     "AM + EM": "EcMAM",
     "AM + NM": "NMAM"
}

# drop the rows if F00645 is just "mycorrhizal" or any other useless stuff
fred_states = fred_states.query(r"not F00645.isin(['mycorrhizal', 'DS', 'EeM'])") 
fred_states.loc[:, "F00645"] = fred_states.F00645.replace(MYCORRHIZAL_STATE_REPLACEMENTS) # this contains many species we do not have continuous traits for.....

# %%
fred_states.query(r"binominal.isin(@taxa.binominal)").drop_duplicates(subset=("binominal", "F00645")) # that's great
# Out:
#                   binominal         F01286          F01287 F00645
# 0                Abies alba          Abies            alba    EcM
# 12        Abies nephrolepis          Abies     nephrolepis    EcM
# 22    Acacia auriculiformis         Acacia  auriculiformis     AM
# 23       Acacia crassicarpa         Acacia     crassicarpa  EcMAM
# 25           Acacia mangium         Acacia         mangium  EcMAM
# ...                     ...            ...             ...    ...
# 3342     Wurfbainia villosa     Wurfbainia         villosa     AM
# 3344    Xanthophyllum tenue  Xanthophyllum           tenue     AM
# 3346        Zabelia biflora        Zabelia         biflora     AM
# 3347         Zamia lucayana          Zamia        lucayana     AM
# 3357       Zygia inaequalis          Zygia      inaequalis     AM
#
# [920 rows x 4 columns]

# %%
# now, leverage synonyms when the original name is unavailable

# taxa.query(r"not binominal.isin(@fred_states.binominal)")
state_needed_species = np.setdiff1d(taxa.binominal, fred_states.binominal)
state_needed_species[:10]
# Out:
# array(['Acer laurinum', 'Actinodaphne henryi', 'Afrocarpus falcatus',
#        'Agastache foeniculum', 'Aglaia exstipulata',
#        'Aglaia odoratissima', 'Agrostis scabra', 'Ailanthus fordii',
#        'Aiouea montana', 'Allium textile'], dtype=object)

# %%
taxa_synonyms.query(r"name.isin(@state_needed_species)")
# Out:
#                        name                     synonym  \
# 9              Viola adunca    Viola canina var. adunca
# 10    Weinmannia fagaroides       Windmannia fagaroides
# 13         Weinmannia ovata            Windmannia ovata
# 14     Weinmannia elliptica        Windmannia elliptica
# 15      Withania frutescens         Physalis frutescens
# ...                     ...                         ...
# 1762      Coreopsis palmata              Anacis palmata
# 1763         Morus insignis        Paratrophis insignis
# 1765  Glochidion eriocarpum      Phyllanthus eriocarpus
# 1766     Chrysopsis villosa         Heterotheca villosa
# 1767      Aster lanceolatus  Symphyotrichum lanceolatum
#
#                       synonym_gs
# 9                   Viola canina
# 10         Windmannia fagaroides
# 13              Windmannia ovata
# 14          Windmannia elliptica
# 15           Physalis frutescens
# ...                          ...
# 1762              Anacis palmata
# 1763        Paratrophis insignis
# 1765      Phyllanthus eriocarpus
# 1766         Heterotheca villosa
# 1767  Symphyotrichum lanceolatum
#
# [545 rows x 3 columns]

# %%
# use the subset of only synonyms of species we don't have states for
pd.merge(left=fred_states, left_on="binominal", right=taxa_synonyms.query(r"name.isin(@state_needed_species)"), right_on="synonym_gs", how="inner")
# Out:
#                   binominal      F01286         F01287 F00645  \
# 0         Antennaria dioica  Antennaria         dioica     AM
# 1        Artemisia vulgaris   Artemisia       vulgaris     AM
# 2        Artemisia vulgaris   Artemisia       vulgaris     AM
# 3              Carex supina       Carex         supina   NMAM
# 4              Carex supina       Carex         supina   NMAM
# 5              Carex supina       Carex         supina     NM
# 6              Carex supina       Carex         supina     NM
# 7           Celtis sinensis      Celtis       sinensis     AM
# 8        Fraxinus americana    Fraxinus      americana     AM
# 9             Linum perenne       Linum        perenne     AM
# 10            Linum perenne       Linum        perenne     AM
# 11         Litsea baviensis      Litsea      baviensis     AM
# 12         Potentilla verna  Potentilla          verna     AM
# 13         Potentilla verna  Potentilla          verna     AM
# 14            Quercus rubra     Quercus          rubra    EcM
# 15            Quercus rubra     Quercus          rubra     NM
# 16     Tragopogon pratensis  Tragopogon      pratensis     AM
# 17  Trifolium angustifolium   Trifolium  angustifolium     AM
# 18  Trifolium angustifolium   Trifolium  angustifolium     AM
# 19             Viola canina       Viola         canina     AM
# 20           Vitis vinifera       Vitis       vinifera     AM
#
#                      name                                   synonym  \
# 0   Antennaria parvifolia         Antennaria dioica var. parvifolia
# 1   Artemisia ludoviciana       Artemisia vulgaris var. ludoviciana
# 2   Artemisia ludoviciana     Artemisia vulgaris subsp. ludoviciana
# 3       Carex korshinskyi             Carex supina var. korshinskyi
# 4       Carex korshinskyi           Carex supina subsp. korshinskyi
# 5       Carex korshinskyi             Carex supina var. korshinskyi
# 6       Carex korshinskyi           Carex supina subsp. korshinskyi
# 7        Celtis tetrandra            Celtis sinensis var. tetrandra
# 8          Fraxinus nigra             Fraxinus americana var. nigra
# 9           Linum lewisii              Linum perenne subsp. lewisii
# 10          Linum lewisii                Linum perenne var. lewisii
# 11        Litsea szemaois            Litsea baviensis var. szemaois
# 12     Potentilla pusilla             Potentilla verna var. pusilla
# 13     Potentilla pusilla               Potentilla verna f. pusilla
# 14      Quercus palustris              Quercus rubra var. palustris
# 15      Quercus palustris              Quercus rubra var. palustris
# 16      Tragopogon dubius        Tragopogon pratensis subsp. dubius
# 17    Trifolium purpureum  Trifolium angustifolium subsp. purpureum
# 18    Trifolium purpureum  Trifolium angustifolium subsp. purpureum
# 19           Viola adunca                  Viola canina var. adunca
# 20          Vitis vulpina               Vitis vinifera var. vulpina
#
#                  synonym_gs
# 0         Antennaria dioica
# 1        Artemisia vulgaris
# 2        Artemisia vulgaris
# 3              Carex supina
# 4              Carex supina
# 5              Carex supina
# 6              Carex supina
# 7           Celtis sinensis
# 8        Fraxinus americana
# 9             Linum perenne
# 10            Linum perenne
# 11         Litsea baviensis
# 12         Potentilla verna
# 13         Potentilla verna
# 14            Quercus rubra
# 15            Quercus rubra
# 16     Tragopogon pratensis
# 17  Trifolium angustifolium
# 18  Trifolium angustifolium
# 19             Viola canina
# 20           Vitis vinifera

# %%
# here the name colum contains the binomianl names we have continuous traits for in the FRED 4.0 subset!!!

pd.merge(left=fred_states, left_on="binominal", right=taxa_synonyms.query(r"name.isin(@state_needed_species)"), right_on="synonym_gs", how="inner").drop_duplicates(subset=("name", "F00645"))
# Out:
#                   binominal      F01286         F01287 F00645  \
# 0         Antennaria dioica  Antennaria         dioica     AM
# 1        Artemisia vulgaris   Artemisia       vulgaris     AM
# 3              Carex supina       Carex         supina   NMAM
# 5              Carex supina       Carex         supina     NM
# 7           Celtis sinensis      Celtis       sinensis     AM
# 8        Fraxinus americana    Fraxinus      americana     AM
# 9             Linum perenne       Linum        perenne     AM
# 11         Litsea baviensis      Litsea      baviensis     AM
# 12         Potentilla verna  Potentilla          verna     AM
# 14            Quercus rubra     Quercus          rubra    EcM
# 15            Quercus rubra     Quercus          rubra     NM
# 16     Tragopogon pratensis  Tragopogon      pratensis     AM
# 17  Trifolium angustifolium   Trifolium  angustifolium     AM
# 19             Viola canina       Viola         canina     AM
# 20           Vitis vinifera       Vitis       vinifera     AM
#
#                      name                                   synonym  \
# 0   Antennaria parvifolia         Antennaria dioica var. parvifolia
# 1   Artemisia ludoviciana       Artemisia vulgaris var. ludoviciana
# 3       Carex korshinskyi             Carex supina var. korshinskyi
# 5       Carex korshinskyi             Carex supina var. korshinskyi
# 7        Celtis tetrandra            Celtis sinensis var. tetrandra
# 8          Fraxinus nigra             Fraxinus americana var. nigra
# 9           Linum lewisii              Linum perenne subsp. lewisii
# 11        Litsea szemaois            Litsea baviensis var. szemaois
# 12     Potentilla pusilla             Potentilla verna var. pusilla
# 14      Quercus palustris              Quercus rubra var. palustris
# 15      Quercus palustris              Quercus rubra var. palustris
# 16      Tragopogon dubius        Tragopogon pratensis subsp. dubius
# 17    Trifolium purpureum  Trifolium angustifolium subsp. purpureum
# 19           Viola adunca                  Viola canina var. adunca
# 20          Vitis vulpina               Vitis vinifera var. vulpina
#
#                  synonym_gs
# 0         Antennaria dioica
# 1        Artemisia vulgaris
# 3              Carex supina
# 5              Carex supina
# 7           Celtis sinensis
# 8        Fraxinus americana
# 9             Linum perenne
# 11         Litsea baviensis
# 12         Potentilla verna
# 14            Quercus rubra
# 15            Quercus rubra
# 16     Tragopogon pratensis
# 17  Trifolium angustifolium
# 19             Viola canina
# 20           Vitis vinifera

# %%
# now combine this with the species FRED already had state info for (for original names)

fred_states_final = pd.concat([fred_states.query(r"binominal.isin(@taxa.binominal)").loc[:, ("binominal", "F00645")].drop_duplicates(), # states fetched using the original names
            pd.merge(left=fred_states, left_on="binominal", right=taxa_synonyms.query(r"name.isin(@state_needed_species)"), right_on="synonym_gs", how="inner").loc[:, ["name", "F00645"]].drop_duplicates().rename({"name": "binominal"}, axis=1)] # states fetched using synonyms
).drop_duplicates().reset_index(drop=True)

fred_states_final
# Out:
#                  binominal F00645
# 0               Abies alba    EcM
# 1        Abies nephrolepis    EcM
# 2    Acacia auriculiformis     AM
# 3       Acacia crassicarpa  EcMAM
# 4           Acacia mangium  EcMAM
# ..                     ...    ...
# 930      Quercus palustris     NM
# 931      Tragopogon dubius     AM
# 932    Trifolium purpureum     AM
# 933           Viola adunca     AM
# 934          Vitis vulpina     AM
#
# [935 rows x 2 columns]

# %%
fred_states_final.to_csv(r"../../data/chapter2/FRED/subsets/states_FRED4.csv", index=False) # this will need a little manual cleanup

# %%
#----------------------
# reusing the serialized states_FRED4.csv dataset instead of redoing all the wranging every time

state_needed_species = np.setdiff1d(taxa.binominal, pd.read_csv(r"../../data/chapter2/FRED/subsets/states_FRED4.csv").binominal.unique())
state_needed_species.size
# Out:
# 430

# %%
#------------------------------------------------------
# MYCORRHIZAL STATE HARVEST FROM Maherali et al. 2016
#-----------------------------------------------------

# %%
maherali.query(r"binominal.isin(@state_needed_species)")
# Out:
#                      binominal state
# 102            Agrostis scabra    AM
# 164    Ambrosia artemisiifolia    AM
# 187        Andropogon gerardii    AM
# 209       Anthyllis cytisoides    AM
# 230              Arbutus unedo    EM
# 269        Asclepias incarnata    AM
# 270          Asclepias syriaca    AM
# 271         Asclepias tuberosa    AM
# 326              Baptisia alba    AM
# 350            Berteroa incana    NM
# 388     Bouteloua curtipendula    AM
# 389         Bouteloua gracilis    AM
# 551            Carex filifolia    NM
# 629         Castanopsis indica  AMNM
# 804        Coriaria nepalensis    AM
# 843             Crepis foetida    AM
# 857           Croton kongensis    AM
# 904             Dalea purpurea    AM
# 970             Draba nemorosa    NM
# 1002        Ekebergia capensis    AM
# 1004       Elaeagnus commutata    AM
# 1177          Ficus citrifolia    AM
# 1213         Fumana thymifolia    AM
# 1239     Garcinia xanthochymus    AM
# 1269    Geranium rotundifolium    AM
# 1313     Gutierrezia sarothrae    AM
# 1331   Helianthemum almeriense    EM
# 1333         Helianthus annuus    AM
# 1334    Helianthus maximiliani    AM
# 1337      Helichrysum italicum    AM
# 1338      Helichrysum stoechas    AM
# 1343    Heliocarpus americanus    AM
# 1427         Ilex verticillata    AM
# 1443              Inga nobilis    AM
# 1466           Iris versicolor    AM
# 1534       Koeleria vallesiana    AM
# 1598      Lepidium densiflorum    NM
# 1613        Lespedeza capitata    AM
# 1627            Liatris aspera    AM
# 1891         Oenothera biennis    AM
# 1895             Olea europaea    AM
# 1941         Panicum capillare  AMNM
# 2017         Phoebe lanceolata    AM
# 2163      Podophyllum peltatum    AM
# 2181           Pometia pinnata  AMNM
# 2189       Populus trichocarpa    EM
# 2276  Pycnanthemum virginianum    AM
# 2295             Quercus suber    EM
# 2497   Schizachyrium scoparium    AM
# 2606        Solidago nemoralis    AM
# 2607           Solidago rigida    AM
# 2620        Sorghastrum nutans    AM
# 2654    Sporobolus heterolepis    AM
# 2704  Symphyotrichum ericoides    AM
# 2757           Theobroma cacao    AM
# 2769         Thymus mastichina    AM
# 2855          Ulex parviflorus    AM
# 2883           Verbena hastata    AM
# 2886      Vernonia fasciculata    AM
# 2921             Vicia villosa    AM

# %%
# for the state needed species not found in Maherali 2016, try leveraging their synonyms

taxa_synonyms.loc[taxa_synonyms.name.isin(np.setdiff1d(state_needed_species, maherali.query(r"binominal.isin(@state_needed_species)").binominal)), :]
# Out:
#                        name                     synonym  \
# 10    Weinmannia fagaroides       Windmannia fagaroides
# 13         Weinmannia ovata            Windmannia ovata
# 14     Weinmannia elliptica        Windmannia elliptica
# 15      Withania frutescens         Physalis frutescens
# 20          Hedeoma hispida              Cunila hispida
# ...                     ...                         ...
# 1762      Coreopsis palmata              Anacis palmata
# 1763         Morus insignis        Paratrophis insignis
# 1765  Glochidion eriocarpum      Phyllanthus eriocarpus
# 1766     Chrysopsis villosa         Heterotheca villosa
# 1767      Aster lanceolatus  Symphyotrichum lanceolatum
#
#                       synonym_gs
# 10         Windmannia fagaroides
# 13              Windmannia ovata
# 14          Windmannia elliptica
# 15           Physalis frutescens
# 20                Cunila hispida
# ...                          ...
# 1762              Anacis palmata
# 1763        Paratrophis insignis
# 1765      Phyllanthus eriocarpus
# 1766         Heterotheca villosa
# 1767  Symphyotrichum lanceolatum
#
# [418 rows x 3 columns]

# %%
pd.merge(left=maherali, left_on="binominal", right=taxa_synonyms.loc[taxa_synonyms.name.isin(np.setdiff1d(state_needed_species, maherali.query(r"binominal.isin(@state_needed_species)").binominal)), :],
         right_on="synonym_gs", how="inner")
# Out:
#               binominal state                    name  \
# 0  Anthyllis cytisoides    AM    Anthyllis terniflora
# 1      Armeria maritima  AMNM        Armeria velutina
# 2        Arnica montana    AM          Arnica fulgens
# 3     Helianthus annuus    AM       Helianthus niveus
# 4     Helianthus annuus    AM  Helianthus argophyllus
# 5     Helianthus annuus    AM   Helianthus petiolaris
# 6     Helianthus annuus    AM      Helianthus debilis
# 7      Shorea leprosula    EM   Rubroshorea leprosula
# 8       Thymus vulgaris    AM         Thymus hyemalis
#
#                                   synonym            synonym_gs
# 0  Anthyllis cytisoides subsp. terniflora  Anthyllis cytisoides
# 1        Armeria maritima subsp. velutina      Armeria maritima
# 2             Arnica montana var. fulgens        Arnica montana
# 3           Helianthus annuus var. niveus     Helianthus annuus
# 4      Helianthus annuus var. argophyllus     Helianthus annuus
# 5     Helianthus annuus subsp. petiolaris     Helianthus annuus
# 6          Helianthus annuus var. debilis     Helianthus annuus
# 7                        Shorea leprosula      Shorea leprosula
# 8           Thymus vulgaris var. hyemalis       Thymus vulgaris

# %%
pd.merge(left=maherali, left_on="binominal", right=taxa_synonyms.loc[taxa_synonyms.name.isin(np.setdiff1d(state_needed_species, maherali.query(r"binominal.isin(@state_needed_species)").binominal)), :],
         right_on="synonym_gs", how="inner").loc[:, ("name", "state")]
# Out:
#                      name state
# 0    Anthyllis terniflora    AM
# 1        Armeria velutina  AMNM
# 2          Arnica fulgens    AM
# 3       Helianthus niveus    AM
# 4  Helianthus argophyllus    AM
# 5   Helianthus petiolaris    AM
# 6      Helianthus debilis    AM
# 7   Rubroshorea leprosula    EM
# 8         Thymus hyemalis    AM

# %%
maherali_final =  pd.concat([pd.merge(left=maherali, left_on="binominal", right=taxa_synonyms.loc[taxa_synonyms.name.isin(np.setdiff1d(state_needed_species, maherali.query(r"binominal.isin(@state_needed_species)").binominal)), :],
         right_on="synonym_gs", how="inner").loc[:, ("name", "state")].rename({"name": "binominal"}, axis=1), # states salvaged leveraging synonyms
           maherali.query(r"binominal.isin(@state_needed_species)")] # states found using the original names
).drop_duplicates().reset_index(drop=True)
maherali_final
# Out:
#                  binominal state
# 0     Anthyllis terniflora    AM
# 1         Armeria velutina  AMNM
# 2           Arnica fulgens    AM
# 3        Helianthus niveus    AM
# 4   Helianthus argophyllus    AM
# ..                     ...   ...
# 64       Thymus mastichina    AM
# 65        Ulex parviflorus    AM
# 66         Verbena hastata    AM
# 67    Vernonia fasciculata    AM
# 68           Vicia villosa    AM
#
# [69 rows x 2 columns]

# %%
maherali_final.to_csv(r"../../data/chapter2/FRED/subsets/states_Maherali_2016.csv", index=False)

# %%
# reusing the serialized datset

maherali_final = pd.read_csv(r"../../data/chapter2/FRED/subsets/states_Maherali_2016.csv")

# %%
# update the state needed species

state_needed_species = np.setdiff1d(state_needed_species, maherali_final.binominal)
state_needed_species
# Out:
# array(['Acer laurinum', 'Actinodaphne henryi', 'Afrocarpus falcatus',
#        'Agastache foeniculum', 'Aglaia exstipulata',
#        'Aglaia odoratissima', 'Ailanthus fordii', 'Aiouea montana',
#        'Allium textile', 'Allophylus abyssinicus',
#        'Alseodaphnopsis andersonii', 'Amelanchier alnifolia',
#        'Anaxagorea javanica', 'Andesanthus lepidotus',
#        'Androsace occidentalis', 'Anemone cylindrica', 'Aniba coto',
#        'Aniba muca', 'Antennaria neglecta', 'Antiaris toxicaria',
#        'Apodytes dimidiata', 'Aporosa subcaudata', 'Ardisia quinquegona',
#        'Arnica sororia', 'Artemisia barrelieri', 'Artemisia cana',
#        'Artocarpus lakoocha', 'Aster lanceolatus',
#        'Astragalus aboriginum', 'Astragalus agrestis',
#        'Astragalus bisulcatus', 'Astragalus canadensis',
#        'Astragalus scaberrimus', 'Atractylis humilis',
#        'Baccaurea ramiflora', 'Barringtonia fusicarpa',
#        'Bathysa australis', 'Beilschmiedia purpurascens',
#        'Bituminaria bituminosa', 'Blechnum fluviatilis',
#        'Blechnum lanceolatum', 'Blumeodendron tokbrai',
#        'Calamagrostis canadensis', 'Calpurnia aurea',
#        'Canarium subulatum', 'Carex atrofusca', 'Carex coriophora',
#        'Carex pseuduncinoides', 'Carex tibetikobresia',
#        'Carpinus caroliniana', 'Carya cordiformis', 'Castanopsis boisii',
#        'Castanopsis calathiformis', 'Castanopsis ferox',
#        'Castanopsis fleuryi', 'Cecropia angustifolia', 'Cedrela montana',
#        'Celtis timorensis', 'Cenchrus americanus', 'Centaurea pectinata',
#        'Centronia laurifolia', 'Cestrum schlechtendalii',
#        'Chamaecrista fasciculata', 'Chloranthus henryi',
#        'Chrysopsis villosa', 'Cinnamomum contractum',
#        'Cinnamomum glanduliferum', 'Cistus calycinus', 'Cistus crispus',
#        'Cistus halimifolius', 'Cistus libanotis', 'Clarisia biflora',
#        'Clarisia racemosa', 'Cleidion brevipetiolatum',
#        'Clethra revoluta', 'Clinopodium nepeta', 'Clusia alata',
#        'Clusia ducuoides', 'Clusia elliptica', 'Comandra umbellata',
#        'Combretum collinum', 'Coreopsis palmata', 'Coronilla juncea',
#        'Coronilla minima', 'Critoniopsis floribunda',
#        'Critoniopsis pycnantha', 'Cryptocarya acutifolia',
#        'Cryptocarya brachythyrsa', 'Cryptocarya yunnanensis',
#        'Cystopteris sudetica', 'Cytisus grandiflorus',
#        'Dacryodes peruviana', 'Danthonia intermedia',
#        'Desmodium canadense', 'Dovyalis abyssinica', 'Drymocallis arguta',
#        'Dussia tessmannii', 'Echinacea serotina', 'Elymus lanceolatus',
#        'Endlicheria oreocola', 'Endlicheria ruforamula',
#        'Engelhardia serrata', 'Engelhardia spicata', 'Ephedra fragilis',
#        'Eragrostis trichodes', 'Erica arborea', 'Erica scoparia',
#        'Erigeron glabellus', 'Erigeron pumilus',
#        'Eriotheca longitubulosa', 'Eriotheca surinamensis',
#        'Erysimum inconspicuum', 'Eugenia florida',
#        'Eugenia sinemariensis', 'Euptelea pleiosperma', 'Faramea bangii',
#        'Festuca christianii-bernardii', 'Festuca hallii',
#        'Ficus apollinaris', 'Ficus fistulosa', 'Ficus langkokensis',
#        'Ficus maclellandii', 'Ficus pertusa', 'Ficus simplicissima',
#        'Ficus sodiroi', 'Ficus tonduzii', 'Ficus vasculosa',
#        'Galearia maingayi', 'Garuga floribunda',
#        'Geissanthus vanderwerffii', 'Genista triacanthos',
#        'Gentiana andrewsii', 'Glochidion eriocarpum',
#        'Glochidion lanceolarium', 'Gordonia fruticosa',
#        'Graffenrieda emarginata', 'Graffenrieda harlingii',
#        'Graffenrieda uribei', 'Grias peruviana', 'Guarea kunthiana',
#        'Guarea macrophylla', 'Guarea subandina',
#        'Gymnosporia arbutifolia', 'Hakea ceratophylla',
#        'Hakea cyclocarpa', 'Hakea linearis', 'Hakea lissocarpha',
#        'Hakea oldfieldii', 'Hakea tuberculata', 'Hakea varia',
#        'Halesia tetraptera', 'Harpullia cupanioides', 'Hedeoma hispida',
#        'Hedyosmum goudotianum', 'Hedyosmum purpurascens',
#        'Helianthemum apenninum', 'Helianthemum oelandicum',
#        'Helianthemum syriacum', 'Helianthus agrestis',
#        'Helianthus angustifolius', 'Helianthus atrorubens',
#        'Helianthus carnosus', 'Helianthus cusickii',
#        'Helianthus floridanus', 'Helianthus giganteus',
#        'Helianthus grosseserratus', 'Helianthus heterophyllus',
#        'Helianthus longifolius', 'Helianthus mollis',
#        'Helianthus neglectus', 'Helianthus occidentalis',
#        'Helianthus pauciflorus', 'Helianthus porteri',
#        'Helianthus praecox', 'Helianthus radula',
#        'Helianthus salicifolius', 'Helianthus silphioides',
#        'Helianthus verticillatus', 'Helicostylis tomentosa',
#        'Helicostylis tovarensis', 'Heliopsis helianthoides',
#        'Hesperostipa comata', 'Hesperostipa spartea',
#        'Heuchera richardsonii', 'Hieronyma asperifolia',
#        'Hieronyma fendleri', 'Hieronyma macrocarpa', 'Hieronyma oblonga',
#        'Horsfieldia amygdalina', 'Hymenoxys richardsonii',
#        'Hypobathrum racemosum', 'Ilex laurina', 'Ilex macropoda',
#        'Ilex pedunculosa', 'Ilex teratopis', 'Imbralyx leptobotrys',
#        'Inga extra-nodis', 'Inga loubryana', 'Inga rubiginosa',
#        'Juniperus phoenicea', 'Ladenbergia riveroana', 'Lathyrus venosus',
#        'Launaea arborescens', 'Leonia glycycarpa',
#        'Lepisanthes senegalensis', 'Lespedeza davurica',
#        'Lespedeza thunbergii', 'Licania harlingii', 'Licania irwinii',
#        'Licania ovalifolia', 'Lindera metcalfiana',
#        'Liquidambar gracilipes', 'Liquidambar obovata',
#        'Lithocarpus bacgiangensis', 'Lithocarpus elegans',
#        'Lithocarpus fohaiensis', 'Lithocarpus variolosus',
#        'Litsea glutinosa', 'Litsea martabanica', 'Litsea mollis',
#        'Litsea panamanja', 'Litsea salicifolia', 'Litsea umbellata',
#        'Lupinus perennis', 'Machilus rufipes', 'Machilus tenuipilis',
#        'Matayba inelegans', 'Matayba peruviana', 'Meriania franciscana',
#        'Miconia calophylla', 'Miconia crebribullata',
#        'Miconia dolichorrhyncha', 'Miconia jahnii', 'Miconia punctata',
#        'Miconia radula', 'Micromelum integerrimum',
#        'Mitrephora tomentosa', 'Monarda fistulosa', 'Monoon simiarum',
#        'Morus insignis', 'Munroa christianii-bernardii',
#        'Musineon divaricatum', 'Myrcianthes rhopaloides',
#        'Myrica pubescens', 'Myriocarpa stipitata', 'Myrsine andina',
#        'Mytilaria laosensis', 'Nassella viridula',
#        'Naucleopsis francisci', 'Noronhia mildbraedii', 'Nyssa aquatica',
#        'Ocotea andina', 'Ocotea cuneifolia', 'Ocotea infrafoveolata',
#        'Ocotea nigra', 'Ocotea pedanomischa', 'Ocotea rotundata',
#        'Onoclea sensibilis', 'Oreopanax sessiliflorus',
#        'Orthocarpus luteus', 'Osyris alba', 'Oxytropis sericea',
#        'Palicourea stenosepala', 'Palicourea thyrsiflora',
#        'Palicourea tinctoria', 'Pappobolus microphyllus',
#        'Penstemon bradburyi', 'Penstemon confertus', 'Penstemon nitidus',
#        'Penstemon procerus', 'Pentaspadon motleyi',
#        'Persea areolatocostae', 'Persea ferruginea', 'Persea weberbaueri',
#        'Philadelphus incanus', 'Phlox hoodii', 'Phoebe puwenensis',
#        'Physalis virginiana', 'Picramnia latifolia',
#        'Picrasma longistaminea', 'Piper arboreum',
#        'Planchonella grandifolia', 'Plantago patagonica',
#        'Platanus acerifolia', 'Pleioblastus amarus',
#        'Pleroma ochypetalum', 'Poa cusickii', 'Podocarpus oleifolius',
#        'Pourouma cecropiifolia', 'Pouteria austin-smithii',
#        'Protium giganteum', 'Protium sagotianum', 'Prumnopitys montana',
#        'Prunus herthae', 'Prunus opaca', 'Pseudodictamnus hirsutus',
#        'Pseudolmedia rigida', 'Pseuduvaria trimera',
#        'Puccinellia rupestris', 'Quercus bicolor', 'Quercus canariensis',
#        'Quercus glauca', 'Ratibida pinnata', 'Rhamnus alaternus',
#        'Rhododendron ponticum', 'Richetia multiflora', 'Rosa arkansana',
#        'Roucheria columbiana', 'Ruagea glabra', 'Rubia peregrina',
#        'Rubroshorea acuminata', 'Salix abscondita', 'Sapium stylare',
#        'Sarcandra glabra', 'Saurauia herthae', 'Sciodaphyllum acuminatum',
#        'Semecarpus reticulata', 'Sextonia rubra', 'Sideritis pusilla',
#        'Siparuna aspera', 'Siparuna muricata', 'Sloanea grandiflora',
#        'Sloanea rufa', 'Solidago missouriensis', 'Solidago ptarmicoides',
#        'Solidago speciosa', 'Sorbus discolor', 'Sphaeralcea coccinea',
#        'Sporobolus rigidus', 'Stauracanthus genistoides',
#        'Symphoricarpos occidentalis', 'Symphyotrichum ciliolatum',
#        'Symphyotrichum laeve', 'Symphyotrichum novae-angliae',
#        'Symphyotrichum oolentangiense', 'Symphyotrichum puniceum',
#        'Symplocos cochinchinensis', 'Teucrium charidemi',
#        'Thermopsis rhombifolia', 'Thymelaea hirsuta',
#        'Thymus dolomiticus', 'Tordylium maximum',
#        'Toxicodendron acuminatum', 'Toxicoscordion venenosum',
#        'Trattinnickia lawrancei', 'Trichilia septentrionalis',
#        'Turpinia occidentalis', 'Unonopsis rufescens', 'Vepris nobilis',
#        'Veronicastrum virginicum', 'Viburnum stipitatum',
#        'Vicia americana', 'Weinmannia elliptica', 'Weinmannia fagaroides',
#        'Weinmannia magnifolia', 'Weinmannia microphylla',
#        'Weinmannia ovata', 'Withania frutescens', 'Xanthisma spinulosum',
#        'Xanthophyllum flavescens', 'Zizia aurea'], dtype=object)

# %%
state_needed_species.size
# Out:
# 361

# %%
#-----------------------------------------------
# MYCORRHIZAL STATE HARVEST FROM FungalRoot
#-----------------------------------------------

# %%
fungalroot.query(r"species.isin(@state_needed_species)").loc[:, ["species", "mycorrhiza type"]].drop_duplicates()
# Out:
#                        species                          mycorrhiza type
# 2578             Erica arborea                                      ErM
# 3640       Juniperus phoenicea                 AM; others not addressed
# 7518    Astragalus scaberrimus                 AM; others not addressed
# 7631            Sextonia rubra                 AM; others not addressed
# 7642        Protium sagotianum                 AM; others not addressed
# ...                        ...                                      ...
# 33875     Sphaeralcea coccinea                            AM; no others
# 33877             Phlox hoodii                            AM; no others
# 34266  Symphyotrichum puniceum                            AM; no others
# 34318              Zizia aurea                            AM; no others
# 35636       Apodytes dimidiata  non-mycorrhizal (checked for all types)
#
# [110 rows x 2 columns]

# %%
# okay, try leveraging synonyms

taxa_synonyms.loc[taxa_synonyms.name.isin(np.setdiff1d(state_needed_species, fungalroot.query(r"species.isin(@state_needed_species)").species.unique())), :]
# Out:
#                        name                     synonym  \
# 10    Weinmannia fagaroides       Windmannia fagaroides
# 13         Weinmannia ovata            Windmannia ovata
# 14     Weinmannia elliptica        Windmannia elliptica
# 15      Withania frutescens         Physalis frutescens
# 20          Hedeoma hispida              Cunila hispida
# ...                     ...                         ...
# 1760  Ocotea infrafoveolata        Andea infrafoveolata
# 1762      Coreopsis palmata              Anacis palmata
# 1763         Morus insignis        Paratrophis insignis
# 1765  Glochidion eriocarpum      Phyllanthus eriocarpus
# 1767      Aster lanceolatus  Symphyotrichum lanceolatum
#
#                       synonym_gs
# 10         Windmannia fagaroides
# 13              Windmannia ovata
# 14          Windmannia elliptica
# 15           Physalis frutescens
# 20                Cunila hispida
# ...                          ...
# 1760        Andea infrafoveolata
# 1762              Anacis palmata
# 1763        Paratrophis insignis
# 1765      Phyllanthus eriocarpus
# 1767  Symphyotrichum lanceolatum
#
# [296 rows x 3 columns]

# %%
pd.merge(left=taxa_synonyms.loc[taxa_synonyms.name.isin(np.setdiff1d(state_needed_species, fungalroot.query(r"species.isin(@state_needed_species)").species.unique())), :],
        left_on="synonym_gs", right=fungalroot.loc[:, ("species", "mycorrhiza type")], right_on="species", how="inner")
# Out:
#                         name                                    synonym  \
# 0       Carex tibetikobresia        Kobresia capillifolia var. tibetica
# 1       Carex tibetikobresia        Kobresia capillifolia var. tibetica
# 2      Amelanchier alnifolia       Amelanchier sanguinea var. alnifolia
# 3      Amelanchier alnifolia      Amelanchier canadensis var. alnifolia
# 4      Amelanchier alnifolia      Amelanchier canadensis var. alnifolia
# 5             Festuca hallii              Festuca altaica subsp. hallii
# 6             Festuca hallii             Festuca altaica subvar. hallii
# 7     Bituminaria bituminosa                        Psoralea bituminosa
# 8       Imbralyx leptobotrys                      Millettia leptobotrys
# 9        Hesperostipa comata                               Stipa comata
# 10       Hesperostipa comata                               Stipa comata
# 11       Hesperostipa comata                               Stipa comata
# 12  Chamaecrista fasciculata                         Cassia fasciculata
# 13  Chamaecrista fasciculata                         Cassia fasciculata
# 14       Cistus halimifolius                      Halimium halimifolium
# 15            Arnica sororia                Arnica fulgens var. sororia
# 16      Hesperostipa spartea                              Stipa spartea
# 17  Toxicodendron acuminatum  Toxicodendron succedaneum var. acuminatum
# 18  Toxicodendron acuminatum             Rhus succedanea var. acuminata
# 19         Aster lanceolatus                 Symphyotrichum lanceolatum
#
#                     synonym_gs                     species  \
# 0        Kobresia capillifolia       Kobresia capillifolia
# 1        Kobresia capillifolia       Kobresia capillifolia
# 2        Amelanchier sanguinea       Amelanchier sanguinea
# 3       Amelanchier canadensis      Amelanchier canadensis
# 4       Amelanchier canadensis      Amelanchier canadensis
# 5              Festuca altaica             Festuca altaica
# 6              Festuca altaica             Festuca altaica
# 7          Psoralea bituminosa         Psoralea bituminosa
# 8        Millettia leptobotrys       Millettia leptobotrys
# 9                 Stipa comata                Stipa comata
# 10                Stipa comata                Stipa comata
# 11                Stipa comata                Stipa comata
# 12          Cassia fasciculata          Cassia fasciculata
# 13          Cassia fasciculata          Cassia fasciculata
# 14       Halimium halimifolium       Halimium halimifolium
# 15              Arnica fulgens              Arnica fulgens
# 16               Stipa spartea               Stipa spartea
# 17   Toxicodendron succedaneum   Toxicodendron succedaneum
# 18             Rhus succedanea             Rhus succedanea
# 19  Symphyotrichum lanceolatum  Symphyotrichum lanceolatum
#
#                             mycorrhiza type
# 0                 EcM; others not addressed
# 1   non-mycorrhizal (checked for all types)
# 2                             AM; no others
# 3                 EcM; others not addressed
# 4                             AM; no others
# 5                             AM; no others
# 6                             AM; no others
# 7                             AM; no others
# 8                  AM; others not addressed
# 9                  AM; others not addressed
# 10                 AM; others not addressed
# 11                            AM; no others
# 12                            AM; no others
# 13                            AM; no others
# 14                            AM; no others
# 15                 AM; others not addressed
# 16                            AM; no others
# 17                 AM; others not addressed
# 18                 AM; others not addressed
# 19                 AM; others not addressed

# %%
pd.merge(left=taxa_synonyms.loc[taxa_synonyms.name.isin(np.setdiff1d(state_needed_species, fungalroot.query(r"species.isin(@state_needed_species)").species.unique())), :],
        left_on="synonym_gs", right=fungalroot.loc[:, ("species", "mycorrhiza type")], right_on="species", how="inner").loc[:, ("name", "mycorrhiza type")].drop_duplicates().rename({"name": "species"}, axis=1)
# Out:
#                      species                          mycorrhiza type
# 0       Carex tibetikobresia                EcM; others not addressed
# 1       Carex tibetikobresia  non-mycorrhizal (checked for all types)
# 2      Amelanchier alnifolia                            AM; no others
# 3      Amelanchier alnifolia                EcM; others not addressed
# 5             Festuca hallii                            AM; no others
# 7     Bituminaria bituminosa                            AM; no others
# 8       Imbralyx leptobotrys                 AM; others not addressed
# 9        Hesperostipa comata                 AM; others not addressed
# 11       Hesperostipa comata                            AM; no others
# 12  Chamaecrista fasciculata                            AM; no others
# 14       Cistus halimifolius                            AM; no others
# 15            Arnica sororia                 AM; others not addressed
# 16      Hesperostipa spartea                            AM; no others
# 17  Toxicodendron acuminatum                 AM; others not addressed
# 19         Aster lanceolatus                 AM; others not addressed

# %%
fungalroot_final = pd.concat([
    # states fished out using synonyms
    pd.merge(left=taxa_synonyms.loc[taxa_synonyms.name.isin(np.setdiff1d(state_needed_species, fungalroot.query(r"species.isin(@state_needed_species)").species.unique())), :],
        left_on="synonym_gs", right=fungalroot.loc[:, ("species", "mycorrhiza type")], right_on="species", how="inner").loc[:, ("name", "mycorrhiza type")].drop_duplicates().rename({"name": "species"}, axis=1),
    # states found using the original names in FRED 4.0
    fungalroot.query(r"species.isin(@state_needed_species)").loc[:, ["species", "mycorrhiza type"]].drop_duplicates()
]).reset_index(drop=True).drop_duplicates()

fungalroot_final
# Out:
#                      species                          mycorrhiza type
# 0       Carex tibetikobresia                EcM; others not addressed
# 1       Carex tibetikobresia  non-mycorrhizal (checked for all types)
# 2      Amelanchier alnifolia                            AM; no others
# 3      Amelanchier alnifolia                EcM; others not addressed
# 4             Festuca hallii                            AM; no others
# ..                       ...                                      ...
# 120     Sphaeralcea coccinea                            AM; no others
# 121             Phlox hoodii                            AM; no others
# 122  Symphyotrichum puniceum                            AM; no others
# 123              Zizia aurea                            AM; no others
# 124       Apodytes dimidiata  non-mycorrhizal (checked for all types)
#
# [125 rows x 2 columns]

# %%
fungalroot_final.to_csv(r"../../data/chapter2/FRED/subsets/states_FungalRoot.csv", index=False)

# %%
# update the state needed species

state_needed_species = np.setdiff1d(state_needed_species, fungalroot_final.species)
state_needed_species.size
# Out:
# 264

# %%
with open (file=r"../../data/chapter2/FRED/subsets/state_missing_species.json", mode="wt") as fp:
    json.dump(obj={
                    "species": [
                    {
                    "binominal": n,
                    "synonyms": list(taxa_synonyms.query(r"name==@n").synonym.values) if (n in taxa_synonyms.name.values) else None,
                    "F01286": taxa.loc[taxa.binominal==n, "F01286"].values[0],
                    "F01287": taxa.loc[taxa.binominal==n, "F01287"].values[0],
                    "F01289": taxa.loc[taxa.binominal==n, "F01289"].values[0],
                    "F01290": taxa.loc[taxa.binominal==n, "F01290"].values[0]
                    }
                    for n in state_needed_species
                    ]
                    }, indent=4, sort_keys=True, fp=fp)

# %%
[name for name in state_needed_species if name in taxa_synonyms.name.values][:10] # [ .... in taxa_synonyms.name] did not work???
# Out:
# ['Agastache foeniculum',
#  'Aglaia exstipulata',
#  'Aiouea montana',
#  'Allophylus abyssinicus',
#  'Alseodaphnopsis andersonii',
#  'Andesanthus lepidotus',
#  'Androsace occidentalis',
#  'Aniba coto',
#  'Aniba muca',
#  'Artemisia barrelieri']

# %%
np.intersect1d(state_needed_species, taxa_synonyms.name).size
# Out:
# 140

# %%
"Weinmannia fagaroides" in taxa_synonyms.name, "Weinmannia fagaroides" in taxa_synonyms.name.values # that's strange???
# Out:
# (False, True)

# %%
#-----------------------------------------------------------------------------
# compile all the mycorrhizal state subsets that were cleaned up by hand
#-----------------------------------------------------------------------------

compiled_states = pd.concat([
            pd.read_excel(r"../../data/chapter2/FRED/subsets/species.xlsx", sheet_name="FRED4").loc[:, ["binominal", "reconciled_state"]].drop_duplicates().assign(source="FRED4"),
            pd.read_excel(r"../../data/chapter2/FRED/subsets/species.xlsx", sheet_name="FungalRoot").loc[:, ["binominal", "reconciled_state"]].drop_duplicates().assign(source="FungalRoot"),
            pd.read_excel(r"../../data/chapter2/FRED/subsets/species.xlsx", sheet_name="Maherali_2016").loc[:, ["binominal", "state"]].drop_duplicates().rename({"state": "reconciled_state"}, axis=1).assign(source="Maherali et. al. 2016")
]).reset_index(drop=True).sort_values(by="binominal")

compiled_states.loc[:, "reconciled_state"] = compiled_states.reconciled_state.replace({"EM": "EcM", "AMNM": "NMAM"})
assert compiled_states.binominal.unique().size == compiled_states.binominal.size, "cannot have duplicates here!"

compiled_states
# Out:
#                  binominal reconciled_state      source
# 0               Abies alba              EcM       FRED4
# 1        Abies nephrolepis              EcM       FRED4
# 2    Acacia auriculiformis               AM       FRED4
# 3       Acacia crassicarpa            EcMAM       FRED4
# 4           Acacia mangium            EcMAM       FRED4
# ..                     ...              ...         ...
# 854    Xanthophyllum tenue               AM       FRED4
# 855        Zabelia biflora               AM       FRED4
# 856         Zamia lucayana               AM       FRED4
# 967            Zizia aurea               AM  FungalRoot
# 857       Zygia inaequalis               AM       FRED4
#
# [1037 rows x 3 columns]

# %%
compiled_states.reconciled_state.unique() # cool
# Out:
# <StringArray>
# ['EcM', 'AM', 'EcMAM', 'NMAM', 'NM', 'ErM']
# Length: 6, dtype: str

# %%
compiled_states_extended = pd.merge(left=taxa, left_on="binominal", right=compiled_states, right_on="binominal", how="left").loc[:, ["binominal"] + PLANT_TAXONOMY_ACCEPTED_COLUMNS + ["reconciled_state", "source"]]
compiled_states_extended
# Out:
#                   binominal         F01286          F01287          F01289  \
# 0                Abies alba          Abies            alba        Pinaceae
# 1         Abies nephrolepis          Abies     nephrolepis        Pinaceae
# 2     Acacia auriculiformis         Acacia  auriculiformis        Fabaceae
# 3        Acacia crassicarpa         Acacia     crassicarpa        Fabaceae
# 4            Acacia mangium         Acacia         mangium        Fabaceae
# ...                     ...            ...             ...             ...
# 1296    Xanthophyllum tenue  Xanthophyllum           tenue    Polygalaceae
# 1297        Zabelia biflora        Zabelia         biflora  Caprifoliaceae
# 1298         Zamia lucayana          Zamia        lucayana       Zamiaceae
# 1299            Zizia aurea          Zizia           aurea        Apiaceae
# 1300       Zygia inaequalis          Zygia      inaequalis        Fabaceae
#
#           F01290 reconciled_state      source
# 0        Pinales              EcM       FRED4
# 1        Pinales              EcM       FRED4
# 2        Fabales               AM       FRED4
# 3        Fabales            EcMAM       FRED4
# 4        Fabales            EcMAM       FRED4
# ...          ...              ...         ...
# 1296     Fabales               AM       FRED4
# 1297  Dipsacales               AM       FRED4
# 1298   Cycadales               AM       FRED4
# 1299     Apiales               AM  FungalRoot
# 1300     Fabales               AM       FRED4
#
# [1301 rows x 7 columns]

# %%
synonyms = []

for sp in compiled_states_extended.binominal:
    _syns = wcvp_synonyms_lookup_table.loc[wcvp_synonyms_lookup_table.name==sp, "synonym"].values
    synonyms.append(list(_syns) if _syns.any() else np.nan) # if not empty append the synonyms else append a np.nan

compiled_states_extended.loc[:, "synonyms"] = pd.Series(synonyms)
compiled_states_extended
# Out:
#                   binominal         F01286          F01287          F01289  \
# 0                Abies alba          Abies            alba        Pinaceae
# 1         Abies nephrolepis          Abies     nephrolepis        Pinaceae
# 2     Acacia auriculiformis         Acacia  auriculiformis        Fabaceae
# 3        Acacia crassicarpa         Acacia     crassicarpa        Fabaceae
# 4            Acacia mangium         Acacia         mangium        Fabaceae
# ...                     ...            ...             ...             ...
# 1296    Xanthophyllum tenue  Xanthophyllum           tenue    Polygalaceae
# 1297        Zabelia biflora        Zabelia         biflora  Caprifoliaceae
# 1298         Zamia lucayana          Zamia        lucayana       Zamiaceae
# 1299            Zizia aurea          Zizia           aurea        Apiaceae
# 1300       Zygia inaequalis          Zygia      inaequalis        Fabaceae
#
#           F01290 reconciled_state      source  \
# 0        Pinales              EcM       FRED4
# 1        Pinales              EcM       FRED4
# 2        Fabales               AM       FRED4
# 3        Fabales            EcMAM       FRED4
# 4        Fabales            EcMAM       FRED4
# ...          ...              ...         ...
# 1296     Fabales               AM       FRED4
# 1297  Dipsacales               AM       FRED4
# 1298   Cycadales               AM       FRED4
# 1299     Apiales               AM  FungalRoot
# 1300     Fabales               AM       FRED4
#
#                                                synonyms
# 0     [Pinus alba, Pinus abies var. pectinata, Pinus...
# 1     [Abies veitchii var. nephrolepis, Abies sibiri...
# 2                            [Racosperma auriculiforme]
# 3                             [Racosperma crassicarpum]
# 4                                  [Racosperma mangium]
# ...                                                 ...
# 1296                                                NaN
# 1297                                   [Abelia biflora]
# 1298                                                NaN
# 1299  [Smyrnium aureum, Sison aureum, Carum aureum, ...
# 1300  [Inga inaequalis, Pithecellobium inaequale, Fe...
#
# [1301 rows x 8 columns]

# %%
compiled_states_extended.to_csv(r"../../data/chapter2/FRED/subsets/species_hand_cleaned.csv", index=False)

# %% [markdown]
# ### ___1. State revision___
# ------------------------

# %%
states = pd.read_csv(r"../../data/chapter2/FRED/subsets/species_hand_cleaned.csv")
states
# Out:
#                   binominal         F01286          F01287          F01289  \
# 0                Abies alba          Abies            alba        Pinaceae
# 1         Abies nephrolepis          Abies     nephrolepis        Pinaceae
# 2     Acacia auriculiformis         Acacia  auriculiformis        Fabaceae
# 3        Acacia crassicarpa         Acacia     crassicarpa        Fabaceae
# 4            Acacia mangium         Acacia         mangium        Fabaceae
# ...                     ...            ...             ...             ...
# 1296    Xanthophyllum tenue  Xanthophyllum           tenue    Polygalaceae
# 1297        Zabelia biflora        Zabelia         biflora  Caprifoliaceae
# 1298         Zamia lucayana          Zamia        lucayana       Zamiaceae
# 1299            Zizia aurea          Zizia           aurea        Apiaceae
# 1300       Zygia inaequalis          Zygia      inaequalis        Fabaceae
#
#           F01290 reconciled_state  \
# 0        Pinales              EcM
# 1        Pinales              EcM
# 2        Fabales               AM
# 3        Fabales            EcMAM
# 4        Fabales            EcMAM
# ...          ...              ...
# 1296     Fabales               AM
# 1297  Dipsacales               AM
# 1298   Cycadales               AM
# 1299     Apiales               AM
# 1300     Fabales               AM
#
#                                                synonyms
# 0     ['Pinus alba', 'Pinus abies var. pectinata', '...
# 1     ['Abies veitchii var. nephrolepis', 'Abies sib...
# 2                          ['Racosperma auriculiforme']
# 3                           ['Racosperma crassicarpum']
# 4                                ['Racosperma mangium']
# ...                                                 ...
# 1296                                                NaN
# 1297                                 ['Abelia biflora']
# 1298                                                NaN
# 1299  ['Smyrnium aureum', 'Sison aureum', 'Carum aur...
# 1300  ['Inga inaequalis', 'Pithecellobium inaequale'...
#
# [1301 rows x 7 columns]

# %%
#--------------------------------------------------------------
# cross checking state conflicts after the first revision
#--------------------------------------------------------------

revision = pd.read_excel(r"../../data/chapter2/FRED/subsets/species.xlsx", sheet_name="combined")
revision.head()
# Out:
#                binominal  F01286    F01289 F01290_not_crosschecked  \
# 0             Abies alba   Abies  Pinaceae                 Pinales
# 1      Abies nephrolepis   Abies  Pinaceae                 Pinales
# 2  Acacia auriculiformis  Acacia  Fabaceae                 Fabales
# 3     Acacia crassicarpa  Acacia  Fabaceae                 Fabales
# 4         Acacia mangium  Acacia  Fabaceae                 Fabales
#
#   reconciled_state source state_revision_1 revision_1_source state_revision_2  \
# 0              EcM  FRED4              EcM               NaN              EcM
# 1              EcM  FRED4              EcM               NaN              EcM
# 2               AM  FRED4               AM               NaN            EcMAM
# 3            EcMAM  FRED4            EcMAM               NaN            EcMAM
# 4            EcMAM  FRED4            EcMAM               NaN            EcMAM
#
#                revision_2_source  \
# 0                            NaN
# 1                            NaN
# 2  (Soudzilovskaia et al., 2020)
# 3                            NaN
# 4                            NaN
#
#                                             synonyms
# 0  ['Pinus alba', 'Pinus abies var. pectinata', '...
# 1  ['Abies veitchii var. nephrolepis', 'Abies sib...
# 2                       ['Racosperma auriculiforme']
# 3                        ['Racosperma crassicarpum']
# 4                             ['Racosperma mangium']

# %%
# see which families have multiple state encodings and what are they???
# and cross check that with Brundrett, M.C. and Tedersoo, L. (2018) ‘Evolutionary history of mycorrhizal symbioses and global host plant diversity’,
# New Phytologist, 220(4), pp. 1108–1115. Available at: https://doi.org/10.1111/nph.14976.

{fam: tuple(df.state_revision_1.unique()) for (fam, df) in revision.groupby("F01289", as_index=False) if df.state_revision_1.unique().size > 1}
# Out:
# {'Amaranthaceae': ('NMAM', 'AM'),
#  'Annonaceae': ('AM', 'NM'),
#  'Apocynaceae': ('AM', 'NMAM'),
#  'Asparagaceae': ('AM', 'NMAM'),
#  'Asteraceae': ('NMAM', 'AM', 'NM'),
#  'Cannabaceae': ('AM', 'NM'),
#  'Chloranthaceae': ('AM', 'NMAM'),
#  'Cistaceae': ('EcM', 'AM', 'EcMAM'),
#  'Cornaceae': ('AM', 'EcMAM'),
#  'Cupressaceae': ('AM', 'NMAM'),
#  'Cyperaceae': ('NM', 'NMAM', 'AM'),
#  'Dryopteridaceae': ('NM', 'AM'),
#  'Equisetaceae': ('NMAM', 'NM'),
#  'Ericaceae': ('EcM', 'ErM'),
#  'Fabaceae': ('AM', 'EcMAM', 'NMAM', 'NM'),
#  'Fagaceae': ('EcM', 'AM', 'NMAM'),
#  'Gleicheniaceae': ('AM', 'NM'),
#  'Juglandaceae': ('EcM', 'AM'),
#  'Lamiaceae': ('AM', 'NMAM'),
#  'Lauraceae': ('AM', 'NM'),
#  'Malvaceae': ('AM', 'EcM', 'EcMAM'),
#  'Melastomataceae': ('AM', 'EcMAM'),
#  'Moraceae': ('NMAM', 'AM'),
#  'Myrtaceae': ('AM', 'EcMAM', 'EcM'),
#  'Nothofagaceae': ('EcMAM', 'AM', 'EcM'),
#  'Oleaceae': ('AM', 'EcMAM'),
#  'Pinaceae': ('EcM', 'EcMAM'),
#  'Plantaginaceae': ('AM', 'NMAM'),
#  'Poaceae': ('AM', 'NMAM', 'EcMAM'),
#  'Polygonaceae': ('EcMAM', 'NMAM'),
#  'Primulaceae': ('AM', 'NMAM'),
#  'Proteaceae': ('NM', 'AM', 'NMAM'),
#  'Ranunculaceae': ('NMAM', 'AM'),
#  'Rhamnaceae': ('NMAM', 'AM'),
#  'Rosaceae': ('AM', 'EcMAM', 'NM', 'NMAM'),
#  'Rubiaceae': ('AM', 'NMAM', 'EcMAM'),
#  'Salicaceae': ('AM', 'EcM', 'EcMAM'),
#  'Santalaceae': ('AM', 'NMAM'),
#  'Sapindaceae': ('AM', 'NMAM'),
#  'Saxifragaceae': ('AM', 'NMAM'),
#  'Ulmaceae': ('AM', 'EcMAM')}

# %%
# families that need to be hand reconciled ??.....

# Amaranthaceae - correct, has been cross checked with FungalRoot (Soudzilovskaia et al., 2020)
# Annonaceae - rectified using (Brundrett and Tedersoo, 2018)
# Apocynaceae - rectified using (Soudzilovskaia et al., 2020)
# Asparagaceae - rectified using (Soudzilovskaia et al., 2020)
# Asteraceae - rectified using (Soudzilovskaia et al., 2020) & (Brundrett and Tedersoo, 2018)
# Cannabaceae - rectified using (Brundrett and Tedersoo, 2018)
# Chloranthaceae - rectified using (Soudzilovskaia et al., 2020)
# Cistaceae - rectified using (Soudzilovskaia et al., 2020)
# Cornaceae - rectified using (Soudzilovskaia et al., 2020)
# Cupressaceae - rectified using (Soudzilovskaia et al., 2020)
# Cyperaceae - rectified using (Soudzilovskaia et al., 2020)
# Dryopteridaceae - rectified using (Soudzilovskaia et al., 2020)
# Equisetaceae - rectified using (Soudzilovskaia et al., 2020)
# Ericaceae - correct, has been cross checked with FungalRoot (Soudzilovskaia et al., 2020)
# Fabaceae - rectified using (Soudzilovskaia et al., 2020)
# Fagaceae - rectified using (Soudzilovskaia et al., 2020)
# Gleicheniaceae - rectified using (Soudzilovskaia et al., 2020)
# Juglandaceae - correct, has been cross checked with FungalRoot (Soudzilovskaia et al., 2020)
# Lamiaceae - correct, has been cross checked with (Soudzilovskaia et al., 2020) & (Brundrett and Tedersoo, 2018)
# Lauraceae - rectified using (Soudzilovskaia et al., 2020)
# Malvaceae - rectified using (Soudzilovskaia et al., 2020)
# Melastomataceae - rectified using (Soudzilovskaia et al., 2020)
# Moraceae - rectified using (Soudzilovskaia et al., 2020)
# Myrtaceae - rectified using (Soudzilovskaia et al., 2020)
# Nothofagaceae - rectified using (Soudzilovskaia et al., 2020)
# Oleaceae - rectified using (Soudzilovskaia et al., 2020)
# Pinaceae - rectified using (Soudzilovskaia et al., 2020)
# Plantaginaceae - rectified using (Soudzilovskaia et al., 2020)
# Poaceae - rectified using (Soudzilovskaia et al., 2020)
# Polygonaceae - rectified using (Soudzilovskaia et al., 2020)
# Primulaceae - rectified using (Soudzilovskaia et al., 2020)
# Proteaceae - rectified using (Soudzilovskaia et al., 2020)
# Ranunculaceae - rectified using (Soudzilovskaia et al., 2020)
# Rhamnaceae - rectified using (Soudzilovskaia et al., 2020)
# Rosaceae - rectified using (Brundrett and Tedersoo, 2018)
# Rubiaceae - rectified using (Soudzilovskaia et al., 2020)
# Salicaceae - rectified using (Brundrett and Tedersoo, 2018)
# Santalaceae - all good, has been cross checked with (Soudzilovskaia et al., 2020)
# Sapindaceae - rectified using (Brundrett and Tedersoo, 2018)
# Saxifragaceae - rectified using (Soudzilovskaia et al., 2020)
# Ulmaceae - rectified using (Brundrett and Tedersoo, 2018)

# %%
# cool :)
{fam: tuple(df.state_revision_2.unique()) for (fam, df) in revision.groupby("F01289", as_index=False) if df.state_revision_2.unique().size > 1}
# Out:
# {'Amaranthaceae': ('NMAM', 'AM'),
#  'Aspleniaceae': ('NMAM', 'AM'),
#  'Ericaceae': ('EcM', 'ErM'),
#  'Fabaceae': ('EcMAM', 'AM', 'NM'),
#  'Juglandaceae': ('EcM', 'AM'),
#  'Lamiaceae': ('AM', 'NMAM'),
#  'Lauraceae': ('AM', 'NMAM'),
#  'Lecythidaceae': ('AM', 'NMAM'),
#  'Malvaceae': ('AM', 'EcM'),
#  'Myrtaceae': ('AM', 'EcMAM'),
#  'Poaceae': ('AM', 'NMAM'),
#  'Polygonaceae': ('EcM', 'NMAM'),
#  'Ranunculaceae': ('AM', 'NMAM'),
#  'Rubiaceae': ('AM', 'NMAM'),
#  'Salicaceae': ('AM', 'EcMAM'),
#  'Santalaceae': ('AM', 'NMAM'),
#  'Urticaceae': ('NMAM', 'AM')}

# %%
# for families that only have one mycorrhizal state, cross check the states with FungalRoot genus level recommendations

one_state_fams = np.array([fam for (fam, df) in revision.groupby("F01289", as_index=False) if df.state_revision_1.unique().size == 1])
one_state_genera = revision.query(r"F01289.isin(@one_state_fams)").loc[:, ["F01286", "F01289", "state_revision_1", "state_revision_2"]].drop_duplicates()
one_state_genera
# Out:
#              F01286          F01289 state_revision_1 state_revision_2
# 24           Ackama     Cunoniaceae               AM               AM
# 25       Acronychia        Rutaceae               AM               AM
# 27        Actinidia   Actinidiaceae               AM               AM
# 30         Adiantum     Pteridaceae               AM               AM
# 35       Afrocarpus   Podocarpaceae               AM               AM
# ...             ...             ...              ...              ...
# 1293     Wurfbainia   Zingiberaceae               AM               AM
# 1295  Xanthophyllum    Polygalaceae               AM               AM
# 1297        Zabelia  Caprifoliaceae               AM               AM
# 1298          Zamia       Zamiaceae               AM               AM
# 1299          Zizia        Apiaceae               AM               AM
#
# [246 rows x 4 columns]

# %%
fungalroot_genus_level_states = pd.read_excel(r"../../data/chapter2/FungalRoot/nph16569-sup-0002-tabless1-s4.xlsx", sheet_name="Table S2", skiprows=2).rename({"Genus": "genus", "Mycorrhizal type": "state"}, axis=1)
fungalroot_genus_level_states.loc[:, "state"] = fungalroot_genus_level_states.state.replace({"NM-AM": "NMAM"})

# %%
fungalroot_genus_level_states.state.unique()
# Out:
# <StringArray>
# [                                         'OM',
#                                           'AM',
#                                           'NM',
#                                          'EcM',
#                                         'NMAM',
#                                       'EcM-AM',
#                                          'ErM',
#                                    'uncertain',
#          'species-specific EcM-AM or AM or NM',
#  'species-specific: AM or rarely EcM-AM or AM',
#                            'NM-AM, rarely EcM',
#               'species-specific: EcM or NM-AM',
#                                  'Thysanothus',
#                                           'nM']
# Length: 14, dtype: str

# %%
# seems doable :)

pd.merge(left=one_state_genera, left_on="F01286", right=fungalroot_genus_level_states, right_on="genus", how="left").query(r"state_revision_1!=state")
# Out:
#               F01286            F01289 state_revision_1 state_revision_2  \
# 22          Apodytes    Metteniusaceae             NMAM               AM
# 29     Sciodaphyllum        Araliaceae               AM               AM
# 30         Asplenium      Aspleniaceae               AM             NMAM
# 41         Campanula     Campanulaceae             NMAM               AM
# 55          Cibotium       Cibotiaceae               NM               AM
# 65      Corythophora     Lecythidaceae               AM             NMAM
# 81      Didymocheton         Meliaceae               AM               AM
# 99          Richetia  Dipterocarpaceae              EcM              EcM
# 101      Rubroshorea  Dipterocarpaceae              EcM              EcM
# 111           Gnetum         Gnetaceae               AM              EcM
# 120     Heptapleurum        Araliaceae               AM               AM
# 121        Hymenopus  Chrysobalanaceae               AM               AM
# 130     Leptobalanus  Chrysobalanaceae               AM               AM
# 134          Lomaria       Blechnaceae               AM               AM
# 162        Oreocnide        Urticaceae               AM             NMAM
# 163      Orthocarpus     Orobanchaceae             NMAM               NM
# 166     Parablechnum       Blechnaceae               AM               AM
# 169     Pectinopitys     Podocarpaceae               AM               AM
# 186       Prasoxylon         Meliaceae               AM               AM
# 189  Pseudodiphasium     Lycopodiaceae               AM               AM
# 193      Pterophylla       Cunoniaceae               AM               AM
# 203        Schoepfia     Schoepfiaceae               NM               AM
# 219        Thymelaea     Thymelaeaceae             NMAM               AM
# 238       Myriocarpa        Urticaceae               AM             NMAM
# 241       Wurfbainia     Zingiberaceae               AM               AM
#
#             genus state
# 22       Apodytes    AM
# 29            NaN   NaN
# 30      Asplenium  NMAM
# 41      Campanula    AM
# 55       Cibotium    AM
# 65   Corythophora  NMAM
# 81            NaN   NaN
# 99            NaN   NaN
# 101           NaN   NaN
# 111        Gnetum   EcM
# 120           NaN   NaN
# 121           NaN   NaN
# 130           NaN   NaN
# 134           NaN   NaN
# 162     Oreocnide  NMAM
# 163   Orthocarpus    NM
# 166           NaN   NaN
# 169           NaN   NaN
# 186           NaN   NaN
# 189           NaN   NaN
# 193           NaN   NaN
# 203     Schoepfia    AM
# 219     Thymelaea    AM
# 238    Myriocarpa  NMAM
# 241           NaN   NaN

# %%
pd.merge(left=one_state_genera, left_on="F01286", right=fungalroot_genus_level_states, right_on="genus", how="left").query(r"state_revision_2!=state")
# Out:
#               F01286            F01289 state_revision_1 state_revision_2  \
# 29     Sciodaphyllum        Araliaceae               AM               AM
# 81      Didymocheton         Meliaceae               AM               AM
# 99          Richetia  Dipterocarpaceae              EcM              EcM
# 101      Rubroshorea  Dipterocarpaceae              EcM              EcM
# 120     Heptapleurum        Araliaceae               AM               AM
# 121        Hymenopus  Chrysobalanaceae               AM               AM
# 130     Leptobalanus  Chrysobalanaceae               AM               AM
# 134          Lomaria       Blechnaceae               AM               AM
# 166     Parablechnum       Blechnaceae               AM               AM
# 169     Pectinopitys     Podocarpaceae               AM               AM
# 186       Prasoxylon         Meliaceae               AM               AM
# 189  Pseudodiphasium     Lycopodiaceae               AM               AM
# 193      Pterophylla       Cunoniaceae               AM               AM
# 241       Wurfbainia     Zingiberaceae               AM               AM
#
#     genus state
# 29    NaN   NaN
# 81    NaN   NaN
# 99    NaN   NaN
# 101   NaN   NaN
# 120   NaN   NaN
# 121   NaN   NaN
# 130   NaN   NaN
# 134   NaN   NaN
# 166   NaN   NaN
# 169   NaN   NaN
# 186   NaN   NaN
# 189   NaN   NaN
# 193   NaN   NaN
# 241   NaN   NaN

# %%
# reconcile these
# all of these have been corrected manually in state_revision_2

pd.merge(left=one_state_genera, left_on="F01286", right=fungalroot_genus_level_states, right_on="genus", how="left").query(r"state_revision_1!=state").dropna(subset="state")
# Out:
#            F01286          F01289 state_revision_1 state_revision_2  \
# 22       Apodytes  Metteniusaceae             NMAM               AM
# 30      Asplenium    Aspleniaceae               AM             NMAM
# 41      Campanula   Campanulaceae             NMAM               AM
# 55       Cibotium     Cibotiaceae               NM               AM
# 65   Corythophora   Lecythidaceae               AM             NMAM
# 111        Gnetum       Gnetaceae               AM              EcM
# 162     Oreocnide      Urticaceae               AM             NMAM
# 163   Orthocarpus   Orobanchaceae             NMAM               NM
# 203     Schoepfia   Schoepfiaceae               NM               AM
# 219     Thymelaea   Thymelaeaceae             NMAM               AM
# 238    Myriocarpa      Urticaceae               AM             NMAM
#
#             genus state
# 22       Apodytes    AM
# 30      Asplenium  NMAM
# 41      Campanula    AM
# 55       Cibotium    AM
# 65   Corythophora  NMAM
# 111        Gnetum   EcM
# 162     Oreocnide  NMAM
# 163   Orthocarpus    NM
# 203     Schoepfia    AM
# 219     Thymelaea    AM
# 238    Myriocarpa  NMAM

# %%
# great :)
pd.merge(left=one_state_genera, left_on="F01286", right=fungalroot_genus_level_states, right_on="genus", how="left").query(r"state_revision_2!=state").dropna(subset="state")
# Out:
# Empty DataFrame
# Columns: [F01286, F01289, state_revision_1, state_revision_2, genus, state]
# Index: []

# %%
# cross validate these at a higher taxonomic level
# these records are all correct :)

pd.merge(left=one_state_genera, left_on="F01286", right=fungalroot_genus_level_states, right_on="genus", how="left").query(r"state.isna()").sort_values(by="F01289")
# Out:
#               F01286            F01289 state_revision_1 state_revision_2  \
# 29     Sciodaphyllum        Araliaceae               AM               AM
# 120     Heptapleurum        Araliaceae               AM               AM
# 134          Lomaria       Blechnaceae               AM               AM
# 166     Parablechnum       Blechnaceae               AM               AM
# 121        Hymenopus  Chrysobalanaceae               AM               AM
# 130     Leptobalanus  Chrysobalanaceae               AM               AM
# 193      Pterophylla       Cunoniaceae               AM               AM
# 99          Richetia  Dipterocarpaceae              EcM              EcM
# 101      Rubroshorea  Dipterocarpaceae              EcM              EcM
# 189  Pseudodiphasium     Lycopodiaceae               AM               AM
# 81      Didymocheton         Meliaceae               AM               AM
# 186       Prasoxylon         Meliaceae               AM               AM
# 169     Pectinopitys     Podocarpaceae               AM               AM
# 241       Wurfbainia     Zingiberaceae               AM               AM
#
#     genus state
# 29    NaN   NaN
# 120   NaN   NaN
# 134   NaN   NaN
# 166   NaN   NaN
# 121   NaN   NaN
# 130   NaN   NaN
# 193   NaN   NaN
# 99    NaN   NaN
# 101   NaN   NaN
# 189   NaN   NaN
# 81    NaN   NaN
# 186   NaN   NaN
# 169   NaN   NaN
# 241   NaN   NaN

# %%
#---------
# tests
#---------

pd.merge(
    left=revision.query(r"F01289==''").loc[:, ["binominal", "F01286", "state_revision_1"]].drop_duplicates(subset=["F01286", "state_revision_1"]),
    left_on="F01286", right=fungalroot_genus_level_states, right_on="genus", how="left"
).drop("genus", axis=1).query(r"state_revision_1!=state")
# Out:
# Empty DataFrame
# Columns: [binominal, F01286, state_revision_1, state]
# Index: []

# %% [markdown]
# ## ___Final dataset___
# --------------------------------

# %%
continuous = pd.read_csv(r"../../data/chapter2/FRED/subsets/continuous.csv")#.drop("F01290", axis=1)
continuous.insert(loc=0, column="binominal", value=(continuous.F01286 + ' ' + continuous.F01287).str.strip())
continuous
# Out:
#                   binominal         F01286          F01287    F00679  \
# 0                Abies alba          Abies            alba -0.596620
# 1         Abies nephrolepis          Abies     nephrolepis -0.878915
# 2     Acacia auriculiformis         Acacia  auriculiformis -0.775306
# 3        Acacia crassicarpa         Acacia     crassicarpa -1.487530
# 4            Acacia mangium         Acacia         mangium -1.376146
# ...                     ...            ...             ...       ...
# 1296    Xanthophyllum tenue  Xanthophyllum           tenue -0.839657
# 1297        Zabelia biflora        Zabelia         biflora -0.636389
# 1298         Zamia lucayana          Zamia        lucayana -1.122257
# 1299            Zizia aurea          Zizia           aurea -1.171183
# 1300       Zygia inaequalis          Zygia      inaequalis -1.002393
#
#       F00679_se    F00727  F00727_se    F00709  F00709_se
# 0      0.064797  3.254372   0.456743 -1.461081   0.231134
# 1           NaN  3.297534        NaN -1.274017        NaN
# 2      0.157080  3.024911   0.570188 -1.241175   0.077620
# 3           NaN  4.684720        NaN -1.021651        NaN
# 4           NaN  4.597037        NaN -1.237874        NaN
# ...         ...       ...        ...       ...        ...
# 1296   0.076147  3.227455   0.019219 -1.283188   0.154148
# 1297        NaN  3.432278        NaN -1.919393        NaN
# 1298   0.078265  4.008260   0.258687 -1.516667   0.032747
# 1299        NaN  4.605170        NaN -2.040221        NaN
# 1300        NaN  3.264232        NaN -1.016111        NaN
#
# [1301 rows x 9 columns]

# %%
categorical = pd.read_excel(r"../../data/chapter2/FRED/subsets/species.xlsx", sheet_name="combined").drop("F01290_not_crosschecked", axis=1)
categorical
# Out:
#                   binominal         F01286          F01289 reconciled_state  \
# 0                Abies alba          Abies        Pinaceae              EcM
# 1         Abies nephrolepis          Abies        Pinaceae              EcM
# 2     Acacia auriculiformis         Acacia        Fabaceae               AM
# 3        Acacia crassicarpa         Acacia        Fabaceae            EcMAM
# 4            Acacia mangium         Acacia        Fabaceae            EcMAM
# ...                     ...            ...             ...              ...
# 1296    Xanthophyllum tenue  Xanthophyllum    Polygalaceae               AM
# 1297        Zabelia biflora        Zabelia  Caprifoliaceae               AM
# 1298         Zamia lucayana          Zamia       Zamiaceae               AM
# 1299            Zizia aurea          Zizia        Apiaceae               AM
# 1300       Zygia inaequalis          Zygia        Fabaceae               AM
#
#           source state_revision_1 revision_1_source state_revision_2  \
# 0          FRED4              EcM               NaN              EcM
# 1          FRED4              EcM               NaN              EcM
# 2          FRED4               AM               NaN            EcMAM
# 3          FRED4            EcMAM               NaN            EcMAM
# 4          FRED4            EcMAM               NaN            EcMAM
# ...          ...              ...               ...              ...
# 1296       FRED4               AM               NaN               AM
# 1297       FRED4               AM               NaN               AM
# 1298       FRED4               AM               NaN               AM
# 1299  FungalRoot               AM               NaN               AM
# 1300       FRED4               AM               NaN               AM
#
#                   revision_2_source  \
# 0                               NaN
# 1                               NaN
# 2     (Soudzilovskaia et al., 2020)
# 3                               NaN
# 4                               NaN
# ...                             ...
# 1296                            NaN
# 1297                            NaN
# 1298                            NaN
# 1299                            NaN
# 1300                            NaN
#
#                                                synonyms
# 0     ['Pinus alba', 'Pinus abies var. pectinata', '...
# 1     ['Abies veitchii var. nephrolepis', 'Abies sib...
# 2                          ['Racosperma auriculiforme']
# 3                           ['Racosperma crassicarpum']
# 4                                ['Racosperma mangium']
# ...                                                 ...
# 1296                                                NaN
# 1297                                 ['Abelia biflora']
# 1298                                                NaN
# 1299  ['Smyrnium aureum', 'Sison aureum', 'Carum aur...
# 1300  ['Inga inaequalis', 'Pithecellobium inaequale'...
#
# [1301 rows x 10 columns]

# %%
source = categorical.loc[:, ["reconciled_state", "source", "state_revision_1", "revision_1_source", "state_revision_2", "revision_2_source"]]
source
# Out:
#      reconciled_state      source state_revision_1 revision_1_source  \
# 0                 EcM       FRED4              EcM               NaN
# 1                 EcM       FRED4              EcM               NaN
# 2                  AM       FRED4               AM               NaN
# 3               EcMAM       FRED4            EcMAM               NaN
# 4               EcMAM       FRED4            EcMAM               NaN
# ...               ...         ...              ...               ...
# 1296               AM       FRED4               AM               NaN
# 1297               AM       FRED4               AM               NaN
# 1298               AM       FRED4               AM               NaN
# 1299               AM  FungalRoot               AM               NaN
# 1300               AM       FRED4               AM               NaN
#
#      state_revision_2              revision_2_source
# 0                 EcM                            NaN
# 1                 EcM                            NaN
# 2               EcMAM  (Soudzilovskaia et al., 2020)
# 3               EcMAM                            NaN
# 4               EcMAM                            NaN
# ...               ...                            ...
# 1296               AM                            NaN
# 1297               AM                            NaN
# 1298               AM                            NaN
# 1299               AM                            NaN
# 1300               AM                            NaN
#
# [1301 rows x 6 columns]

# %%
# to unify the sources the state info has come from; 
# first prioritize the revision 2 source, if that's empty, use revision 1 source
# if both of these are empty, use the original 'source' column

unified_sources = source.revision_2_source.fillna(source.revision_1_source).fillna(source.source)#.isna().sum()
unified_sources.value_counts()
# Out:
# revision_2_source
# FRED4                             775
# (Brundrett and Tedersoo, 2018)    240
# (Soudzilovskaia et al., 2020)     110
# FungalRoot                         76
# Maherali et. al. 2016              62
# Luke                               38
# Name: count, dtype: int64

# %%
# cleanup the state resource column

unified_sources = unified_sources.replace({"FungalRoot": "(Soudzilovskaia et al., 2020)", "Luke": "(Brundrett and Tedersoo, 2018)", "Maherali et. al. 2016": "(Maherali et. al. 2016)"})
unified_sources.value_counts()
# Out:
# revision_2_source
# FRED4                             775
# (Brundrett and Tedersoo, 2018)    278
# (Soudzilovskaia et al., 2020)     186
# (Maherali et. al. 2016)            62
# Name: count, dtype: int64

# %%
continuous.columns
# Out:
# Index(['binominal', 'F01286', 'F01287', 'F00679', 'F00679_se', 'F00727',
#        'F00727_se', 'F00709', 'F00709_se'],
#       dtype='str')

# %%
# categorical.loc[:, ["binominal", "F01286", "F01289", "state_revision_2"]].assign(state_source=unified_sources)

# %%
final = pd.merge(left=categorical.loc[:, ["binominal", "F01286", "F01289", "state_revision_2", "synonyms"]].assign(state_source=unified_sources), left_on="binominal",
        right=continuous, right_on="binominal", how="left", suffixes=('', '_')).rename({"state_revision_2": "state"}, axis=1)
final
# Out:
#                   binominal         F01286          F01289  state  \
# 0                Abies alba          Abies        Pinaceae    EcM
# 1         Abies nephrolepis          Abies        Pinaceae    EcM
# 2     Acacia auriculiformis         Acacia        Fabaceae  EcMAM
# 3        Acacia crassicarpa         Acacia        Fabaceae  EcMAM
# 4            Acacia mangium         Acacia        Fabaceae  EcMAM
# ...                     ...            ...             ...    ...
# 1296    Xanthophyllum tenue  Xanthophyllum    Polygalaceae     AM
# 1297        Zabelia biflora        Zabelia  Caprifoliaceae     AM
# 1298         Zamia lucayana          Zamia       Zamiaceae     AM
# 1299            Zizia aurea          Zizia        Apiaceae     AM
# 1300       Zygia inaequalis          Zygia        Fabaceae     AM
#
#                                                synonyms  \
# 0     ['Pinus alba', 'Pinus abies var. pectinata', '...
# 1     ['Abies veitchii var. nephrolepis', 'Abies sib...
# 2                          ['Racosperma auriculiforme']
# 3                           ['Racosperma crassicarpum']
# 4                                ['Racosperma mangium']
# ...                                                 ...
# 1296                                                NaN
# 1297                                 ['Abelia biflora']
# 1298                                                NaN
# 1299  ['Smyrnium aureum', 'Sison aureum', 'Carum aur...
# 1300  ['Inga inaequalis', 'Pithecellobium inaequale'...
#
#                        state_source        F01286_          F01287    F00679  \
# 0                             FRED4          Abies            alba -0.596620
# 1                             FRED4          Abies     nephrolepis -0.878915
# 2     (Soudzilovskaia et al., 2020)         Acacia  auriculiformis -0.775306
# 3                             FRED4         Acacia     crassicarpa -1.487530
# 4                             FRED4         Acacia         mangium -1.376146
# ...                             ...            ...             ...       ...
# 1296                          FRED4  Xanthophyllum           tenue -0.839657
# 1297                          FRED4        Zabelia         biflora -0.636389
# 1298                          FRED4          Zamia        lucayana -1.122257
# 1299  (Soudzilovskaia et al., 2020)          Zizia           aurea -1.171183
# 1300                          FRED4          Zygia      inaequalis -1.002393
#
#       F00679_se    F00727  F00727_se    F00709  F00709_se
# 0      0.064797  3.254372   0.456743 -1.461081   0.231134
# 1           NaN  3.297534        NaN -1.274017        NaN
# 2      0.157080  3.024911   0.570188 -1.241175   0.077620
# 3           NaN  4.684720        NaN -1.021651        NaN
# 4           NaN  4.597037        NaN -1.237874        NaN
# ...         ...       ...        ...       ...        ...
# 1296   0.076147  3.227455   0.019219 -1.283188   0.154148
# 1297        NaN  3.432278        NaN -1.919393        NaN
# 1298   0.078265  4.008260   0.258687 -1.516667   0.032747
# 1299        NaN  4.605170        NaN -2.040221        NaN
# 1300        NaN  3.264232        NaN -1.016111        NaN
#
# [1301 rows x 14 columns]

# %%
final.columns
# Out:
# Index(['binominal', 'F01286', 'F01289', 'state', 'synonyms', 'state_source',
#        'F01286_', 'F01287', 'F00679', 'F00679_se', 'F00727', 'F00727_se',
#        'F00709', 'F00709_se'],
#       dtype='str')

# %%
final = final.loc[:, ["binominal", "F01286", "F01289", "F00679", "F00679_se", "F00727", "F00727_se", "F00709", "F00709_se", "state", "state_source"]]
final
# Out:
#                   binominal         F01286          F01289    F00679  \
# 0                Abies alba          Abies        Pinaceae -0.596620
# 1         Abies nephrolepis          Abies        Pinaceae -0.878915
# 2     Acacia auriculiformis         Acacia        Fabaceae -0.775306
# 3        Acacia crassicarpa         Acacia        Fabaceae -1.487530
# 4            Acacia mangium         Acacia        Fabaceae -1.376146
# ...                     ...            ...             ...       ...
# 1296    Xanthophyllum tenue  Xanthophyllum    Polygalaceae -0.839657
# 1297        Zabelia biflora        Zabelia  Caprifoliaceae -0.636389
# 1298         Zamia lucayana          Zamia       Zamiaceae -1.122257
# 1299            Zizia aurea          Zizia        Apiaceae -1.171183
# 1300       Zygia inaequalis          Zygia        Fabaceae -1.002393
#
#       F00679_se    F00727  F00727_se    F00709  F00709_se  state  \
# 0      0.064797  3.254372   0.456743 -1.461081   0.231134    EcM
# 1           NaN  3.297534        NaN -1.274017        NaN    EcM
# 2      0.157080  3.024911   0.570188 -1.241175   0.077620  EcMAM
# 3           NaN  4.684720        NaN -1.021651        NaN  EcMAM
# 4           NaN  4.597037        NaN -1.237874        NaN  EcMAM
# ...         ...       ...        ...       ...        ...    ...
# 1296   0.076147  3.227455   0.019219 -1.283188   0.154148     AM
# 1297        NaN  3.432278        NaN -1.919393        NaN     AM
# 1298   0.078265  4.008260   0.258687 -1.516667   0.032747     AM
# 1299        NaN  4.605170        NaN -2.040221        NaN     AM
# 1300        NaN  3.264232        NaN -1.016111        NaN     AM
#
#                        state_source
# 0                             FRED4
# 1                             FRED4
# 2     (Soudzilovskaia et al., 2020)
# 3                             FRED4
# 4                             FRED4
# ...                             ...
# 1296                          FRED4
# 1297                          FRED4
# 1298                          FRED4
# 1299  (Soudzilovskaia et al., 2020)
# 1300                          FRED4
#
# [1301 rows x 11 columns]

# %%
# the synonyms column in species.xlsx needs some changes as i didn't include the matches from the synonyms column in the WCVP table
# this will rectify that

synonyms = pd.read_csv(r"../../data/chapter2/FRED/subsets/synonyms.csv")
final = pd.merge(left=final, left_on="binominal", right=synonyms, right_on="name", how="left").drop("name", axis=1)
final
# Out:
#                   binominal         F01286          F01289    F00679  \
# 0                Abies alba          Abies        Pinaceae -0.596620
# 1         Abies nephrolepis          Abies        Pinaceae -0.878915
# 2     Acacia auriculiformis         Acacia        Fabaceae -0.775306
# 3        Acacia crassicarpa         Acacia        Fabaceae -1.487530
# 4            Acacia mangium         Acacia        Fabaceae -1.376146
# ...                     ...            ...             ...       ...
# 1296    Xanthophyllum tenue  Xanthophyllum    Polygalaceae -0.839657
# 1297        Zabelia biflora        Zabelia  Caprifoliaceae -0.636389
# 1298         Zamia lucayana          Zamia       Zamiaceae -1.122257
# 1299            Zizia aurea          Zizia        Apiaceae -1.171183
# 1300       Zygia inaequalis          Zygia        Fabaceae -1.002393
#
#       F00679_se    F00727  F00727_se    F00709  F00709_se  state  \
# 0      0.064797  3.254372   0.456743 -1.461081   0.231134    EcM
# 1           NaN  3.297534        NaN -1.274017        NaN    EcM
# 2      0.157080  3.024911   0.570188 -1.241175   0.077620  EcMAM
# 3           NaN  4.684720        NaN -1.021651        NaN  EcMAM
# 4           NaN  4.597037        NaN -1.237874        NaN  EcMAM
# ...         ...       ...        ...       ...        ...    ...
# 1296   0.076147  3.227455   0.019219 -1.283188   0.154148     AM
# 1297        NaN  3.432278        NaN -1.919393        NaN     AM
# 1298   0.078265  4.008260   0.258687 -1.516667   0.032747     AM
# 1299        NaN  4.605170        NaN -2.040221        NaN     AM
# 1300        NaN  3.264232        NaN -1.016111        NaN     AM
#
#                        state_source  \
# 0                             FRED4
# 1                             FRED4
# 2     (Soudzilovskaia et al., 2020)
# 3                             FRED4
# 4                             FRED4
# ...                             ...
# 1296                          FRED4
# 1297                          FRED4
# 1298                          FRED4
# 1299  (Soudzilovskaia et al., 2020)
# 1300                          FRED4
#
#                                                 synonym
# 0     ('Pinus alba', 'Pinus abies var. pectinata', '...
# 1     ('Abies veitchii var. nephrolepis', 'Abies sib...
# 2                         ('Racosperma auriculiforme',)
# 3                          ('Racosperma crassicarpum',)
# 4                               ('Racosperma mangium',)
# ...                                                 ...
# 1296                                                NaN
# 1297                                ('Abelia biflora',)
# 1298                                                NaN
# 1299  ('Smyrnium aureum', 'Sison aureum', 'Carum aur...
# 1300  ('Inga inaequalis', 'Pithecellobium inaequale'...
#
# [1301 rows x 12 columns]

# %%
# this needs to be hand edited to recitify some issues with phylogeny creation - names not binding the phylogeny
# which can be rectified using synonyms

final.to_excel(r"../../data/chapter2/FRED/subsets/_final.xlsx", sheet_name="final", index=False)

# %%
# species that failed to bind the phylogeny
__sp = ("Blechnopsis orientalis", "Lomaria discolor", "Parablechnum novae-zelandiae", "Parablechnum procerum", "Richetia multiflora", "Rubroshorea acuminata", "Rubroshorea leprosula", "Pseudodiphasium volubile")


synonyms.query(r"name.isin(@__sp)")
# Out:
#                              name  \
# 107        Blechnopsis orientalis
# 455              Lomaria discolor
# 594  Parablechnum novae-zelandiae
# 595         Parablechnum procerum
# 679      Pseudodiphasium volubile
# 711           Richetia multiflora
# 716         Rubroshorea acuminata
# 717         Rubroshorea leprosula
#
#                                                synonym
# 107                            ('Blechnum orientale',)
# 455                             ('Blechnum discolor',)
# 594                      ('Blechnum novae-zelandiae',)
# 595                             ('Blechnum procerum',)
# 679                           ('Lycopodium volubile',)
# 711  ('Doona multiflora', 'Balanocarpus multiflorus...
# 716                              ('Shorea acuminata',)
# 717                              ('Shorea leprosula',)

# %% [markdown]
# ## ___Interspecific trait variations___
# ---------------------

# %%
continuous = pd.read_csv(r"../../data/chapter2/FRED/subsets/continuous_raw.csv")
continuous.loc[:, CHOSEN_ROOT_TRAITS] = continuous.loc[:, CHOSEN_ROOT_TRAITS].apply(np.log) # log transform the traits
# tranformed_traits = StandardScaler().fit_transform(X=continuous.loc[:, CHOSEN_ROOT_TRAITS]) # X must be of shape (n_samples, n_features)

# %%
multiple_entries = continuous.binominal.value_counts()[continuous.binominal.value_counts() > 1].index
multiple_entries = continuous.query(r"binominal.isin(@multiple_entries)")

# %%
multiple_entries.groupby("binominal", as_index=False).agg({"F00679": ["mean", "std"], "F00727": ["mean", "std"], "F00709": ["mean", "std"]})
# Out:
#                     binominal    F00679              F00727            \
#                                    mean       std      mean       std
# 0                  Abies_alba -0.596620  0.112231  3.254372  0.791102
# 1       Acacia_auriculiformis -0.775306  0.384766  3.024911  1.396669
# 2              Acer_campestre -0.865303  0.026877  3.340003  0.619470
# 3         Acer_coriaceifolium -1.222555  0.233877  4.408035  0.480166
# 4                Acer_davidii -1.020159  0.502850  3.388624  1.330575
# ..                        ...       ...       ...       ...       ...
# 564    Weinmannia_microphylla -0.972320  0.132791  2.987252  0.617997
# 565      Weinmannia_silvicola -0.966956  0.125816  3.730058  0.374090
# 566  Xanthophyllum_flavescens -0.305876  0.194167  1.775389  0.473521
# 567       Xanthophyllum_tenue -0.839657  0.152294  3.227455  0.038439
# 568            Zamia_lucayana -1.122257  0.135559  4.008260  0.448059
#
#        F00709
#          mean       std
# 0   -1.461081  0.400336
# 1   -1.241175  0.190130
# 2   -1.356783  0.587145
# 3   -1.661656  0.052686
# 4   -1.104812  0.412239
# ..        ...       ...
# 564 -0.801480  0.417682
# 565 -1.547968  0.355135
# 566 -0.775080  0.173947
# 567 -1.283188  0.308296
# 568 -1.516667  0.056719
#
# [569 rows x 7 columns]

# %%
fig, axes = plt.subplots()
fig.set_size_inches(20, 10)
#
plt.show()
