# %%
# !python --version
# Out:
# Python 3.13.7

# %%
import os
import gc
import re

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from Bio import Phylo

# %%
[gc.collect(_) for _ in range(3)]
# Out:
# [0, 0, 0]

# %%
phylogeny = Phylo.read(r"../data/UPhyloMaker/chapter03.tre", format="newick")
phylogeny.rooted = True

# %%
fig, axes = plt.subplots()
fig.set_size_inches(20, 50)
Phylo.draw(phylogeny, axes=axes)
