# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array([0, 3, 6, 8]) # widths of the cubes along the x and y axis
z = np.array([2, 2, 3, 3]) # heights of the cubes along the x and y axis - which makes the z axis

# %%
# https://matplotlib.org/stable/gallery/mplot3d/voxels_numpy_logo.html

# %%
def explode(data):
    size = np.array(data.shape)*2
    data_e = np.zeros(size - 1, dtype=data.dtype)
    data_e[::2, ::2, ::2] = data
    return data_e

# build up the numpy logo
filled = np.ones(shape=(3, 3, 4))

# upscale the above voxel image, leaving gaps
filled = explode(filled)


# Shrink the gaps
x, y, z = np.indices(np.array(filled_2.shape) + 1).astype(float) // 2
x[0::2, :, :] += 0.05
y[:, 0::2, :] += 0.05
z[:, :, 0::2] += 0.05
x[1::2, :, :] += 0.95
y[:, 1::2, :] += 0.95
z[:, :, 1::2] += 0.95

ax = plt.figure().add_subplot(projection='3d')
ax.voxels(x, y, z, filled)#, facecolors=fcolors_2, edgecolors=ecolors_2)
# ax.set_aspect('equal')

plt.show()
