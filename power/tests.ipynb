# %%
# !python --version
# Out:
# Python 3.13.8
# The system cannot find the path specified.

# %%
from power import ttest, TtestDispatcher, ttest2n, Ttest2nDispatcher

# %%
ttest(d=0.5, n=20, power=None, contrast="one-sample")
# Out:
# np.float64(0.5645044184390379)

# %%
ttest.__name__
# Out:
# 'ttest'

# %%
print("power: %.4f" % ttest(d=0.5, n=20, contrast="one-sample")) # power: 0.5645
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 print("power: %.4f" % ttest(d=0.5, n=20, contrast="one-sample")) # power: 0.5645
#
# TypeError: ttest() missing 1 required positional argument: 'power'

# %%
print("n: %.4f" % ttest(d=0.5, power=0.80, _func_alternative=TtestDispatcher.greater)) # n: 50.1508
# Out:
# n: 50.1508

# %%
print("d: %.4f" % ttest(n=20, power=0.80, alpha=0.05, contrast="paired")) # cd: 0.6604
# Out:
# d: 0.6604

# %%
print("alpha: %.4f" % ttest(d=0.5, n=20, power=0.80, alpha=None)) # alpha: 0.4430
# Out:
# alpha: 0.4430

# %%
print("power: %.4f" % ttest(d=0.5, n=20, _func_alternative=TtestDispatcher.greater)) # power: 0.4634
# Out:
# power: 0.4634

# %%
print("power: %.4f" % power_ttest(d=0.5, n=20, _func_alternative=ttest_dispatcher.less)) # power: 0.0007
# Out:
# power: 0.0007

# %%
print("power: %.4f" % ttest2n(nx=20, ny=15, d=0.5, _func_alternative=Ttest2nDispatcher.greater)) # power: 0.4164
# Out:
# power: 0.4164

# %%
print("alpha: %.4f" % ttest2n(nx=20, ny=15, d=0.5, power=0.80, alpha=None)) # alpha: 0.5000
# Out:
# alpha: 0.5000

# %%
print("d: %.4f" % ttest2n(nx=20, ny=15, power=0.80, alpha=0.05)) # d: 0.9859
# Out:
# d: 0.9859
