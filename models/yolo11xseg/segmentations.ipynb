# %% [markdown]
# ## ___YOLO11X-seg___
# ------------------

# %%
# of all the segmentation libs I've refactored so far this is the most bloated garbage POS

# %%
# !python --version
# Out:
# Python 3.14.2
# The system cannot find the path specified.

# %%
from PIL import Image
import torch
import matplotlib.pyplot as plt
import numpy as np

# %%
from model import YOLO
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 from model import YOLO
#
# File ~\OneDrive - Western Sydney University\PhD\code\models\yolo11xseg\model.py:8
#       5 from pathlib import Path
#       6 from typing import Any, override
# ----> 8 from yolo.detect import DetectionPredictor, DetectionTrainer, DetectionValidator
#       9 from yolo.engine.model import Model
#      10 from yolo.nn.tasks import DetectionModel, SegmentationModel
#
# File ~\OneDrive - Western Sydney University\PhD\code\models\yolo11xseg\yolo\detect\__init__.py:3
#       1 # Ultralytics 🚀 AGPL-3.0 License - https://ultralytics.com/license
# ----> 3 from .predict import DetectionPredictor
#       4 from .train import DetectionTrainer
#       5 from .val import DetectionValidator
#
# ...

# %%
seg11x = YOLO(r"../bin/yolo11x-seg.pt")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 seg11x = YOLO(r"../bin/yolo11x-seg.pt")
#
# NameError: name 'YOLO' is not defined
