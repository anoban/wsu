# %% [markdown]
# # ___Segment Anything Model (SAM)___
# -------------------------

# %%
from segment_anything import SamPredictor, build_sam_vit_h

# %%
model = SamPredictor(build_sam_vit_h(r"../bin/sam_vit_h_4b8939.pth"))

# %%
model
