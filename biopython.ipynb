# %%
import os
import gc

from matplotlib import pyplot as plt
from matplotlib import pylab
from Bio import Phylo

# %%
# os.listdir()
tree = Phylo.read(r"./ALLOTB.tre", format="newick")

# %%
# print(tree)
tree.rooted = True # why??
Phylo.draw(tree)

# %%
gc.collect(2)
# Out:
# 75783572

# %%
# use a simple newick file
os.listdir(r"./phylocom/example_data/phylomatic/")
# Out:
# ['davies.bl.new', 'phylo', 'R20100701.new', 'taxa', 'taxa_2']

# %%
with open(file=r"./phylocom/example_data/phylomatic/R20100701.new", mode="r") as fp:
    r20100701 = fp.read()

# %%
r20100701 = Phylo.read(r"./phylocom/example_data/phylomatic/R20100701.new", format="newick")

# %%
# print(r20100701);

fig, axes = plt.subplots(nrows=1, ncols=1)
fig.set_size_inches(40, 300)
Phylo.draw(r20100701, axes=axes)
fig.savefig("./r20100701.jpeg", format="jpeg", dpi=200)

# %%
# well that's something :)
