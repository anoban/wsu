# %%
import os
import gc

import matplotlib.pyplot as plt
from matplotlib import pylab
from Bio import Phylo

# %%
# os.listdir()
tree = Phylo.read(r"./ALLOTB.tre", format="newick")

# %%
# print(tree)
tree.rooted = True # why??
Phylo.draw(tree)

# %%
gc.collect(2)
# Out:
# 75783572
