# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter
import os
import torch

pd.options.display.max_rows = 100
np.set_printoptions(threshold=np.inf)

# %%
# https://github.com/GRooT-Database/GRooT-Data/blob/master/DataFiles/GRooTAggregateSpeciesVersion.zip
# download and unzip the above .zip file for the .csv database
groot = pd.read_csv(r"./GRooTFullVersion.csv", encoding="latin", low_memory=False)
groot.head()
# Out:
#    GRooTID source  versionSource  originalID referencesAbbreviated  \
# 0        1   FRED            2.0     33116.0         Aaltonen 1920
# 1        2   FRED            2.0     33115.0         Aaltonen 1920
# 2        3   FRED            2.0     33113.0         Aaltonen 1920
# 3        4   FRED            2.0     33112.0         Aaltonen 1920
# 4        5   FRED            2.0     33114.0         Aaltonen 1920
#
#                                           references  \
# 0  Aaltonen VT. 1920. Abreiten Der Forstwissensch...
# 1  Aaltonen VT. 1920. Abreiten Der Forstwissensch...
# 2  Aaltonen VT. 1920. Abreiten Der Forstwissensch...
# 3  Aaltonen VT. 1920. Abreiten Der Forstwissensch...
# 4  Aaltonen VT. 1920. Abreiten Der Forstwissensch...
#
#                                    referencesDataset referencesAdditional  \
# 0  Fan Y, Miguez-Macho G, Jobbagy EG, Jackson RB,...                  NaN
# 1  Fan Y, Miguez-Macho G, Jobbagy EG, Jackson RB,...                  NaN
# 2  Fan Y, Miguez-Macho G, Jobbagy EG, Jackson RB,...                  NaN
# 3  Fan Y, Miguez-Macho G, Jobbagy EG, Jackson RB,...                  NaN
# 4  Fan Y, Miguez-Macho G, Jobbagy EG, Jackson RB,...                  NaN
#
#   family   genus  ... belowgroundEntitiesOrder belowgroundEntitiesOrderMin  \
# 0    NaN  Betula  ...                      NaN                         NaN
# 1    NaN   Picea  ...                      NaN                         NaN
# 2    NaN   Pinus  ...                      NaN                         NaN
# 3    NaN   Pinus  ...                      NaN                         NaN
# 4    NaN   Pinus  ...                      NaN                         NaN
#
#   belowgroundEntitiesOrderMax belowgroundEntitiesFunctional  \
# 0                         NaN                           NaN
# 1                         NaN                           NaN
# 2                         NaN                           NaN
# 3                         NaN                           NaN
# 4                         NaN                           NaN
#
#   belowgroundEntitiesDiameterMin belowgroundEntitiesDiameterMax  \
# 0                            NaN                            NaN
# 1                            NaN                            NaN
# 2                            NaN                            NaN
# 3                            NaN                            NaN
# 4                            NaN                            NaN
#
#        traitName traitValue errorRiskEntries errorRisk
# 0  Rooting_depth       0.85              NaN       NaN
# 1  Rooting_depth       0.90              NaN       NaN
# 2  Rooting_depth       1.00              NaN       NaN
# 3  Rooting_depth       0.98              NaN       NaN
# 4  Rooting_depth       0.56              NaN       NaN
#
# [5 rows x 73 columns]

# %%
# it's not that big though!!!!!
groot.shape
# Out:
# (114222, 73)

# %%
groot.columns
# Out:
# Index(['GRooTID', 'source', 'versionSource', 'originalID',
#        'referencesAbbreviated', 'references', 'referencesDataset',
#        'referencesAdditional', 'family', 'genus', 'species', 'infraspecific',
#        'familyTNRS', 'genusTNRS', 'speciesTNRS', 'infraspecificTNRS',
#        'taxonomicStatus', 'taxonomicInformation', 'group', 'order',
#        'growthForm', 'photosyntheticPathway', 'woodiness',
#        'mycorrhizalAssociationType', 'mycorrhizalAssociationTypeFungalRoot',
#        'nitrogenFixationNodDB', 'abilityToGrownClonallyCloPla',
#        'budBearingOrganCloPla', 'vitality', 'measurementProvenance',
#        'measurementTreatments', 'measurementMethod', 'year', 'yearBegin',
#        'yearEnd', 'ageStand', 'agePlant', 'locationID', 'location',
#        'decimalLatitude', 'decimalLongitud', 'climaticInformation',
#        'biomesKoeppen', 'biomesKoeppenGroup', 'temperatureColdestMonth',
#        'temperatureWarmestMonth', 'meanAnnualTemperature',
#        'meanAnnualPrecipitation', 'elevation', 'slope', 'soilpH',
#        'soilTexture', 'soilCarbon', 'soilNitrogen', 'soilPhosphorus',
#        'soilCarbonToNitrogen', 'soilBaseCationSaturation',
#        'soilCationExchangeCapacity', 'soilOrganicMatter',
#        'soilWaterGravimetric', 'soilWaterVolumetric', 'belowgroundEntities',
#        'belowgroundEntitiesOrderClassification', 'belowgroundEntitiesOrder',
#        'belowgroundEntitiesOrderMin', 'belowgroundEntitiesOrderMax',
#        'belowgroundEntitiesFunctional', 'belowgroundEntitiesDiameterMin',
#        'belowgroundEntitiesDiameterMax', 'traitName', 'traitValue',
#        'errorRiskEntries', 'errorRisk'],
#       dtype='object')

# %%
# this is a ROOT trait database!!!!
groot.loc[:, "traitName"].unique()
# Out:
# array(['Rooting_depth', 'Root_production', 'Root_turnover_rate',
#        'Root_C_concentration', 'Root_C_N_ratio',
#        'Root_lignin_concentration', 'Root_N_concentration',
#        'Root_total_structural_carbohydrate_concentration',
#        'Root_Ca_concentration', 'Root_K_concentration',
#        'Root_Mg_concentration', 'Root_P_concentration',
#        'Root_length_density_volume', 'Specific_root_respiration',
#        'Root_mass_density', 'Root_Mn_concentration',
#        'Root_mycorrhizal colonization', 'Root_mass_fraction',
#        'Root_litter_mass_loss_rate', 'Coarse_root_fine_root_mass_ratio',
#        'Fine_root_mass_leaf_mass_ratio', 'Mean_Root_diameter',
#        'Root_tissue_density', 'Specific_root_area',
#        'Specific_root_length', 'Root_stele_diameter',
#        'Root_stele_fraction', 'Root_branching_density',
#        'Root_lifespan_mean', 'Root_lifespan_median',
#        'Root_vessel_diameter', 'Root_branching_ratio',
#        'Root_dry_matter_content', 'Root_cortex_thickness',
#        'Net_nitrogen_uptake_rate', 'Root_xylem_vessel_number',
#        'Root_N_P_ratio', 'Lateral_spread'], dtype=object)

# %%
np.unique(groot.loc[:, "traitName"], return_counts=True)
# Out:
# (array(['Coarse_root_fine_root_mass_ratio',
#         'Fine_root_mass_leaf_mass_ratio', 'Lateral_spread',
#         'Mean_Root_diameter', 'Net_nitrogen_uptake_rate', 'Root_C_N_ratio',
#         'Root_C_concentration', 'Root_Ca_concentration',
#         'Root_K_concentration', 'Root_Mg_concentration',
#         'Root_Mn_concentration', 'Root_N_P_ratio', 'Root_N_concentration',
#         'Root_P_concentration', 'Root_branching_density',
#         'Root_branching_ratio', 'Root_cortex_thickness',
#         'Root_dry_matter_content', 'Root_length_density_volume',
#         'Root_lifespan_mean', 'Root_lifespan_median',
#         'Root_lignin_concentration', 'Root_litter_mass_loss_rate',
#         'Root_mass_density', 'Root_mass_fraction',
#         'Root_mycorrhizal colonization', 'Root_production',
#         'Root_stele_diameter', 'Root_stele_fraction',
#         'Root_tissue_density',
#         'Root_total_structural_carbohydrate_concentration',
#         'Root_turnover_rate', 'Root_vessel_diameter',
#         'Root_xylem_vessel_number', 'Rooting_depth', 'Specific_root_area',
#         'Specific_root_length', 'Specific_root_respiration'], dtype=object),
#  array([ 1719,  1818,  1422, 10719,   239,  4493,  6124,  1521,  1460,
#          1408,   251,   179, 10212,  2742,  2130,   474,   384,  4097,
#          1794,   244,   231,   837,   621,  1815, 15524,  6819,   734,
#           982,  1080, 10521,   465,   523,   165,   129,  2669,  2693,
#         12364,  2620]))

# %%
fig, axes = plt.subplots()
fig.set_size_inches(20, 6)
traits, t_count = np.unique(groot.traitName, return_counts=True)
axes.hist(t_count, bins=t_count.size, color = "brown", rwidth=0.8)
axes.set_xticks(labels=traits, ticks=np.linspace(start=axes.get_xlim()[0], stop=axes.get_xlim()[1], num=traits.size), rotation=90)
plt.show()

# %%
groot.loc[:, ["traitName", "traitValue"]].isna().mean()
# Out:
# traitName     0.0
# traitValue    0.0
# dtype: float64

# %%
groot.loc[:, "family"].isna().mean()  # fucking hell!!!
# Out:
# np.float64(0.7910822783701914)

# %%
rdepth = groot.loc[groot.loc[:, "traitName"] == "Rooting_depth", ["genus", "traitValue"]]

# %%
rdepth.shape
# Out:
# (2669, 2)

# %%
genus = np.unique(groot.genus)

# %%
genus.size  # that's a lot!!!
# Out:
# 1959

# %%
genus, freqs = np.unique(groot.genus, return_counts=True)
pd.Series(genus, index=freqs).sort_index(ascending=False)[:20] # Pinus has the most records
# Out:
# 6675           Pinus
# 4075         Quercus
# 4069          Betula
# 3775            Acer
# 1966             Poa
# 1957         Festuca
# 1636           Carex
# 1589        Fraxinus
# 1485           Picea
# 1440        Plantago
# 1436          Galium
# 1398       Trifolium
# 1312    Anthoxanthum
# 1287           Larix
# 1283      Ranunculus
# 1259         Populus
# 1238        Dactylis
# 1148        Veronica
# 1118           Rumex
# 1113           Fagus
# dtype: object

# %%
pinus = groot.loc[np.bitwise_and(groot.genus == "Pinus", groot.traitName == "Rooting_depth"), "traitValue"]

# %%
pinus
# Out:
# 2        1.0000
# 3        0.9800
# 4        0.5600
# 290      2.2000
# 291      2.0000
#           ...
# 60095    0.8128
# 60096    0.0762
# 60097    0.9779
# 61501    1.2500
# 61510    1.0000
# Name: traitValue, Length: 140, dtype: float64

# %%
fig, axes = plt.subplots()
fig.set_size_inches(6, 6)
axes.hist(pinus)
plt.show()

# %%
# dask seems cumbersome, sticking to pandas :(

# %%
groot.columns, groot.columns.size
# Out:
# (Index(['GRooTID', 'source', 'versionSource', 'originalID',
#         'referencesAbbreviated', 'references', 'referencesDataset',
#         'referencesAdditional', 'family', 'genus', 'species', 'infraspecific',
#         'familyTNRS', 'genusTNRS', 'speciesTNRS', 'infraspecificTNRS',
#         'taxonomicStatus', 'taxonomicInformation', 'group', 'order',
#         'growthForm', 'photosyntheticPathway', 'woodiness',
#         'mycorrhizalAssociationType', 'mycorrhizalAssociationTypeFungalRoot',
#         'nitrogenFixationNodDB', 'abilityToGrownClonallyCloPla',
#         'budBearingOrganCloPla', 'vitality', 'measurementProvenance',
#         'measurementTreatments', 'measurementMethod', 'year', 'yearBegin',
#         'yearEnd', 'ageStand', 'agePlant', 'locationID', 'location',
#         'decimalLatitude', 'decimalLongitud', 'climaticInformation',
#         'biomesKoeppen', 'biomesKoeppenGroup', 'temperatureColdestMonth',
#         'temperatureWarmestMonth', 'meanAnnualTemperature',
#         'meanAnnualPrecipitation', 'elevation', 'slope', 'soilpH',
#         'soilTexture', 'soilCarbon', 'soilNitrogen', 'soilPhosphorus',
#         'soilCarbonToNitrogen', 'soilBaseCationSaturation',
#         'soilCationExchangeCapacity', 'soilOrganicMatter',
#         'soilWaterGravimetric', 'soilWaterVolumetric', 'belowgroundEntities',
#         'belowgroundEntitiesOrderClassification', 'belowgroundEntitiesOrder',
#         'belowgroundEntitiesOrderMin', 'belowgroundEntitiesOrderMax',
#         'belowgroundEntitiesFunctional', 'belowgroundEntitiesDiameterMin',
#         'belowgroundEntitiesDiameterMax', 'traitName', 'traitValue',
#         'errorRiskEntries', 'errorRisk'],
#        dtype='object'),
#  73)

# %%
groot.agePlant.isna().mean()  # WTF????
# Out:
# np.float64(0.9128626709390485)

# %%
groot.isna().mean(axis=0)
# Out:
# GRooTID                                   0.000000
# source                                    0.000000
# versionSource                             0.472238
# originalID                                0.301439
# referencesAbbreviated                     0.000000
# references                                0.000000
# referencesDataset                         0.656143
# referencesAdditional                      0.979312
# family                                    0.791082
# genus                                     0.000000
# species                                   0.014463
# infraspecific                             0.991324
# familyTNRS                                0.000079
# genusTNRS                                 0.000000
# speciesTNRS                               0.015645
# infraspecificTNRS                         0.991368
# taxonomicStatus                           0.000000
# taxonomicInformation                      0.000000
# group                                     0.089694
# order                                     0.000140
# growthForm                                0.043538
# photosyntheticPathway                     0.157141
# woodiness                                 0.036770
# mycorrhizalAssociationType                0.838017
# mycorrhizalAssociationTypeFungalRoot      0.019497
# nitrogenFixationNodDB                     0.934513
# abilityToGrownClonallyCloPla              0.580011
# budBearingOrganCloPla                     0.747894
# vitality                                  0.000000
# measurementProvenance                     0.000000
# measurementTreatments                     0.838639
# measurementMethod                         0.594912
# year                                      0.636182
# yearBegin                                 0.656301
# yearEnd                                   0.658472
# ageStand                                  0.890722
# agePlant                                  0.912863
# locationID                                0.713321
# location                                  0.319037
# decimalLatitude                           0.156572
# decimalLongitud                           0.156572
# climaticInformation                       0.914544
# biomesKoeppen                             0.375190
# biomesKoeppenGroup                        0.377948
# temperatureColdestMonth                   0.945974
# temperatureWarmestMonth                   0.945974
# meanAnnualTemperature                     0.767278
# meanAnnualPrecipitation                   0.753235
# elevation                                 0.836249
# slope                                     0.986903
# soilpH                                    0.839584
# soilTexture                               0.904887
# soilCarbon                                0.940152
# soilNitrogen                              0.871058
# soilPhosphorus                            0.925417
# soilCarbonToNitrogen                      0.985703
# soilBaseCationSaturation                  0.958677
# soilCationExchangeCapacity                0.955595
# soilOrganicMatter                         0.963755
# soilWaterGravimetric                      0.977159
# soilWaterVolumetric                       0.994379
# belowgroundEntities                       0.000000
# belowgroundEntitiesOrderClassification    0.808942
# belowgroundEntitiesOrder                  0.818564
# belowgroundEntitiesOrderMin               0.967432
# belowgroundEntitiesOrderMax               0.967624
# belowgroundEntitiesFunctional             0.819054
# belowgroundEntitiesDiameterMin            0.809459
# belowgroundEntitiesDiameterMax            0.805502
# traitName                                 0.000000
# traitValue                                0.000000
# errorRiskEntries                          0.015645
# errorRisk                                 0.015645
# dtype: float64

# %%
# screw this man
groot.agePlant.isna().mean()
# Out:
# np.float64(0.9128626709390485)

# %%
np.logical_not(groot.agePlant.isna()).sum()
# Out:
# np.int64(9953)

# %%
fig, axes = plt.subplots()
fig.set_size_inches(10, 10)
axes.hist(groot.agePlant, bins=groot.agePlant.unique().size, color="red", rwidth=0.9)
axes.set_xlabel("Age of plant (in years)")
plt.show()

# %%
pd.DataFrame(np.unique_counts(groot.loc[:, "mycorrhizalAssociationTypeFungalRoot"].dropna())).T
# Out:
#                                              0      1
# 0                                           AM  71043
# 1                                          EcM  22727
# 2                                       EcM-AM   2835
# 3                                          ErM   1177
# 4                                           NM   1497
# 5                                        NM-AM  12231
# 6                            NM-AM, rarely EcM     14
# 7                                           OM    315
# 8  species-specific: AM or rarely EcM-AM or AM     15
# 9                                    uncertain    141

# %%
groot.loc[:, ["family", "genus", "species"]].isna().sum()
# Out:
# family     90359
# genus          0
# species     1652
# dtype: int64

# %%
unique_groot_genus = groot.loc[:, "genus"].unique()

# %%
print(unique_groot_genus);
# Out:
# ['Betula' 'Picea' 'Pinus' 'Agropyron' 'Artemisia' 'Chrysothamnus' 'Elymus'
#  'Leymus' 'Acer' 'Dacrydium' 'Quercus' 'Brachiaria' 'Oryza' 'Soja'
#  'Triticum' 'Sorghum' 'Liriodendron' 'Populus' 'Deschampsia' 'Molinia'
#  'Faidherbia' 'Avicennia' 'Rhizophora' 'Fraxinus' 'Helianthus' 'Clintonia'
#  'Smilacina' 'Erythronium' 'Rubus' 'Streptopus' 'Alnus' 'Brassica'
#  'Cannabis' 'Dactylis' 'Hordeum' 'Linum' 'Lolium' 'Lupinus' 'Papaver'
#  'Phacelia' 'Poa' 'Sinapis' 'Spinacia' 'Trifolium' 'Vicia' 'Anthyllis'
#  'Retama' 'Juniperus' 'Pistacia' 'Alhagi' 'Tamarix' 'Calligonum'
#  'Phaseolus' 'Pisum' 'Cupressus' 'Festuca' 'Allophylus' 'Apodytes'
#  'Calpurnia' 'Combretum' 'Dovyalis' 'Ekebergia' 'Podocarpus' 'Teclea'
#  'Chionanthus' 'Maytenus' 'Achillea' 'Plantago' 'Silene' 'Liquidambar'
#  'Platanus' 'Juglans' 'Larix' 'Bromus' 'Phleum' 'Anabasis' 'Eurotia'
#  'Haloxylon' 'Karelinia' 'Kochia' 'Pteridium' 'Ulex' 'Eichhornia' 'Abies'
#  'Carpinus' 'Cercis' 'Gleditsia' 'Anisophyllea' 'Eurycoma' 'Antidesma'
#  'Ixora' 'Tarenna' 'Alopecurus' 'Cerastium' 'Luzula' 'Phippsia'
#  'Potentilla' 'Puccinellia' 'Ranunculus' 'Cardamine' 'Cochlearia'
#  'Saxifraga' 'Draba' 'Griselinia' 'Metrosideros' 'Weinmannia' 'Calluna'
#  'Vaccinium' 'Carex' 'Cladium' 'Arctostaphylos' 'Cercocarpus'
#  'Muhlenbergia' 'Pseudotsuga' 'Dupontia' 'Eriophorum' 'Arenaria'
#  'Brachypodium' 'Calamintha' 'Crepis' 'Daucus' 'Geranium' 'Inula'
#  'Medicago' 'Picris' 'Psoralea' 'Rubia' 'Teucrium' 'Tordylium' 'Veronica'
#  'Cassiope' 'Salix' 'Juncus' 'Stellaria' 'Dacryodes' 'Manilkara'
#  'Prestoea' 'Fouquieria' 'Dicorynia' 'Eperua' 'Andropogon' 'Drypetes'
#  'Sarcocornia' 'Eucalyptus' 'Acacia' 'Citrus' 'Malus' 'Hilaria' 'Opuntia'
#  'Prosopis' 'Colliguaja' 'Euphorbia' 'Lycium' 'Mulinum' 'Senecio'
#  'Adesmia' 'Brachyclados' 'Morus' 'Prunus' 'Robinia' 'Ulmus' 'Toxylon'
#  'Halimione' 'Achnatherum' 'Aristida' 'Bouteloua' 'Pleuraphis'
#  'Sporobolus' 'Hesperostipa' 'Fagus' 'Atriplex' 'Ceratoides' 'Empetrum'
#  'Banksia' 'Encelia' 'Peganum' 'Acanthyllis' 'Deverra' 'Henophyton'
#  'Cryptomeria' 'Cunninghamia' 'Berberis' 'Lindera' 'Lonicera' 'Viburnum'
#  'Leipoldtia' 'Hirpicium' 'Ruschia' 'Scirpus' 'Fragaria' 'Hieracium'
#  'Impatiens' 'Spirea' 'Tiarella' 'Clematis' 'Galium' 'Agrostis' 'Bellis'
#  'Cynosurus' 'Parapholis' 'Ledum' 'Calamagrostis' 'Chamerion' 'Dryas'
#  'Loiseleuria' 'Petasites' 'Polygonum' 'Anthoxanthum' 'Calocedrus' 'Thuja'
#  'Tsuga' 'Acronychia' 'Barringtonia' 'Canarium' 'Chenopodium' 'Cinnamomum'
#  'Cornus' 'Cryptocarya' 'Euonymus' 'Eurya' 'Ginkgo' 'Macaranga' 'Machilus'
#  'Michelia' 'Rapanea' 'Sambucus' 'Sanguisorba' 'Tilia' 'Lithocarpus'
#  'Phoebe' 'Rhodoleia' 'Sorbus' 'Syzygium' 'Alchornea' 'Aphanamixis'
#  'Ardisia' 'Diospyros' 'Dysoxylum' 'Goniothalamus' 'Knema' 'Magnolia'
#  'Memecylon' 'Pyrus' 'Randia' 'Sterculia' 'Swida' 'Syringa'
#  'Tsoongiodendron' 'Carya' 'Sassafras' 'Pleioblastus' 'Allium'
#  'Calystegia' 'Cleistogenes' 'Corispermum' 'Filifolium' 'Hemerocallis'
#  'Heteropappus' 'Hierochloe' 'Iris' 'Koeleria' 'Pulsatilla' 'Stipa'
#  'Thalictrum' 'Dysphania' 'Leontopodium' 'Orostachys' 'Schizonepeta'
#  'Rosa' 'Alseis' 'Coccoloba' 'Platypodium' 'Prionostemma' 'Tabebuia'
#  'Terminalia' 'Chomelia' 'Clitoria' 'Paragonia' 'Hamamelis' 'Rhus'
#  'Crataegus' 'Cichorium' 'Lotus' 'Phalaris' 'Solidago' 'Taraxacum'
#  'Spartina' 'Equisetum' 'Gutierrezia' 'Sphaeralcea' 'Haplopappus' 'Phlox'
#  'Selaginella' 'Calamovilfa' 'Liatris' 'Anemone' 'Aster' 'Chrysopsis'
#  'Lygodesmia' 'Thermopsis' 'Agastache' 'Ambrosia' 'Asclepias' 'Astragalus'
#  'Baptisia' 'Berteroa' 'Cassia' 'Coreopsis' 'Desmodium' 'Eragrostis'
#  'Erigeron' 'Gentiana' 'Hedeoma' 'Heliopsis' 'Lespedeza' 'Melilotus'
#  'Monarda' 'Oenothera' 'Panicum' 'Penstemon' 'Petalostemon' 'Physalis'
#  'Ratibida' 'Rudbeckia' 'Rumex' 'Schizachyrium' 'Setaria' 'Sorghastrum'
#  'Verbascum' 'Verbena' 'Vernonia' 'Veronicastrum' 'Zizia' 'Pycnanthemum'
#  'Euterpe' 'Azadirachta' 'Bauhinia' 'Bombax' 'Androsace' 'Sedum'
#  'Sieversia' 'Eritrichium' 'Lewisia' 'Paronychia' 'Polemonium' 'Rydbergia'
#  'Atractylis' 'Ballota' 'Cistus' 'Coronilla' 'Ephedra' 'Fumana'
#  'Helianthemum' 'Helichrysum' 'Launaea' 'Lavandula' 'Phlomis' 'Rosmarinus'
#  'Thymelaea' 'Thymus' 'Hippocrepis' 'Sideritis' 'Arbutus' 'Armeria'
#  'Celtis' 'Cydonia' 'Cytisus' 'Erica' 'Ficus' 'Genista' 'Halimium'
#  'Hedera' 'Jasminum' 'Myrtus' 'Nerium' 'Osyris' 'Phillyrea' 'Rhamnus'
#  'Rhododendron' 'Ruscus' 'Stauracanthus' 'Vitis' 'Smilax' 'Helychrisum'
#  'Withania' 'Nicotiana' 'Microstegium' 'Themeda' 'Croton' 'Franseria'
#  'Ipomoea' 'Salsola' 'Solanum' 'Dalea' 'Chamaecyparis' 'Adiantum'
#  'Cystopteris' 'Matteuccia' 'Onoclea' 'Athyrium' 'Phellodendron'
#  'Sarcobatus' 'Kobresia' 'Zea' 'Diplopterygium' 'Symphoricarpos' 'Carria'
#  'Poncirus' 'Swinglea' 'Acamptopappus' 'Enarganthe' 'Eriogonum'
#  'Thamnosma' 'Yucca' 'Zygophyllum' 'Cephalophyllum' 'Menodora' 'Stoeberia'
#  'Pentaclethra' 'Stipagrostis' 'Adansonia' 'Phragmites' 'Acomastylis'
#  'Byrsonima' 'Curatella' 'Amorpha' 'Holcus' 'Onobrychis' 'Securigera'
#  'Aciphylla' 'Brachyglottis' 'Celmisia' 'Hypochaeris' 'Rytidosperma'
#  'Anisotome' 'Colobanthus' 'Epilobium' 'Hebe' 'Lobelia' 'Raoulia'
#  'Angelica' 'Caltha' 'Comarum' 'Filipendula' 'Hippuris' 'Lycopodium'
#  'Menyanthes' 'Potamogeton' 'Ribes' 'Saussurea' 'Trollius' 'Melicytus'
#  'Pittosporum' 'Coprosma' 'Arrhenatherum' 'Digitalis' 'Leontodon'
#  'Castanea' 'Entandrophragma' 'Glycine' 'Adinandra' 'Loropetalum'
#  'Serissa' 'Hopea' 'Arundinaria' 'Agoseris' 'Lasthenia' 'Layia'
#  'Microseris' 'Distichlis' 'Nothofagus' 'Baccharis' 'Pluchea' 'Flourensia'
#  'Gaura' 'Larrea' 'Scleropogon' 'Aphanostephus' 'Caesalpinia' 'Dasyochloa'
#  'Desmanthus' 'Dimorphocarpa' 'Hymenopappus' 'Iva' 'Koeberlinia'
#  'Krameria' 'Nama' 'Nerisyrenia' 'Psilostrophe' 'Talinum' 'Zinnia'
#  'Arachis' 'Centrosema' 'Adenium' 'Aloe' 'Caralluma' 'Sansevieria'
#  'Desmostachya' 'Dichanthium' 'Sesbania' 'Sesleria' 'Trisetum'
#  'Castanopsis' 'Sabina' 'Adenostoma' 'Ceanothus' 'Polylepis' 'Theobroma'
#  'Aristea' 'Cliffortia' 'Watsonia' 'Ischyrolepis' 'Otholobium' 'Tetraria'
#  'Arctotheca' 'Austrodanthonia' 'Microlaena' 'Vulpia' 'Mutisia' 'Satureja'
#  'Stachys' 'Trichocereus' 'Aristotelia' 'Ascarina' 'Asplenium' 'Astelia'
#  'Blechnum' 'Carpodetus' 'Coriaria' 'Cyathea' 'Dicksonia' 'Gahnia'
#  'Gleichenia' 'Hedycarya' 'Leptecophylla' 'Leptospermum' 'Neomyrtus'
#  'Prumnopitys' 'Pseudopanax' 'Pseudowintera' 'Schefflera' 'Sticherus'
#  'Lepidothamnus' 'Manoao' 'Phyllocladus' 'Quintinia' 'Raukaua'
#  'Rhipogonum' 'Myrsine' 'Olearia' 'Polystichum' 'Baikiaea' 'Brachystegia'
#  'Burkea' 'Guibourtia' 'Ochna' 'Incarvillea' 'Oxytropis' 'Butea'
#  'Dalbergia' 'Eriobotrya' 'Mangifera' 'Melia' 'Nephelium' 'Phyllanthus'
#  'Psidium' 'Tectona' 'Millingtonia' 'Anona' 'Ailanthus' 'Caragana'
#  'Dipterocarpus' 'Cenchrus' 'Boscia' 'Leucaena' 'Celastrus' 'Cephalanthus'
#  'Diervilla' 'Dirca' 'Elaeagnus' 'Frangula' 'Shepherdia' 'Anacardium'
#  'Trichostigma' 'Antennaria' 'Bartsia' 'Pedicularis' 'Phyllodoce'
#  'Tofieldia' 'Harrimanella' 'Boswellia' 'Erianthus' 'Saccharum'
#  'Halostachys' 'Rheum' 'Araucaria' 'Biota' 'Cedrus' 'Cycas' 'Keteleeria'
#  'Metasequoia' 'Sciadopitys' 'Sequoia' 'Taxodium' 'Taxus' 'Thujopsis'
#  'Torreya' 'Amelanchier' 'Arnica' 'Campanula' 'Comandra' 'Danthonia'
#  'Descurainia' 'Elytrigia' 'Heterotheca' 'Heuchera' 'Hymenoxys' 'Lactuca'
#  'Lathyrus' 'Lepidium' 'Musineon' 'Nassella' 'Orthocarpus' 'Tragopogon'
#  'Viola' 'Zigadenus' 'Erysimum' 'Pseudosclerochloa' 'Dillenia'
#  'Endospermum' 'Homalanthus' 'Melastoma' 'Fagraea' 'Artocarpus'
#  'Callicarpa' 'Andromeda' 'Alchemilla' 'Geum' 'Nardus' 'Balsamorhiza'
#  'Cymopterus' 'Oryzopsis' 'Purshia' 'Bidens' 'Hydrangea' 'Ilex' 'Isachne'
#  'Miscanthus' 'Alangium' 'Alniphyllum' 'Alstonia' 'Decaspermum' 'Microcos'
#  'Pentaphylax' 'Gordonia' 'Litsea' 'Cyclobalanopsis' 'Osmanthus'
#  'Pertusadina' 'Wendlandia' 'Aporosa' 'Carallia' 'Catunaregam'
#  'Cratoxylum' 'Elaeocarpus' 'Garcinia' 'Gironniera' 'Helicia' 'Itea'
#  'Pithecellobium' 'Pometia' 'Pterospermum' 'Rhaphiolepis' 'Schima'
#  'Engelhardia' 'Euodia' 'Macropanax' 'Manglietia' 'Mezzettiopsis'
#  'Microtropis' 'Millettia' 'Olea' 'Parakmeria' 'Paramichelia' 'Psychotria'
#  'Saprosma' 'Dicranopteris' 'Vignea' 'Agathis' 'Dacrycarpus' 'Laurelia'
#  'Knightia' 'Alectryon' 'Beilschmiedia' 'Dracophyllum' 'Fuchsia'
#  'Halocarpus' 'Hoheria' 'Kunzea' 'Pennantia' 'Plagianthus' 'Rhopalostylis'
#  'Sophora' 'Vitex' 'Ackama' 'Corynocarpus' 'Nestegis' 'Lophozonia'
#  'Jatropha' 'Chamaedaphne' 'Acanthosicyos' 'Commiphora' 'Bahia'
#  'Blepharoneuron' 'Castilleja' 'Centaurea' 'Chaetopappa' 'Chamaesyce'
#  'Cirsium' 'Cologania' 'Convolvulus' 'Cosmos' 'Drymaria' 'Echeandia'
#  'Erodium' 'Gaillardia' 'Helianthella' 'Heliomeris' 'Houstonia'
#  'Ipomopsis' 'Laennecia' 'Linaria' 'Lithospermum' 'Machaeranthera'
#  'Mirabilis' 'Monroa' 'Noccaea' 'Packera' 'Pascopyrum' 'Portulaca'
#  'Pseudocymopterus' 'Pseudognaphalium' 'Symphyotrichum' 'Townsendia'
#  'Oxalis' 'Calliandra' 'Gliricidia' 'Senna' 'Akebia' 'Buddleja'
#  'Koelreuteria' 'Ajania' 'Ceratostigma' 'Cotinus' 'Indigofera'
#  'Podocarpium' 'Platycladus' 'Chamaerhodos' 'Cymbaria' 'Melissitus'
#  'Carum' 'Chondrilla' 'Eryngium' 'Onosma' 'Dactylorhiza' 'Primula'
#  'Scorzonera' 'Trigonella' 'Avena' 'Carlina' 'Altingia' 'Grayia'
#  'Agriophyllum' 'Bassia' 'Ceratocarpus' 'Cynanchum' 'Halogeton'
#  'Horaninovia' 'Nitraria' 'Reaumuria' 'Sympegma' 'Ixeris' 'Petrosimonia'
#  'Seriphidium' 'Echinochloa' 'Hedysarum' 'Rhodiola' 'Choerospondias'
#  'Neolitsea' 'Apocynum' 'Mytilaria' 'Ziziphus' 'Aglaia' 'Blumeodendron'
#  'Hypobathrum' 'Pentaspadon' 'Shorea' 'Anaxagorea' 'Galearia'
#  'Dichrostachys' 'Baccaurea' 'Pittosporopsis' 'Acosmium' 'Ampelocera'
#  'Anadenanthera' 'Aspidosperma' 'Batocarpus' 'Bougainvillea' 'Cariniana'
#  'Casearia' 'Cavanillesia' 'Cecropia' 'Cedrela' 'Ceiba' 'Centrolobium'
#  'Erythroxylum' 'Gallesia' 'Heliocarpus' 'Hirtella' 'Hura' 'Hymenaea'
#  'Jacaratia' 'Licaria' 'Machaerium' 'Myrciaria' 'Nectandra' 'Phyllostylon'
#  'Pogonopus' 'Pourouma' 'Pouteria' 'Pseudolmedia' 'Pterogyne' 'Sapindus'
#  'Sapium' 'Schizolobium' 'Simira' 'Spondias' 'Sweetia' 'Swietenia' 'Trema'
#  'Trichilia' 'Urera' 'Zanthoxylum' 'Rollinia' 'Adenanthera' 'Alibertia'
#  'Capparis' 'Copaifera' 'Ocotea' 'Stylogyne' 'Mercurialis' 'Allenrolfea'
#  'Loudetia' 'Chlorophora' 'Melaleuca' 'Schaefferia' 'Porlieria' 'Aira'
#  'Bothriochloa' 'Joycea' 'Lomandra' 'Passiflora' 'Erioneuron' 'Baileya'
#  'Corylus' 'Scolochloa' 'Spiraea' 'Armeniaca' 'Cotoneaster'
#  'Dracocephalum' 'Hypericum' 'Pennisetum' 'Thinopyrum' 'Radermachera'
#  'Sindora' 'Pachycereus' 'Securidaca' 'Valeriana' 'Brosimum'
#  'Clathrotropis' 'Goupia' 'Miconia' 'Vismia' 'Condalia' 'Piptochaetium'
#  'Bulnesia' 'Bunchosia' 'Bursera' 'Calyptranthes' 'Cordia' 'Couroupita'
#  'Dodonaea' 'Enterolobium' 'Erithalis' 'Guaiacum' 'Hamelia' 'Mayodendron'
#  'Moringa' 'Myrica' 'Persea' 'Plumeria' 'Polyalthia' 'Pseudobombax'
#  'Spathodea' 'Tamarindus' 'Triplaris' 'Lysiloma' 'Pleiogynium' 'Streblus'
#  'Banara' 'Cameraria' 'Chorisia' 'Clausena' 'Cnidoscolus' 'Eugenia'
#  'Finschia' 'Handroanthus' 'Malpighia' 'Myrcianthes' 'Peltophorum'
#  'Tabernaemontana' 'Nardophyllum' 'Nassauvia' 'Junellia' 'Mimosa'
#  'Piptadenia' 'Alliaria' 'Aquilegia' 'Hesperis' 'Leucanthemum' 'Prunella'
#  'Hakea' 'Nyssa' 'Hydrophyllum' 'Eleocharis' 'Gonocarpus' 'Muehlenbeckia'
#  'Myosotis' 'Pilosella' 'Wahlenbergia' 'Amphibromus' 'Deyeuxia'
#  'Glossostigma' 'Hydrocotyle' 'Lachnagrostis' 'Leptinella' 'Leucopogon'
#  'Lilaeopsis' 'Myriophyllum' 'Pilularia' 'Pimelea' 'Talisia' 'Aleurites'
#  'Carica' 'Cocos' 'Durio' 'Gnetum' 'Lansium' 'Pterocarpus' 'Musa'
#  'Knautia' 'Lantana' 'Andira' 'Acanthococos' 'Aristolochia' 'Attalea'
#  'Cochlospermum' 'Craniolaria' 'Echinolaena' 'Stryphnodendron' 'Buchloe'
#  'Leersia' 'Petalostemum' 'Davilla' 'Cordylanthus' 'Trachydium'
#  'Eustachys' 'Noticastrum' 'Paspalum' 'Stylosanthes' 'Tagetes'
#  'Alternanthera' 'Arthraxon' 'Chloris' 'Cyperus' 'Digitaria' 'Eclipta'
#  'Lysimachia' 'Merremia' 'Sida' 'Trichophorum' 'Astrantia' 'Pueraria'
#  'Rungia' 'Bituminaria' 'Clinopodium' 'Isoetes' 'Bowdichia' 'Caryocar'
#  'Dipteryx' 'Simarouba' 'Annona' 'Mouriri' 'Trachypogon' 'Salvia'
#  'Erucaria' 'Aizoon' 'Haplophyllum' 'Heliotropium' 'Reseda' 'Suaeda'
#  'Lannea' 'Cymbopogon' 'Tristachya' 'Acalypha' 'Boltonia' 'Callitriche'
#  'Ludwigia' 'Lycopus' 'Nymphaea' 'Penthorum' 'Sagittaria' 'Sparganium'
#  'Lilium' 'Proserpinaca' 'Sium' 'Hevea' 'Daphne' 'Chamaespartium'
#  'Chrysopogon' 'Acaena' 'Graffenrieda' 'Clethra' 'Clusia' 'Styrax' 'Piper'
#  'Dialium' 'Inga' 'Ormosia' 'Tapirira' 'Virola' 'Lappula' 'Sisyrinchium'
#  'Lepachys' 'Parthenium' 'Silphium' 'Tradescantia' 'Brauneria' 'Ruellia'
#  'Aesculus' 'Catalpa' 'Maclura' 'Ostrya' 'Casuarina' 'Agrimonia'
#  'Roegneria' 'Tephroseris' 'Imperata' 'Argyrodendron' 'Flindersia' 'Toona'
#  'Baphia' 'Balanites' 'Colophospermum' 'Diplorhynchus' 'Dombeya'
#  'Erythrophleum' 'Grewia' 'Julbernardia' 'Kirkia' 'Pseudolachnostylis'
#  'Ricinodendron' 'Strychnos' 'Pericopsis' 'Grafia' 'Piliostigma' 'Albizia'
#  'Azanza' 'Flueggea' 'Hymenocardia' 'Isoberlinia' 'Lonchocarpus'
#  'Markhamia' 'Marquesia' 'Monotes' 'Parinari' 'Steganotaenia' 'Triumfetta'
#  'Uapaca' 'Faurea' 'Atalaya' 'Brachylaena' 'Dimorphandra' 'Eriotheca'
#  'Erythrina' 'Euclea' 'Grevillea' 'Kielmeyera' 'Petalostigma'
#  'Gymnosporia' 'Lysiphyllum' 'Plathymenia' 'Schotia' 'Dendrocalamus'
#  'Sasa' 'Hippophae' 'Ternstroemia' 'Tristaniopsis' 'Payena' 'Madhuca'
#  'Tetractomia' 'Xanthophyllum' 'Hyeronima' 'Vochysia' 'Asimina'
#  'Cercidiphyllum' 'Halesia' 'Styphnolobium' 'Calla' 'Podophyllum'
#  'Lindenia' 'Symplocarpus' 'Serenoa' 'Moltkiopsis' 'Abelia' 'Adina'
#  'Anaphalis' 'Asparagus' 'Astilbe' 'Calamus' 'Caulophyllum' 'Chloranthus'
#  'Cibotium' 'Convallaria' 'Deutzia' 'Duchesnea' 'Eleutherococcus'
#  'Euptelea' 'Hosta' 'Lamium' 'Mallotus' 'Oreocnide' 'Parthenocissus'
#  'Sarcandra' 'Veratrum' 'Daphniphyllum' 'Actaea' 'Actinidia' 'Adenocaulon'
#  'Alpinia' 'Amomum' 'Blastus' 'Caryota' 'Dendropanax' 'Dioscorea'
#  'Diplospora' 'Doellingeria' 'Dryopteris' 'Embelia' 'Nabalus' 'Osmunda'
#  'Philadelphus' 'Phlomoides' 'Sanicula' 'Schoepfia' 'Strobilanthes'
#  'Trachelospermum' 'Anthemis' 'Carduus' 'Chrysanthemum' 'Sisymbrium'
#  'Spergula' 'Leptotaenia' 'Sidalcea' 'Wyethia' 'Hoorebekia' 'Aragallus'
#  'Argemone' 'Chamaenerion' 'Thlaspi' 'Aletes' 'Besseya' 'Frasera' 'Gilia'
#  'Krynitzkia' 'Mentzelia' 'Pachylophus' 'Redfieldia' 'Bulbilis'
#  'Glycyrrhiza' 'Grindelia' 'Kuhnia' 'Bruguiera' 'Ceriops' 'Bashania'
#  'Cryptotaenia' 'Rhynchosia' 'Fokienia' 'Biserrula' 'Ornithopus'
#  'Jacobaea' 'Ostrowskia' 'Buxus' 'Dorycnium' 'Ononis' 'Staehelina' 'Beta'
#  'Capsicum' 'Cicer' 'Cucumis' 'Cynara' 'Eruca' 'Gossypium' 'Lens' 'Secale'
#  'Vigna' 'Helictotrichon' 'Briza' 'Lychnis' 'Peucedanum' 'Pimpinella'
#  'Succisa' 'Triglochin' 'Urtica' 'Coffea' 'Ajuga' 'Anthriscus' 'Avenula'
#  'Glechoma' 'Heracleum' 'Pastinaca' 'Arctium' 'Borago' 'Capsella'
#  'Erophila' 'Lapsana' 'Lythrum' 'Microrrhinum' 'Myosurus' 'Scabiosa'
#  'Sonchus' 'Tanacetum' 'Tripleurospermum' 'Archidendron' 'Polyspora'
#  'Cerasus' 'Melicope' 'Orophea' 'Acroclinium' 'Acroptilon' 'Asperugo'
#  'Bolboschoenus' 'Colpodium' 'Cynodon' 'Echinops' 'Eremopyrum' 'Gagea'
#  'Halimodendron' 'Malcolmia' 'Mulgedium' 'Salicornia' 'Schismus'
#  'Tetracme' 'Viscaria' 'Hypecoum' 'Acanthophyllum' 'Alyssum' 'Amberboa'
#  'Ammodendron' 'Argusia' 'Arthrophytum' 'Asperula' 'Atraphaxis'
#  'Biebersteinia' 'Cacalia' 'Ceratocephala' 'Chamaesphacos' 'Climacoptera'
#  'Consolida' 'Corydalis' 'Cousinia' 'Eremosparton' 'Eremostachys'
#  'Eremurus' 'Euclidium' 'Ferula' 'Fritillaria' 'Goldbachia' 'Halothamnus'
#  'Hyalea' 'Hyoscyamus' 'Isatis' 'Jurinea' 'Koelpinia' 'Lallemantia'
#  'Leontice' 'Leptaleum' 'Limonium' 'Matthiola' 'Megacarpaea' 'Nanophyton'
#  'Nonea' 'Prangos' 'Rhammatophyllum' 'Rindera' 'Rochelia' 'Sameraria'
#  'Serratula' 'Spirorhynchus' 'Streptoloma' 'Syrenia' 'Tauscheria' 'Tulipa'
#  'Adonis' 'Aegilops' 'Aegopodium' 'Conium' 'Corchorus' 'Crotalaria'
#  'Eupatorium' 'Fimbristylis' 'Fumaria' 'Helleborus' 'Hibiscus' 'Laser'
#  'Milium' 'Myricaria' 'Polypodium' 'Polypogon' 'Psathyrostachys' 'Pteris'
#  'Sesamum' 'Taeniatherum' 'Telekia' 'Vinca' 'Xanthium' 'Cyclachaena'
#  'Holosteum' 'Hypogomphia' 'Mentha' 'Nigella' 'Pseudohandelia' 'Roemeria'
#  'Scirpoides' 'Valerianella' 'Aconitum' 'Adenophora' 'Adoxa' 'Alisma'
#  'Arabis' 'Asarum' 'Astrodaucus' 'Barbarea' 'Botrychium' 'Bunias'
#  'Bupleurum' 'Camelina' 'Catabrosa' 'Cephalanthera' 'Cephalaria'
#  'Cerinthe' 'Chaerophyllum' 'Chamaesciadium' 'Chimaphila' 'Chrysosplenium'
#  'Cicerbita' 'Circaea' 'Commelina' 'Cortusa' 'Crocus' 'Cruciata'
#  'Cryptogramma' 'Delphinium' 'Dianthus' 'Diapensia' 'Doronicum' 'Drosera'
#  'Echinaria' 'Eremopoa' 'Euphrasia' 'Filago' 'Gentianella' 'Glaux'
#  'Glyceria' 'Gnaphalium' 'Goodyera' 'Gymnadenia' 'Gymnocarpium'
#  'Gypsophila' 'Huperzia' 'Kemulariella' 'Laurocerasus' 'Ligularia'
#  'Ligustrum' 'Linnaea' 'Listera' 'Lloydia' 'Maianthemum' 'Matricaria'
#  'Melampyrum' 'Melica' 'Merendera' 'Minuartia' 'Moneses' 'Muscari'
#  'Nepeta' 'Nuphar' 'Odontites' 'Oenanthe' 'Ophioglossum' 'Origanum'
#  'Orthilia' 'Oxyria' 'Paris' 'Parnassia' 'Platanthera' 'Polygala'
#  'Polygonatum' 'Pulmonaria' 'Puschkinia' 'Pyrola' 'Rhinanthus'
#  'Rhynchospora' 'Rorippa' 'Scheuchzeria' 'Schizachne' 'Scilla'
#  'Scrophularia' 'Scutellaria' 'Sempervivum' 'Seseli' 'Sibbaldia' 'Silaum'
#  'Swertia' 'Symphytum' 'Thelypteris' 'Traunsteinera' 'Trientalis'
#  'Tussilago' 'Vaccaria' 'Aethionema' 'Alajja' 'Alcea' 'Arnebia' 'Asyneuma'
#  'Aulacospermum' 'Bunium' 'Chamaecytisus' 'Chorispora' 'Chrozophora'
#  'Cypripedium' 'Didymophysa' 'Diplazium' 'Drepanocaryum' 'Echium'
#  'Eminium' 'Frankenia' 'Galega' 'Goniolimon' 'Ixiolirion' 'Lagochilus'
#  'Lagotis' 'Lepechiniella' 'Lindelofia' 'Macrosciadium' 'Moehringia'
#  'Murbeckiella' 'Oedibasis' 'Ornithogalum' 'Orthurus' 'Pachypleurum'
#  'Paeonia' 'Parrya' 'Patrinia' 'Physochlaina' 'Pleurospermum' 'Psephellus'
#  'Ptarmica' 'Rhynchocorys' 'Schivereckia' 'Schizanthus' 'Symphyoloma'
#  'Umbilicus' 'Vincetoxicum' 'Waldheimia' 'Ziziphora' 'Blysmus' 'Marrubium'
#  'Ageratum' 'Agrostemma' 'Althaea' 'Amaranthus' 'Anchusa' 'Antirrhinum'
#  'Beckmannia' 'Calendula' 'Callistephus' 'Chaenomeles' 'Clarkia'
#  'Cynoglossum' 'Eschscholzia' 'Galeopsis' 'Iberis' 'Illicium' 'Kalmia'
#  'Kengia' 'Lagurus' 'Lamarckia' 'Laserpitium' 'Leptochloa' 'Maackia'
#  'Mahonia' 'Photinia' 'Pleuropogon' 'Poupartia' 'Rhipsalis' 'Sagina'
#  'Sorbaria' 'Tragus' 'Ursinia' 'Washingtonia' 'Pereskia' 'Schisandra'
#  'Alocasia' 'Begonia' 'Cereus' 'Cocculus' 'Crassula' 'Echeveria'
#  'Echinopsis' 'Epiphyllum' 'Forsythia' 'Gazania' 'Gladiolus' 'Justicia'
#  'Kalanchoe' 'Mammillaria' 'Nemesia' 'Perilla' 'Petunia' 'Sibiraea'
#  'Weigela' 'Aralia' 'Comptonia' 'Epigaea' 'Gaultheria' 'Waldsteinia'
#  'Ericameria' 'Hymenoclea' 'Hyptis' 'Keckiella' 'Simmondsia' 'Parkinsonia'
#  'Chamaecrista' 'Strophostyles' 'Arctagrostis' 'Aulacomnium' 'Globularia'
#  'Laburnum' 'Laurus' 'Santolina' 'Alloteropsis' 'Bewsia' 'Chionochloa'
#  'Dactyloctenium' 'Diheteropogon' 'Diplachne' 'Elionurus' 'Enneapogon'
#  'Eriachne' 'Eulalia' 'Harpochloa' 'Heteropogon' 'Hyparrhenia'
#  'Hyperthelia' 'Mnesithea' 'Perotis' 'Plectrachne' 'Sehima' 'Urochloa'
#  'Whiteochloa' 'Marah' 'Apera' 'Raphanus' 'Dipsacus' 'Pseudoroegneria'
#  'Orchis' 'Adenostyles' 'Aeluropus' 'Aposeris' 'Baumea' 'Buchenavia'
#  'Calotropis' 'Calycogonium' 'Camphorosma' 'Claytonia' 'Cryptantha'
#  'Cyrilla' 'Dicentra' 'Didymopanax' 'Dimerandra' 'Gaylussacia' 'Kalidium'
#  'Manihot' 'Meliosma' 'Myrcia' 'Rourea' 'Sloanea' 'Tetragastris' 'Typha'
#  'Heteropterys' 'Matayba' 'Micropholis' 'Parrotia' 'Cattleya' 'Chaenactis'
#  'Cymbidium' 'Dentaria' 'Linosyris' 'Melandrium' 'Palicourea'
#  'Phalaenopsis' 'Matthiolaria' 'Narcissus' 'Spergularia' 'Ceratonia'
#  'Echinospartum' 'Lithodora' 'Bromopsis' 'Ligusticum' 'Acorus' 'Camellia'
#  'Ageratina' 'Cucurbita' 'Echinacea' 'Echinodorus' 'Eleusine'
#  'hesperostipa' 'penstemon' 'vulpia' 'Prenanthes' 'dichanthelium'
#  'mirabilis' 'oenothera' 'packera' 'psoralidium' 'stenosiphon'
#  'tradescantia' 'verbesina' 'Diplotaxis' 'Samolus' 'Schoenus' 'Halophytum'
#  'Chasmanthium' 'AGROSTIS' 'ANTENNARIA' 'ANTHOXANTHUM' 'CAREX'
#  'Catabrosella' 'GNAPHALIUM' 'Hyalopoa' 'LEONTODON' 'NARDUS' 'SIBBALDIA'
#  'Eschweilera' 'Licania' 'Protium' 'Unonopsis' 'Sextonia' 'Aniba'
#  'Endlicheria' 'Abrus' 'Abutilon' 'Achyranthes' 'Alysicarpus' 'Bambusa'
#  'Biophytum' 'Braciaria' 'Bulbostylis' 'Cardiospermum' 'Crescentia'
#  'Curculigo' 'Cyanodon' 'Cyrtococcum' 'Datura' 'Delonix' 'Emilia'
#  'Eragrostiella' 'Evolvulus' 'Gloriosa' 'Guazuma' 'Hedyotis' 'Iphigenia'
#  'Micrococca' 'Paspalidium' 'Pedalium' 'Plumbago' 'Pongamia' 'Rynchosia'
#  'Scleria' 'Tephrosia' 'Trianthema' 'Trichodesma' 'Tridax' 'Andrographis'
#  'Atylosia' 'Barleria' 'Cadaba' 'Crossandra' 'Cryptostegia' 'Eleiotis'
#  'Glossogyne' 'Gomphrena' 'Hemidesmus' 'Lagascea' 'Leptadenia' 'Leucas'
#  'Ocimum' 'Pavetta' 'Pavonia' 'Rauwolfia' 'Rostellularia' 'Spermacoce'
#  'Vicoa' 'Zornia' 'Cleyera' 'Lyonia' 'Pieris' 'Chimonanthus' 'Pyrenaria'
#  'Bryonia' 'Humulus' 'Brachypodium ' 'Corynephorus' 'Galinsoga' 'Atropa'
#  'Sonneratia' 'Aegiceras' 'Backhousia' 'Callicoma' 'Ceratopetalum'
#  'Clidemia' 'Arthrostemma' 'Tibouchina' 'Crambe' 'Maranthes' 'Vatica'
#  'Platymiscium' 'Psiguria' 'Abronia' 'Cakile' 'Agonis' 'Lawsonia'
#  'Himatanthus' 'Zantedeschia' 'Arabidopsis' 'Cleistanthus' 'Stephanomeria'
#  'Diplacus' 'Fallopia' 'Amphipterygium' 'Bernardia' 'Chloroleucon'
#  'Hintonia' 'Lagrezia' 'Recchia' 'Ruprechtia' 'Thouinia' 'Cascabela'
#  'Hesperalbizia' 'Piranhea' 'Ventenata' 'Vachellia' 'Lafoensia' 'Luehea'
#  'Ochroma' 'Pachira' 'Trichospermum' 'Vatairea' 'Khaya' 'Genipa' 'Mucuna'
#  'Dryobalanops' 'Parkia' 'Gonystylus' 'Dyera' 'Milicia' 'Tripolium'
#  'Calophyllum' 'Gustavia' 'Prioria' 'Carapa' 'Tachigali' 'Hemarthria'
#  'Aextoxicon' 'Amomyrtus' 'Eucryphia' 'Fitzroya' 'Laureliopsis'
#  'Saxegothaea' 'Tridens' 'Laguncularia' 'Anacamptis' 'Persicaria'
#  'Eutrochium' 'Scorzoneroides' 'Agave' 'Ferocactus' 'Jaumea' 'Abelmoschus'
#  'Rottboellia' 'Anoda' 'Cestrum' 'Citharexylum' 'Schinus' 'Kadua'
#  'Ammophila' 'Salvadora' 'Senegalia' 'Doryphora' 'Pallenis' 'Catostemma'
#  'Mora' 'Afrocarpus' 'Zizania' 'Mikania' 'Paederia' 'Sphagneticola'
#  'Hemisteptia' 'Torilis' 'Callistemon' 'Tecoma' 'Corymbia' 'Racosperma'
#  'Duboisia' 'Acmena' 'Castilla' 'Pittoniotis' 'Protea' 'Panax' 'Ananas'
#  'Pharus' 'Aechmea' 'Flaveria' 'Megathyrsus' 'Anagallis' 'Anemonastrum'
#  'Anthericum' 'Apium' 'Aremonia' 'Arum' 'Aruncus' 'Asphodelus' 'Avenella'
#  'Baldellia' 'Batrachium' 'Berula' 'Betonica' 'Biscutella' 'Bistorta'
#  'Buglossoides' 'Buphthalmum' 'Butomus' 'Caldesia' 'Calypso' 'Chamorchis'
#  'Cicuta' 'Coeloglossum' 'Colchicum' 'Corallorhiza' 'Cymodocea' 'Daboecia'
#  'Diphasiastrum' 'Elodea' 'Epimedium' 'Epipactis' 'Epipogium' 'Eranthis'
#  'Galanthus' 'Galeobdolon' 'Gratiola' 'Groenlandia' 'Hammarbya' 'Hepatica'
#  'Herminium' 'Himantoglossum' 'Homogyne' 'Honckenya' 'Hordelymus'
#  'Hottonia' 'Hyacinthoides' 'Hydrocharis' 'Hylotelephium' 'Hymenophyllum'
#  'Isolepis' 'Isopyrum' 'Kernera' 'Lathraea' 'Leonurus' 'Leucojum'
#  'Limodorum' 'Liparis' 'Littorella' 'Luronium' 'Lycopodiella' 'Malaxis'
#  'Marsilea' 'Melittis' 'Mimulus' 'Monotropa' 'Mycelis' 'Myosoton'
#  'Narthecium' 'Nasturtium' 'Neottia' 'Neottianthe' 'Nymphoides'
#  'Omphalodes' 'Ophrys' 'Oreochloa' 'Orobanche' 'Othocallis' 'Parietaria'
#  'Phegopteris' 'Pinguicula' 'Posidonia' 'Pseudorchis' 'Pulicaria'
#  'Reynoutria' 'Ruppia' 'Saponaria' 'Schoenoplectus' 'Selinum' 'Soldanella'
#  'Spiranthes' 'Stuckenia' 'Succisella' 'Thesium' 'Tolpis' 'Vallisneria'
#  'Willemetia' 'Woodsia' 'Zannichellia' 'Zostera' 'Hacquetia' 'Hydrilla'
#  'Peltaria' 'Bellidiastrum' 'Ficaria' 'Fourraea' 'Galatella'
#  'Gentianopsis' 'Helictochloa' 'Jovibarba' 'Lamprocapnos' 'Paederota'
#  'Prospero' 'Rhaponticum' 'Serapias']

# %%
groot_gs = groot.loc[:, ["genus", "species"]].dropna()

# %%
scientific_names_unique = np.unique(np.array([g.title() + " " + s.lower() for (g, s) in zip(groot_gs.genus, groot_gs.species)]))

# %%
scientific_names_unique.size
# Out:
# 6610

# %%
"hello".title()
# Out:
# 'Hello'

# %%
scientific_names_unique
# Out:
# array(['Abelia biflora', 'Abelmoschus esculentus', 'Abies alba',
#        'Abies amabilis', 'Abies arizonica', 'Abies balsamea',
#        'Abies balsamifera', 'Abies cephalonica', 'Abies cilicica',
#        'Abies concolor', 'Abies faxoniana', 'Abies firma',
#        'Abies fraseri', 'Abies gamblei', 'Abies grandis',
#        'Abies holophylla', 'Abies homolepis', 'Abies koreana',
#        'Abies lasiocarpa', 'Abies magnifica', 'Abies mariesii',
#        'Abies nephrolepis', 'Abies nordmanniana', 'Abies numidica',
#        'Abies pinsapo', 'Abies procera', 'Abies sachalinensis',
#        'Abies sibirica', 'Abies veitchii', 'Abronia maritima',
#        'Abrus precatorius', 'Abutilon indicum', 'Abutilon theophrasti',
#        'Acacia albida', 'Acacia amythethophylla', 'Acacia aneura',
#        'Acacia aulacocarpa', 'Acacia auriculiformis', 'Acacia bidwillii',
#        'Acacia cambagei', 'Acacia colei', 'Acacia coriacea',
#        'Acacia crassicarpa', 'Acacia dealbata', 'Acacia eburnea',
#        'Acacia eriocarpa', 'Acacia erioloba', 'Acacia farnesiana',
#        'Acacia fleckii', 'Acacia gerrardii', 'Acacia goetzei',
#        'Acacia greggii', 'Acacia harpophylla', 'Acacia hockii',
#        'Acacia implexa', 'Acacia irrorata', 'Acacia leucophloea',
#        'Acacia mangium', 'Acacia mearnsii', 'Acacia melanoxylon',
#        'Acacia melenoxylon', 'Acacia mellifera', 'Acacia natalitia',
#        'Acacia neovernicosa', 'Acacia nigrescens', 'Acacia nilotica',
#        'Acacia polyacantha', 'Acacia reficiens', 'Acacia robusta',
#        'Acacia salicina', 'Acacia saligna', 'Acacia seyal',
#        'Acacia shirleyi', 'Acacia sieberiana', 'Acacia tetragonaphylla',
#        'Acacia tetragonophylla', 'Acacia tortilis', 'Acacia tortillis',
#        'Acaena magellanica', 'Acaena novae-zelandiae',
#        'Acalypha fruticosa', 'Acalypha indica', 'Acalypha lanceolata',
#        'Acalypha virginica', 'Acalypha wilkesiana',
#        'Acamptopappus shockleyi', 'Acamptopappus sphaerocephalus',
#        'Acanthophyllum borsczowi', 'Acanthophyllum korolkowi',
#        'Acanthophyllum krascheninnikovii', 'Acanthophyllum paniculatum',
#        'Acanthosicyos horrida', 'Acanthosicyos horridus',
#        'Acanthyllis tragacanthoides', 'Acer barbinerve',
#        'Acer buergerianum', 'Acer campbellii', 'Acer campestre',
#        'Acer cappadocicum', 'Acer caudatum', 'Acer cinnamomifolium',
#        'Acer davidii', 'Acer fabri', 'Acer ginnala', 'Acer glabra',
#        'Acer glabrum', 'Acer laetum', 'Acer macrophyllum', 'Acer mono',
#        'Acer negundo', 'Acer pensylvanicum', 'Acer pictum',
#        'Acer platanoides', 'Acer pseudoplatanus',
#        'Acer pseudosieboldianum', 'Acer pubescens', 'Acer rubrum',
#        'Acer saccharinum', 'Acer saccharum', 'Acer semenovii',
#        'Acer spicatum', 'Acer tataricum', 'Acer tegmentosum',
#        'Acer triflorum', 'Acer truncatum', 'Acer turkestanicum',
#        'Acer ukurunduense', 'Achillea atrata', 'Achillea clavennae',
#        'Achillea crithmifolia', 'Achillea erba-rotta',
#        'Achillea lanulosa', 'Achillea macrocephala',
#        'Achillea macrophylla', 'Achillea millefolium', 'Achillea nana',
#        'Achillea nobilis', 'Achillea oxyloba', 'Achillea pannonica',
#        'Achillea ptarmica', 'Achillea salicifolia', 'Achillea setacea',
#        'Achillea subalpina', 'Achillea tomentosa',
#        'Achnatherum hymenoides', 'Achnatherum lettermanii',
#        'Achnatherum sibiricum', 'Achyranthes aspera', 'Aciphylla aurea',
#        'Ackama rosifolia', 'Acmena ingens', 'Acomastylis rossii',
#        'Aconitum anthora', 'Aconitum confertiflorum', 'Aconitum degenii',
#        'Aconitum nasutum', 'Aconitum plicatum', 'Aconitum septentrionale',
#        'Aconitum variegatum', 'Acorus calamus', 'Acosmium cardenasii',
#        'Acroclinium roseum', 'Acronychia pedunculata',
#        'Acroptilon repens', 'Actaea cimicifuga', 'Actaea spicata',
#        'Actinidia kolomikta', 'Adansonia digitata', 'Adenium somalense',
#        'Adenocaulon himalaicum', 'Adenophora liliifolia',
#        'Adenostoma fasciculatum', 'Adenostyles alliariae',
#        'Adenostyles alpina', 'Adesmia bicolor', 'Adesmia boronioides',
#        'Adesmia volckmanni', 'Adiantum pedatum', 'Adina pilulifera',
#        'Adinandra millettii', 'Adonis aestivalis', 'Adonis parviflora',
#        'Adonis turkestanica', 'Adonis vernalis', 'Adoxa moschatellina',
#        'Aechmea rubiginosa', 'Aegiceras corniculatum', 'Aegilops crassa',
#        'Aegilops cylindrica', 'Aegilops tauschii', 'Aegilops triuncialis',
#        'Aegopodium alpestre', 'Aegopodium podagraria',
#        'Aeluropus litoralis', 'Aesculus glabra', 'Aesculus hippocastanum',
#        'Aesculus parviflora', 'Aethionema rotundifolia',
#        'Aextoxicon punctatum', 'Afrocarpus gracilior',
#        'Agastache foeniculum', 'Agathis australis',
#        'Agathis kinabaluensis', 'Agave americana', 'Agave deserti',
#        'Ageratina altissima', 'Ageratum mexicanum', 'Aglaia exstipulata',
#        'Aglaia odorata', 'Aglaia odoratissima', 'Aglaia squamulosa',
#        'Agonis flexuosa', 'Agoseris glauca', 'Agoseris heterophylla',
#        'Agrimonia eupatoria', 'Agrimonia pilosa', 'Agrimonia procera',
#        'Agriophyllum arenarium', 'Agriophyllum squarrosum',
#        'Agropyron cristatum', 'Agropyron dasystachyum',
#        'Agropyron desertorum', 'Agropyron fragile', 'Agropyron glaucum',
#        'Agropyron inerme', 'Agropyron intermedium',
#        'Agropyron lavrenkoanum', 'Agropyron michnoi',
#        'Agropyron mongolicum', 'Agropyron pectinatum', 'Agropyron repens',
#        'Agropyron scabrum', 'Agropyron smithii', 'Agropyron spicatum',
#        'Agrostemma githago', 'Agrostis agrostiflora', 'Agrostis alba',
#        'Agrostis alpina', 'Agrostis canina', 'Agrostis capillare',
#        'Agrostis capillaris', 'Agrostis castellana', 'Agrostis coarctata',
#        'Agrostis curtisii', 'Agrostis gigantea', 'Agrostis halli',
#        'Agrostis macrantha', 'Agrostis mertensii', 'Agrostis planifolia',
#        'Agrostis rupestris', 'Agrostis scabra', 'Agrostis schleicheri',
#        'Agrostis stolonifera', 'Agrostis tenuis', 'Agrostis vinealis',
#        'Ailanthus altissima', 'Aira elegantissima', 'Aira praecox',
#        'Aizoon hispanicum', 'Ajania fastigiata', 'Ajania potaninii',
#        'Ajuga genevensis', 'Ajuga orientalis', 'Ajuga pyramidalis',
#        'Ajuga reptans', 'Akebia quinata', 'Alajja anomala',
#        'Alangium chinense', 'Albizia amara', 'Albizia julibrissin',
#        'Albizia versicolor', 'Alcea nudiflora', 'Alchemilla alpina',
#        'Alchemilla caucasica', 'Alchemilla conjuncta',
#        'Alchemilla debilis', 'Alchemilla dura', 'Alchemilla fissa',
#        'Alchemilla glabra', 'Alchemilla glacialis',
#        'Alchemilla glomerulans', 'Alchemilla haraldi',
#        'Alchemilla leiophylla', 'Alchemilla monticola',
#        'Alchemilla obtusa', 'Alchemilla persica', 'Alchemilla retinervis',
#        'Alchemilla sericata', 'Alchemilla sericea', 'Alchemilla sibirica',
#        'Alchemilla smirnovii', 'Alchemilla strictissima',
#        'Alchemilla vulgaris', 'Alchemilla wichurae',
#        'Alchemilla xanthochlora', 'Alchornea tiliifolia',
#        'Alchornea trewioides', 'Alectryon excelsus', 'Aletes acaulis',
#        'Aleurites fordii', 'Aleurites moluccana', 'Alhagi canescens',
#        'Alhagi pseudalhagi', 'Alhagi pseudoalhagi', 'Alhagi sparsifolia',
#        'Alibertia verrucosa', 'Alisma gramineum', 'Alisma lanceolatum',
#        'Alisma plantago-aquatica', 'Allenrolfea occidentalis',
#        'Alliaria petiolata', 'Allium albidum', 'Allium ampeloprasum',
#        'Allium angulosum', 'Allium bidentatum', 'Allium borszczowii',
#        'Allium carinatum', 'Allium carolinianum', 'Allium caspium',
#        'Allium cepa', 'Allium chamaemoly', 'Allium decipiens',
#        'Allium ericetorum', 'Allium fedschenkoanum', 'Allium fetisowi',
#        'Allium fistulosum', 'Allium flavum', 'Allium jodanthum',
#        'Allium karsianum', 'Allium moly', 'Allium mongolicum',
#        'Allium moschatum', 'Allium neapolitanum', 'Allium nigrum',
#        'Allium nutans', 'Allium oleraceum', 'Allium palentinum',
#        'Allium paniculatum', 'Allium paradoxum', 'Allium polyrhizum',
#        'Allium porrum', 'Allium pseudostrictum', 'Allium ramosum',
#        'Allium roseum', 'Allium rotundum', 'Allium sabulosum',
#        'Allium sativum', 'Allium saxatile', 'Allium schoenophrasum',
#        'Allium schoenoprasum', 'Allium schuberti', 'Allium scorodoprasum',
#        'Allium senescens', 'Allium sphaerocephalon', 'Allium strictum',
#        'Allium suaveolens', 'Allium subhirsutum', 'Allium tenuissimum',
#        'Allium textile', 'Allium triquetrum', 'Allium ursinum',
#        'Allium victorialis', 'Allium vineale', 'Allium waldsteinii',
#        'Allophylus abyssinicus', 'Alloteropsis cimicina',
#        'Alloteropsis semialata', 'Alniphyllum fortunei', 'Alnus crispa',
#        'Alnus formosana', 'Alnus glutinosa', 'Alnus hirsute',
#        'Alnus incana', 'Alnus japonica', 'Alnus mandshurica',
#        'Alnus rubra', 'Alnus sibirica', 'Alnus viridis',
#        'Alocasia macrorhiza', 'Aloe littoralis', 'Aloe vera',
#        'Alopecurus aequalis', 'Alopecurus alpinus',
#        'Alopecurus arundinaceus', 'Alopecurus bulbosus',
#        'Alopecurus dasyanthus', 'Alopecurus geniculatus',
#        'Alopecurus glacialis', 'Alopecurus magellanicus',
#        'Alopecurus pratensis', 'Alopecurus sericeus',
#        'Alopecurus soongaricus', 'Alopecurus vaginatus',
#        'Alpinia japonica', 'Alseis blackiana', 'Alstonia scholaris',
#        'Alternanthera philoxeroides', 'Alternanthera sessilis',
#        'Althaea officinalis', 'Althaea rosea', 'Altingia gracilipes',
#        'Altingia obovata', 'Alysicarpus monilifer', 'Alyssum dasycarpum',
#        'Alyssum linifolius', 'Alyssum maritimum', 'Alyssum tortuosum',
#        'Alyssum turkestanicum', 'Amaranthus blitoides',
#        'Amaranthus blitum', 'Amaranthus caudatus', 'Amaranthus cruentus',
#        'Amaranthus hypochondriacus', 'Amaranthus retroflexus',
#        'Amaranthus tricolor', 'Amberboa turanica',
#        'Ambrosia acanthicarpa', 'Ambrosia artemisiifolia',
#        'Ambrosia dumosa', 'Ambrosia psilostachya',
#        'Amelanchier alnifolia', 'Amelanchier spp.',
#        'Ammodendron argenteum', 'Ammodendron conollyi',
#        'Ammophila arenaria', 'Amomum villosum', 'Amomyrtus luma',
#        'Amomyrtus meli', 'Amorpha canescen', 'Amorpha canescens',
#        'Amorpha fruticosa', 'Ampelocera ruizii', 'Amphibromus fluitans',
#        'Amphipterygium adstringens', 'Anabasis aphylla', 'Anabasis salsa',
#        'Anacamptis morio', 'Anacamptis pyramidalis',
#        'Anacardium excelsum', 'Anadenanthera colubrina',
#        'Anagallis tenella', 'Ananas comosus', 'Anaphalis aureopunctata',
#        'Anaphalis elliptica', 'Anaphalis hancockii',
#        'Anaxagorea javanica', 'Anchusa officinalis', 'Andira humilis',
#        'Andrographis paniculata', 'Andromeda polifolia',
#        'Andropogon furcatus', 'Andropogon gayanus', 'Andropogon gerardi',
#        'Andropogon gerardii', 'Andropogon halii', 'Andropogon hallii',
#        'Andropogon nutans', 'Andropogon scoparius',
#        'Andropogon seoparius', 'Androsace caduca',
#        'Androsace chamaejasme', 'Androsace filiformis',
#        'Androsace koso-poljanskii', 'Androsace lactea',
#        'Androsace occidentalis', 'Androsace septenrionalis',
#        'Androsace septentrionalis', 'Androsace subumbellata',
#        'Androsace villosa', 'Anemonastrum narcissiflorum',
#        'Anemone altaica', 'Anemone cylindrica', 'Anemone dichotoma',
#        'Anemone narcissiflora', 'Anemone nemorosa', 'Anemone patens',
#        'Anemone pavoniana', 'Anemone protracta', 'Anemone ranunculoides',
#        'Anemone speciosa', 'Anemone sylvestris', 'Anemone trifolia',
#        'Angelica archangelica', 'Angelica sylvestris', 'Aniba citrifolia',
#        'Anisophyllea disticha', 'Anisotome aromatica', 'Annona dioica',
#        'Anoda cristata', 'Anona squamosa', 'Antennaria carpatica',
#        'Antennaria caucasica', 'Antennaria dioica', 'Antennaria neglecta',
#        'Antennaria parvifolia', 'Antennaria rosulata',
#        'Anthemis abagensis', 'Anthemis cotula', 'Anthemis cretica',
#        'Anthemis iberica', 'Anthemis rigescens', 'Anthemis rudolphiana',
#        'Anthemis sosnovskyana', 'Anthemis tinctoria',
#        'Anthericum liliago', 'Anthericum ramosum',
#        'Anthoxanthum monticola', 'Anthoxanthum odoratum',
#        'Anthriscus ruprechtii', 'Anthriscus sylvestris',
#        'Anthyllis cytisoides', 'Anthyllis henoniana',
#        'Anthyllis macrocephala', 'Anthyllis terniflora',
#        'Anthyllis variegata', 'Anthyllis vulneraria',
#        'Antidesma cuspidatum', 'Antidesma leucopodum',
#        'Antidesma maclurei', 'Antirrhinum majus', 'Apera spica',
#        'Apera spica-venti', 'Aphanamixis grandifolia',
#        'Aphanostephus ramosissimus', 'Apium inundatum',
#        'Apium nodiflorum', 'Apium repens', 'Apocynum androsaemifolium',
#        'Apocynum androsremifolium', 'Apocynum cannabinum',
#        'Apocynum venetum', 'Apodytes dimidiata', 'Aporosa bracteosa',
#        'Aporosa dioica', 'Aporosa villosa', 'Aporosa yunnanensis',
#        'Aposeris foetida', 'Aquilegia olympica', 'Aquilegia pyrenaica',
#        'Aquilegia vulgaris', 'Arabidopsis halleri',
#        'Arabidopsis thaliana', 'Arabis alpina', 'Arabis caucasica',
#        'Arabis glabra', 'Arabis hirsuta', 'Arabis pendula',
#        'Arabis scabra', 'Arabis soyeri', 'Arachis hypogaea',
#        'Arachis pintoi', 'Aragallus lambertii', 'Aralia nudicaulis',
#        'Araucaria angustifolia', 'Araucaria araucana',
#        'Araucaria cunninghamii', 'Arbutus unedo',
#        'Archidendron clypearia', 'Archidendron lucidum',
#        'Arctagrostis latifolia', 'Arctium lappa', 'Arctium nemorosum',
#        'Arctium tomentosum', 'Arctostaphylos alpina',
#        'Arctostaphylos glandalosa', 'Arctostaphylos patula',
#        'Arctostaphylos uva-ursi', 'Arctotheca calendula',
#        'Ardisia crenata', 'Ardisia depressa', 'Ardisia elliptica',
#        'Ardisia japonica', 'Ardisia quinquegona', 'Ardisia sieboldii',
#        'Ardisia virens', 'Aremonia agrimonoides', 'Arenaria aequicaulis',
#        'Arenaria fendleri', 'Arenaria griffithii', 'Arenaria lanuginosa',
#        'Arenaria ledebouriana', 'Arenaria longifolia',
#        'Arenaria lychnidea', 'Arenaria montana', 'Arenaria musciformis',
#        'Arenaria procera', 'Arenaria purpurascens', 'Arenaria sajanensis',
#        'Arenaria serpillyfolia', 'Arenaria serpyllifolia',
#        'Argemone platyceras', 'Argusia sogdiana',
#        'Argyrodendron actinophyllum', 'Argyrodendron spec.',
#        'Argyrodendron trifoliolatum', 'Aristea major',
#        'Aristida holothera', 'Aristida inaequiglumis',
#        'Aristida oligantha', 'Aristida pennata', 'Aristida pungens',
#        'Aristida purpurea', 'Aristida ramosa', 'Aristida setacea',
#        'Aristolochia bracteata', 'Aristolochia giberti',
#        'Aristotelia serrata', 'Armeniaca vulgaris', 'Armeria cantabrica',
#        'Armeria maritima', 'Armeria velutina', 'Arnebia decumbens',
#        'Arnebia echioides', 'Arnica fulgens', 'Arnica mollis',
#        'Arnica montana', 'Arnica sororia', 'Arrhenatherum elatius',
#        'Artemisia absinthium', 'Artemisia aralensis',
#        'Artemisia arenaria', 'Artemisia armeniaca', 'Artemisia austriaca',
#        'Artemisia austriaco', 'Artemisia badhysi', 'Artemisia barrelieri',
#        'Artemisia campestris', 'Artemisia cana', 'Artemisia capillaris',
#        'Artemisia carruthii', 'Artemisia caucasica', 'Artemisia cina',
#        'Artemisia codonocephala', 'Artemisia dracunculus',
#        'Artemisia eranthema', 'Artemisia ferganensis',
#        'Artemisia filifolia', 'Artemisia frigida', 'Artemisia fukudo',
#        'Artemisia genipi', 'Artemisia glauca', 'Artemisia gmelinii',
#        'Artemisia halodendron', 'Artemisia herba-alba',
#        'Artemisia igniaria', 'Artemisia incana',
#        'Artemisia intramongolica', 'Artemisia kemrudica',
#        'Artemisia laciniata', 'Artemisia latifolia', 'Artemisia leucodes',
#        'Artemisia ludoviciana', 'Artemisia maritima',
#        'Artemisia marschalliana', 'Artemisia mongolica',
#        'Artemisia nanschanica', 'Artemisia nitrosa', 'Artemisia ordosica',
#        'Artemisia pauciflora', 'Artemisia pontica', 'Artemisia procera',
#        'Artemisia quinqueloba', 'Artemisia rupestris',
#        'Artemisia sacrorum', 'Artemisia santolinifolia',
#        'Artemisia scoparia', 'Artemisia scopulorum', 'Artemisia sericea',
#        'Artemisia sieberi', 'Artemisia soongarica',
#        'Artemisia sphaerocephala', 'Artemisia stelleriana',
#        'Artemisia tanacetifolia', 'Artemisia terra?albae',
#        'Artemisia terrae-albae', 'Artemisia tomentella',
#        'Artemisia transiliensis', 'Artemisia tridentata',
#        'Artemisia turanica', 'Artemisia verlotiorum',
#        'Artemisia vulgaris', 'Arthraxon hispidus',
#        'Arthrophytum pulvinatum', 'Arthrostemma ciliatum',
#        'Artocarpus altilis', 'Artocarpus nitidus',
#        'Artocarpus styracifolius', 'Arum italicum', 'Arum maculatum',
#        'Aruncus dioicus', 'Arundinaria alpina', 'Arundinaria falcata',
#        'Arundinaria pusilla', 'Asarum europaeum', 'Ascarina lucida',
#        'Asclepias incarnata', 'Asclepias speciosa',
#        'Asclepias sullivantii', 'Asclepias syriaca', 'Asclepias tuberosa',
#        'Asclepias verticillata', 'Asclepias viridis', 'Asimina triloba',
#        'Asparagus acutifolius', 'Asparagus breslerianus',
#        'Asparagus inderiensis', 'Asparagus maritimus',
#        'Asparagus officinalis', 'Asparagus racemosus',
#        'Asparagus schoberioides', 'Asparagus tenuifolius',
#        'Asperugo procumbens', 'Asperula albovii',
#        'Asperula danilevskiana', 'Asperula tinctoria', 'Asphodelus albus',
#        'Aspidosperma cylindrocarpon', 'Aspidosperma desmanthum',
#        'Aspidosperma macrocarpon', 'Aspidosperma pyrifolium',
#        'Aspidosperma tomentosum', 'Asplenium adiantum-nigrum',
#        'Asplenium adulterinum', 'Asplenium alternifolium',
#        'Asplenium bulbiferum', 'Asplenium ceterach',
#        'Asplenium cuneifolium', 'Asplenium fissum', 'Asplenium fontanum',
#        'Asplenium obovatum', 'Asplenium ruta-muraria',
#        'Asplenium scolopendrium', 'Asplenium seelosii',
#        'Asplenium septentrionale', 'Asplenium trichomanes',
#        'Asplenium viride', 'Astelia fragrans', 'Astelia nervosa',
#        'Aster alpinus', 'Aster amellus', 'Aster azureus', 'Aster biennis',
#        'Aster canescens', 'Aster ciliolatus', 'Aster ericoides',
#        'Aster falcatus', 'Aster fastigiata', 'Aster laevis',
#        'Aster lanceolatus', 'Aster laurentianus', 'Aster linosyris',
#        'Aster macrophyllus', 'Aster multiflorus', 'Aster novae-angliae',
#        'Aster oblongifolius', 'Aster porteri', 'Aster punctata',
#        'Aster puniceus', 'Aster tataricus', 'Aster tripolium',
#        'Aster umbellatus', 'Astilbe rivularis', 'Astilbe rubra',
#        'Astragalus aboriginum', 'Astragalus alatavicus',
#        'Astragalus alopecias', 'Astragalus alpinus',
#        'Astragalus arpilobus', 'Astragalus arrectus', 'Astragalus aureus',
#        'Astragalus bisulcatus', 'Astragalus bornmuellerianus',
#        'Astragalus brachypus', 'Astragalus canadensis',
#        'Astragalus canidensis', 'Astragalus captiosus',
#        'Astragalus confertus', 'Astragalus contortuplicatus',
#        'Astragalus crassicarpus', 'Astragalus danicus',
#        'Astragalus dasyglottis', 'Astragalus denudatus',
#        'Astragalus deserti', 'Astragalus drobovii',
#        'Astragalus filicaulis', 'Astragalus flexus',
#        'Astragalus galactites', 'Astragalus glycyphyllos',
#        'Astragalus humistratus', 'Astragalus jagnobicus',
#        'Astragalus lasioglottis', 'Astragalus lasiosemius',
#        'Astragalus lehmannianus', 'Astragalus macrostachys',
#        'Astragalus melilotoides', 'Astragalus membranaceus',
#        'Astragalus monspessulanus', 'Astragalus onobrychis',
#        'Astragalus oxyglottis', 'Astragalus paucijugus',
#        'Astragalus peduncularis', 'Astragalus purshii',
#        'Astragalus rigidulus', 'Astragalus rusbyi',
#        'Astragalus sabulonum', 'Astragalus supinus',
#        'Astragalus testiculatus', 'Astragalus turczaninowii',
#        'Astragalus villosissimus', 'Astragalus vulpinus',
#        'Astrantia bavarica', 'Astrantia major', 'Astrantia maxima',
#        'Astrantia minor', 'Astrantia ossica', 'Astrodaucus orientalis',
#        'Asyneuma campanuloides', 'Asyneuma canescens',
#        'Atalaya hemiglauca', 'Athyrium brevifrons',
#        'Athyrium disentifolium', 'Athyrium distentifolium',
#        'Athyrium filix-femina', 'Athyrium sinense', 'Athyrium spinulosum',
#        'Atractylis humilis', 'Atraphaxis pyrifolia', 'Atraphaxis spinosa',
#        'Atriplex californica', 'Atriplex cana', 'Atriplex canescens',
#        'Atriplex confertifolia', 'Atriplex dimorphostegia',
#        'Atriplex halimus', 'Atriplex lampa', 'Atriplex leucophylla',
#        'Atriplex littoralis', 'Atriplex nummularia', 'Atriplex patula',
#        'Atriplex portulacoides', 'Atriplex prostrata', 'Atriplex spinosa',
#        'Atriplex tatarica', 'Atriplex torreyi', 'Atropa belladonna',
#        'Attalea exigua', 'Atylosia scarabaeoides', 'Aulacomnium turgidum',
#        'Aulacospermum simplex', 'Austrodanthonia caespitosa',
#        'Austrodanthonia carphoides', 'Austrodanthonia richardsonii',
#        'Avena barbata', 'Avena fatua', 'Avena nuda', 'Avena sativa',
#        'Avena sterilis', 'Avena strigosa', 'Avena versicolor',
#        'Avenella flexuosa', 'Avenula pratensis', 'Avenula pubescens',
#        'Avicennia germinans', 'Avicennia marina', 'Azadirachta indica',
#        'Azanza garckeana', 'Baccaurea ramiflora', 'Baccharis glutinosa',
#        'Backhousia myrtifolia', 'Bahia dissecta', 'Baikiaea plurijuga',
#        'Baileya multiradiata', 'Baileya pleniradiata',
#        'Balanites aegyptiaca', 'Baldellia ranunculoides',
#        'Ballota hirsuta', 'Balsamorhiza careyana',
#        'Balsamorhiza sagittata', 'Bambusa bambos', 'Banara vanderbiltii',
#        'Banksia attenuata', 'Banksia ilicifolia', 'Banksia prionotes',
#        'Baphia massaiensis', 'Baptisia alba', 'Baptisia australis',
#        'Baptisia bracteata', 'Baptisia leucantha', 'Barbarea vulgaris',
#        'Barleria cristata', 'Barleria cuspidata', 'Barleria noctiflora',
#        'Barringtonia fusicarpa', 'Barringtonia macrostachya',
#        'Barringtonia racemosa', 'Bartsia alpina', 'Bashania fangiana',
#        'Bassia dasyphylla', 'Batocarpus amazonicus',
#        'Batrachium baudotii', 'Batrachium circinatum',
#        'Batrachium fluitans', 'Batrachium trichophyllum',
#        'Bauhinia brachycarpa', 'Bauhinia championii',
#        'Bauhinia petersiana', 'Bauhinia racemosa', 'Bauhinia variegata',
#        'Baumea articulata', 'Beckmannia eruciformis', 'Begonia fista',
#        'Beilschmiedia tarairi', 'Beilschmiedia tawa',
#        'Bellidiastrum michelii', 'Bellis perennis', 'Berberis heteropoda',
#        'Berberis koreana', 'Berberis oblonga', 'Berberis repens',
#        'Berberis thunbergii', 'Berberis vulgaris', 'Berberis wilsonae',
#        'Bernardia spongiosa', 'Berteroa incana', 'Berula erecta',
#        'Besseya plantaginea', 'Beta vulgaris', 'Betonica alopecuros',
#        'Betonica officinalis', 'Betula albo-sinensis',
#        'Betula alleghaniensis', 'Betula costata', 'Betula dahurica',
#        'Betula ermanii', 'Betula fruticosa', 'Betula glandulosa',
#        'Betula lenta', 'Betula lutea', 'Betula nana', 'Betula nigra',
#        'Betula papyrifera', 'Betula pendula', 'Betula platyphylla',
#        'Betula populifolia', 'Betula pubescens', 'Betula tortuosa',
#        'Betula utilis', 'Betula verrucosa', 'Bewsia biflora',
#        'Bidens frondosa', 'Bidens pilosa', 'Bidens tripartita',
#        'Biebersteinia multifida', 'Biophytum sensitivum',
#        'Biota orientalis', 'Biscutella laevigata', 'Biserrula pelecinus',
#        'Bistorta officinalis', 'Bistorta vivipara',
#        'Bituminaria bituminosa', 'Blastus cochinchinensis',
#        'Blastus pauciflorus', 'Blechnum chambersii', 'Blechnum discolor',
#        'Blechnum fluviatile', 'Blechnum novae-zelandiae',
#        'Blechnum orientale', 'Blechnum procerum', 'Blechnum spicant',
#        'Blepharoneuron tricholepis', 'Blumeodendron tokbrai',
#        'Blysmus compressus', 'Blysmus rufus', 'Bolboschoenus maritimus',
#        'Boltonia asteroides', 'Bombax ceiba', 'Borago officinalis',
#        'Boscia albitrunca', 'Boswellia serrata', 'Bothriochloa insculpta',
#        'Bothriochloa ischaemum', 'Bothriochloa macra',
#        'Botrychium lunaria', 'Botrychium matricariifolium',
#        'Botrychium multifidum', 'Botrychium simplex',
#        'Botrychium virginianum', 'Bougainvillea modesta',
#        'Bouteloua curtipendula', 'Bouteloua dactyloides',
#        'Bouteloua eriopoda', 'Bouteloua gracilils', 'Bouteloua gracilis',
#        'Bouteloua simplex', 'Bowdichia virgilioides',
#        'Brachiaria dictyoneura', 'Brachiaria eruciformis',
#        'Brachiaria humidicola', 'Brachiaria muctica', 'Brachiaria mutica',
#        'Brachiaria pubigera', 'Brachiaria ruziziensis',
#        'Brachyclados caespitosus', 'Brachyglottis bellidioides',
#        'Brachylaena discolor', 'Brachypodium  pinnatum',
#        'Brachypodium distachya', 'Brachypodium distachyon',
#        'Brachypodium phoenicoides', 'Brachypodium pinnatum',
#        'Brachypodium rupestre', 'Brachypodium sylvaticum',
#        'Brachystegia boehmii', 'Brachystegia florabunda',
#        'Brachystegia longifolia', 'Brachystegia spiciformis',
#        'Brachystegia utilis', 'Braciaria ramosa', 'Brassica juncea',
#        'Brassica napus', 'Brassica oleracea', 'Brassica rapa',
#        'Brauneria pallida', 'Briza elatior', 'Briza marcowiczii',
#        'Briza maxima', 'Briza media', 'Bromopsis inermis',
#        'Bromus adjaricus', 'Bromus anomalus', 'Bromus benekenii',
#        'Bromus brizaeformis', 'Bromus briziformis', 'Bromus catharticus',
#        'Bromus ciliatus', 'Bromus commutatus', 'Bromus danthoniae',
#        'Bromus diandrus', 'Bromus erectus', 'Bromus hordaceaus',
#        'Bromus hordaceous', 'Bromus hordeaceus', 'Bromus inermis',
#        'Bromus intermedius', 'Bromus japanicus', 'Bromus japonicus',
#        'Bromus kalmii', 'Bromus lanceolatus', 'Bromus madritensis',
#        'Bromus molliformis', 'Bromus ornans', 'Bromus porteri',
#        'Bromus racemosus', 'Bromus ramosus', 'Bromus riparia',
#        'Bromus riparius', 'Bromus scoparius', 'Bromus secalinus',
#        'Bromus sewerzowi', 'Bromus squarrosus', 'Bromus stamineus',
#        'Bromus sterilis', 'Bromus tectorum', 'Bromus tomentellus',
#        'Bromus turkestanica', 'Bromus unioloides', 'Bromus variegata',
#        'Bromus villosula', 'Brosimum alicastrum', 'Brosimum rubescens',
#        'Bruguiera sexangula', 'Bryonia cretica', 'Buchenavia capitata',
#        'Buchloe dactyloides', 'Buddleja davidii',
#        'Buglossoides purpurocaerulea', 'Bulbilis dactyloide',
#        'Bulbostylis barbata', 'Bulnesia arborea', 'Bunchosia argentea',
#        'Bunias orientalis', 'Bunium chaerophylloides',
#        'Buphthalmum salicifolium', 'Bupleurum longifolium',
#        'Bupleurum multinerve', 'Bupleurum nordmannianum',
#        'Bupleurum polyphyllum', 'Bupleurum ranunculoides',
#        'Burkea africana', 'Bursera simaruba', 'Butea frondosa',
#        'Butea monosperma', 'Butomus umbellatus', 'Buxus colchica',
#        'Buxus sempervirens', 'Byrsonima crassifolia',
#        'Byrsonima cydoniifolia', 'Byrsonima spicata', 'Cacalia hastata',
#        'Cadaba fruticosa', 'Caesalpinia bonduc', 'Caesalpinia coriaria',
#        'Caesalpinia eriostachys', 'Caesalpinia jamesii',
#        'Caesalpinia platyloba', 'Caesalpinia pluviosa',
#        'Caesalpinia pyramidalis', 'Caesalpinia sclerocarpa',
#        'Cakile maritima', 'Calamagrostis angustifolia',
#        'Calamagrostis anthoxanthoides', 'Calamagrostis arundinacea',
#        'Calamagrostis canadensis', 'Calamagrostis canescens',
#        'Calamagrostis epigeios', 'Calamagrostis epigejos',
#        'Calamagrostis glauca', 'Calamagrostis hedinii',
#        'Calamagrostis lapponica', 'Calamagrostis neglecta',
#        'Calamagrostis obtusata', 'Calamagrostis persica',
#        'Calamagrostis phragmitoides', 'Calamagrostis pseudophragmites',
#        'Calamagrostis purpuras', 'Calamagrostis purpurascens',
#        'Calamagrostis purpurea', 'Calamagrostis rivalis',
#        'Calamagrostis stricta', 'Calamagrostis varia',
#        'Calamagrostis villosa', 'Calamintha grandiflora',
#        'Calamintha nepeta', 'Calamovilfa longifolia',
#        'Calamus rhabdocladus', 'Caldesia parnassiifolia',
#        'Calendula officinalis', 'Calla cordifolia', 'Calla palustris',
#        'Calliandra calothyrsus', 'Calliandra eriophylla',
#        'Callicarpa americana', 'Callicarpa havilandii',
#        'Callicoma serratifolia', 'Calligonum aphyllum',
#        'Calligonum bykovii', 'Calligonum caput-medusae',
#        'Calligonum leucocladum', 'Calligonum mongolicum',
#        'Calligonum murex', 'Calligonum polygonoides',
#        'Calligonum roborovskii', 'Callistemon citrinus',
#        'Callistephus chinensis', 'Callitriche cophocarpa',
#        'Callitriche hamulata', 'Callitriche obtusangula',
#        'Callitriche palustris', 'Callitriche platycarpa',
#        'Callitriche stagnalis', 'Callitriche truncata',
#        'Calluna vulgaris', 'Calocedrus decurrens',
#        'Calophyllum longifolium', 'Calotropis gigantea',
#        'Calotropis procera', 'Calpurnia aurea', 'Caltha palustris',
#        'Calycogonium squamulosum', 'Calypso bulbosa',
#        'Calyptranthes pallens', 'Calystegia hederacea',
#        'Calystegia pulchra', 'Calystegia sepium', 'Calystegia soldanella',
#        'Camelina microcarpa', 'Camellia chekiangoleosa',
#        'Camellia cuspidata', 'Camellia fraterna', 'Camellia oleifera',
#        'Cameraria retusa', 'Campanula altaica', 'Campanula annae',
#        'Campanula arvatica', 'Campanula aucheri', 'Campanula barbata',
#        'Campanula bellidifolia', 'Campanula bononiensis',
#        'Campanula carnica', 'Campanula cespitosa', 'Campanula circassica',
#        'Campanula collina', 'Campanula darialica', 'Campanula glomerata',
#        'Campanula grossheimii', 'Campanula hohenackeri',
#        'Campanula latifolia', 'Campanula ochroleuca', 'Campanula patula',
#        'Campanula persicifolia', 'Campanula rapunculoides',
#        'Campanula rotundifolia', 'Campanula saxifraga',
#        'Campanula sibirica', 'Campanula trachelium',
#        'Campanula trautvetteri', 'Campanula tridentata',
#        'Camphorosma monspeliacum', 'Canarium album',
#        'Canarium tonkinense', 'Cannabis sativa', 'Capparis aphylla',
#        'Capparis prisca', 'Capparis yco', 'Capsella bursa-pastoris',
#        'Capsicum annuum', 'Capsicum anuum', 'Capsicum baccattum',
#        'Caragana arborescens', 'Caragana korshinskii',
#        'Caragana microphylia', 'Caragana microphylla', 'Caragana pygmaea',
#        'Caragana spinosa', 'Caragana stenophylla', 'Carallia brachiata',
#        'Carapa guianensis', 'Cardamine amara', 'Cardamine bellidifolia',
#        'Cardamine microphylla', 'Cardamine oligosperma',
#        'Cardamine pratensis', 'Cardamine trifida', 'Cardamine trifolia',
#        'Cardamine uliginosa', 'Cardiospermum halicacabum',
#        'Carduus defloratus', 'Carduus nutans', 'Carduus personata',
#        'Carduus thoermeri', 'Carex acuta', 'Carex acutiformis',
#        'Carex alba', 'Carex albonigra', 'Carex annectens',
#        'Carex appropinquata', 'Carex aquatilis', 'Carex arenaria',
#        'Carex aristata', 'Carex arnellii', 'Carex atherodes',
#        'Carex atrata', 'Carex atrofusca', 'Carex baccans',
#        'Carex baldensis', 'Carex bigelowii', 'Carex binervis',
#        'Carex bohemica', 'Carex bostrychostigma', 'Carex brachystachys',
#        'Carex brizoides', 'Carex brunnescens', 'Carex buekii',
#        'Carex buschiorum', 'Carex buxbaumii', 'Carex canescens',
#        'Carex capillaris', 'Carex capitata', 'Carex cariophyllea',
#        'Carex caryophyllea', 'Carex caucasica', 'Carex cespitosa',
#        'Carex chordorrhiza', 'Carex colchica', 'Carex concolor',
#        'Carex contigua', 'Carex crinata', 'Carex crinita',
#        'Carex curvata', 'Carex curvula', 'Carex davalliana',
#        'Carex demissa', 'Carex depauperata', 'Carex diandra',
#        'Carex digitata', 'Carex diluta', 'Carex dioica', 'Carex distans',
#        'Carex disticha', 'Carex divisa', 'Carex divulsa',
#        'Carex doisutepensis', 'Carex duriuscula', 'Carex echinata',
#        'Carex elata', 'Carex eleocharis', 'Carex elongata',
#        'Carex enervis', 'Carex ericetorum', 'Carex extensa',
#        'Carex ferruginea', 'Carex filifolia', 'Carex firma',
#        'Carex flacca', 'Carex flava', 'Carex frigida', 'Carex fritschii',
#        'Carex fuliginosa', 'Carex fusca', 'Carex gaudichaudiana',
#        'Carex geophila', 'Carex geophylla', 'Carex geyeri',
#        'Carex globularis', 'Carex goodenoughii', 'Carex griffithii',
#        'Carex halleriana', 'Carex hartmanii', 'Carex heleonastes',
#        'Carex hirta', 'Carex hordeistichos', 'Carex hostiana',
#        'Carex huetiana', 'Carex humilis', 'Carex hyperborea',
#        'Carex interior', 'Carex juncella', 'Carex laevigata',
#        'Carex lasiocarpa', 'Carex laxa', 'Carex leporina', 'Carex limosa',
#        'Carex liparocarpos', 'Carex loliacea', 'Carex lupulina',
#        'Carex lurida', 'Carex magell-anica', 'Carex magellanica',
#        'Carex medwedewii', 'Carex meinshauseniana', 'Carex melanantha',
#        'Carex melanostachya', 'Carex meyeriana', 'Carex michelii',
#        'Carex microglochin', 'Carex mollissima', 'Carex montana',
#        'Carex moorcroftii', 'Carex mucronata', 'Carex muricata',
#        'Carex myosurus', 'Carex nardina', 'Carex nebrascensi',
#        'Carex nigra', 'Carex norvegica', 'Carex obtusata', 'Carex oederi',
#        'Carex orbicularis', 'Carex oreophila', 'Carex ornithopoda',
#        'Carex otrubae', 'Carex pachystylis', 'Carex pallescens',
#        'Carex panicea', 'Carex paniculata', 'Carex parviflora',
#        'Carex pauciflora', 'Carex pediformis', 'Carex pendula',
#        'Carex pennsylvanica', 'Carex physodes', 'Carex pilosa',
#        'Carex pilulifera', 'Carex polyphylla', 'Carex praecox',
#        'Carex pseudobrizoides', 'Carex pseudocyperus',
#        'Carex pseudofoetida', 'Carex pulicaris', 'Carex punctata',
#        'Carex pyrenaica', 'Carex rariflora', 'Carex remota',
#        'Carex repens', 'Carex rhizina', 'Carex rhyncho-physa',
#        'Carex rhynchophysa', 'Carex riparia', 'Carex rostrata',
#        'Carex rotundata', 'Carex rupestris', 'Carex saxatilis',
#        'Carex schmidtii', 'Carex scoparium', 'Carex scopulorum',
#        'Carex secalina', 'Carex sempervirens', 'Carex songorica',
#        'Carex spicata', 'Carex stans', 'Carex stenophylla',
#        'Carex stenophylloides', 'Carex stricta', 'Carex strigosa',
#        'Carex subspathacea', 'Carex supina', 'Carex sylvatica',
#        'Carex tenuiflora', 'Carex tomentosa', 'Carex trinervis',
#        'Carex tristachya', 'Carex tristis', 'Carex turkestanica',
#        'Carex umbrosa', 'Carex utriculata', 'Carex vaginata',
#        'Carex varia', 'Carex vesicaria', 'Carex viridula',
#        'Carex vulgaris', 'Carex vulpina', 'Carica papaya',
#        'Cariniana estrellensis', 'Cariniana ianeirensis',
#        'Cariniana legalis', 'Carlina acaulis', 'Carlina longifolia',
#        'Carlina vulgaris', 'Carpinus betula', 'Carpinus betulus',
#        'Carpinus cordata', 'Carpinus orientalis', 'Carpodetus serratus',
#        'Carum carvi', 'Carum caucasicum', 'Carum meifolium', 'Carum spp',
#        'Carum verticillatum', 'Carya cordiformis', 'Carya glabra',
#        'Carya ovata', 'Carya tomentosa', 'Caryocar brasiliense',
#        'Caryota maxima', 'Cascabela ovata', 'Casearia arborea',
#        'Casearia bicolor', 'Casearia gossypiosperma',
#        'Casearia sylvestris', 'Cassia absus', 'Cassia auriculata',
#        'Cassia bauhinioides', 'Cassia fasciculata', 'Cassia fistula',
#        'Cassia hirsuta', 'Cassia occidentalis', 'Cassia siamea',
#        'Cassiope hypnoides', 'Cassiope tetragona', 'Castanea henrii',
#        'Castanea henryi', 'Castanea sativa', 'Castanopsis carlesii',
#        'Castanopsis chinensis', 'Castanopsis echidnocarpa',
#        'Castanopsis echinocarpa', 'Castanopsis eyrei',
#        'Castanopsis faberi', 'Castanopsis fabri', 'Castanopsis fargesii',
#        'Castanopsis fissa', 'Castanopsis hystrix',
#        'Castanopsis kawakamii', 'Castanopsis sclerophylla',
#        'Castanopsis tibetana', 'Castanopsis wattii', 'Castilla elastica',
#        'Castilleja austromontana', 'Castilleja integra',
#        'Casuarina equisetifolia', 'Casuarina glauca', 'Casuarina obesa',
#        'Catabrosa aquatica', 'Catabrosella variegata',
#        'Catalpa bignonioides', 'Catalpa bungei', 'Catalpa speciosa',
#        'Catostemma fragrans', 'Catunaregam spinosa',
#        'Caulophyllum robustum', 'Cavanillesia hylogeiton',
#        'Ceanothus cuneatus', 'Ceanothus fendleri',
#        'Ceanothus leucodermis', 'Ceanothus leucoderuis',
#        'Ceanothus megacarpus', 'Ceanothus ovatus', 'Ceanothus tomentosus',
#        'Cecropia concolor', 'Cecropia distachya', 'Cecropia ficifolia',
#        'Cecropia longipes', 'Cecropia obtusa', 'Cecropia obtusifolia',
#        'Cecropia pachystachya', 'Cecropia peltata',
#        'Cecropia sciadophylla', 'Cedrela fissilis', 'Cedrela odorata',
#        'Cedrus atlantica', 'Cedrus deodara', 'Ceiba pentandra',
#        'Ceiba samauma', 'Ceiba speciosa', 'Celastrus orbiculatus',
#        'Celastrus scandens', 'Celmisia angustifolia',
#        'Celmisia hieraciifolia', 'Celmisia lyallii', 'Celtis australis',
#        'Celtis caucasica', 'Celtis laevigata', 'Celtis occidentalis',
#        'Celtis pallida', 'Celtis sinensis', 'Cenchrus ciliaris',
#        'Centaurea aspera', 'Centaurea cheiranthifolia',
#        'Centaurea diffusa', 'Centaurea jacea', 'Centaurea nigra',
#        'Centaurea nigrescens', 'Centaurea pectinata', 'Centaurea phrygia',
#        'Centaurea pseudophrygia', 'Centaurea pulchella',
#        'Centaurea ruthenica', 'Centaurea scabiosa', 'Centaurea sibirica',
#        'Centaurea solstitialis', 'Centaurea squarrosa',
#        'Centaurea stoebe', 'Centrolobium microchaete',
#        'Centrosema acutifolium', 'Cephalanthera damasonium',
#        'Cephalanthera longifolia', 'Cephalanthera rubra',
#        'Cephalanthus occidentalis', 'Cephalaria gigantea',
#        'Cerastium alpinum', 'Cerastium arcticum', 'Cerastium argenteum',
#        'Cerastium arvense', 'Cerastium bungeanum',
#        'Cerastium cerastoides', 'Cerastium davuricum',
#        'Cerastium dichotomum', 'Cerastium fontanum',
#        'Cerastium glomeratum', 'Cerastium kasbek',
#        'Cerastium multiflorum', 'Cerastium pauciflorum',
#        'Cerastium pumilum', 'Cerastium svanicum', 'Cerastium sylvaticum',
#        'Cerastium tomentosum', 'Cerastium uralense',
#        'Cerasus sachalinensis', 'Ceratocarpus arenarius',
#        'Ceratocarpus utriculosus', 'Ceratocephala testiculata',
#        'Ceratoides lanata', 'Ceratoides latens', 'Ceratonia siliqua',
#        'Ceratopetalum apetalum', 'Ceratostigma minus',
#        'Ceratostigma willmottianum', 'Cercidiphyllum japonicum',
#        'Cercis canadensis', 'Cercis siliquastrum', 'Cercocarpus montanus',
#        'Cereus peruvianus', 'Cerinthe glabra', 'Ceriops australis',
#        'Ceriops decandra', 'Ceriops tagal', 'Cestrum nocturnum',
#        'Chaenactis carphoclinia', 'Chaenactis fremontii',
#        'Chaenomeles japonica', 'Chaerophyllum aromaticum',
#        'Chaerophyllum aureum', 'Chaerophyllum bulbosum',
#        'Chaerophyllum hirsutum', 'Chaerophyllum millefolium',
#        'Chaerophyllum roseum', 'Chaetopappa ericoides',
#        'Chamaecrista fasciculata', 'Chamaecyparis formosensis',
#        'Chamaecyparis lawsoniana', 'Chamaecyparis obtusa',
#        'Chamaecyparis pisifera', 'Chamaecyparis thyoides',
#        'Chamaecytisus ruthenicus', 'Chamaecytisus zingeri',
#        'Chamaedaphne calyculata', 'Chamaenerion angustifolium',
#        'Chamaerhodos erecta', 'Chamaesciadium acaule',
#        'Chamaespartium tridentatum', 'Chamaesphacos ilicifolius',
#        'Chamaesyce fendleri', 'Chamaesyce nutans',
#        'Chamaesyce serpyllifolia', 'Chamerion angustifolium',
#        'Chamorchis alpina', 'Chasmanthium latifolium',
#        'Chenopodium acuminatum', 'Chenopodium album',
#        'Chenopodium aristatum', 'Chenopodium bonus-henricus',
#        'Chenopodium ficifolium', 'Chenopodium fremontii',
#        'Chenopodium glaucum', 'Chenopodium graveolens',
#        'Chenopodium rubrum', 'Chenopodium serotinum',
#        'Chimaphila umbellata', 'Chimonanthus salicifolius',
#        'Chionanthus mildbraedii', 'Chionanthus retusus',
#        'Chionanthus virginicus', 'Chionochloa crassiuscula',
#        'Chionochloa macra', 'Chionochloa rigida', 'Chionochloa rubra',
#        'Chionochloa teretifolia', 'Chloranthus henryi', 'Chloris anomala',
#        'Chloris verticillata', 'Chloroleucon mangense',
#        'Chlorophora excelsa', 'Choerospondias axillaris',
#        'Chomelia psilocarpa', 'Chondrilla ambigua',
#        'Chondrilla brevirostris', 'Chondrilla juncea',
#        'Chorispora macropoda', 'Chorispora sibirica',
#        'Chrozophora sabulosa', 'Chrysanthemum bipinnatum',
#        'Chrysanthemum carinatum', 'Chrysanthemum corymbosum',
#        'Chrysanthemum leucanthemum', 'Chrysanthemum morifolium',
#        'Chrysanthemum sibiricum', 'Chrysopogon fallax',
#        'Chrysopogon fulvus', 'Chrysopogon gryllus',
#        'Chrysopogon latifolius', 'Chrysopogon zeylanicus',
#        'Chrysopsis villosa', 'Chrysosplenium alternifolium',
#        'Chrysosplenium oppositifolium', 'Chrysothamnus nauseosus',
#        'Chrysothamnus viscidiflorus', 'Cibotium barometz',
#        'Cicer arietinum', 'Cicer reticulatum', 'Cicerbita alpina',
#        'Cicerbita macrophylla', 'Cicerbita olgae', 'Cicerbita plumieri',
#        'Cicerbita pontica', 'Cicerbita racemosa', 'Cichorium intybus',
#        'Cicuta virosa', 'Cinnamomum austrosinense',
#        'Cinnamomum burmannii', 'Cinnamomum camphora', 'Cinnamomum cassia',
#        'Cinnamomum chekiangense', 'Cinnamomum griffithii',
#        'Cinnamomum japonicum', 'Cinnamomum micranthum',
#        'Cinnamomum parthenoxylon', 'Cinnamomum porrectum',
#        'Cinnamomum subavenium', 'Cinnamomum tenuifolium',
#        'Circaea alpina', 'Circaea intermedia', 'Circaea latifolia',
#        'Circaea lutetiana', 'Cirsium acaule', 'Cirsium acaulon',
#        'Cirsium altissimum', 'Cirsium arvense', 'Cirsium brevipapposum',
#        'Cirsium canum', 'Cirsium dissectum', 'Cirsium heterophyllum',
#        'Cirsium oleraceum', 'Cirsium palustre', 'Cirsium pannonicum',
#        'Cirsium pugnax', 'Cirsium rhizocephalum', 'Cirsium rivulare',
#        'Cirsium semenowi', 'Cirsium setosum', 'Cirsium simplex',
#        'Cirsium tuberosum', 'Cirsium vulgare', 'Cirsium wheeleri',
#        'Cistus albidus', 'Cistus clusii', 'Cistus crispus',
#        'Cistus ladanifer', 'Cistus laurifolius', 'Cistus libanotis',
#        'Cistus monspeliensis', 'Cistus salvifolius',
#        'Citharexylum caudatum', 'Citrus aurantium', 'Citrus jambhiri',
#        'Citrus macrophylla', 'Citrus medica', 'Citrus paradisi',
#        'Citrus reshni', 'Citrus reticulata', 'Citrus sinensis',
#        'Citrus tangerina', 'Citrus trifoliata', 'Citrus volkameriana',
#        'Cladium jamaicense', 'Cladium mariscoides', 'Cladium mariscus',
#        'Clarkia amoena', 'Clarkia elegans', 'Clathrotropis macrocarpa',
#        'Clausena lansium', 'Claytonia virginica',
#        'Cleistanthus sumatranus', 'Cleistogenes songorica',
#        'Cleistogenes squarrosa', 'Clematis akebioides', 'Clematis alpina',
#        'Clematis hexapetala', 'Clematis hirsutissima',
#        'Clematis integrifolia', 'Clematis orientalis', 'Clematis recta',
#        'Clematis sibirica', 'Clematis virginiana', 'Clematis vitalba',
#        'Clematis viticella', 'Clethra revoluta', 'Cleyera japonica',
#        'Clidemia hirta', 'Cliffortia ruscifolia',
#        'Climacoptera brachiata', 'Climacoptera crassa',
#        'Climacoptera lanata', 'Clinopodium chinense',
#        'Clinopodium menthifolium', 'Clinopodium nepeta',
#        'Clinopodium vulgare', 'Clintonia uniflora', 'Clitoria javitensis',
#        'Clitoria ternatea', 'Cnidoscolus aconitifolius',
#        'Coccoloba barbadensis', 'Coccoloba manzinellensis',
#        'Coccoloba parimensis', 'Coccoloba uvifera', 'Cocculus trilobus',
#        'Cochlearia fenestrata', 'Cochlearia officinalis',
#        'Cochlospermum insigne', 'Cochlospermum vitifolium',
#        'Cocos nucifera', 'Coeloglossum viride', 'Coffea arabica',
#        'Colchicum autumnale', 'Colchicum bulbocodium',
#        'Colliguaja integerrima', 'Colobanthus acicularis',
#        'Colobanthus quitensis', 'Cologania angustifolia',
#        'Colophospermum mopane', 'Colpodium colchicum',
#        'Colpodium humilis', 'Colpodium pontica', 'Colpodium variegata',
#        'Colpodium versicolor', 'Comandra umbellata', 'Comarum palustre',
#        'Combretum adenogonium', 'Combretum apiculatum',
#        'Combretum celastroides', 'Combretum collinum',
#        'Combretum decandrum', 'Combretum elaeagnoides',
#        'Combretum glutinosum', 'Combretum hereroense',
#        'Combretum imberbe', 'Combretum leprosum', 'Combretum molle',
#        'Combretum zeyheri', 'Commelina attenuata', 'Commelina communis',
#        'Commelina diffusa', 'Commiphora glandulosa', 'Commiphora mollis',
#        'Commiphora mossambicensis', 'Commiphora saxicola',
#        'Commiphora ugogensis', 'Comptonia peregrina',
#        'Condalia microphylla', 'Conium maculatum', 'Consolida ajacis',
#        'Consolida camptocarpa', 'Consolida rugulosa',
#        'Convallaria majalis', 'Convolvulus ammannii',
#        'Convolvulus arvensis', 'Convolvulus fruticosus',
#        'Convolvulus hamadae', 'Convolvulus subsericeus',
#        'Convolvulus tricolor', 'Copaifera chodatiana', 'Coprosma ciliata',
#        'Coprosma foetidissima', 'Coprosma linariifolia',
#        'Coprosma lucida', 'Coprosma macrocarpa', 'Coprosma perpusilla',
#        'Coprosma petriei', 'Coprosma rhamnoides', 'Corallorhiza trifida',
#        'Corchorus olitorius', 'Corchorus trilocularis',
#        'Cordia alliodora', 'Cordia borinquensis', 'Cordia dodecandra',
#        'Cordia elaeagnoides', 'Cordia megalantha', 'Cordia sinensis',
#        'Cordia sulcata', 'Cordylanthus ramosus', 'Coreopsis palmata',
#        'Coreopsis tinctoria', 'Coriaria arborea', 'Coriaria nepalensis',
#        'Corispermum heptapotamicum', 'Corispermum lehmannianum',
#        'Corispermum mongolicum', 'Corispermum papillosum',
#        'Corispermum puberulum', 'Cornus alba', 'Cornus alternifolia',
#        'Cornus amomum', 'Cornus bretschneideri', 'Cornus canadensis',
#        'Cornus controversa', 'Cornus florida', 'Cornus kousa',
#        'Cornus mas', 'Cornus officinalis', 'Cornus sanguinea',
#        'Cornus sibirica', 'Cornus stolonifera', 'Cornus suecica',
#        'Cornus ulotricha', 'Coronilla balansae', 'Coronilla juncea',
#        'Coronilla minima', 'Coronilla varia', 'Cortusa matthioli',
#        'Cortusa matthiolii', 'Corydalis alpestris', 'Corydalis bulbosa',
#        'Corydalis caucasica', 'Corydalis conorhiza',
#        'Corydalis intermedia', 'Corydalis pumila', 'Corydalis schanginii',
#        'Corydalis solida', 'Corylus americana', 'Corylus americanus',
#        'Corylus avellana', 'Corylus cornuta', 'Corylus ferox',
#        'Corylus sieboldiana', 'Corymbia erythrophloia',
#        'Corymbia tessellaris', 'Corynephorus canescens',
#        'Corynocarpus laevigatus', 'Cosmos parviflorus',
#        'Cotinus coggygria', 'Cotinus szechuanensis',
#        'Cotoneaster acutifolius', 'Cotoneaster adpressus',
#        'Cotoneaster hissaricus', 'Cotoneaster lucidus',
#        'Cotoneaster megalocarpa', 'Cotoneaster melanocarpus',
#        'Cotoneaster multiflorus', 'Cotoneaster nummularioides',
#        'Cotoneaster sanguineus', 'Cotoneaster subacutus',
#        'Cotoneaster submultiflorus', 'Couroupita guianensis',
#        'Cousinia affinis', 'Cousinia alpestris', 'Cousinia astracanica',
#        'Cousinia franchetii', 'Cousinia hamadae', 'Cousinia microcarpa',
#        'Cousinia verticillaris', 'Crambe maritima',
#        'Craniolaria integrifolia', 'Crassula arborescens',
#        'Crassula falcata', 'Crataegus almaatensis', 'Crataegus calycina',
#        'Crataegus chlorocarpa', 'Crataegus maximowiczii',
#        'Crataegus mollis', 'Crataegus monogyna', 'Crataegus pinnatifida',
#        'Crataegus pontica', 'Crataegus songorica',
#        'Crataegus turkestanica', 'Cratoxylum cochinchinense',
# ...
#        'Stipa viridulias', 'Stipagrostis brevifolia',
#        'Stipagrostis pennata', 'Streblus asper', 'Streptoloma desertorum',
#        'Streptopus amplexifolius', 'Streptopus roseus',
#        'Strobilanthes dimorphotricha', 'Strophostyles leiosperma',
#        'Strychnos cocculoides', 'Strychnos innocua', 'Strychnos pungens',
#        'Strychnos spinosa', 'Stryphnodendron adstringens',
#        'Stryphnodendron barbatimao', 'Stuckenia filiformis',
#        'Stuckenia pectinata', 'Stylogyne ambigua',
#        'Stylosanthes guianensis', 'Styphnolobium japonicum',
#        'Styrax foveolaria', 'Styrax suberifolius', 'Suaeda altissima',
#        'Suaeda asphaltica', 'Suaeda maritima', 'Succisa pratensis',
#        'Succisella inflexa', 'Sweetia fruticosa', 'Swertia dichotoma',
#        'Swertia iberica', 'Swertia lactea', 'Swertia perennis',
#        'Swida bretschneideri', 'Swietenia macrophylla',
#        'Swinglea glutinosa', 'Sympegma regelii', 'Symphoricarpos albus',
#        'Symphoricarpos occidentalis', 'Symphoricarpos orbiculatus',
#        'Symphoricarpos racemosus', 'Symphoricarpos vulgaris',
#        'Symphyoloma graveolens', 'Symphyotrichum ascendens',
#        'Symphyotrichum falcatum', 'Symphyotrichum laeve',
#        'Symphyotrichum novae-angliae', 'Symphyotrichum novi-belgii',
#        'Symphyotrichum salignum', 'Symphyotrichum tradescantii',
#        'Symphyotrichum versicolor', 'Symphytum bulbosum',
#        'Symphytum officinale', 'Symphytum tuberosum', 'Syrenia montana',
#        'Syringa amurensis', 'Syringa josikaea', 'Syringa pekinensis',
#        'Syringa persica', 'Syringa reticulata', 'Syringa vulgaris',
#        'Syzygium acuminatissimum', 'Syzygium buxifolium',
#        'Syzygium castaneum', 'Syzygium chrysanthum',
#        'Syzygium globiflorum', 'Syzygium guineense', 'Syzygium hancei',
#        'Syzygium jambos', 'Syzygium levine', 'Syzygium levinei',
#        'Syzygium maire', 'Syzygium malaccense', 'Syzygium napiforme',
#        'Syzygium pachysepalum', 'Syzygium smithii',
#        'Syzygium subdecussata', 'Syzygium szemaoense', 'Tabebuia aurea',
#        'Tabebuia chrysantha', 'Tabebuia donnell-smithii',
#        'Tabebuia guayacan', 'Tabebuia heterophylla',
#        'Tabebuia impetiginosa', 'Tabebuia rosea',
#        'Tabernaemontana litoralis', 'Tachigali versicolor',
#        'Taeniatherum caput-medusae', 'Taeniatherum crinitum',
#        'Tagetes erecta', 'Tagetes minuta', 'Tagetes patula',
#        'Talinum angustissimum', 'Talisia olivaeformis',
#        'Tamarindus indicus', 'Tamarix arceuthoides', 'Tamarix hispida',
#        'Tamarix pentantra', 'Tamarix ramosissima',
#        'Tamarix taklamakanensis', 'Tanacetum achilleifolium',
#        'Tanacetum balsamita', 'Tanacetum carneum', 'Tanacetum coccineum',
#        'Tanacetum corymbosum', 'Tanacetum daghestanicum',
#        'Tanacetum parthenifolium', 'Tanacetum partheniifolium',
#        'Tanacetum pyrethroides', 'Tanacetum vulgare',
#        'Tapirira guinensis', 'Taraxacum confusum',
#        'Taraxacum erythrospermum', 'Taraxacum glabrum',
#        'Taraxacum glaucanthum', 'Taraxacum monochlamydeum',
#        'Taraxacum officinale', 'Taraxacum sect. ruderalia',
#        'Taraxacum spec.', 'Taraxacum stevenii', 'Taraxacum vulgare',
#        'Tauscheria lasiocarpa', 'Taxodium distichum', 'Taxus baccata',
#        'Taxus chinensis', 'Taxus cuspidata', 'Teclea nobilis',
#        'Tecoma stans', 'Tectona grandis', 'Telekia speciosa',
#        'Tephroseris crispa', 'Tephroseris helenitis',
#        'Tephroseris kirilowii', 'Tephroseris tenuifolia',
#        'Tephrosia hookeniana', 'Tephrosia pumila', 'Tephrosia purpurea',
#        'Terminalia amazonia', 'Terminalia brachystemma',
#        'Terminalia ivorensis', 'Terminalia macroptera',
#        'Terminalia mollis', 'Terminalia oblonga', 'Terminalia paniculata',
#        'Terminalia sericea', 'Terminalia superba',
#        'Ternstroemia coriacea', 'Ternstroemia gymnanthera',
#        'Tetracme quadricornis', 'Tetractomia tetrandrum',
#        'Tetragastris balsamifera', 'Tetragastris panamensis',
#        'Tetraria bromoides', 'Teucrium chamaedrys', 'Teucrium charidemi',
#        'Teucrium fruticans', 'Teucrium multinodum', 'Teucrium nuchense',
#        'Teucrium orientale', 'Teucrium polium', 'Teucrium scordium',
#        'Teucrium taylorii', 'Thalictrum alpinum',
#        'Thalictrum aquilegifolium', 'Thalictrum aquilegiifolium',
#        'Thalictrum collinum', 'Thalictrum fendleri', 'Thalictrum flavum',
#        'Thalictrum foetidum', 'Thalictrum lucidum', 'Thalictrum minus',
#        'Thalictrum petaloideum', 'Thalictrum simplex',
#        'Thalictrum squarrosum', 'Thamnosma montana',
#        'Thelypteris limbosperma', 'Thelypteris palustris',
#        'Thelypteris phegopteris', 'Themeda australis', 'Themeda cymbaria',
#        'Themeda triandra', 'Theobroma cacao', 'Thermopsis lanceolata',
#        'Thermopsis rhombifolia', 'Thesium ebracteatum',
#        'Thinopyrum ponticum', 'Thlaspi alpestre', 'Thlaspi perfoliatum',
#        'Thlaspi pumila', 'Thouinia paucidentata', 'Thuja occidentales',
#        'Thuja occidentalis', 'Thuja plicata', 'Thuja standishii',
#        'Thujopsis dolabrata', 'Thymelaea hirsuta', 'Thymelaea tinctoria',
#        'Thymus caucasicus', 'Thymus desjatovae', 'Thymus dolomiticus',
#        'Thymus hyemalis', 'Thymus marschallianus', 'Thymus mastichina',
#        'Thymus mongolicus', 'Thymus polytrichus', 'Thymus praecox',
#        'Thymus pulegioides', 'Thymus serpyllum', 'Thymus transcaucasicus',
#        'Thymus vulgaris', 'Tiarella cordifolia', 'Tibouchina herbacea',
#        'Tilia americana', 'Tilia amurensis', 'Tilia begoniifolia',
#        'Tilia cordata', 'Tilia mandshurica', 'Tilia mongolica',
#        'Tilia oliveri', 'Tilia vulgaris', 'Tofieldia calyculata',
#        'Tofieldia coccinea', 'Tofieldia pusilla', 'Tolpis staticifolia',
#        'Toona ciliata', 'Tordylium maximum', 'Torilis scabra',
#        'Torreya nucifera', 'Townsendia exscapa', 'Toxylon pomiferum',
#        'Trachelospermum axillare', 'Trachydium roylei',
#        'Tradescantia blossfeldiana', 'Tradescantia bracteata',
#        'Tradescantia fluminensis', 'Tradescantia ohiensis',
#        'Tradescantia purpurea', 'Tradescantia reflexa',
#        'Tradescantia virginiana', 'Tradescantia virginica',
#        'Tradescantia zebrina', 'Tragopogon capitatus',
#        'Tragopogon duarius', 'Tragopogon dubius',
#        'Tragopogon marginifolius', 'Tragopogon orientalis',
#        'Tragopogon pratensis', 'Tragus racemosus',
#        'Traunsteinera globosa', 'Traunsteinera sphaerica',
#        'Trema micrantha', 'Trema orientalis', 'Trianthema portulacastrum',
#        'Trichilia elegans', 'Trichilia trifolia',
#        'Trichocereus chiloensis', 'Trichodesma indicum',
#        'Trichodesma zeylanicum', 'Trichophorum alpinum',
#        'Trichophorum caespitos', 'Trichophorum cespitosum',
#        'Trichospermum mexicanum', 'Trichostigma octandrum',
#        'Tridax procumbens', 'Tridens flavus', 'Trientalis borealis',
#        'Trientalis europaea', 'Trifolium alpestre', 'Trifolium ambiguum',
#        'Trifolium angustifolium', 'Trifolium arvense', 'Trifolium aureum',
#        'Trifolium badium', 'Trifolium campestre', 'Trifolium canescens',
#        'Trifolium dasyphyllum', 'Trifolium dubium', 'Trifolium fontanum',
#        'Trifolium fragiferum', 'Trifolium hirtum', 'Trifolium hybridum',
#        'Trifolium incarnatum', 'Trifolium longipes',
#        'Trifolium lupinaster', 'Trifolium medium',
#        'Trifolium michelianum', 'Trifolium montanum',
#        'Trifolium pannonicum', 'Trifolium parryi',
#        'Trifolium polyphyllum', 'Trifolium pratense',
#        'Trifolium purpureum', 'Trifolium repens', 'Trifolium resupinatum',
#        'Trifolium ruprechtii', 'Trifolium spadiceum',
#        'Trifolium spumosum', 'Trifolium squamosum',
#        'Trifolium subterraneum', 'Trifolium thalii',
#        'Trifolium trichocephalum', 'Triglochin maritima',
#        'Triglochin maritimum', 'Triglochin palustre',
#        'Triglochin palustris', 'Triglochin procerum',
#        'Trigonella arcuata', 'Trigonella balancae',
#        'Trigonella grandiflora', 'Trigonella platycarpus',
#        'Triplaris cumingiana', 'Tripleurospermum caucasicum',
#        'Tripleurospermum indorum', 'Tripleurospermum inodorum',
#        'Tripleurospermum maritimum', 'Tripleurospermum perforatum',
#        'Tripolium pannonicum', 'Trisetum argenteum',
#        'Trisetum distichophyllum', 'Trisetum flavescens',
#        'Trisetum sibiricum', 'Trisetum spicatum', 'Tristachya leucothrix',
#        'Tristaniopsis clementis', 'Tristaniopsis elliptica',
#        'Tristaniopsis laurina', 'Triticum aestivum',
#        'Triticum araraticum', 'Triticum dicoccoides', 'Triticum durum',
#        'Triumfetta amuletum', 'Trollius altissimus', 'Trollius asiaticus',
#        'Trollius europaeus', 'Trollius ranunculinus',
#        'Tsoongiodendron odorum', 'Tsuga canadensis', 'Tsuga diversijolia',
#        'Tsuga heterophylla', 'Tsuga sieboldii', 'Tulipa behmiana',
#        'Tulipa biflora', 'Tulipa bifloriformis', 'Tulipa buhseana',
#        'Tulipa gesneriana', 'Tulipa greigi', 'Tulipa kaufmanniana',
#        'Tulipa schrenkii', 'Tulipa sylvestris', 'Tussilago farfara',
#        'Typha angustata', 'Typha angustifolia', 'Typha domingensis',
#        'Typha glauca', 'Typha latifolia', 'Typha minima',
#        'Typha shuttleworthii', 'Uapaca kirkiana', 'Uapaca nitida',
#        'Ulex australis', 'Ulex europaeus', 'Ulex gallii', 'Ulex jussiaei',
#        'Ulex minor,', 'Ulex parviflorus', 'Ulmus americana',
#        'Ulmus crassifolia', 'Ulmus davidiana', 'Ulmus glabra',
#        'Ulmus japonica', 'Ulmus laciniata', 'Ulmus macrocarpa',
#        'Ulmus minor', 'Ulmus propingqua', 'Ulmus pumila', 'Ulmus rubra',
#        'Umbilicus oppositifolius', 'Unonopsis rufescens',
#        'Urera baccifera', 'Urera caracasana', 'Urochloa brizantha',
#        'Urochloa decumbens', 'Urochloa mosambicensis',
#        'Urochloa mossambicensis', 'Ursinia anthemoides',
#        'Urtica cannabina', 'Urtica dioica', 'Urtica kioviensis',
#        'Urtica urens', 'Vaccaria hispanica', 'Vaccinium angustifolium',
#        'Vaccinium bracteatum', 'Vaccinium carlesii',
#        'Vaccinium corymbosum', 'Vaccinium macrocarpon',
#        'Vaccinium mandarinorum', 'Vaccinium microcarpum',
#        'Vaccinium microcarpus', 'Vaccinium myrtilloides',
#        'Vaccinium myrtillus', 'Vaccinium oxycoccos', 'Vaccinium pallidum',
#        'Vaccinium palustris', 'Vaccinium uliginosum',
#        'Vaccinium ulignosum', 'Vaccinium vacillans',
#        'Vaccinium vitis-idaea', 'Vaccinium vitisidaea',
#        'Vachellia bidwellii', 'Vachellia erioloba', 'Vachellia karroo',
#        'Valeriana alpestris', 'Valeriana apula', 'Valeriana cardamines',
#        'Valeriana celtica', 'Valeriana colchica', 'Valeriana dioica',
#        'Valeriana elongata', 'Valeriana excelsa', 'Valeriana jelenevskyi',
#        'Valeriana montana', 'Valeriana officinalis', 'Valeriana rossica',
#        'Valeriana saxatilis', 'Valeriana saxicola',
#        'Valeriana tiliifolia', 'Valerianella turkestanica',
#        'Vallisneria spiralis', 'Vatairea erythrocarpa', 'Vatica maingayi',
#        'Ventenata dubia', 'Veratrum album', 'Veratrum lobelianum',
#        'Veratrum nigrum', 'Verbascum nigrum', 'Verbascum phoeniceum',
#        'Verbascum pyramidatum', 'Verbascum thapsus', 'Verbena bracteata',
#        'Verbena hastata', 'Verbena officinalis', 'Verbena stricta',
#        'Verbesina alternifolia', 'Vernonia baldwinii', 'Vernonia cinerea',
#        'Vernonia fasciculata', 'Vernonia grandiflora', 'Veronica alpina',
#        'Veronica anagallis-aquatica', 'Veronica aphylla',
#        'Veronica arguteserrata', 'Veronica arvense', 'Veronica arvensis',
#        'Veronica beccabunga', 'Veronica bellidioides', 'Veronica biloba',
#        'Veronica campylopoda', 'Veronica chamaedrys', 'Veronica denudata',
#        'Veronica filiformis', 'Veronica fruticans',
#        'Veronica gentianoides', 'Veronica gorbunovii', 'Veronica incana',
#        'Veronica lilliputiana', 'Veronica longifolia',
#        'Veronica maritima', 'Veronica minuta', 'Veronica montana',
#        'Veronica officinalis', 'Veronica peduncularis',
#        'Veronica persica', 'Veronica petraea', 'Veronica prostrata',
#        'Veronica schistosa', 'Veronica scutellata',
#        'Veronica serpyllifolia', 'Veronica spicata', 'Veronica spuria',
#        'Veronica teucrium', 'Veronica urticifolia', 'Veronica verna',
#        'Veronicastrum virginicum', 'Viburnum dentatum', 'Viburnum edule',
#        'Viburnum lantana', 'Viburnum opulus', 'Viburnum orientale',
#        'Viburnum sargentii', 'Viburnum sieboldii', 'Viburnum tinus',
#        'Vicia alpestris', 'Vicia americana', 'Vicia amoena',
#        'Vicia angustifolia', 'Vicia balansae', 'Vicia cassubica',
#        'Vicia cracca', 'Vicia faba', 'Vicia graminea', 'Vicia hirsuta',
#        'Vicia multicaulis', 'Vicia narbonensis', 'Vicia onobrychioides',
#        'Vicia oroboides', 'Vicia pisiformis', 'Vicia pulchella',
#        'Vicia purpurea', 'Vicia sativa', 'Vicia sepium',
#        'Vicia sylvatica', 'Vicia tenuifolia', 'Vicia tetrasperma',
#        'Vicia tetraspermum', 'Vicia unijuga', 'Vicia villosa',
#        'Vicoa indica', 'Vigna radiata', 'Vigna unguiculata',
#        'Vignea appropinquata', 'Vignea bohemica', 'Vignea canescens',
#        'Vignea chordorrhiza', 'Vignea elongata', 'Vignea leporina',
#        'Vignea loliacea', 'Vignea praecox', 'Vinca major', 'Vinca minor',
#        'Vincetoxicum hirundinaria', 'Vincetoxicum officinale',
#        'Viola adunca', 'Viola alba', 'Viola altaica', 'Viola arenaria',
#        'Viola arvensis', 'Viola biflora', 'Viola canadensis',
#        'Viola canina', 'Viola caucasica', 'Viola collina',
#        'Viola conspersa', 'Viola cucullata', 'Viola epipsila',
#        'Viola hirta', 'Viola lactea', 'Viola lutea', 'Viola mauritii',
#        'Viola minuta', 'Viola mirabilis', 'Viola odorata',
#        'Viola oreades', 'Viola palustris', 'Viola papilionacea',
#        'Viola pubescens', 'Viola reichenbachiana', 'Viola riviniana',
#        'Viola rupestris', 'Viola somchetica', 'Viola suavis',
#        'Viola thomasiana', 'Viola tricolor', 'Viola uliginosa',
#        'Virola koschnyi', 'Virola koshnyi', 'Virola sebifera',
#        'Virola surinamensis', 'Viscaria cardinalis', 'Viscaria oculata',
#        'Viscaria viscosa', 'Viscaria vulgaris', 'Vismia glaziovii',
#        'Vismia japurensis', 'Vismia macrophylla', 'Vismia tomentosa',
#        'Vitex lucens', 'Vitex negundo', 'Vitis amurensis',
#        'Vitis riparia', 'Vitis silvestris', 'Vitis vinifera',
#        'Vitis vulpina', 'Vochysia ferruginea', 'Vochysia guatemalensis',
#        'Vulpia bromoides', 'Vulpia myuros', 'Vulpia octoflora',
#        'Wahlenbergia albomarginata', 'Wahlenbergia hederacea',
#        'Waldheimia tridactylites', 'Waldsteinia fragarioides',
#        'Waldsteinia ternata', 'Washingtonia filifera',
#        'Watsonia pyramidata', 'Weigela suavis', 'Weinmannia blumei',
#        'Weinmannia loxensis', 'Weinmannia racemosa',
#        'Weinmannia silvicola', 'Weinmannia trichosperma',
#        'Wendlandia uvariifolia', 'Whiteochloa multiciliata',
#        'Willemetia stipitata', 'Withania frutescens', 'Woodsia alpina',
#        'Woodsia glabella', 'Woodsia ilvensis', 'Wyethia amplexicaulis',
#        'Xanthium albinum', 'Xanthium strumarium', 'Xanthophyllum tenue',
#        'Yucca elata', 'Yucca glauca', 'Yucca schidigera',
#        'Zannichellia palustris', 'Zantedeschia pentlandii',
#        'Zanthoxylum americanum', 'Zanthoxylum fagara',
#        'Zanthoxylum monogynum', 'Zanthoxylum rigidum', 'Zea mays',
#        'Zea mexicana', 'Zigadenus venenosus', 'Zinnia elegans',
#        'Zinnia grandiflora', 'Zinnia peruviana', 'Zizania palustris',
#        'Zizia aurea', 'Ziziphora pamiroalaica', 'Ziziphora pedicellata',
#        'Ziziphora puschkini', 'Ziziphus abyssinica', 'Ziziphus jujuba',
#        'Ziziphus jujube', 'Ziziphus mucronata', 'Ziziphus obtusifolia',
#        'Zornia gibbosa', 'Zostera marina', 'Zostera noltii',
#        'Zygophyllum dumosum', 'Zygophyllum fabago',
#        'Zygophyllum pinnatum', 'Zygophyllum prismatocarpum',
#        'Zygophyllum xanthoxylum'], dtype='<U33')

# %%
scientific_names_unique.size, np.unique(scientific_names_unique).size
# Out:
# (6610, 6610)

# %%
with open(file=r"./groot_unique_scientific_names.txt", mode="w") as fp:
    for unqscname in scientific_names_unique:
        fp.write(f"{unqscname}\n")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\90963425\\phd'

# %%
os.listdir()
# Out:
# ['.clang-format',
#  '.clang-tidy',
#  '.clangd',
#  '.git',
#  '.gitignore',
#  '.ipynb_checkpoints',
#  'a.exe',
#  'abm.cpp',
#  'abm.cu',
#  'abm.ipynb',
#  'abm.py',
#  'build.ps1',
#  'clean.ps1',
#  'compile.ps1',
#  'dummy.cpp',
#  'dummy.exe',
#  'dummy.obj',
#  'googletest',
#  'GRoot.ipynb',
#  'GRooTFullVersion.csv',
#  'groot_unique_scientific_names.txt',
#  'LICENSE',
#  'README.md',
#  'ruff.toml',
#  'vs19test',
#  'vstest']

# %%
with open(file=r"./groot_unique_scientific_names.csv", mode="w") as fp:
    for unqscname in scientific_names_unique:
        fp.write(f"{unqscname},")
