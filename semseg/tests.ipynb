# %% [markdown]
# # ___Tests___
# -----------------

# %%
# !python --version
# Out:
# Python 3.14.6
# The system cannot find the path specified.

# %%
import os

import matplotlib.pyplot as plt
from datasets import RootImageDataset

# %%
os.listdir(r"./images/MaxSee/")
# Out:
# ['annotations', 'images']

# %%
dataset = RootImageDataset(dir_images=r"./images/MaxSee/images/", dir_annotations=r"./images/MaxSee/annotations/")

# %%
len(dataset) # cool
# Out:
# 17

# %%
fig, axes = plt.subplots()
fig.set_size_inches(4, 6)

for (img, mask) in dataset:
    axes.imshow(img)

plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [16.0..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..255.0].
# ...
