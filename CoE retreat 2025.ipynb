# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import pandas as pd

# %%
roots = plt.imread(r"./skillnadenstradgard_rotter_planta-1070x713.jpg")
soil = pd.read_csv(r"./CSBP_soil_analysis_Themeda_and_Sorghum.csv", skiprows=range(1, 20)).dropna()
sorghum = pd.read_csv(r"./field_sorghum_locations.csv", header=1)
with open(file=r"./data/australia-borders-coordinates.npy", mode="rb") as fp:
    COORDINATES_AUSTRALIA = np.load(file=fp, allow_pickle=False)
austraits = pd.read_csv(r"./data/austraits-3.0.2/traits.csv", low_memory=False)

# %%
austraits.query("trait_name.str.contains(\"root_diameter\")")
# Out:
#          dataset_id               taxon_name                     site_name  \
# 432200  Mokany_2008         Acacia decurrens  field site north of Canberra
# 432209  Mokany_2008         Acacia decurrens  field site north of Canberra
# 432237  Mokany_2008           Acaena x ovina  field site north of Canberra
# 432249  Mokany_2008           Acaena x ovina  field site north of Canberra
# 432261  Mokany_2008           Acaena x ovina  field site north of Canberra
# ...             ...                      ...                           ...
# 435396  Mokany_2008  Wahlenbergia capillaris  field site north of Canberra
# 435407  Mokany_2008           Wurmbea dioica  field site north of Canberra
# 435418  Mokany_2008           Wurmbea dioica  field site north of Canberra
# 435429  Mokany_2008           Wurmbea dioica  field site north of Canberra
# 435433  Mokany_2008        Microtis unifolia  field site north of Canberra
#
#        context_name   observation_id              trait_name  value unit  \
# 432200          NaN  Mokany_2008_002  thickest_root_diameter  30.82   mm
# 432209          NaN  Mokany_2008_003  thickest_root_diameter  19.16   mm
# 432237          NaN  Mokany_2008_006  thickest_root_diameter   3.16   mm
# 432249          NaN  Mokany_2008_007  thickest_root_diameter   3.65   mm
# 432261          NaN  Mokany_2008_008  thickest_root_diameter   5.19   mm
# ...             ...              ...                     ...    ...  ...
# 435396          NaN  Mokany_2008_268  thickest_root_diameter   4.15   mm
# 435407          NaN  Mokany_2008_269  thickest_root_diameter   0.46   mm
# 435418          NaN  Mokany_2008_270  thickest_root_diameter   0.79   mm
# 435429          NaN  Mokany_2008_271  thickest_root_diameter   0.42   mm
# 435433          NaN  Mokany_2008_272  thickest_root_diameter   1.11   mm
#
#               date value_type replicates          original_name
# 432200  19/12/2005  raw_value          1       Acacia decurrens
# 432209  19/12/2005  raw_value          1       Acacia decurrens
# 432237   9/11/2005  raw_value          1           Acaena ovina
# 432249   5/12/2005  raw_value          1           Acaena ovina
# 432261   5/12/2005  raw_value          1           Acaena ovina
# ...            ...        ...        ...                    ...
# 435396  17/10/2005  raw_value          1  Wahlenbergia communis
# 435407  20/09/2005  raw_value          1         Wurmbia dioica
# 435418  21/09/2005  raw_value          1         Wurmbia dioica
# 435429  21/09/2005  raw_value          1         Wurmbia dioica
# 435433   5/12/2005  raw_value          1      Microtis unifolia
#
# [264 rows x 12 columns]

# %%
type(roots)
# Out:
# numpy.ndarray

# %%
roots[:12, :12].shape
# Out:
# (12, 12, 3)

# %%
roots[0]
# Out:
# array([[79, 77, 82],
#        [76, 74, 79],
#        [72, 70, 75],
#        ...,
#        [61, 59, 60],
#        [58, 56, 57],
#        [56, 54, 55]], shape=(713, 3), dtype=uint8)

# %%
roots[:712, :712]
# Out:
# array([[[79, 77, 82],
#         [76, 74, 79],
#         [72, 70, 75],
#         ...,
#         [59, 57, 58],
#         [61, 59, 60],
#         [58, 56, 57]],
#
#        [[82, 80, 85],
#         [80, 78, 83],
#         [78, 76, 81],
#         ...,
#         [55, 53, 54],
#         [56, 54, 55],
#         [53, 51, 52]],
#
#        [[87, 85, 90],
#         [85, 83, 88],
#         [84, 82, 87],
#         ...,
#         [56, 54, 55],
#         [56, 54, 55],
#         [53, 51, 52]],
#
#        ...,
#
#        [[29, 31, 30],
#         [29, 31, 30],
#         [30, 32, 31],
#         ...,
#         [36, 31, 28],
#         [36, 31, 28],
#         [36, 31, 28]],
#
#        [[32, 32, 30],
#         [32, 32, 30],
#         [33, 33, 31],
#         ...,
#         [37, 32, 29],
#         [37, 32, 29],
#         [37, 32, 29]],
#
#        [[33, 33, 31],
#         [34, 34, 32],
#         [34, 34, 32],
#         ...,
#         [39, 34, 31],
#         [39, 34, 31],
#         [39, 34, 31]]], shape=(712, 712, 3), dtype=uint8)

# %%
np.linspace(start=0, stop=712, endpoint=True, num=4).astype(np.uint32)
# Out:
# array([  0, 237, 474, 712], dtype=uint32)

# %%
712/4
# Out:
# 178.0

# %%
712*712
# Out:
# 506944

# %%
c.reshape(178, 178, 16, 3);

# %%
fig, axes = plt.subplots()
axes.imshow(roots[:712, :712])
axes.set_xticks([])
axes.set_yticks([])
plt.show()

# %%
roots[:712, :712].reshape(16, 178, 178, 3)[0]
# Out:
# array([[[ 79,  77,  82],
#         [ 76,  74,  79],
#         [ 72,  70,  75],
#         ...,
#         [106,  98,  95],
#         [105,  96, 101],
#         [ 79,  69,  77]],
#
#        [[ 53,  47,  51],
#         [ 42,  36,  40],
#         [ 39,  33,  37],
#         ...,
#         [ 53,  37,  37],
#         [ 44,  29,  32],
#         [ 40,  25,  28]],
#
#        [[ 32,  19,  26],
#         [ 25,  12,  19],
#         [ 26,  14,  24],
#         ...,
#         [ 88,  95, 103],
#         [116, 134, 146],
#         [145, 171, 186]],
#
#        ...,
#
#        [[ 24,  37,  43],
#         [ 30,  53,  61],
#         [ 67,  94, 111],
#         ...,
#         [ 38,  30,  28],
#         [ 38,  30,  28],
#         [ 36,  28,  26]],
#
#        [[ 98,  99,  93],
#         [ 95,  96,  90],
#         [ 89,  88,  83],
#         ...,
#         [ 15,  14,  12],
#         [ 21,  17,  18],
#         [ 25,  21,  22]],
#
#        [[ 25,  20,  24],
#         [ 20,  16,  17],
#         [ 19,  15,  16],
#         ...,
#         [ 84,  77,  84],
#         [ 79,  72,  79],
#         [ 68,  61,  68]]], shape=(178, 178, 3), dtype=uint8)

# %%
fig, axes = plt.subplots()
axes.imshow(roots[:178, :178])
axes.set_xticks([])
axes.set_yticks([])
plt.show()

# %%
roots[:178, :178].shape
# Out:
# (178, 178, 3)

# %%
np.meshgrid()
# Out:
# ()

# %%
roots[:712, :712].shape
# Out:
# (712, 712, 3)

# %%
fig, axes = plt.subplots()
axes.imshow(roots[:712, :712].reshape(16, 178, 178, 3)[0])
axes.set_xticks([])
axes.set_yticks([])
plt.show()

# %%
fig, axes = plt.subplots(nrows=4, ncols=4)
fig.set_size_inches(16, 16)

for (i, axis, subset) in zip(range(16), axes.flatten(), roots[:712, :712].reshape(178, 178, 16, 3)):
    axis.set_xticks([])
    axis.set_yticks([])
    axis.imshow(subset)
    axis.set_title(f"{i}")
plt.show()

# %%
soil
# Out:
#    Lab Number\n               Date Received Customer Sample ID Sample Name 1  \
# 0                   2KGS24043    12/09/2024                 S1         SB WA
# 1                   2KGS24044    12/09/2024                 S2         SE WA
# 2                   2KGS24045    12/09/2024                 S3         SE NT
# 3                   2KGS24046    12/09/2024                 S4         SI WA
# 4                   2KGS24047    12/09/2024                 S5         SI NT
# 5                   2KGS24048    12/09/2024                 S6        SL NSW
# 6                   2KGS24049    12/09/2024                 S7         SM NT
# 7                   2KGS24050    12/09/2024                 S8      SP DW NT
# 8                   2KGS24051    12/09/2024                 S9        SPT WA
# 9                   2KGS24052    12/09/2024                S10         SS NT
# 10                  2KGS24053    12/09/2024                S11         ST NT
# 11                  2KGS24054    12/09/2024                S12      SP MC NT
# 12                  2KGS24055    12/09/2024                S13       SMAT NT
# 13                  2KGS24056    12/09/2024                S14         SG NT
# 14                  2KGS24057    12/09/2024                S15        SA QLD
#
#                         Sample Name 2   Latitude   Longitude Depth Colour  \
# 0                    Sorghum Bulbosum -19.615600  147.961153  0-10   BROR
# 1                  Sorghum Ecarinatum -17.354575  123.741343  0-10   BROR
# 2                     Sorghum Exstans -12.434222  130.876718  0-10   BRGR
# 3                 Sorghum Interjectum -15.992228  128.974654  0-10   BROR
# 4                     Sorghum Intrans -14.407553  132.197353  0-10   BRRD
# 5                  Sorghum Leiocladum -28.941111  152.428611  0-10   DKGR
# 6                Sorghum Macrospermum -14.407640  132.197460  0-10     BR
# 7                    Sorghum Plumosum -16.062387  133.428109  0-10     GR
# 8   Sorghum Plumosum var teretifolium -15.992164  128.984524  0-10   BRGR
# 9                  Sorghum Stipoideum -12.511434  130.996383  0-10   GRBR
# 10                  Sorghum Timorense -16.306314  133.401888  0-10   BRGR
# 11                   Sorghum Plumosum -12.511661  130.996358  0-10     GR
# 12               Sorghum Matarankense -16.004959  133.418802  0-10     BR
# 13                     Sorghum Grande -14.478000  132.312000  0-10   BROR
# 14                   Sorghum Angustum -15.543095  144.433999  0-10   GRBR
#
#    Gravel_percent  ...  pH Level (CaCl2)  pH Level (H2O) Total Nitrogen  \
# 0           25-30  ...               5.9             6.6           0.02
# 1           15-20  ...               5.6             6.6           0.03
# 2           15-20  ...               5.7             6.6           0.09
# 3            5-10  ...               6.0             6.7           0.05
# 4               5  ...               6.0             6.8           0.03
# 5               5  ...               6.0             6.5           0.22
# 6               5  ...               6.1             6.8           0.22
# 7           45-50  ...               7.1             8.2           0.03
# 8           35-40  ...               5.8             6.8           0.09
# 9           45-50  ...               5.6             6.5           0.12
# 10          35-40  ...               6.5             7.3           0.07
# 11           5-10  ...               5.0             5.9           0.11
# 12           5-10  ...               6.4             7.3           0.16
# 13              5  ...               5.9             6.6           0.07
# 14              5  ...               5.0             6.3           0.06
#
#     Total Phosphorus  Total Carbon % Clay  % Course Sand  % Fine Sand  % Sand  \
# 0               84.9          0.40   9.87          63.40        22.77   86.17
# 1               56.3          0.53   6.93          59.63        31.45   91.08
# 2              108.5          2.41  15.86          38.85        36.80   75.65
# 3              118.8          0.54   9.20          50.41        27.01   77.42
# 4              176.2          0.44  43.07          29.41        18.50   47.91
# 5              237.2          3.89  14.71          18.75        46.50   65.25
# 6              684.7          3.65  25.68           4.38        30.35   34.73
# 7              169.4          1.30   8.08          64.16        21.66   85.82
# 8              139.5          1.34  10.87          42.47        34.76   77.23
# 9              131.8          2.23  10.26          52.36        28.10   80.46
# 10             152.8          1.34  16.93          58.59        16.49   75.08
# 11              74.1          2.39  11.24          44.87        24.39   69.26
# 12             255.7          2.31  29.98          39.48        18.12   57.60
# 13             126.3          1.09  40.75          21.78        21.14   42.92
# 14              70.6          0.99   6.95          58.00        27.03   85.03
#
#     % Silt
# 0      3.97
# 1      2.00
# 2      8.49
# 3     13.37
# 4      9.02
# 5     20.04
# 6     39.58
# 7      6.10
# 8     11.91
# 9      9.28
# 10     7.99
# 11    19.51
# 12    12.43
# 13    16.32
# 14     8.00
#
# [15 rows x 28 columns]

# %%
soil.columns.str.replace(' ', '_').str.lower()
# Out:
# Index(['lab_number\n______________', 'date_received', 'customer_sample_id',
#        'sample_name_1', 'sample_name_2', 'latitude', 'longitude', 'depth',
#        'colour', 'gravel_percent', 'texture', 'ammonium_nitrogen',
#        'nitrate_nitrogen', 'phosphorus_colwell', 'potassium_colwell', 'sulfur',
#        'organic_carbon', 'conductivity', 'ph_level_(cacl2)', 'ph_level_(h2o)',
#        'total_nitrogen', 'total_phosphorus', 'total_carbon', '%_clay',
#        '%_course_sand', '%_fine_sand', '%_sand', '%_silt_'],
#       dtype='object')

# %%
sorghum
# Out:
#                site_name                        species_name   latitude  \
# 0           Kununurra_WA                    Sorghum bulbosum -15.965052
# 1               Derby_WA                  Sorghum ecarinatum -17.354575
# 2   Charles_Darwin_NP_NT                     Sorghum exstans -12.434222
# 3           Kununurra_WA                 Sorghum interjectum -15.992228
# 4           Katherine_NT                     Sorghum intrans -14.407553
# 5              Drake_NSW                  Sorghum leiocladum -28.941111
# 6           Katherine_NT                Sorghum macrospermum -14.407640
# 7         Daly_Waters_NT                    Sorghum plumosum -16.062387
# 8           Kununurra_WA  Sorghum plumosum var. teretifolium -15.992164
# 9         Mitchell_Ck_NT                  Sorghum stipoideum -12.511434
# 10        Daly_Waters_NT                   Sorghum timorense -16.306314
# 11        Mitchell_Ck_NT                    Sorhgum plumosum -12.511661
# 12        Daly_Waters_NT                Sorghum matarankense -16.004959
# 13          Katherine_NT                      Sorghum grande -14.478000
# 14             Laura_QLD                    Sorghum angustum -15.543095
#
#      longitude date_sampled soil_sample_ID      code  \
# 0   128.957012   24/03/2024             S1     SB_WA
# 1   123.741343   27/03/2024             S2     SE_WA
# 2   130.876718   27/02/2024             S3     SE_NT
# 3   128.974654   24/03/2024             S4     SI_WA
# 4   132.197353    2/03/2024             S5     SI_NT
# 5   152.428611   25/01/2024             S6    SL_NSW
# 6   132.197460    2/03/2024             S7     SM_NT
# 7   133.428109    3/03/2024             S8  SP_DW_NT
# 8   128.984524   24/03/2024             S9    SPT_WA
# 9   130.996383    5/03/2024            S10     SS_NT
# 10  133.401888    3/03/2024            S11     ST_NT
# 11  130.996358   28/02/2024            S12  SP_MC_NT
# 12  133.418802    2/05/2024            S13   SMAT_NT
# 13  132.312000    3/05/2024            S14     SG_NT
# 14  144.433999    6/05/2024            S15    SA_QLD
#
#                                   Name  Unnamed: 8
# 0                     Sorghum bulbosum         NaN
# 1                   Sorghum ecarinatum         NaN
# 2                      Sorghum exstans         NaN
# 3                  Sorghum interjectum         NaN
# 4                      Sorghum intrans         NaN
# 5                   Sorghum leiocladum         NaN
# 6                 Sorghum macrospermum         NaN
# 7                     Sorghum plumosum         NaN
# 8   Sorghum plumosum var. teretifolium         NaN
# 9                   Sorghum stipoideum         NaN
# 10                   Sorghum timorense         NaN
# 11                    Sorhgum plumosum         NaN
# 12                Sorghum matarankense         NaN
# 13                      Sorghum grande         NaN
# 14                    Sorghum angustum         NaN

# %%
sorghum.species_name.astype("category").cat.codes
# Out:
# 0      1
# 1      2
# 2      3
# 3      5
# 4      6
# 5      7
# 6      8
# 7     10
# 8     11
# 9     12
# 10    13
# 11    14
# 12     9
# 13     4
# 14     0
# dtype: int8

# %%
sorghum.shape
# Out:
# (15, 9)

# %%
fig, axes = plt.subplots()
fig.set_size_inches(20, 10)
axes.scatter(COORDINATES_AUSTRALIA[:, 0], COORDINATES_AUSTRALIA[:, 1], s=0.5, color="black")
axes.scatter(sorghum.longitude, sorghum.latitude, s=60, edgecolor="black", color="red")#=sorghum.species_name.astype("category").cat.codes)
plt.show()
