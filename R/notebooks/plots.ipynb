# %% [markdown]
# ## ___Plots using matplotlib for data serialized by R___
# -------------------------------------------------

# %%
# !python --version
# Out:
# Python 3.14.3
# The system cannot find the path specified.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
summary = pd.read_csv(r"./994species_5states_model_averages.csv")
summary
# Out:
#                     binominal     rates     alpha  sigma.sq     theta  \
# 0             Rudbeckia_hirta  0.001442  0.172868  0.081197 -1.059224
# 1            Ratibida_pinnata  0.001442  0.172868  0.081197 -1.059224
# 2     Heliopsis_helianthoides  0.000279  0.172868  0.081202 -1.359386
# 3              Liatris_aspera  0.001442  0.172868  0.081197 -1.059224
# 4              Arnica_sororia  0.001442  0.172868  0.081197 -1.059224
# ...                       ...       ...       ...       ...       ...
# 3971   Dicranopteris_linearis  0.001657  0.099575  0.172946  3.839744
# 3972         Osmunda_japonica  0.001657  0.099575  0.172946  3.839744
# 3973        Equisetum_hyemale  0.001134  0.099575  0.172946  3.839744
# 3974       Equisetum_pratense  0.001134  0.099575  0.172946  3.839744
# 3975      Lycopodium_volubile  0.001134  0.099575  0.172946  3.839744
#
#       expected_mean  expected_var tip_state  is_cd   trait
# 0         -1.059224      0.234855        AM   True   logRD
# 1         -1.059224      0.234855        AM   True   logRD
# 2         -1.348426      0.234876        NM   True   logRD
# 3         -1.059224      0.234855        AM   True   logRD
# 4         -1.059224      0.234855        AM   True   logRD
# ...             ...           ...       ...    ...     ...
# 3971       3.839744      0.868425        AM  False  logSRL
# 3972       3.839744      0.868425        AM  False  logSRL
# 3973       3.839744      0.868425      NMAM  False  logSRL
# 3974       3.839744      0.868425      NMAM  False  logSRL
# 3975       3.839744      0.868425      NMAM  False  logSRL
#
# [3976 rows x 10 columns]

# %%
summary.query(r"trait=='logRD'")
# Out:
#                     binominal     rates     alpha  sigma.sq     theta  \
# 0             Rudbeckia_hirta  0.001442  0.172868  0.081197 -1.059224
# 1            Ratibida_pinnata  0.001442  0.172868  0.081197 -1.059224
# 2     Heliopsis_helianthoides  0.000279  0.172868  0.081202 -1.359386
# 3              Liatris_aspera  0.001442  0.172868  0.081197 -1.059224
# 4              Arnica_sororia  0.001442  0.172868  0.081197 -1.059224
# ...                       ...       ...       ...       ...       ...
# 1983   Dicranopteris_linearis  0.001308  0.172946  0.082183 -1.090062
# 1984         Osmunda_japonica  0.001308  0.172946  0.082183 -1.090062
# 1985        Equisetum_hyemale  0.001308  0.172946  0.082183 -1.090062
# 1986       Equisetum_pratense  0.001308  0.172946  0.082183 -1.090062
# 1987      Lycopodium_volubile  0.001308  0.172946  0.082183 -1.090062
#
#       expected_mean  expected_var tip_state  is_cd  trait
# 0         -1.059224      0.234855        AM   True  logRD
# 1         -1.059224      0.234855        AM   True  logRD
# 2         -1.348426      0.234876        NM   True  logRD
# 3         -1.059224      0.234855        AM   True  logRD
# 4         -1.059224      0.234855        AM   True  logRD
# ...             ...           ...       ...    ...    ...
# 1983      -1.090062      0.237596        AM  False  logRD
# 1984      -1.090062      0.237596        AM  False  logRD
# 1985      -1.090062      0.237596      NMAM  False  logRD
# 1986      -1.090062      0.237596      NMAM  False  logRD
# 1987      -1.090062      0.237596      NMAM  False  logRD
#
# [1988 rows x 10 columns]

# %%
COLUMNS_OF_INTEREST = ["rates", "alpha", "sigma.sq", "theta"]

# %%
COLS = {
    "AM": "red", "NM": "blue", "NMAM": "purple", "EcMAM": "orange", "EcM": "yellow"
}

# %%
plt.rcParams["font.size"] = 10
fig, axes = plt.subplots(nrows=2, ncols=2, sharex=True, sharey=False)
fig.set_size_inches(10, 10)

for (axis, col) in zip(axes.flatten(), COLUMNS_OF_INTEREST): # first row
    axis.scatter(x=summary.query(r"trait=='logRD' and is_cd==True").tip_state, y=summary.query(r"trait=='logRD' and is_cd==True").loc[:, col], s=100, edgecolor = "black", color="red")
    # axis.violinplot([df.loc[:, col] for (_, df) in summary.query(r"trait=='logRD' and is_cd==True").groupby("tip_state")], showmeans=True, showmedians=True)
    axis.set_title(col.title())
    axis.grid()
    axis.set_axisbelow(True)

# for (axis, col) in zip(axes[1], COLUMNS_OF_INTEREST): # first row
#     axis.scatter(x=summary.query(r"trait=='logRD' and is_cd==False").tip_state, y=summary.query(r"trait=='logRD' and is_cd==False").loc[:, col], s=150, edgecolor = "black", color="red")
#     axis.set_title(col.title())
#     axis.grid()
#     axis.set_axisbelow(True)
    
plt.tight_layout()
# plt.show()
plt.savefig(fname=r"../../plots/houwie_5states_994sp_summary_logrd.png", dpi=800)

# %%
plt.rcParams["font.size"] = 20
fig, axes = plt.subplots(nrows=2, ncols=4, sharex=True, sharey=False)
fig.set_size_inches(40, 20)

for (axis, col) in zip(axes[0], COLUMNS_OF_INTEREST): # first row
    axis.scatter(x=summary.query(r"trait=='logSRL' and is_cd==True").tip_state,
                 y=summary.query(r"trait=='logSRL' and is_cd==True").loc[:, col], s=150, edgecolor = "black",
                 color="red"
                )
    axis.set_title(col.title())
    axis.grid()
    axis.set_axisbelow(True)

for (axis, col) in zip(axes[1], COLUMNS_OF_INTEREST): # first row
    axis.scatter(x=summary.query(r"trait=='logSRL' and is_cd==False").tip_state,
                 y=summary.query(r"trait=='logSRL' and is_cd==False").loc[:, col], s=150, edgecolor = "black",
                 color="red"
                )
    axis.set_title(col.title())
    axis.grid()
    axis.set_axisbelow(True)
    
plt.tight_layout()
# plt.show()
plt.savefig(fname=r"../../plots/houwie_5states_994sp_summary_logsrl.png", dpi=800)
