# %% [markdown]
# # ___Try and see if parallelizing on Linux improves performance of `OUwie::hOUwie`___
# ------------------------------------------------------------------------------

# %%
# specs of the colab instance
system("lscpu", intern = TRUE)
# Out:
#  [1] "Architecture:                            x86_64"
#  [2] "CPU op-mode(s):                          32-bit, 64-bit"
#  [3] "Address sizes:                           46 bits physical, 48 bits virtual"
#  [4] "Byte Order:                              Little Endian"
#  [5] "CPU(s):                                  2"
#  [6] "On-line CPU(s) list:                     0,1"
#  [7] "Vendor ID:                               GenuineIntel"
#  [8] "Model name:                              Intel(R) Xeon(R) CPU @ 2.20GHz"
#  [9] "CPU family:                              6"
# [10] "Model:                                   79"
# [11] "Thread(s) per core:                      2"
# [12] "Core(s) per socket:                      1"
# [13] "Socket(s):                               1"
# [14] "Stepping:                                0"
# [15] "BogoMIPS:                                4399.99"
# [16] "Flags:                                   fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities"
# [17] "Hypervisor vendor:                       KVM"
# [18] "Virtualization type:                     full"
# [19] "L1d cache:                               32 KiB (1 instance)"
# [20] "L1i cache:                               32 KiB (1 instance)"
# [21] "L2 cache:                                256 KiB (1 instance)"
# [22] "L3 cache:                                55 MiB (1 instance)"
# [23] "NUMA node(s):                            1"
# [24] "NUMA node0 CPU(s):                       0,1"
# [25] "Vulnerability Gather data sampling:      Not affected"
# [26] "Vulnerability Indirect target selection: Vulnerable"
# [27] "Vulnerability Itlb multihit:             Not affected"
# [28] "Vulnerability L1tf:                      Mitigation; PTE Inversion"
# [29] "Vulnerability Mds:                       Vulnerable; SMT Host state unknown"
# [30] "Vulnerability Meltdown:                  Vulnerable"
# [31] "Vulnerability Mmio stale data:           Vulnerable"
# [32] "Vulnerability Reg file data sampling:    Not affected"
# [33] "Vulnerability Retbleed:                  Vulnerable"
# [34] "Vulnerability Spec rstack overflow:      Not affected"
# [35] "Vulnerability Spec store bypass:         Vulnerable"
# [36] "Vulnerability Spectre v1:                Vulnerable: __user pointer sanitization and usercopy barriers only; no swapgs barriers"
# [37] "Vulnerability Spectre v2:                Vulnerable; IBPB: disabled; STIBP: disabled; PBRSB-eIBRS: Not affected; BHI: Vulnerable"
# [38] "Vulnerability Srbds:                     Not affected"
# [39] "Vulnerability Tsa:                       Not affected"
# [40] "Vulnerability Tsx async abort:           Vulnerable"

# %%
# OS of the instance
system("cat /etc/issue", intern = TRUE)
# Out:
# [1] "Ubuntu 22.04.4 LTS \\n \\l" ""

# %%
print(R.version.string)
# Out:
# [1] "R version 4.5.2 (2025-10-31)"

# %%
# is git installed??
system("git --version", intern = TRUE)
# Out:
# [1] "git version 2.34.1"

# %%
# clone, build and install corHMM & OUwie
system("git clone 'https://github.com/thej022214/corHMM.git'")

# %%
setwd("../") # on Linux, yo build the package outside of the package directory - whereas this is done inside the package directory on Windows???
system("ls", intern = TRUE)
# Out:
# [1] "corHMM"      "sample_data"

# %%
system("R --version", intern = TRUE) # on Linux, it's just R not Rcmd as in Windows :?
# Out:
#  [1] "R version 4.5.2 (2025-10-31) -- \"[Not] Part in a Rumble\""
#  [2] "Copyright (C) 2025 The R Foundation for Statistical Computing"
#  [3] "Platform: x86_64-pc-linux-gnu"
#  [4] ""
#  [5] "R is free software and comes with ABSOLUTELY NO WARRANTY."
#  [6] "You are welcome to redistribute it under the terms of the"
#  [7] "GNU General Public License versions 2 or 3."
#  [8] "For more information about these matters see"
#  [9] "https://www.gnu.org/licenses/."
# [10] ""

# %%
system("R CMD build corHMM --no-build-vignettes", intern = TRUE) # build the package
# Out:
# [1] "* checking for file ‘corHMM/DESCRIPTION’ ... OK"
# [2] "* preparing ‘corHMM’:"
# [3] "* checking DESCRIPTION meta-information ... OK"
# [4] "* checking for LF line-endings in source and make files and shell scripts"
# [5] "* checking for empty or unneeded directories"
# [6] "* looking to see if a ‘data/datalist’ file should be added"
# [7] "* building ‘corHMM_2.10.tar.gz’"

# %%
list.files("./") # don't see the built .tar.gz file????
# Out:
# [1] "corHMM"             "corHMM_2.10.tar.gz" "OUwie"
# [4] "OUwie_2.16.tar.gz"  "sample_data"

# %%
readLines("./DESCRIPTION") # version of the built package should be 2.10
# Out:
#  [1] "Package: corHMM"
#  [2] "Version: 2.10"
#  [3] "Date: 2025-08-06"
#  [4] "Title: Hidden Markov Models of Character Evolution"
#  [5] "Authors@R: c(person(\"Jeremy\", \"Beaulieu\", role=c(\"aut\", \"cre\"),"
#  [6] "                     email = \"jmbeauli@uark.edu\"),"
#  [7] "                     person(\"Brian\", \"O'Meara\", role=c(\"aut\")),"
#  [8] "\t\t      person(\"Jeffrey\", \"Oliver\", role=c(\"aut\")),"
#  [9] "\t\t\tperson(\"James\", \"Boyko\", role=c(\"aut\")))"
# [10] "Maintainer: Jeremy Beaulieu <jmbeauli@uark.edu>"
# [11] "Depends: ape, nloptr, GenSA"
# [12] "Suggests: testthat, knitr, rmarkdown"
# [13] "Imports: expm, numDeriv, corpcor, MASS, nnet, phangorn, parallel, viridis, Rmpfr, igraph, phytools, lhs"
# [14] "Description: Fits hidden Markov models of discrete character evolution which allow different transition rate classes on different portions of a phylogeny. Beaulieu et al (2013) <doi:10.1093/sysbio/syt034>."
# [15] "License: GPL (>= 2)"
# [16] "VignetteBuilder: knitr"
# [17] ""

# %%
system("R CMD INSTALL corHMM_2.10.tar.gz", intern = TRUE) # corHMM installation keeps failing tf???
# Out:
# Warning message in system("R CMD INSTALL corHMM_2.10.tar.gz", intern = TRUE):
# “running command 'R CMD INSTALL corHMM_2.10.tar.gz' had status 1”
# character(0)
# attr(,"status")
# [1] 1
# attr(,"errmsg")
# [1] "Resource temporarily unavailable"

# %%
# try OUwie
system("git clone 'https://github.com/thej022214/OUwie.git'", intern = TRUE)
system("R CMD build OUwie --no-build-vignettes", intern = TRUE)
system("R CMD INSTALL OUwie_2.16.tar.gz", intern = TRUE)
# Out:
# character(0)
# [1] "* checking for file ‘OUwie/DESCRIPTION’ ... OK"
# [2] "* preparing ‘OUwie’:"
# [3] "* checking DESCRIPTION meta-information ... OK"
# [4] "* checking for LF line-endings in source and make files and shell scripts"
# [5] "* checking for empty or unneeded directories"
# [6] "* looking to see if a ‘data/datalist’ file should be added"
# [7] "* building ‘OUwie_2.16.tar.gz’"
# Warning message in system("R CMD INSTALL OUwie_2.16.tar.gz", intern = TRUE):
# “running command 'R CMD INSTALL OUwie_2.16.tar.gz' had status 1”
# character(0)
# attr(,"status")
# [1] 1
# attr(,"errmsg")
# [1] "Resource temporarily unavailable"

# %%
install.packages('Rmpfr', dependencies = TRUE, repos='http://cran.rstudio.com/')
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘DPQ’, ‘gmp’, ‘DPQmpfr’, ‘Bessel’, ‘polynom’, ‘sfsmisc’
#
#
# Warning message in install.packages("Rmpfr", dependencies = TRUE, repos = "http://cran.rstudio.com/"):
# “installation of package ‘gmp’ had non-zero exit status”
# Warning message in install.packages("Rmpfr", dependencies = TRUE, repos = "http://cran.rstudio.com/"):
# “installation of package ‘Rmpfr’ had non-zero exit status”
# Warning message in install.packages("Rmpfr", dependencies = TRUE, repos = "http://cran.rstudio.com/"):
# “installation of package ‘DPQmpfr’ had non-zero exit status”
# Warning message in install.packages("Rmpfr", dependencies = TRUE, repos = "http://cran.rstudio.com/"):
# “installation of package ‘Bessel’ had non-zero exit status”

# %%
install.packages(c("corHMM", "ape")) # took 7 mins first time, tf??
# Out:
# Installing packages into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘gmp’, ‘Rmpfr’
#
#
# Warning message in install.packages(c("corHMM", "ape")):
# “installation of package ‘gmp’ had non-zero exit status”
# Warning message in install.packages(c("corHMM", "ape")):
# “installation of package ‘Rmpfr’ had non-zero exit status”
# Warning message in install.packages(c("corHMM", "ape")):
# “installation of package ‘corHMM’ had non-zero exit status”

# %%
library("ape")
library("corHMM")
library("Phytools")
library("OUwie")
# Out:
# Error in library("corHMM"): there is no package called ‘corHMM’
# Traceback:
#
# 1. stop(packageNotFoundError(package, lib.loc, sys.call()))

# %%
data <- read.csv("https://raw.githubusercontent.com/anoban/phd/refs/heads/main/data/chapter2/FREDv3subset/FRED_subset_collab_states_n_species_avg_traits.csv")
tree <- ape::read.tree("https://raw.githubusercontent.com/anoban/phd/refs/heads/main/data/chapter2/uphylomaker/fredv3subset_collab_trait_n_states.tre")

# %%
# Out:
# Phylogenetic tree with 344 tips and 313 internal nodes.
#
# Tip labels:
#   Anaphalis_aureopunctata, Anaphalis_hancockii, Solidago_decurrens, Doellingeria_scabra, Aster_tataricus, Artemisia_igniaria, ...
# Node labels:
#   , Spermatophyta, Mesangiospermae, mrcaott2ott121, eudicotyledons, mrcaott2ott969, ...
#
# Rooted; includes branch length(s).
